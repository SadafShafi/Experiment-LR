# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display


# Set seed for experiment reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  # plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
data_dir = pathlib.Path('data/mini_speech_commands')
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip
# 182083584/182082353 [==============================] - 2s 0us/step

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['right' 'left' 'up' 'stop' 'yes' 'no' 'down' 'go']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 8000
# Number of examples per label: 1000
# Example file tensor: tf.Tensor(b'data/mini_speech_commands/go/dabf67d9_nohash_0.wav', shape=(), dtype=string)

# %%
train_files = filenames[:6400]
val_files = filenames[6400: 6400 + 800]
test_files = filenames[-800:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 6400
# Validation set size 800
# Test set size 800

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)

  # Note: You'll use indexing here instead of tuple unpacking to enable this 
  # to work in a TensorFlow graph.
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
AUTOTUNE = tf.data.AUTOTUNE
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
  # Padding for files with less than 16000 samples
  zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)

  # Concatenate audio with padding so that all audio clips will be of the 
  # same length
  waveform = tf.cast(waveform, tf.float32)
  equal_length = tf.concat([waveform, zero_padding], 0)
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
      
  spectrogram = tf.abs(spectrogram)

  return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: go
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
  # Convert to frequencies to log scale and transpose so that the time is
  # represented in the x-axis (columns).
  log_spec = np.log(spectrogram.T)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)


fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])
plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now transform the waveform dataset to have spectrogram images and their corresponding labels as integer IDs.

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  spectrogram = tf.expand_dims(spectrogram, -1)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %%
spectrogram_ds = waveform_ds.map(
    get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(np.squeeze(spectrogram.numpy()), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')
  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(
      get_spectrogram_and_label_id,  num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
def mymodel():
  for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
  print('Input shape:', input_shape)
  num_labels = len(commands)

  norm_layer = preprocessing.Normalization()
  norm_layer.adapt(spectrogram_ds.map(lambda x, _: x))

  model = models.Sequential([
      layers.Input(shape=input_shape),
      preprocessing.Resizing(32, 32), 
      norm_layer,
      layers.Conv2D(32, 3, activation='relu'),
      layers.Conv2D(64, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.25),
      layers.Flatten(),
      layers.Dense(128, activation='relu'),
      layers.Dropout(0.5),
      layers.Dense(num_labels),
  ])

  model.summary()

  model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
  )

  return model

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=150
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):
  LR = random() * batch_size/10000
  lr.append(LR)
lr = lr[::-1] 
lord_LR = lr


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
EPOCHS = 150
model = mymodel()
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=EPOCHS,
)
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing (Resizing)          (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization (Normalization (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1605760
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
# Epoch 1/150
# 100/100 [==============================] - 45s 142ms/step - loss: 1.7281 - accuracy: 0.3800 - val_loss: 1.3061 - val_accuracy: 0.5738
# Epoch 2/150
# 100/100 [==============================] - 1s 7ms/step - loss: 1.1786 - accuracy: 0.5911 - val_loss: 0.9445 - val_accuracy: 0.6775
# Epoch 3/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.9103 - accuracy: 0.6764 - val_loss: 0.7753 - val_accuracy: 0.7300
# Epoch 4/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7444 - accuracy: 0.7339 - val_loss: 0.6986 - val_accuracy: 0.7688
# Epoch 5/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6599 - accuracy: 0.7647 - val_loss: 0.6794 - val_accuracy: 0.7663
# Epoch 6/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5972 - accuracy: 0.7848 - val_loss: 0.6100 - val_accuracy: 0.8012
# Epoch 7/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5181 - accuracy: 0.8144 - val_loss: 0.5712 - val_accuracy: 0.8125
# Epoch 8/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4666 - accuracy: 0.8384 - val_loss: 0.5560 - val_accuracy: 0.8150
# Epoch 9/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4407 - accuracy: 0.8473 - val_loss: 0.5213 - val_accuracy: 0.8388
# Epoch 10/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3937 - accuracy: 0.8622 - val_loss: 0.5277 - val_accuracy: 0.8263
# Epoch 11/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3817 - accuracy: 0.8642 - val_loss: 0.4785 - val_accuracy: 0.8438
# Epoch 12/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3385 - accuracy: 0.8803 - val_loss: 0.5109 - val_accuracy: 0.8400
# Epoch 13/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3217 - accuracy: 0.8841 - val_loss: 0.4913 - val_accuracy: 0.8413
# Epoch 14/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3008 - accuracy: 0.8952 - val_loss: 0.4568 - val_accuracy: 0.8550
# Epoch 15/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2641 - accuracy: 0.9064 - val_loss: 0.5020 - val_accuracy: 0.8375
# Epoch 16/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2703 - accuracy: 0.9050 - val_loss: 0.4821 - val_accuracy: 0.8487
# Epoch 17/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2515 - accuracy: 0.9100 - val_loss: 0.4593 - val_accuracy: 0.8562
# Epoch 18/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2351 - accuracy: 0.9211 - val_loss: 0.4867 - val_accuracy: 0.8487
# Epoch 19/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2375 - accuracy: 0.9184 - val_loss: 0.4781 - val_accuracy: 0.8462
# Epoch 20/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2243 - accuracy: 0.9214 - val_loss: 0.5171 - val_accuracy: 0.8575
# Epoch 21/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2006 - accuracy: 0.9295 - val_loss: 0.4935 - val_accuracy: 0.8425
# Epoch 22/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2008 - accuracy: 0.9287 - val_loss: 0.5412 - val_accuracy: 0.8475
# Epoch 23/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2103 - accuracy: 0.9247 - val_loss: 0.5448 - val_accuracy: 0.8637
# Epoch 24/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1925 - accuracy: 0.9333 - val_loss: 0.5320 - val_accuracy: 0.8600
# Epoch 25/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1680 - accuracy: 0.9428 - val_loss: 0.5229 - val_accuracy: 0.8662
# Epoch 26/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1727 - accuracy: 0.9420 - val_loss: 0.5105 - val_accuracy: 0.8737
# Epoch 27/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1696 - accuracy: 0.9394 - val_loss: 0.5757 - val_accuracy: 0.8537
# Epoch 28/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1722 - accuracy: 0.9416 - val_loss: 0.5609 - val_accuracy: 0.8575
# Epoch 29/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1491 - accuracy: 0.9461 - val_loss: 0.5715 - val_accuracy: 0.8587
# Epoch 30/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1475 - accuracy: 0.9502 - val_loss: 0.5615 - val_accuracy: 0.8712
# Epoch 31/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1486 - accuracy: 0.9483 - val_loss: 0.5545 - val_accuracy: 0.8750
# Epoch 32/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1488 - accuracy: 0.9483 - val_loss: 0.5129 - val_accuracy: 0.8687
# Epoch 33/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1225 - accuracy: 0.9595 - val_loss: 0.5508 - val_accuracy: 0.8763
# Epoch 34/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1375 - accuracy: 0.9530 - val_loss: 0.5380 - val_accuracy: 0.8737
# Epoch 35/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1269 - accuracy: 0.9544 - val_loss: 0.5734 - val_accuracy: 0.8650
# Epoch 36/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1278 - accuracy: 0.9555 - val_loss: 0.5575 - val_accuracy: 0.8725
# Epoch 37/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1437 - accuracy: 0.9495 - val_loss: 0.5508 - val_accuracy: 0.8737
# Epoch 38/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1254 - accuracy: 0.9536 - val_loss: 0.5898 - val_accuracy: 0.8763
# Epoch 39/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1239 - accuracy: 0.9566 - val_loss: 0.5622 - val_accuracy: 0.8788
# Epoch 40/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1168 - accuracy: 0.9578 - val_loss: 0.5523 - val_accuracy: 0.8763
# Epoch 41/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1127 - accuracy: 0.9633 - val_loss: 0.6085 - val_accuracy: 0.8813
# Epoch 42/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1150 - accuracy: 0.9605 - val_loss: 0.6175 - val_accuracy: 0.8700
# Epoch 43/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1098 - accuracy: 0.9636 - val_loss: 0.6110 - val_accuracy: 0.8700
# Epoch 44/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1078 - accuracy: 0.9638 - val_loss: 0.6395 - val_accuracy: 0.8637
# Epoch 45/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1107 - accuracy: 0.9606 - val_loss: 0.7543 - val_accuracy: 0.8737
# Epoch 46/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1084 - accuracy: 0.9648 - val_loss: 0.5827 - val_accuracy: 0.8750
# Epoch 47/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1012 - accuracy: 0.9661 - val_loss: 0.6041 - val_accuracy: 0.8587
# Epoch 48/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1193 - accuracy: 0.9600 - val_loss: 0.6320 - val_accuracy: 0.8712
# Epoch 49/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0925 - accuracy: 0.9667 - val_loss: 0.6347 - val_accuracy: 0.8737
# Epoch 50/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1038 - accuracy: 0.9647 - val_loss: 0.6426 - val_accuracy: 0.8675
# Epoch 51/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0990 - accuracy: 0.9672 - val_loss: 0.6441 - val_accuracy: 0.8788
# Epoch 52/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0986 - accuracy: 0.9661 - val_loss: 0.6767 - val_accuracy: 0.8750
# Epoch 53/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1001 - accuracy: 0.9684 - val_loss: 0.6158 - val_accuracy: 0.8675
# Epoch 54/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.6511 - val_accuracy: 0.8700
# Epoch 55/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0929 - accuracy: 0.9694 - val_loss: 0.5893 - val_accuracy: 0.8725
# Epoch 56/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0903 - accuracy: 0.9683 - val_loss: 0.7238 - val_accuracy: 0.8813
# Epoch 57/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0903 - accuracy: 0.9681 - val_loss: 0.6761 - val_accuracy: 0.8700
# Epoch 58/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0960 - accuracy: 0.9697 - val_loss: 0.6517 - val_accuracy: 0.8725
# Epoch 59/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0807 - accuracy: 0.9722 - val_loss: 0.6369 - val_accuracy: 0.8725
# Epoch 60/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0936 - accuracy: 0.9683 - val_loss: 0.6358 - val_accuracy: 0.8763
# Epoch 61/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0934 - accuracy: 0.9688 - val_loss: 0.6159 - val_accuracy: 0.8737
# Epoch 62/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0767 - accuracy: 0.9745 - val_loss: 0.5834 - val_accuracy: 0.8913
# Epoch 63/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0822 - accuracy: 0.9720 - val_loss: 0.5920 - val_accuracy: 0.8775
# Epoch 64/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0810 - accuracy: 0.9741 - val_loss: 0.6984 - val_accuracy: 0.8637
# Epoch 65/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0762 - accuracy: 0.9761 - val_loss: 0.6592 - val_accuracy: 0.8800
# Epoch 66/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0836 - accuracy: 0.9720 - val_loss: 0.6314 - val_accuracy: 0.8675
# Epoch 67/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0789 - accuracy: 0.9748 - val_loss: 0.5970 - val_accuracy: 0.8825
# Epoch 68/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0802 - accuracy: 0.9719 - val_loss: 0.7802 - val_accuracy: 0.8788
# Epoch 69/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0844 - accuracy: 0.9727 - val_loss: 0.7048 - val_accuracy: 0.8750
# Epoch 70/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0729 - accuracy: 0.9753 - val_loss: 0.6043 - val_accuracy: 0.8675
# Epoch 71/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0674 - accuracy: 0.9783 - val_loss: 0.6161 - val_accuracy: 0.8700
# Epoch 72/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0787 - accuracy: 0.9725 - val_loss: 0.6559 - val_accuracy: 0.8800
# Epoch 73/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0791 - accuracy: 0.9747 - val_loss: 0.9186 - val_accuracy: 0.8650
# Epoch 74/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0830 - accuracy: 0.9731 - val_loss: 0.5963 - val_accuracy: 0.8763
# Epoch 75/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 0.9783 - val_loss: 0.6438 - val_accuracy: 0.8763
# Epoch 76/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0746 - accuracy: 0.9767 - val_loss: 0.6705 - val_accuracy: 0.8775
# Epoch 77/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0668 - accuracy: 0.9767 - val_loss: 0.6513 - val_accuracy: 0.8763
# Epoch 78/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0687 - accuracy: 0.9766 - val_loss: 0.7593 - val_accuracy: 0.8675
# Epoch 79/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0828 - accuracy: 0.9720 - val_loss: 0.6911 - val_accuracy: 0.8737
# Epoch 80/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0697 - accuracy: 0.9784 - val_loss: 0.7271 - val_accuracy: 0.8763
# Epoch 81/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0712 - accuracy: 0.9780 - val_loss: 0.6873 - val_accuracy: 0.8763
# Epoch 82/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0691 - accuracy: 0.9752 - val_loss: 0.6246 - val_accuracy: 0.8700
# Epoch 83/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0629 - accuracy: 0.9802 - val_loss: 0.6741 - val_accuracy: 0.8875
# Epoch 84/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0628 - accuracy: 0.9795 - val_loss: 0.6587 - val_accuracy: 0.8850
# Epoch 85/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0693 - accuracy: 0.9806 - val_loss: 0.7603 - val_accuracy: 0.8775
# Epoch 86/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0747 - accuracy: 0.9747 - val_loss: 0.7048 - val_accuracy: 0.8888
# Epoch 87/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0642 - accuracy: 0.9791 - val_loss: 0.6366 - val_accuracy: 0.8750
# Epoch 88/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0727 - accuracy: 0.9764 - val_loss: 0.6321 - val_accuracy: 0.8875
# Epoch 89/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0722 - accuracy: 0.9758 - val_loss: 0.7761 - val_accuracy: 0.8800
# Epoch 90/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0631 - accuracy: 0.9814 - val_loss: 0.6862 - val_accuracy: 0.8850
# Epoch 91/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0645 - accuracy: 0.9777 - val_loss: 0.6925 - val_accuracy: 0.8813
# Epoch 92/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0575 - accuracy: 0.9798 - val_loss: 0.6508 - val_accuracy: 0.8838
# Epoch 93/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0679 - accuracy: 0.9798 - val_loss: 0.7699 - val_accuracy: 0.8763
# Epoch 94/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0681 - accuracy: 0.9775 - val_loss: 0.7720 - val_accuracy: 0.8788
# Epoch 95/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0604 - accuracy: 0.9811 - val_loss: 0.7152 - val_accuracy: 0.8875
# Epoch 96/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0512 - accuracy: 0.9828 - val_loss: 0.7511 - val_accuracy: 0.8800
# Epoch 97/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0589 - accuracy: 0.9828 - val_loss: 0.7684 - val_accuracy: 0.8775
# Epoch 98/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0641 - accuracy: 0.9781 - val_loss: 0.8123 - val_accuracy: 0.8800
# Epoch 99/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0689 - accuracy: 0.9787 - val_loss: 0.7718 - val_accuracy: 0.8763
# Epoch 100/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0758 - accuracy: 0.9762 - val_loss: 0.6846 - val_accuracy: 0.8813
# Epoch 101/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0518 - accuracy: 0.9830 - val_loss: 0.8340 - val_accuracy: 0.8813
# Epoch 102/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0554 - accuracy: 0.9806 - val_loss: 0.6960 - val_accuracy: 0.8775
# Epoch 103/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0559 - accuracy: 0.9823 - val_loss: 0.7381 - val_accuracy: 0.8800
# Epoch 104/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.9861 - val_loss: 0.8073 - val_accuracy: 0.8850
# Epoch 105/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.7987 - val_accuracy: 0.8863
# Epoch 106/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0606 - accuracy: 0.9816 - val_loss: 0.7171 - val_accuracy: 0.8925
# Epoch 107/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0521 - accuracy: 0.9833 - val_loss: 0.7534 - val_accuracy: 0.8813
# Epoch 108/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0578 - accuracy: 0.9811 - val_loss: 0.7648 - val_accuracy: 0.8838
# Epoch 109/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0578 - accuracy: 0.9791 - val_loss: 0.7826 - val_accuracy: 0.8788
# Epoch 110/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0537 - accuracy: 0.9808 - val_loss: 0.7457 - val_accuracy: 0.8850
# Epoch 111/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0575 - accuracy: 0.9812 - val_loss: 0.7716 - val_accuracy: 0.8900
# Epoch 112/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0612 - accuracy: 0.9800 - val_loss: 0.7592 - val_accuracy: 0.8700
# Epoch 113/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 0.8116 - val_accuracy: 0.8788
# Epoch 114/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0538 - accuracy: 0.9842 - val_loss: 0.7645 - val_accuracy: 0.8838
# Epoch 115/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0472 - accuracy: 0.9850 - val_loss: 0.7591 - val_accuracy: 0.8788
# Epoch 116/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0542 - accuracy: 0.9827 - val_loss: 0.7855 - val_accuracy: 0.8763
# Epoch 117/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0570 - accuracy: 0.9820 - val_loss: 0.8555 - val_accuracy: 0.8737
# Epoch 118/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0557 - accuracy: 0.9830 - val_loss: 0.7990 - val_accuracy: 0.8813
# Epoch 119/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0459 - accuracy: 0.9848 - val_loss: 0.7564 - val_accuracy: 0.8763
# Epoch 120/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0440 - accuracy: 0.9856 - val_loss: 0.7996 - val_accuracy: 0.8838
# Epoch 121/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0465 - accuracy: 0.9870 - val_loss: 0.7322 - val_accuracy: 0.8863
# Epoch 122/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.7787 - val_accuracy: 0.8875
# Epoch 123/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0434 - accuracy: 0.9850 - val_loss: 0.7827 - val_accuracy: 0.8750
# Epoch 124/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0440 - accuracy: 0.9859 - val_loss: 0.8364 - val_accuracy: 0.8763
# Epoch 125/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0558 - accuracy: 0.9842 - val_loss: 0.7822 - val_accuracy: 0.8813
# Epoch 126/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0622 - accuracy: 0.9808 - val_loss: 0.8370 - val_accuracy: 0.8825
# Epoch 127/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0621 - accuracy: 0.9817 - val_loss: 0.7691 - val_accuracy: 0.8850
# Epoch 128/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0518 - accuracy: 0.9842 - val_loss: 0.8122 - val_accuracy: 0.8825
# Epoch 129/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0542 - accuracy: 0.9839 - val_loss: 0.8025 - val_accuracy: 0.8825
# Epoch 130/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0537 - accuracy: 0.9794 - val_loss: 0.8510 - val_accuracy: 0.8775
# Epoch 131/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0529 - accuracy: 0.9819 - val_loss: 0.7543 - val_accuracy: 0.8763
# Epoch 132/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0481 - accuracy: 0.9833 - val_loss: 0.8154 - val_accuracy: 0.8800
# Epoch 133/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0477 - accuracy: 0.9866 - val_loss: 0.9478 - val_accuracy: 0.8700
# Epoch 134/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0517 - accuracy: 0.9833 - val_loss: 0.8023 - val_accuracy: 0.8788
# Epoch 135/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0478 - accuracy: 0.9847 - val_loss: 0.8683 - val_accuracy: 0.8813
# Epoch 136/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0574 - accuracy: 0.9812 - val_loss: 0.8771 - val_accuracy: 0.8838
# Epoch 137/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0457 - accuracy: 0.9850 - val_loss: 0.8585 - val_accuracy: 0.8850
# Epoch 138/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0379 - accuracy: 0.9878 - val_loss: 0.8847 - val_accuracy: 0.8888
# Epoch 139/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0432 - accuracy: 0.9856 - val_loss: 0.8297 - val_accuracy: 0.8800
# Epoch 140/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0411 - accuracy: 0.9864 - val_loss: 0.8535 - val_accuracy: 0.8775
# Epoch 141/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0460 - accuracy: 0.9867 - val_loss: 0.8866 - val_accuracy: 0.8737
# Epoch 142/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0552 - accuracy: 0.9828 - val_loss: 0.8578 - val_accuracy: 0.8788
# Epoch 143/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0423 - accuracy: 0.9881 - val_loss: 0.8535 - val_accuracy: 0.8863
# Epoch 144/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0432 - accuracy: 0.9850 - val_loss: 0.8966 - val_accuracy: 0.8838
# Epoch 145/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0470 - accuracy: 0.9845 - val_loss: 0.9291 - val_accuracy: 0.8725
# Epoch 146/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0574 - accuracy: 0.9833 - val_loss: 0.8512 - val_accuracy: 0.8775
# Epoch 147/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0559 - accuracy: 0.9836 - val_loss: 0.9285 - val_accuracy: 0.8725
# Epoch 148/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0424 - accuracy: 0.9844 - val_loss: 0.8350 - val_accuracy: 0.8850
# Epoch 149/150
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0504 - accuracy: 0.9836 - val_loss: 0.9104 - val_accuracy: 0.8763
# Epoch 150/150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 0.9279 - val_accuracy: 0.8800

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
metrics = history.history
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = mymodel()
from random import random
from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo),range(5,10000,5)):

  # if (z%2 == 0):
  LR = random() * batch_size/10000
  # lr.append(LR)
  # else:
  #   LR = random() * z/10000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.009):
      LR = 0.009
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=epoch,
    batch_size=batch_size,
    callbacks=call
  )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_1 (Resizing)        (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_1 (Normalizati (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
#
#
# epoch 1, Learning Rate 0.0003823945850656789, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 8ms/step - loss: 1.7874 - accuracy: 0.3273 - val_loss: 1.3851 - val_accuracy: 0.4975
#
#
# epoch 2, Learning Rate 0.0002821207614591288, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 1.3033 - accuracy: 0.5078 - val_loss: 1.0201 - val_accuracy: 0.6075
#
#
# epoch 3, Learning Rate 0.0012705055373058989, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 1.1714 - accuracy: 0.5519 - val_loss: 0.8901 - val_accuracy: 0.6513
#
#
# epoch 4, Learning Rate 0.0018517487664433396, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 1.0248 - accuracy: 0.5995 - val_loss: 0.9092 - val_accuracy: 0.6587
#
#
# epoch 5, Learning Rate 0.001159583425578815, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.9822 - accuracy: 0.6231 - val_loss: 0.7932 - val_accuracy: 0.7212
#
#
# epoch 6, Learning Rate 0.002664158341690512, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.9160 - accuracy: 0.6464 - val_loss: 0.7878 - val_accuracy: 0.7150
#
#
# epoch 7, Learning Rate 0.00135487855852642, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8922 - accuracy: 0.6542 - val_loss: 0.8089 - val_accuracy: 0.6975
#
#
# epoch 8, Learning Rate 0.00024380618018044942, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8623 - accuracy: 0.6737 - val_loss: 0.7270 - val_accuracy: 0.7237
#
#
# epoch 9, Learning Rate 0.00435062576137867, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8760 - accuracy: 0.6609 - val_loss: 0.7648 - val_accuracy: 0.7113
#
#
# epoch 10, Learning Rate 0.0014081549877831333, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8368 - accuracy: 0.6733 - val_loss: 0.7255 - val_accuracy: 0.7113
#
#
# epoch 11, Learning Rate 0.00313953596388572, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8265 - accuracy: 0.6869 - val_loss: 0.7511 - val_accuracy: 0.7237
#
#
# epoch 12, Learning Rate 4.6574351921074176e-05, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005951790762957532.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7818 - accuracy: 0.7006 - val_loss: 0.6854 - val_accuracy: 0.7525
#
#
# epoch 13, Learning Rate 0.00487475420028077, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7735 - accuracy: 0.7003 - val_loss: 0.6739 - val_accuracy: 0.7500
#
#
# epoch 14, Learning Rate 0.0006343662491624534, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7913 - accuracy: 0.6917 - val_loss: 0.6930 - val_accuracy: 0.7337
#
#
# epoch 15, Learning Rate 0.005518980656435565, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8122 - accuracy: 0.6864 - val_loss: 0.7135 - val_accuracy: 0.7250
#
#
# epoch 16, Learning Rate 0.0017412366294669284, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7566 - accuracy: 0.7164 - val_loss: 0.6747 - val_accuracy: 0.7575
#
#
# epoch 17, Learning Rate 0.007133984649206489, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7630 - accuracy: 0.7073 - val_loss: 0.7275 - val_accuracy: 0.7325
#
#
# epoch 18, Learning Rate 0.0059655220903338, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7401 - accuracy: 0.7116 - val_loss: 0.7377 - val_accuracy: 0.7362
#
#
# epoch 19, Learning Rate 0.00130982806987469, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010312003282796692.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6790 - accuracy: 0.7392 - val_loss: 0.6584 - val_accuracy: 0.7738
#
#
# epoch 20, Learning Rate 0.007358935543243845, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7416 - accuracy: 0.7192 - val_loss: 0.7331 - val_accuracy: 0.7387
#
#
# epoch 21, Learning Rate 0.0027834828041505047, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7348 - accuracy: 0.7234 - val_loss: 0.6763 - val_accuracy: 0.7538
#
#
# epoch 22, Learning Rate 0.0033448367541288647, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7269 - accuracy: 0.7278 - val_loss: 0.7181 - val_accuracy: 0.7425
#
#
# epoch 23, Learning Rate 0.0044049010637544385, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7384 - accuracy: 0.7208 - val_loss: 0.7475 - val_accuracy: 0.7387
#
#
# epoch 24, Learning Rate 0.0020902304367542263, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005241425496566408.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6741 - accuracy: 0.7519 - val_loss: 0.7325 - val_accuracy: 0.7525
#
#
# epoch 25, Learning Rate 0.0070150683308089655, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005914702977521728.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6515 - accuracy: 0.7550 - val_loss: 0.6702 - val_accuracy: 0.7613
#
#
# epoch 26, Learning Rate 0.008541089344974025, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6818 - accuracy: 0.7387 - val_loss: 0.6895 - val_accuracy: 0.7600
#
#
# epoch 27, Learning Rate 0.008727011322546337, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6598 - accuracy: 0.7469 - val_loss: 0.7030 - val_accuracy: 0.7600
#
#
# epoch 28, Learning Rate 0.001424597200052494, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6621 - accuracy: 0.7466 - val_loss: 0.7118 - val_accuracy: 0.7450
#
#
# epoch 29, Learning Rate 0.010746169033710866, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7103 - accuracy: 0.7405 - val_loss: 0.7461 - val_accuracy: 0.7325
#
#
# epoch 30, Learning Rate 0.011180736250727212, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7041 - accuracy: 0.7403 - val_loss: 0.7461 - val_accuracy: 0.7325
#
#
# epoch 31, Learning Rate 0.0015358743385073302, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6756 - accuracy: 0.7495 - val_loss: 0.7619 - val_accuracy: 0.7362
#
#
# epoch 32, Learning Rate 0.00864473587413694, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000979111235909896.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.6265 - accuracy: 0.7633 - val_loss: 0.6711 - val_accuracy: 0.7688
#
#
# epoch 33, Learning Rate 0.01148907757761483, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003235051577636422.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5790 - accuracy: 0.7844 - val_loss: 0.6604 - val_accuracy: 0.7713
#
#
# epoch 34, Learning Rate 0.0021450204806333414, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7002 - accuracy: 0.7513 - val_loss: 1.1420 - val_accuracy: 0.6488
#
#
# epoch 35, Learning Rate 0.015984795313269025, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6939 - accuracy: 0.7503 - val_loss: 0.7330 - val_accuracy: 0.7613
#
#
# epoch 36, Learning Rate 0.004102305598802304, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6547 - accuracy: 0.7586 - val_loss: 0.7426 - val_accuracy: 0.7300
#
#
# epoch 37, Learning Rate 0.014591981613942264, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6675 - accuracy: 0.7575 - val_loss: 0.7367 - val_accuracy: 0.7325
#
#
# epoch 38, Learning Rate 0.017431277879016428, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6397 - accuracy: 0.7691 - val_loss: 0.7217 - val_accuracy: 0.7350
#
#
# epoch 39, Learning Rate 0.017102365042515118, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6303 - accuracy: 0.7636 - val_loss: 0.7115 - val_accuracy: 0.7425
#
#
# epoch 40, Learning Rate 0.012098725314281383, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6246 - accuracy: 0.7678 - val_loss: 0.7358 - val_accuracy: 0.7575
#
#
# epoch 41, Learning Rate 0.019486542725293394, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6600 - accuracy: 0.7519 - val_loss: 0.6687 - val_accuracy: 0.7600
#
#
# epoch 42, Learning Rate 0.0018701429177686909, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.6379 - accuracy: 0.7630 - val_loss: 0.7000 - val_accuracy: 0.7788
#
#
# epoch 43, Learning Rate 0.005464155025451692, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6064 - accuracy: 0.7786 - val_loss: 0.7279 - val_accuracy: 0.7588
#
#
# epoch 44, Learning Rate 0.005355439500950427, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6261 - accuracy: 0.7677 - val_loss: 0.7257 - val_accuracy: 0.7350
#
#
# epoch 45, Learning Rate 0.01608191508223222, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5885 - accuracy: 0.7744 - val_loss: 0.7821 - val_accuracy: 0.7437
#
#
# epoch 46, Learning Rate 0.009859919405696475, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5768 - accuracy: 0.7858 - val_loss: 0.7437 - val_accuracy: 0.7525
#
#
# epoch 47, Learning Rate 0.005864092557772359, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5824 - accuracy: 0.7828 - val_loss: 0.7769 - val_accuracy: 0.7425
#
#
# epoch 48, Learning Rate 0.020999691595977744, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5704 - accuracy: 0.7936 - val_loss: 0.7389 - val_accuracy: 0.7513
#
#
# epoch 49, Learning Rate 0.008059222164063674, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6158 - accuracy: 0.7802 - val_loss: 0.7643 - val_accuracy: 0.7325
#
#
# epoch 50, Learning Rate 0.007684449444892056, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5879 - accuracy: 0.7875 - val_loss: 0.7251 - val_accuracy: 0.7550
#
#
# epoch 51, Learning Rate 0.023037723844664994, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5620 - accuracy: 0.7845 - val_loss: 0.8096 - val_accuracy: 0.7212
#
#
# epoch 52, Learning Rate 0.006151954731369197, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5916 - accuracy: 0.7833 - val_loss: 0.7837 - val_accuracy: 0.7212
#
#
# epoch 53, Learning Rate 0.009456077705142075, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005626025758531276.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5487 - accuracy: 0.7945 - val_loss: 0.7010 - val_accuracy: 0.7700
#
#
# epoch 54, Learning Rate 0.001286358919940673, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5395 - accuracy: 0.8005 - val_loss: 0.7750 - val_accuracy: 0.7400
#
#
# epoch 55, Learning Rate 0.002259707025310778, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5706 - accuracy: 0.7897 - val_loss: 0.7583 - val_accuracy: 0.7550
#
#
# epoch 56, Learning Rate 0.016227090042389494, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5781 - accuracy: 0.7908 - val_loss: 0.7916 - val_accuracy: 0.7462
#
#
# epoch 57, Learning Rate 0.02596434245023292, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5651 - accuracy: 0.7925 - val_loss: 0.7450 - val_accuracy: 0.7425
#
#
# epoch 58, Learning Rate 0.02255272361361373, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5351 - accuracy: 0.8044 - val_loss: 0.7378 - val_accuracy: 0.7588
#
#
# epoch 59, Learning Rate 0.0029309599069783144, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5353 - accuracy: 0.8008 - val_loss: 0.7412 - val_accuracy: 0.7475
#
#
# epoch 60, Learning Rate 0.015286804170904451, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5516 - accuracy: 0.8009 - val_loss: 0.7396 - val_accuracy: 0.7500
#
#
# epoch 61, Learning Rate 0.0008227575335799424, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5562 - accuracy: 0.7980 - val_loss: 0.7978 - val_accuracy: 0.7225
#
#
# epoch 62, Learning Rate 0.021715835388718727, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5871 - accuracy: 0.7906 - val_loss: 0.7790 - val_accuracy: 0.7538
#
#
# epoch 63, Learning Rate 0.00630230024525663, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5426 - accuracy: 0.8016 - val_loss: 0.8064 - val_accuracy: 0.7525
#
#
# epoch 64, Learning Rate 0.015871973466662102, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5525 - accuracy: 0.8030 - val_loss: 0.7944 - val_accuracy: 0.7650
#
#
# epoch 65, Learning Rate 0.008327156704288593, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5560 - accuracy: 0.7967 - val_loss: 0.7470 - val_accuracy: 0.7600
#
#
# epoch 66, Learning Rate 0.01785892330863372, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008170864162998151.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5180 - accuracy: 0.8094 - val_loss: 0.7911 - val_accuracy: 0.7575
#
#
# epoch 67, Learning Rate 0.0325920541666923, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5624 - accuracy: 0.8037 - val_loss: 0.7457 - val_accuracy: 0.7412
#
#
# epoch 68, Learning Rate 0.033434705010760866, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5210 - accuracy: 0.8062 - val_loss: 0.7564 - val_accuracy: 0.7462
#
#
# epoch 69, Learning Rate 0.017152752371365217, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5140 - accuracy: 0.8156 - val_loss: 0.7581 - val_accuracy: 0.7513
#
#
# epoch 70, Learning Rate 0.025954467903778367, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5086 - accuracy: 0.8095 - val_loss: 0.7776 - val_accuracy: 0.7550
#
#
# epoch 71, Learning Rate 0.00030964512847451027, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008812568128653477.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5094 - accuracy: 0.8150 - val_loss: 0.8329 - val_accuracy: 0.7788
#
#
# epoch 72, Learning Rate 0.0029087391385601395, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5320 - accuracy: 0.8131 - val_loss: 0.7817 - val_accuracy: 0.7525
#
#
# epoch 73, Learning Rate 0.03404602575266137, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4848 - accuracy: 0.8206 - val_loss: 0.7460 - val_accuracy: 0.7500
#
#
# epoch 74, Learning Rate 0.03494641877921842, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5353 - accuracy: 0.8081 - val_loss: 0.8078 - val_accuracy: 0.7262
#
#
# epoch 75, Learning Rate 0.0005074756941745792, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5376 - accuracy: 0.8134 - val_loss: 0.7839 - val_accuracy: 0.7337
#
#
# epoch 76, Learning Rate 0.021059836806085683, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5619 - accuracy: 0.8033 - val_loss: 0.7474 - val_accuracy: 0.7462
#
#
# epoch 77, Learning Rate 0.018863080245767914, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5087 - accuracy: 0.8130 - val_loss: 0.7374 - val_accuracy: 0.7675
#
#
# epoch 78, Learning Rate 0.03628304794384157, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5123 - accuracy: 0.8161 - val_loss: 0.7658 - val_accuracy: 0.7387
#
#
# epoch 79, Learning Rate 0.01008824279426518, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4946 - accuracy: 0.8220 - val_loss: 0.8012 - val_accuracy: 0.7412
#
#
# epoch 80, Learning Rate 0.0049000819187712975, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5255 - accuracy: 0.8178 - val_loss: 0.7252 - val_accuracy: 0.7650
#
#
# epoch 81, Learning Rate 0.030726430488862144, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4977 - accuracy: 0.8194 - val_loss: 0.7948 - val_accuracy: 0.7475
#
#
# epoch 82, Learning Rate 0.020152712855651067, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5051 - accuracy: 0.8136 - val_loss: 0.8157 - val_accuracy: 0.7312
#
#
# epoch 83, Learning Rate 0.028300359528392022, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4729 - accuracy: 0.8303 - val_loss: 0.8702 - val_accuracy: 0.7375
#
#
# epoch 84, Learning Rate 0.004043067324745291, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4947 - accuracy: 0.8208 - val_loss: 0.7473 - val_accuracy: 0.7613
#
#
# epoch 85, Learning Rate 0.012343257505771405, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4950 - accuracy: 0.8239 - val_loss: 0.8001 - val_accuracy: 0.7525
#
#
# epoch 86, Learning Rate 0.03285483839353986, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005145937576550032.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4374 - accuracy: 0.8320 - val_loss: 0.8188 - val_accuracy: 0.7613
#
#
# epoch 87, Learning Rate 0.022117388022977223, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.5059 - accuracy: 0.8270 - val_loss: 0.8488 - val_accuracy: 0.7513
#
#
# epoch 88, Learning Rate 0.026156776022550635, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5217 - accuracy: 0.8120 - val_loss: 0.8216 - val_accuracy: 0.7550
#
#
# epoch 89, Learning Rate 0.008437575561323634, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006077889986940609.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4686 - accuracy: 0.8328 - val_loss: 0.8261 - val_accuracy: 0.7475
#
#
# epoch 90, Learning Rate 0.001377980910232513, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4852 - accuracy: 0.8241 - val_loss: 0.7792 - val_accuracy: 0.7550
#
#
# epoch 91, Learning Rate 0.02287897624206925, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4734 - accuracy: 0.8292 - val_loss: 0.8060 - val_accuracy: 0.7475
#
#
# epoch 92, Learning Rate 0.03530451255743198, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007634087285741292.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4785 - accuracy: 0.8291 - val_loss: 0.8568 - val_accuracy: 0.7412
#
#
# epoch 93, Learning Rate 0.04137360450684546, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4857 - accuracy: 0.8283 - val_loss: 0.8390 - val_accuracy: 0.7663
#
#
# epoch 94, Learning Rate 0.012307072348749198, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4615 - accuracy: 0.8327 - val_loss: 0.7858 - val_accuracy: 0.7650
#
#
# epoch 95, Learning Rate 0.02962629329881172, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.957762616901642e-05.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4678 - accuracy: 0.8363 - val_loss: 0.7725 - val_accuracy: 0.7663
#
#
# epoch 96, Learning Rate 0.01425063684240305, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007993518463918837.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4518 - accuracy: 0.8352 - val_loss: 0.7964 - val_accuracy: 0.7738
#
#
# epoch 97, Learning Rate 0.03201609247873386, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4498 - accuracy: 0.8350 - val_loss: 0.8268 - val_accuracy: 0.7775
#
#
# epoch 98, Learning Rate 0.014441569339272124, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4612 - accuracy: 0.8392 - val_loss: 0.7548 - val_accuracy: 0.7788
#
#
# epoch 99, Learning Rate 0.02914952815284099, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001031692648614982.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4056 - accuracy: 0.8522 - val_loss: 0.8048 - val_accuracy: 0.7688
#
#
# epoch 100, Learning Rate 0.02736688327431377, Batch Size  500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4334 - accuracy: 0.8500 - val_loss: 0.8643 - val_accuracy: 0.7713
#
#
# epoch 101, Learning Rate 0.024282732148651395, Batch Size  505
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004104544252547965.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4087 - accuracy: 0.8545 - val_loss: 0.8724 - val_accuracy: 0.7788
#
#
# epoch 102, Learning Rate 0.006577195705665652, Batch Size  510
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4381 - accuracy: 0.8478 - val_loss: 0.8108 - val_accuracy: 0.7462
#
#
# epoch 103, Learning Rate 0.04217809750159505, Batch Size  515
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006879907709314226.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4493 - accuracy: 0.8502 - val_loss: 0.8456 - val_accuracy: 0.7600
#
#
# epoch 104, Learning Rate 0.051802559073031045, Batch Size  520
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001800038587083295.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3740 - accuracy: 0.8675 - val_loss: 0.8250 - val_accuracy: 0.7575
#
#
# epoch 105, Learning Rate 0.006357136081295896, Batch Size  525
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005089717700897568.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3628 - accuracy: 0.8695 - val_loss: 0.8182 - val_accuracy: 0.7613
#
#
# epoch 106, Learning Rate 0.03342576631182237, Batch Size  530
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4047 - accuracy: 0.8539 - val_loss: 0.8193 - val_accuracy: 0.7538
#
#
# epoch 107, Learning Rate 0.038814092017367206, Batch Size  535
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4331 - accuracy: 0.8452 - val_loss: 0.9296 - val_accuracy: 0.7775
#
#
# epoch 108, Learning Rate 0.0036954816161670957, Batch Size  540
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0040255285342275324.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3915 - accuracy: 0.8522 - val_loss: 0.8139 - val_accuracy: 0.7837
#
#
# epoch 109, Learning Rate 0.015211625021298797, Batch Size  545
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0072634490873473255.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4231 - accuracy: 0.8537 - val_loss: 0.8562 - val_accuracy: 0.7450
#
#
# epoch 110, Learning Rate 0.04669685485181786, Batch Size  550
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4069 - accuracy: 0.8556 - val_loss: 0.9827 - val_accuracy: 0.7450
#
#
# epoch 111, Learning Rate 0.03265618189134857, Batch Size  555
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005871570123645675.
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3899 - accuracy: 0.8636 - val_loss: 0.8139 - val_accuracy: 0.7713
#
#
# epoch 112, Learning Rate 0.013779199586159072, Batch Size  560
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007742109132834605.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4070 - accuracy: 0.8519 - val_loss: 0.8345 - val_accuracy: 0.7588
#
#
# epoch 113, Learning Rate 0.0004654838399783446, Batch Size  565
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4077 - accuracy: 0.8527 - val_loss: 0.8380 - val_accuracy: 0.7625
#
#
# epoch 114, Learning Rate 0.009286813357258356, Batch Size  570
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0019241473079853115.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3613 - accuracy: 0.8692 - val_loss: 0.8388 - val_accuracy: 0.7663
#
#
# epoch 115, Learning Rate 0.006734564852299681, Batch Size  575
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3998 - accuracy: 0.8602 - val_loss: 0.8609 - val_accuracy: 0.7713
#
#
# epoch 116, Learning Rate 0.05758671444193983, Batch Size  580
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4724 - accuracy: 0.8422 - val_loss: 0.8481 - val_accuracy: 0.7600
#
#
# epoch 117, Learning Rate 0.05789820321968616, Batch Size  585
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4405 - accuracy: 0.8425 - val_loss: 0.8260 - val_accuracy: 0.7437
#
#
# epoch 118, Learning Rate 0.02081519710493677, Batch Size  590
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4696 - accuracy: 0.8428 - val_loss: 0.9357 - val_accuracy: 0.7387
#
#
# epoch 119, Learning Rate 0.041520857817866595, Batch Size  595
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0029154064895454417.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3802 - accuracy: 0.8597 - val_loss: 0.8706 - val_accuracy: 0.7700
#
#
# epoch 120, Learning Rate 0.03842257243105096, Batch Size  600
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4058 - accuracy: 0.8569 - val_loss: 0.7815 - val_accuracy: 0.7500
#
#
# epoch 121, Learning Rate 0.03595330594780567, Batch Size  605
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001223553883638383.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3425 - accuracy: 0.8742 - val_loss: 0.7785 - val_accuracy: 0.7713
#
#
# epoch 122, Learning Rate 0.050950985380926676, Batch Size  610
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006074214489022865.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3858 - accuracy: 0.8689 - val_loss: 0.7437 - val_accuracy: 0.7700
#
#
# epoch 123, Learning Rate 0.0525727113810864, Batch Size  615
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3987 - accuracy: 0.8580 - val_loss: 0.8463 - val_accuracy: 0.7487
#
#
# epoch 124, Learning Rate 0.02854429248279756, Batch Size  620
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0039534162455301825.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3806 - accuracy: 0.8659 - val_loss: 0.9136 - val_accuracy: 0.7650
#
#
# epoch 125, Learning Rate 0.006713322993910287, Batch Size  625
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4179 - accuracy: 0.8586 - val_loss: 0.8567 - val_accuracy: 0.7437
#
#
# epoch 126, Learning Rate 0.05301643986528205, Batch Size  630
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010797947134749228.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3771 - accuracy: 0.8656 - val_loss: 0.8212 - val_accuracy: 0.7563
#
#
# epoch 127, Learning Rate 0.007721920380460683, Batch Size  635
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008663366921973855.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3784 - accuracy: 0.8667 - val_loss: 0.7990 - val_accuracy: 0.7550
#
#
# epoch 128, Learning Rate 0.02675736111704186, Batch Size  640
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0025000110389585537.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3517 - accuracy: 0.8745 - val_loss: 0.8444 - val_accuracy: 0.7613
#
#
# epoch 129, Learning Rate 0.04263427677487137, Batch Size  645
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007568664793785494.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3717 - accuracy: 0.8706 - val_loss: 0.8457 - val_accuracy: 0.7763
#
#
# epoch 130, Learning Rate 0.033163261864714605, Batch Size  650
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3937 - accuracy: 0.8609 - val_loss: 0.9162 - val_accuracy: 0.7613
#
#
# epoch 131, Learning Rate 0.029412849300250354, Batch Size  655
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007961113696162559.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3922 - accuracy: 0.8622 - val_loss: 0.8832 - val_accuracy: 0.7575
#
#
# epoch 132, Learning Rate 0.05385178730458666, Batch Size  660
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008960623302404498.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4246 - accuracy: 0.8577 - val_loss: 0.8579 - val_accuracy: 0.7525
#
#
# epoch 133, Learning Rate 0.024519089587852837, Batch Size  665
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0017598688925375377.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3761 - accuracy: 0.8700 - val_loss: 0.8858 - val_accuracy: 0.7725
#
#
# epoch 134, Learning Rate 0.05084363454506178, Batch Size  670
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00047135602107210373.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3299 - accuracy: 0.8770 - val_loss: 0.8609 - val_accuracy: 0.7700
#
#
# epoch 135, Learning Rate 0.00947419984344185, Batch Size  675
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00025182600177103164.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3175 - accuracy: 0.8848 - val_loss: 0.8692 - val_accuracy: 0.7700
#
#
# epoch 136, Learning Rate 0.01421119179625577, Batch Size  680
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005537406611223656.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3525 - accuracy: 0.8744 - val_loss: 1.0090 - val_accuracy: 0.7625
#
#
# epoch 137, Learning Rate 0.009165964696641805, Batch Size  685
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003116313183012158.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3273 - accuracy: 0.8878 - val_loss: 0.8071 - val_accuracy: 0.7688
#
#
# epoch 138, Learning Rate 0.05526608884717385, Batch Size  690
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008865853997769372.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3020 - accuracy: 0.8884 - val_loss: 0.8230 - val_accuracy: 0.7725
#
#
# epoch 139, Learning Rate 0.0013373331525406526, Batch Size  695
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0035924599183472083.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3020 - accuracy: 0.8891 - val_loss: 0.8777 - val_accuracy: 0.7500
#
#
# epoch 140, Learning Rate 0.06222646366102364, Batch Size  700
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003434110184504416.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3052 - accuracy: 0.8863 - val_loss: 0.9016 - val_accuracy: 0.7725
#
#
# epoch 141, Learning Rate 0.059518692608120954, Batch Size  705
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013808694434327834.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2833 - accuracy: 0.8934 - val_loss: 0.9164 - val_accuracy: 0.7700
#
#
# epoch 142, Learning Rate 0.0371469049147965, Batch Size  710
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007614279753048877.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2794 - accuracy: 0.8984 - val_loss: 0.9118 - val_accuracy: 0.7763
#
#
# epoch 143, Learning Rate 0.03539936467759897, Batch Size  715
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.022343592217048e-05.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2752 - accuracy: 0.9050 - val_loss: 0.9070 - val_accuracy: 0.7775
#
#
# epoch 144, Learning Rate 0.029927938778078544, Batch Size  720
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002610000970745034.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2756 - accuracy: 0.9019 - val_loss: 0.9185 - val_accuracy: 0.7675
#
#
# epoch 145, Learning Rate 0.06297307241883691, Batch Size  725
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000658724736365012.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2715 - accuracy: 0.8964 - val_loss: 0.8833 - val_accuracy: 0.7663
#
#
# epoch 146, Learning Rate 0.04471635513070953, Batch Size  730
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023589462123382505.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2654 - accuracy: 0.9045 - val_loss: 0.8990 - val_accuracy: 0.7675
#
#
# epoch 147, Learning Rate 0.04256924033760343, Batch Size  735
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005318434331146269.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2868 - accuracy: 0.8983 - val_loss: 0.8959 - val_accuracy: 0.7688
#
#
# epoch 148, Learning Rate 0.017382694225338977, Batch Size  740
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00045014394281330433.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2641 - accuracy: 0.9103 - val_loss: 0.8856 - val_accuracy: 0.7750
#
#
# epoch 149, Learning Rate 0.06814342516644431, Batch Size  745
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000868851736532247.
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2538 - accuracy: 0.9053 - val_loss: 0.9042 - val_accuracy: 0.7725

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(150):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = mymodel()
# epoo = 1
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
def setLR(step):
  global LR
  lr = initial_learning_rate * decay_rate **(step / decay_steps)
  LR.append(lr)
  print("called here")
  return lr

call = [ LearningRateScheduler(setLR,verbose=1) ]


history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=epoo,
    callbacks=call,
  )

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

# %%
acc_3 = acc
val_acc_3 = val_acc

# %%
Plotter(acc_3,val_acc_3,loss,val_loss,l_r)

# %% [markdown]
# **LR constant**

# %%
model = mymodel()

from keras.callbacks import LearningRateScheduler

LR = 0.01

epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            train_ds,
            validation_data = val_ds,
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_3 (Resizing)        (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_3 (Normalizati (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
#
#
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 100/100 [==============================] - 1s 8ms/step - loss: 1.7235 - accuracy: 0.3887 - val_loss: 1.3440 - val_accuracy: 0.5950
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 100/100 [==============================] - 1s 6ms/step - loss: 1.1470 - accuracy: 0.6014 - val_loss: 0.9569 - val_accuracy: 0.7175
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 100/100 [==============================] - 1s 6ms/step - loss: 0.8602 - accuracy: 0.6977 - val_loss: 0.7822 - val_accuracy: 0.7500
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6918 - accuracy: 0.7533 - val_loss: 0.6520 - val_accuracy: 0.7937
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 100/100 [==============================] - 1s 6ms/step - loss: 0.5925 - accuracy: 0.7916 - val_loss: 0.6136 - val_accuracy: 0.8163
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4992 - accuracy: 0.8202 - val_loss: 0.5725 - val_accuracy: 0.8288
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
# 100/100 [==============================] - 1s 6ms/step - loss: 0.4384 - accuracy: 0.8508 - val_loss: 0.5547 - val_accuracy: 0.8200
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3978 - accuracy: 0.8575 - val_loss: 0.5240 - val_accuracy: 0.8300
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3676 - accuracy: 0.8752 - val_loss: 0.5105 - val_accuracy: 0.8438
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3387 - accuracy: 0.8820 - val_loss: 0.5377 - val_accuracy: 0.8275
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3029 - accuracy: 0.8950 - val_loss: 0.5176 - val_accuracy: 0.8487
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2709 - accuracy: 0.9058 - val_loss: 0.5096 - val_accuracy: 0.8462
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2604 - accuracy: 0.9111 - val_loss: 0.5127 - val_accuracy: 0.8612
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2373 - accuracy: 0.9187 - val_loss: 0.5077 - val_accuracy: 0.8550
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2082 - accuracy: 0.9311 - val_loss: 0.5799 - val_accuracy: 0.8550
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2133 - accuracy: 0.9256 - val_loss: 0.4626 - val_accuracy: 0.8575
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2028 - accuracy: 0.9272 - val_loss: 0.5459 - val_accuracy: 0.8587
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1885 - accuracy: 0.9372 - val_loss: 0.5502 - val_accuracy: 0.8550
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1775 - accuracy: 0.9375 - val_loss: 0.5595 - val_accuracy: 0.8537
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1793 - accuracy: 0.9361 - val_loss: 0.5485 - val_accuracy: 0.8687
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1556 - accuracy: 0.9456 - val_loss: 0.5565 - val_accuracy: 0.8700
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1450 - accuracy: 0.9536 - val_loss: 0.5722 - val_accuracy: 0.8537
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1451 - accuracy: 0.9534 - val_loss: 0.5259 - val_accuracy: 0.8687
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1322 - accuracy: 0.9545 - val_loss: 0.4894 - val_accuracy: 0.8662
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1396 - accuracy: 0.9542 - val_loss: 0.5414 - val_accuracy: 0.8712
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1324 - accuracy: 0.9569 - val_loss: 0.5518 - val_accuracy: 0.8712
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1243 - accuracy: 0.9572 - val_loss: 0.5347 - val_accuracy: 0.8575
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1330 - accuracy: 0.9556 - val_loss: 0.5917 - val_accuracy: 0.8600
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1252 - accuracy: 0.9564 - val_loss: 0.5872 - val_accuracy: 0.8575
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1228 - accuracy: 0.9617 - val_loss: 0.5738 - val_accuracy: 0.8700
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1188 - accuracy: 0.9611 - val_loss: 0.5825 - val_accuracy: 0.8687
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1155 - accuracy: 0.9623 - val_loss: 0.5401 - val_accuracy: 0.8737
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1162 - accuracy: 0.9616 - val_loss: 0.5861 - val_accuracy: 0.8775
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1081 - accuracy: 0.9669 - val_loss: 0.6056 - val_accuracy: 0.8612
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
# 100/100 [==============================] - 1s 7ms/step - loss: 0.1090 - accuracy: 0.9641 - val_loss: 0.5488 - val_accuracy: 0.8612
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1056 - accuracy: 0.9650 - val_loss: 0.5095 - val_accuracy: 0.8662
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1036 - accuracy: 0.9670 - val_loss: 0.5508 - val_accuracy: 0.8763
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0956 - accuracy: 0.9684 - val_loss: 0.5740 - val_accuracy: 0.8662
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1047 - accuracy: 0.9650 - val_loss: 0.5722 - val_accuracy: 0.8575
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0862 - accuracy: 0.9694 - val_loss: 0.5689 - val_accuracy: 0.8763
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0809 - accuracy: 0.9705 - val_loss: 0.5761 - val_accuracy: 0.8625
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0824 - accuracy: 0.9727 - val_loss: 0.5583 - val_accuracy: 0.8725
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0792 - accuracy: 0.9722 - val_loss: 0.5614 - val_accuracy: 0.8700
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0837 - accuracy: 0.9709 - val_loss: 0.6103 - val_accuracy: 0.8687
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0759 - accuracy: 0.9739 - val_loss: 0.6969 - val_accuracy: 0.8612
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0781 - accuracy: 0.9731 - val_loss: 0.6097 - val_accuracy: 0.8788
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0772 - accuracy: 0.9734 - val_loss: 0.5969 - val_accuracy: 0.8725
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0777 - accuracy: 0.9744 - val_loss: 0.6158 - val_accuracy: 0.8687
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0701 - accuracy: 0.9773 - val_loss: 0.5864 - val_accuracy: 0.8813
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0738 - accuracy: 0.9758 - val_loss: 0.6652 - val_accuracy: 0.8600
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0712 - accuracy: 0.9748 - val_loss: 0.7122 - val_accuracy: 0.8662
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0694 - accuracy: 0.9752 - val_loss: 0.6280 - val_accuracy: 0.8838
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0840 - accuracy: 0.9709 - val_loss: 0.6682 - val_accuracy: 0.8725
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0824 - accuracy: 0.9736 - val_loss: 0.6517 - val_accuracy: 0.8750
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0687 - accuracy: 0.9780 - val_loss: 0.6001 - val_accuracy: 0.8763
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0788 - accuracy: 0.9753 - val_loss: 0.6494 - val_accuracy: 0.8725
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0545 - accuracy: 0.9800 - val_loss: 0.6572 - val_accuracy: 0.8888
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0624 - accuracy: 0.9792 - val_loss: 0.6499 - val_accuracy: 0.8750
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0653 - accuracy: 0.9780 - val_loss: 0.6394 - val_accuracy: 0.8700
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0767 - accuracy: 0.9761 - val_loss: 0.6719 - val_accuracy: 0.8763
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0715 - accuracy: 0.9752 - val_loss: 0.6508 - val_accuracy: 0.8813
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0793 - accuracy: 0.9762 - val_loss: 0.6686 - val_accuracy: 0.8712
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0699 - accuracy: 0.9786 - val_loss: 0.6666 - val_accuracy: 0.8712
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0682 - accuracy: 0.9773 - val_loss: 0.6786 - val_accuracy: 0.8813
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0656 - accuracy: 0.9805 - val_loss: 0.6625 - val_accuracy: 0.8800
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0634 - accuracy: 0.9786 - val_loss: 0.5878 - val_accuracy: 0.8788
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0740 - accuracy: 0.9777 - val_loss: 0.6076 - val_accuracy: 0.8800
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0622 - accuracy: 0.9805 - val_loss: 0.6795 - val_accuracy: 0.8737
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0479 - accuracy: 0.9852 - val_loss: 0.6989 - val_accuracy: 0.8800
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0560 - accuracy: 0.9795 - val_loss: 0.6235 - val_accuracy: 0.8875
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0718 - accuracy: 0.9784 - val_loss: 0.6820 - val_accuracy: 0.8788
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0776 - accuracy: 0.9741 - val_loss: 0.6422 - val_accuracy: 0.8650
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0587 - accuracy: 0.9806 - val_loss: 0.6825 - val_accuracy: 0.8775
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0725 - accuracy: 0.9780 - val_loss: 0.6846 - val_accuracy: 0.8687
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0669 - accuracy: 0.9773 - val_loss: 0.6408 - val_accuracy: 0.8813
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0581 - accuracy: 0.9823 - val_loss: 0.6846 - val_accuracy: 0.8788
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0612 - accuracy: 0.9800 - val_loss: 0.7204 - val_accuracy: 0.8737
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0599 - accuracy: 0.9833 - val_loss: 0.6746 - val_accuracy: 0.8825
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0504 - accuracy: 0.9847 - val_loss: 0.6884 - val_accuracy: 0.8875
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0473 - accuracy: 0.9831 - val_loss: 0.7064 - val_accuracy: 0.8662
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0556 - accuracy: 0.9827 - val_loss: 0.7140 - val_accuracy: 0.8712
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0625 - accuracy: 0.9803 - val_loss: 0.7276 - val_accuracy: 0.8575
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0580 - accuracy: 0.9820 - val_loss: 0.7160 - val_accuracy: 0.8750
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0495 - accuracy: 0.9842 - val_loss: 0.6706 - val_accuracy: 0.8750
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0520 - accuracy: 0.9837 - val_loss: 0.7825 - val_accuracy: 0.8700
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0547 - accuracy: 0.9814 - val_loss: 0.7139 - val_accuracy: 0.8750
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0417 - accuracy: 0.9870 - val_loss: 0.7014 - val_accuracy: 0.8763
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0468 - accuracy: 0.9855 - val_loss: 0.7748 - val_accuracy: 0.8737
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0487 - accuracy: 0.9830 - val_loss: 0.7037 - val_accuracy: 0.8888
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0532 - accuracy: 0.9823 - val_loss: 0.6949 - val_accuracy: 0.8737
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0565 - accuracy: 0.9831 - val_loss: 0.6696 - val_accuracy: 0.8875
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0439 - accuracy: 0.9856 - val_loss: 0.7210 - val_accuracy: 0.8850
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0460 - accuracy: 0.9828 - val_loss: 0.7973 - val_accuracy: 0.8763
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0409 - accuracy: 0.9869 - val_loss: 0.7500 - val_accuracy: 0.8813
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0518 - accuracy: 0.9836 - val_loss: 0.7588 - val_accuracy: 0.8838
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0613 - accuracy: 0.9805 - val_loss: 0.7187 - val_accuracy: 0.8775
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0483 - accuracy: 0.9852 - val_loss: 0.8312 - val_accuracy: 0.8725
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0493 - accuracy: 0.9844 - val_loss: 0.7473 - val_accuracy: 0.8825
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0504 - accuracy: 0.9853 - val_loss: 0.8309 - val_accuracy: 0.8813
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0613 - accuracy: 0.9806 - val_loss: 0.7766 - val_accuracy: 0.8725
#
#
# epoch 101, Learning Rate 0.0007659689172843453, Batch Size  505
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0521 - accuracy: 0.9848 - val_loss: 0.6958 - val_accuracy: 0.8763
#
#
# epoch 102, Learning Rate 0.0007623148238224963, Batch Size  510
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0509 - accuracy: 0.9852 - val_loss: 0.8392 - val_accuracy: 0.8788
#
#
# epoch 103, Learning Rate 0.0007587125119904205, Batch Size  515
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.7587 - val_accuracy: 0.8788
#
#
# epoch 104, Learning Rate 0.000755160770733984, Batch Size  520
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0388 - accuracy: 0.9877 - val_loss: 0.7604 - val_accuracy: 0.8838
#
#
# epoch 105, Learning Rate 0.0007516584282688145, Batch Size  525
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0535 - accuracy: 0.9845 - val_loss: 0.8722 - val_accuracy: 0.8662
#
#
# epoch 106, Learning Rate 0.0007482043504588227, Batch Size  530
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0419 - accuracy: 0.9852 - val_loss: 0.7789 - val_accuracy: 0.8763
#
#
# epoch 107, Learning Rate 0.0007447974392757759, Batch Size  535
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0528 - accuracy: 0.9831 - val_loss: 0.8983 - val_accuracy: 0.8600
#
#
# epoch 108, Learning Rate 0.0007414366313351803, Batch Size  540
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0499 - accuracy: 0.9834 - val_loss: 0.8212 - val_accuracy: 0.8788
#
#
# epoch 109, Learning Rate 0.0007381208965040452, Batch Size  545
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0404 - accuracy: 0.9866 - val_loss: 0.8192 - val_accuracy: 0.8863
#
#
# epoch 110, Learning Rate 0.0007348492365763997, Batch Size  550
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0503 - accuracy: 0.9839 - val_loss: 0.7003 - val_accuracy: 0.8850
#
#
# epoch 111, Learning Rate 0.0007316206840126991, Batch Size  555
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0431 - accuracy: 0.9864 - val_loss: 0.8649 - val_accuracy: 0.8813
#
#
# epoch 112, Learning Rate 0.0007284343007395112, Batch Size  560
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.7611 - val_accuracy: 0.8850
#
#
# epoch 113, Learning Rate 0.0007252891770061089, Batch Size  565
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0455 - accuracy: 0.9859 - val_loss: 0.8265 - val_accuracy: 0.8750
#
#
# epoch 114, Learning Rate 0.0007221844302948083, Batch Size  570
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0411 - accuracy: 0.9869 - val_loss: 0.8305 - val_accuracy: 0.8775
#
#
# epoch 115, Learning Rate 0.0007191192042820906, Batch Size  575
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0450 - accuracy: 0.9852 - val_loss: 0.8330 - val_accuracy: 0.8825
#
#
# epoch 116, Learning Rate 0.0007160926678477406, Batch Size  580
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0470 - accuracy: 0.9856 - val_loss: 0.8174 - val_accuracy: 0.8763
#
#
# epoch 117, Learning Rate 0.0007131040141293951, Batch Size  585
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 0.8853 - val_accuracy: 0.8637
#
#
# epoch 118, Learning Rate 0.0007101524596200692, Batch Size  590
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.9415 - val_accuracy: 0.8788
#
#
# epoch 119, Learning Rate 0.0007072372433063668, Batch Size  595
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0410 - accuracy: 0.9864 - val_loss: 0.9129 - val_accuracy: 0.8825
#
#
# epoch 120, Learning Rate 0.0007043576258452291, Batch Size  600
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0519 - accuracy: 0.9839 - val_loss: 0.8252 - val_accuracy: 0.8800
#
#
# epoch 121, Learning Rate 0.0007015128887771992, Batch Size  605
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0540 - accuracy: 0.9837 - val_loss: 0.8294 - val_accuracy: 0.8763
#
#
# epoch 122, Learning Rate 0.0006987023337743061, Batch Size  610
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0472 - accuracy: 0.9833 - val_loss: 0.8406 - val_accuracy: 0.8775
#
#
# epoch 123, Learning Rate 0.0006959252819207823, Batch Size  615
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0501 - accuracy: 0.9839 - val_loss: 0.9248 - val_accuracy: 0.8813
#
#
# epoch 124, Learning Rate 0.0006931810730249348, Batch Size  620
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0390 - accuracy: 0.9866 - val_loss: 0.8993 - val_accuracy: 0.8838
#
#
# epoch 125, Learning Rate 0.0006904690649605871, Batch Size  625
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0511 - accuracy: 0.9845 - val_loss: 0.9199 - val_accuracy: 0.8788
#
#
# epoch 126, Learning Rate 0.000687788633036604, Batch Size  630
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0573 - accuracy: 0.9845 - val_loss: 0.8557 - val_accuracy: 0.8775
#
#
# epoch 127, Learning Rate 0.0006851391693930934, Batch Size  635
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0443 - accuracy: 0.9867 - val_loss: 0.8216 - val_accuracy: 0.8725
#
#
# epoch 128, Learning Rate 0.0006825200824229642, Batch Size  640
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0369 - accuracy: 0.9864 - val_loss: 0.8241 - val_accuracy: 0.8763
#
#
# epoch 129, Learning Rate 0.0006799307962175887, Batch Size  645
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0411 - accuracy: 0.9873 - val_loss: 0.8871 - val_accuracy: 0.8775
#
#
# epoch 130, Learning Rate 0.0006773707500353944, Batch Size  650
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0407 - accuracy: 0.9878 - val_loss: 0.8311 - val_accuracy: 0.8750
#
#
# epoch 131, Learning Rate 0.0006748393977922708, Batch Size  655
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0448 - accuracy: 0.9859 - val_loss: 0.9283 - val_accuracy: 0.8750
#
#
# epoch 132, Learning Rate 0.0006723362075727433, Batch Size  660
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0367 - accuracy: 0.9873 - val_loss: 0.8394 - val_accuracy: 0.8788
#
#
# epoch 133, Learning Rate 0.0006698606611609194, Batch Size  665
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0331 - accuracy: 0.9895 - val_loss: 0.8889 - val_accuracy: 0.8662
#
#
# epoch 134, Learning Rate 0.0006674122535902699, Batch Size  670
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0378 - accuracy: 0.9892 - val_loss: 0.9621 - val_accuracy: 0.8750
#
#
# epoch 135, Learning Rate 0.0006649904927113595, Batch Size  675
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0396 - accuracy: 0.9884 - val_loss: 0.8508 - val_accuracy: 0.8825
#
#
# epoch 136, Learning Rate 0.0006625948987766851, Batch Size  680
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0442 - accuracy: 0.9861 - val_loss: 0.8651 - val_accuracy: 0.8813
#
#
# epoch 137, Learning Rate 0.0006602250040418284, Batch Size  685
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0435 - accuracy: 0.9859 - val_loss: 1.0258 - val_accuracy: 0.8725
#
#
# epoch 138, Learning Rate 0.0006578803523821717, Batch Size  690
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.9174 - val_accuracy: 0.8750
#
#
# epoch 139, Learning Rate 0.0006555604989244632, Batch Size  695
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0408 - accuracy: 0.9869 - val_loss: 0.8821 - val_accuracy: 0.8825
#
#
# epoch 140, Learning Rate 0.0006532650096925569, Batch Size  700
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0362 - accuracy: 0.9891 - val_loss: 0.9578 - val_accuracy: 0.8775
#
#
# epoch 141, Learning Rate 0.0006509934612666877, Batch Size  705
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0409 - accuracy: 0.9853 - val_loss: 1.0382 - val_accuracy: 0.8725
#
#
# epoch 142, Learning Rate 0.0006487454404556758, Batch Size  710
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0486 - accuracy: 0.9858 - val_loss: 0.9554 - val_accuracy: 0.8863
#
#
# epoch 143, Learning Rate 0.0006465205439814815, Batch Size  715
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0401 - accuracy: 0.9869 - val_loss: 0.9104 - val_accuracy: 0.8788
#
#
# epoch 144, Learning Rate 0.0006443183781755687, Batch Size  720
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0418 - accuracy: 0.9880 - val_loss: 0.9579 - val_accuracy: 0.8775
#
#
# epoch 145, Learning Rate 0.0006421385586865547, Batch Size  725
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0332 - accuracy: 0.9906 - val_loss: 1.0051 - val_accuracy: 0.8750
#
#
# epoch 146, Learning Rate 0.0006399807101986559, Batch Size  730
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.9429 - val_accuracy: 0.8813
#
#
# epoch 147, Learning Rate 0.0006378444661604604, Batch Size  735
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0314 - accuracy: 0.9897 - val_loss: 0.9705 - val_accuracy: 0.8775
#
#
# epoch 148, Learning Rate 0.0006357294685235842, Batch Size  740
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0317 - accuracy: 0.9908 - val_loss: 0.9698 - val_accuracy: 0.8775
#
#
# epoch 149, Learning Rate 0.0006336353674907874, Batch Size  745
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.9545 - val_accuracy: 0.8788
#
#
# epoch 150, Learning Rate 0.0006315618212731474, Batch Size  750
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0433 - accuracy: 0.9883 - val_loss: 0.8655 - val_accuracy: 0.8737

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0
