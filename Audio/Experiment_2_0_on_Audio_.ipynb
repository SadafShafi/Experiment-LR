# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display


# Set seed for experiment reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  # plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
data_dir = pathlib.Path('data/mini_speech_commands')
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip
# 182083584/182082353 [==============================] - 5s 0us/step

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['up' 'left' 'no' 'right' 'stop' 'down' 'go' 'yes']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 8000
# Number of examples per label: 1000
# Example file tensor: tf.Tensor(b'data/mini_speech_commands/down/b2fbe484_nohash_0.wav', shape=(), dtype=string)

# %%
train_files = filenames[:6400]
val_files = filenames[6400: 6400 + 800]
test_files = filenames[-800:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 6400
# Validation set size 800
# Test set size 800

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)

  # Note: You'll use indexing here instead of tuple unpacking to enable this 
  # to work in a TensorFlow graph.
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
AUTOTUNE = tf.data.AUTOTUNE
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
  # Padding for files with less than 16000 samples
  zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)

  # Concatenate audio with padding so that all audio clips will be of the 
  # same length
  waveform = tf.cast(waveform, tf.float32)
  equal_length = tf.concat([waveform, zero_padding], 0)
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
      
  spectrogram = tf.abs(spectrogram)

  return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: down
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
  # Convert to frequencies to log scale and transpose so that the time is
  # represented in the x-axis (columns).
  log_spec = np.log(spectrogram.T)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)


fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])
plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now transform the waveform dataset to have spectrogram images and their corresponding labels as integer IDs.

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  spectrogram = tf.expand_dims(spectrogram, -1)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %%
spectrogram_ds = waveform_ds.map(
    get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(np.squeeze(spectrogram.numpy()), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')
  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(
      get_spectrogram_and_label_id,  num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
def mymodel():
  for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
  print('Input shape:', input_shape)
  num_labels = len(commands)

  norm_layer = preprocessing.Normalization()
  norm_layer.adapt(spectrogram_ds.map(lambda x, _: x))

  model = models.Sequential([
      layers.Input(shape=input_shape),
      preprocessing.Resizing(32, 32), 
      norm_layer,
      layers.Conv2D(32, 3, activation='relu'),
      layers.Conv2D(64, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.25),
      layers.Flatten(),
      layers.Dense(128, activation='relu'),
      layers.Dropout(0.5),
      layers.Dense(num_labels),
  ])

  model.summary()

  model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
  )

  return model

# %%
lr = []
epoo=100
from matplotlib import pyplot as plt
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)

  LR = (batch_size)/((z+1)**(3/2)*80)
  LR=LR/8
  lr.append(LR)

plt.plot(lr, label='Learning Rate')
# plt.plot(val_loss, label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(),
#     loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#     metrics=['accuracy'],
# )

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
EPOCHS = 100
model = mymodel()
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    # batch_size = 32, 
    epochs=EPOCHS,
    # callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=2),
)

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
metrics = history.history
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = mymodel()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]


  # history = model.fit(
  #           datagen.flow(x_train, y_train, 
  #           batch_size=batch_size),
  #           validation_data=(x_test,y_test),
  #           epochs=epoch,
  #           callbacks=call
  #           )
  history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    batch_size=batch_size,
    epochs=epoch,
    callbacks=call
  )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
model = mymodel()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  # history = model.fit(
  #           datagen.flow(x_train, y_train, 
  #           # batch_size=batch_size
  #           ),
  #           validation_data=(x_test,y_test),
  #           epochs=epoch,
  #           callbacks=call
  #           )
  

  history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    # batch_size=batch_size,
    epochs=epoch,
    callbacks=call
  )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_6 (Resizing)        (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_6 (Normalizati (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               1605760
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
#
#
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002762135864009951.
# 100/100 [==============================] - 2s 14ms/step - loss: 1.6259 - accuracy: 0.4252 - val_loss: 1.1761 - val_accuracy: 0.6175
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003007032652029301.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0325 - accuracy: 0.6380 - val_loss: 0.7969 - val_accuracy: 0.7300
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0029296875.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.7728 - accuracy: 0.7206 - val_loss: 0.6758 - val_accuracy: 0.7638
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002795084971874737.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.6426 - accuracy: 0.7658 - val_loss: 0.5793 - val_accuracy: 0.7987
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0026578664743741078.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.5493 - accuracy: 0.7991 - val_loss: 0.5663 - val_accuracy: 0.7937
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0025310120960439324.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.4701 - accuracy: 0.8263 - val_loss: 0.5316 - val_accuracy: 0.8188
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0024168688810087074.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.4369 - accuracy: 0.8459 - val_loss: 0.5946 - val_accuracy: 0.8100
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023148148148148147.
# 100/100 [==============================] - 1s 11ms/step - loss: 0.

# 100/100 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9830 - val_loss: 0.7085 - val_accuracy: 0.8662
#
#
# epoch 103, Learning Rate 0.0007587125119904205, Batch Size  515
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007587125119904205.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0608 - accuracy: 0.9809 - val_loss: 0.7026 - val_accuracy: 0.8675
#
#
# epoch 104, Learning Rate 0.000755160770733984, Batch Size  520
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000755160770733984.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0576 - accuracy: 0.9811 - val_loss: 0.7282 - val_accuracy: 0.8600
#
#
# epoch 105, Learning Rate 0.0007516584282688145, Batch Size  525
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007516584282688145.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0480 - accuracy: 0.9850 - val_loss: 0.7592 - val_accuracy: 0.8650
#
#
# epoch 106, Learning Rate 0.0007482043504588227, Batch Size  530
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007482043504588227.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0480 - accuracy: 0.9837 - val_loss: 0.7502 - val_accuracy: 0.8700
#
#
# epoch 107, Learning Rate 0.0007447974392757759, Batch Size  535
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007447974392757759.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0476 - accuracy: 0.9855 - val_loss: 0.8221 - val_accuracy: 0.8575
#
#
# epoch 108, Learning Rate 0.0007414366313351803, Batch Size  540
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007414366313351803.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0561 - accuracy: 0.9817 - val_loss: 0.7388 - val_accuracy: 0.8625
#
#
# epoch 109, Learning Rate 0.0007381208965040452, Batch Size  545
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007381208965040452.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0523 - accuracy: 0.9828 - val_loss: 0.7266 - val_accuracy: 0.8587
#
#
# epoch 110, Learning Rate 0.0007348492365763997, Batch Size  550
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007348492365763997.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0502 - accuracy: 0.9819 - val_loss: 0.7537 - val_accuracy: 0.8675
#
#
# epoch 111, Learning Rate 0.0007316206840126991, Batch Size  555
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007316206840126991.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0454 - accuracy: 0.9839 - val_loss: 0.8061 - val_accuracy: 0.8675
#
#
# epoch 112, Learning Rate 0.0007284343007395112, Batch Size  560
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007284343007395112.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0419 - accuracy: 0.9864 - val_loss: 0.8472 - val_accuracy: 0.8662
#
#
# epoch 113, Learning Rate 0.0007252891770061089, Batch Size  565
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007252891770061089.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0485 - accuracy: 0.9834 - val_loss: 0.7489 - val_accuracy: 0.8675
#
#
# epoch 114, Learning Rate 0.0007221844302948083, Batch Size  570
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007221844302948083.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0467 - accuracy: 0.9830 - val_loss: 0.7357 - val_accuracy: 0.8650
#
#
# epoch 115, Learning Rate 0.0007191192042820906, Batch Size  575
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007191192042820906.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0427 - accuracy: 0.9869 - val_loss: 0.8283 - val_accuracy: 0.8675
#
#
# epoch 116, Learning Rate 0.0007160926678477406, Batch Size  580
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007160926678477406.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0473 - accuracy: 0.9836 - val_loss: 0.7499 - val_accuracy: 0.8712
#
#
# epoch 117, Learning Rate 0.0007131040141293951, Batch Size  585
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007131040141293951.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0425 - accuracy: 0.9864 - val_loss: 0.7683 - val_accuracy: 0.8675
#
#
# epoch 118, Learning Rate 0.0007101524596200692, Batch Size  590
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007101524596200692.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0412 - accuracy: 0.9870 - val_loss: 0.7212 - val_accuracy: 0.8625
#
#
# epoch 119, Learning Rate 0.0007072372433063668, Batch Size  595
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007072372433063668.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 0.7614 - val_accuracy: 0.8775
#
#
# epoch 120, Learning Rate 0.0007043576258452291, Batch Size  600
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007043576258452291.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0439 - accuracy: 0.9845 - val_loss: 0.8310 - val_accuracy: 0.8700
#
#
# epoch 121, Learning Rate 0.0007015128887771992, Batch Size  605
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007015128887771992.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0536 - accuracy: 0.9825 - val_loss: 0.7190 - val_accuracy: 0.8763
#
#
# epoch 122, Learning Rate 0.0006987023337743061, Batch Size  610
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006987023337743061.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0448 - accuracy: 0.9847 - val_loss: 0.7178 - val_accuracy: 0.8763
#
#
# epoch 123, Learning Rate 0.0006959252819207823, Batch Size  615
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006959252819207823.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0457 - accuracy: 0.9864 - val_loss: 0.7146 - val_accuracy: 0.8800
#
#
# epoch 124, Learning Rate 0.0006931810730249348, Batch Size  620
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006931810730249348.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0460 - accuracy: 0.9870 - val_loss: 0.7144 - val_accuracy: 0.8687
#
#
# epoch 125, Learning Rate 0.0006904690649605871, Batch Size  625
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006904690649605871.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0419 - accuracy: 0.9864 - val_loss: 0.7662 - val_accuracy: 0.8725
#
#
# epoch 126, Learning Rate 0.000687788633036604, Batch Size  630
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000687788633036604.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0416 - accuracy: 0.9866 - val_loss: 0.7215 - val_accuracy: 0.8775
#
#
# epoch 127, Learning Rate 0.0006851391693930934, Batch Size  635
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006851391693930934.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0419 - accuracy: 0.9864 - val_loss: 0.7507 - val_accuracy: 0.8763
#
#
# epoch 128, Learning Rate 0.0006825200824229642, Batch Size  640
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006825200824229642.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0400 - accuracy: 0.9862 - val_loss: 0.7630 - val_accuracy: 0.8725
#
#
# epoch 129, Learning Rate 0.0006799307962175887, Batch Size  645
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006799307962175887.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0449 - accuracy: 0.9844 - val_loss: 0.7619 - val_accuracy: 0.8763
#
#
# epoch 130, Learning Rate 0.0006773707500353944, Batch Size  650
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006773707500353944.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0406 - accuracy: 0.9862 - val_loss: 0.8023 - val_accuracy: 0.8725
#
#
# epoch 131, Learning Rate 0.0006748393977922708, Batch Size  655
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006748393977922708.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0405 - accuracy: 0.9866 - val_loss: 0.7739 - val_accuracy: 0.8725
#
#
# epoch 132, Learning Rate 0.0006723362075727433, Batch Size  660
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006723362075727433.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.7775 - val_accuracy: 0.8712
#
#
# epoch 133, Learning Rate 0.0006698606611609194, Batch Size  665
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006698606611609194.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0375 - accuracy: 0.9889 - val_loss: 0.7966 - val_accuracy: 0.8838
#
#
# epoch 134, Learning Rate 0.0006674122535902699, Batch Size  670
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006674122535902699.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0487 - accuracy: 0.9822 - val_loss: 0.7987 - val_accuracy: 0.8637
#
#
# epoch 135, Learning Rate 0.0006649904927113595, Batch Size  675
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006649904927113595.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0458 - accuracy: 0.9842 - val_loss: 0.7779 - val_accuracy: 0.8687
#
#
# epoch 136, Learning Rate 0.0006625948987766851, Batch Size  680
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006625948987766851.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0414 - accuracy: 0.9855 - val_loss: 0.7986 - val_accuracy: 0.8737
#
#
# epoch 137, Learning Rate 0.0006602250040418284, Batch Size  685
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006602250040418284.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0387 - accuracy: 0.9864 - val_loss: 0.8071 - val_accuracy: 0.8662
#
#
# epoch 138, Learning Rate 0.0006578803523821717, Batch Size  690
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006578803523821717.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0379 - accuracy: 0.9861 - val_loss: 0.8177 - val_accuracy: 0.8775
#
#
# epoch 139, Learning Rate 0.0006555604989244632, Batch Size  695
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006555604989244632.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0595 - accuracy: 0.9817 - val_loss: 0.7544 - val_accuracy: 0.8637
#
#
# epoch 140, Learning Rate 0.0006532650096925569, Batch Size  700
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006532650096925569.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0484 - accuracy: 0.9852 - val_loss: 0.7682 - val_accuracy: 0.8750
#
#
# epoch 141, Learning Rate 0.0006509934612666877, Batch Size  705
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006509934612666877.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0408 - accuracy: 0.9880 - val_loss: 0.7831 - val_accuracy: 0.8763
#
#
# epoch 142, Learning Rate 0.0006487454404556758, Batch Size  710
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006487454404556758.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0391 - accuracy: 0.9869 - val_loss: 0.7398 - val_accuracy: 0.8813
#
#
# epoch 143, Learning Rate 0.0006465205439814815, Batch Size  715
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006465205439814815.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0402 - accuracy: 0.9847 - val_loss: 0.7637 - val_accuracy: 0.8775
#
#
# epoch 144, Learning Rate 0.0006443183781755687, Batch Size  720
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006443183781755687.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0415 - accuracy: 0.9858 - val_loss: 0.7635 - val_accuracy: 0.8737
#
#
# epoch 145, Learning Rate 0.0006421385586865547, Batch Size  725
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006421385586865547.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0367 - accuracy: 0.9892 - val_loss: 0.8166 - val_accuracy: 0.8737
#
#
# epoch 146, Learning Rate 0.0006399807101986559, Batch Size  730
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006399807101986559.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0373 - accuracy: 0.9887 - val_loss: 0.8056 - val_accuracy: 0.8825
#
#
# epoch 147, Learning Rate 0.0006378444661604604, Batch Size  735
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006378444661604604.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0408 - accuracy: 0.9858 - val_loss: 0.9671 - val_accuracy: 0.8662
#
#
# epoch 148, Learning Rate 0.0006357294685235842, Batch Size  740
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006357294685235842.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0423 - accuracy: 0.9858 - val_loss: 0.7466 - val_accuracy: 0.8662
#
#
# epoch 149, Learning Rate 0.0006336353674907874, Batch Size  745
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006336353674907874.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0399 - accuracy: 0.9862 - val_loss: 0.8212 - val_accuracy: 0.8662
#
#
# epoch 150, Learning Rate 0.0006315618212731474, Batch Size  750
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006315618212731474.
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0382 - accuracy: 0.9858 - val_loss: 0.8587 - val_accuracy: 0.8725

# %%
acc_3 = acc
val_acc_3 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **LR constant**

# %%
model = mymodel()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,150+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  # history = model.fit(
  #           datagen.flow(x_train, y_train, 
  #           batch_size=batch_size),
  #           validation_data=(x_test,y_test),
  #           epochs=epoch,
  #           # callbacks=call
  #           )
  
  history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    batch_size = batch_size, 
    epochs=1,
    # callbacks=call,
  )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_5 (Resizing)        (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_5 (Normalizati (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               1605760
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
#
#
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 100/100 [==============================] - 2s 14ms/step - loss: 1.7059 - accuracy: 0.3855 - val_loss: 1.3480 - val_accuracy: 0.5562
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1640 - accuracy: 0.6005 - val_loss: 0.9692 - val_accuracy: 0.6712
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 100/100 [==============================] - 1s 11ms/step - loss: 0.9004 - accuracy: 0.6862 - val_loss: 0.8041 - val_accuracy: 0.7450
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 100/100 [==============================] - 1s 11ms/step - loss: 0.7365 - accuracy: 0.7467 - val_loss: 0.7433 - val_accuracy: 0.7513
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 100/100 [==============================] - 1s 11ms/step - loss: 0.6364 - accuracy: 0.7738 - val_loss: 0.6580 - val_accuracy: 0.7950
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0535 - accuracy: 0.9833 - val_loss: 0.7958 - val_accuracy: 0.8725
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0655 - accuracy: 0.9792 - val_loss: 0.7957 - val_accuracy: 0.8737
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0611 - accuracy: 0.9827 - val_loss: 0.9239 - val_accuracy: 0.8637
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0651 - accuracy: 0.9791 - val_loss: 0.8957 - val_accuracy: 0.8612
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0573 - accuracy: 0.9816 - val_loss: 0.8152 - val_accuracy: 0.8737
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0602 - accuracy: 0.9814 - val_loss: 0.8300 - val_accuracy: 0.8662
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0518 - accuracy: 0.9836 - val_loss: 0.9258 - val_accuracy: 0.8575
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0446 - accuracy: 0.9864 - val_loss: 0.8455 - val_accuracy: 0.8725
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0564 - accuracy: 0.9814 - val_loss: 0.8674 - val_accuracy: 0.8537
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0551 - accuracy: 0.9825 - val_loss: 0.8536 - val_accuracy: 0.8625
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0548 - accuracy: 0.9828 - val_loss: 0.7393 - val_accuracy: 0.8763
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0503 - accuracy: 0.9839 - val_loss: 0.7810 - val_accuracy: 0.8737
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0489 - accuracy: 0.9834 - val_loss: 0.8037 - val_accuracy: 0.8687
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0522 - accuracy: 0.9831 - val_loss: 0.8806 - val_accuracy: 0.8525
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0580 - accuracy: 0.9806 - val_loss: 0.7999 - val_accuracy: 0.8512
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0466 - accuracy: 0.9842 - val_loss: 0.7969 - val_accuracy: 0.8662
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0436 - accuracy: 0.9872 - val_loss: 0.7936 - val_accuracy: 0.8737
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0454 - accuracy: 0.9864 - val_loss: 0.7566 - val_accuracy: 0.8725
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0555 - accuracy: 0.9852 - val_loss: 0.7971 - val_accuracy: 0.8700
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0493 - accuracy: 0.9845 - val_loss: 0.8545 - val_accuracy: 0.8662
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0590 - accuracy: 0.9827 - val_loss: 0.8434 - val_accuracy: 0.8750
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0479 - accuracy: 0.9858 - val_loss: 0.8802 - val_accuracy: 0.8612
#
#
# epoch 101, Learning Rate 0.0007659689172843453, Batch Size  505
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0495 - accuracy: 0.9845 - val_loss: 0.8536 - val_accuracy: 0.8675
#
#
# epoch 102, Learning Rate 0.0007623148238224963, Batch Size  510
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0465 - accuracy: 0.9867 - val_loss: 0.8494 - val_accuracy: 0.8725
#
#
# epoch 103, Learning Rate 0.0007587125119904205, Batch Size  515
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0446 - accuracy: 0.9869 - val_loss: 0.8129 - val_accuracy: 0.8687
#
#
# epoch 104, Learning Rate 0.000755160770733984, Batch Size  520
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0450 - accuracy: 0.9859 - val_loss: 0.8201 - val_accuracy: 0.8763
#
#
# epoch 105, Learning Rate 0.0007516584282688145, Batch Size  525
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0408 - accuracy: 0.9873 - val_loss: 0.9041 - val_accuracy: 0.8737
#
#
# epoch 106, Learning Rate 0.0007482043504588227, Batch Size  530
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0428 - accuracy: 0.9867 - val_loss: 0.8607 - val_accuracy: 0.8775
#
#
# epoch 107, Learning Rate 0.0007447974392757759, Batch Size  535
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0515 - accuracy: 0.9831 - val_loss: 0.9212 - val_accuracy: 0.8825
#
#
# epoch 108, Learning Rate 0.0007414366313351803, Batch Size  540
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 0.9305 - val_accuracy: 0.8675
#
#
# epoch 109, Learning Rate 0.0007381208965040452, Batch Size  545
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0421 - accuracy: 0.9858 - val_loss: 0.8767 - val_accuracy: 0.8813
#
#
# epoch 110, Learning Rate 0.0007348492365763997, Batch Size  550
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 0.8311 - val_accuracy: 0.8725
#
#
# epoch 111, Learning Rate 0.0007316206840126991, Batch Size  555
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0422 - accuracy: 0.9852 - val_loss: 0.8481 - val_accuracy: 0.8800
#
#
# epoch 112, Learning Rate 0.0007284343007395112, Batch Size  560
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0537 - accuracy: 0.9833 - val_loss: 0.8371 - val_accuracy: 0.8863
#
#
# epoch 113, Learning Rate 0.0007252891770061089, Batch Size  565
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0489 - accuracy: 0.9853 - val_loss: 0.7620 - val_accuracy: 0.8813
#
#
# epoch 114, Learning Rate 0.0007221844302948083, Batch Size  570
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0348 - accuracy: 0.9891 - val_loss: 0.7793 - val_accuracy: 0.8863
#
#
# epoch 115, Learning Rate 0.0007191192042820906, Batch Size  575
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0344 - accuracy: 0.9887 - val_loss: 0.8116 - val_accuracy: 0.8763
#
#
# epoch 116, Learning Rate 0.0007160926678477406, Batch Size  580
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0400 - accuracy: 0.9861 - val_loss: 0.8330 - val_accuracy: 0.8850
#
#
# epoch 117, Learning Rate 0.0007131040141293951, Batch Size  585
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0445 - accuracy: 0.9858 - val_loss: 0.8034 - val_accuracy: 0.8800
#
#
# epoch 118, Learning Rate 0.0007101524596200692, Batch Size  590
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0470 - accuracy: 0.9867 - val_loss: 0.7817 - val_accuracy: 0.8725
#
#
# epoch 119, Learning Rate 0.0007072372433063668, Batch Size  595
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0366 - accuracy: 0.9880 - val_loss: 0.8584 - val_accuracy: 0.8750
#
#
# epoch 120, Learning Rate 0.0007043576258452291, Batch Size  600
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0349 - accuracy: 0.9880 - val_loss: 0.9289 - val_accuracy: 0.8600
#
#
# epoch 121, Learning Rate 0.0007015128887771992, Batch Size  605
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0500 - accuracy: 0.9858 - val_loss: 0.8382 - val_accuracy: 0.8725
#
#
# epoch 122, Learning Rate 0.0006987023337743061, Batch Size  610
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0477 - accuracy: 0.9845 - val_loss: 0.8926 - val_accuracy: 0.8650
#
#
# epoch 123, Learning Rate 0.0006959252819207823, Batch Size  615
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0436 - accuracy: 0.9866 - val_loss: 0.8722 - val_accuracy: 0.8687
#
#
# epoch 124, Learning Rate 0.0006931810730249348, Batch Size  620
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9856 - val_loss: 0.8652 - val_accuracy: 0.8725
#
#
# epoch 125, Learning Rate 0.0006904690649605871, Batch Size  625
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0441 - accuracy: 0.9866 - val_loss: 0.8995 - val_accuracy: 0.8650
#
#
# epoch 126, Learning Rate 0.000687788633036604, Batch Size  630
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0476 - accuracy: 0.9855 - val_loss: 0.8982 - val_accuracy: 0.8550
#
#
# epoch 127, Learning Rate 0.0006851391693930934, Batch Size  635
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.8927 - val_accuracy: 0.8675
#
#
# epoch 128, Learning Rate 0.0006825200824229642, Batch Size  640
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0369 - accuracy: 0.9887 - val_loss: 1.0011 - val_accuracy: 0.8587
#
#
# epoch 129, Learning Rate 0.0006799307962175887, Batch Size  645
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 1.0541 - val_accuracy: 0.8575
#
#
# epoch 130, Learning Rate 0.0006773707500353944, Batch Size  650
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0401 - accuracy: 0.9881 - val_loss: 1.1058 - val_accuracy: 0.8587
#
#
# epoch 131, Learning Rate 0.0006748393977922708, Batch Size  655
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0483 - accuracy: 0.9861 - val_loss: 0.9381 - val_accuracy: 0.8687
#
#
# epoch 132, Learning Rate 0.0006723362075727433, Batch Size  660
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0387 - accuracy: 0.9873 - val_loss: 0.8818 - val_accuracy: 0.8788
#
#
# epoch 133, Learning Rate 0.0006698606611609194, Batch Size  665
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.9181 - val_accuracy: 0.8737
#
#
# epoch 134, Learning Rate 0.0006674122535902699, Batch Size  670
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0386 - accuracy: 0.9891 - val_loss: 0.9117 - val_accuracy: 0.8675
#
#
# epoch 135, Learning Rate 0.0006649904927113595, Batch Size  675
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0467 - accuracy: 0.9870 - val_loss: 0.8974 - val_accuracy: 0.8712
#
#
# epoch 136, Learning Rate 0.0006625948987766851, Batch Size  680
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 1.0319 - val_accuracy: 0.8687
#
#
# epoch 137, Learning Rate 0.0006602250040418284, Batch Size  685
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0425 - accuracy: 0.9852 - val_loss: 0.9570 - val_accuracy: 0.8687
#
#
# epoch 138, Learning Rate 0.0006578803523821717, Batch Size  690
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0470 - accuracy: 0.9856 - val_loss: 0.8854 - val_accuracy: 0.8788
#
#
# epoch 139, Learning Rate 0.0006555604989244632, Batch Size  695
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0382 - accuracy: 0.9886 - val_loss: 0.9248 - val_accuracy: 0.8650
#
#
# epoch 140, Learning Rate 0.0006532650096925569, Batch Size  700
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0359 - accuracy: 0.9877 - val_loss: 0.8607 - val_accuracy: 0.8712
#
#
# epoch 141, Learning Rate 0.0006509934612666877, Batch Size  705
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0328 - accuracy: 0.9898 - val_loss: 0.9337 - val_accuracy: 0.8725
#
#
# epoch 142, Learning Rate 0.0006487454404556758, Batch Size  710
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0438 - accuracy: 0.9862 - val_loss: 0.8732 - val_accuracy: 0.8750
#
#
# epoch 143, Learning Rate 0.0006465205439814815, Batch Size  715
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0415 - accuracy: 0.9884 - val_loss: 1.0504 - val_accuracy: 0.8475
#
#
# epoch 144, Learning Rate 0.0006443183781755687, Batch Size  720
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0426 - accuracy: 0.9872 - val_loss: 1.0641 - val_accuracy: 0.8537
#
#
# epoch 145, Learning Rate 0.0006421385586865547, Batch Size  725
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0391 - accuracy: 0.9877 - val_loss: 0.9157 - val_accuracy: 0.8675
#
#
# epoch 146, Learning Rate 0.0006399807101986559, Batch Size  730
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0374 - accuracy: 0.9897 - val_loss: 1.0096 - val_accuracy: 0.8687
#
#
# epoch 147, Learning Rate 0.0006378444661604604, Batch Size  735
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0456 - accuracy: 0.9873 - val_loss: 0.9878 - val_accuracy: 0.8737
#
#
# epoch 148, Learning Rate 0.0006357294685235842, Batch Size  740
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.9901 - val_accuracy: 0.8700
#
#
# epoch 149, Learning Rate 0.0006336353674907874, Batch Size  745
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0372 - accuracy: 0.9869 - val_loss: 0.9454 - val_accuracy: 0.8800
#
#
# epoch 150, Learning Rate 0.0006315618212731474, Batch Size  750
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0387 - accuracy: 0.9880 - val_loss: 0.9198 - val_accuracy: 0.8725

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 88%
