# %%
import os
import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display


# Set seed for experiment reproducibility
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  # plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
data_dir = pathlib.Path('data/mini_speech_commands')
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip
# 182083584/182082353 [==============================] - 5s 0us/step

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['up' 'left' 'no' 'right' 'stop' 'down' 'go' 'yes']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print('Example file tensor:', filenames[0])
# Out:
# Number of total examples: 8000
# Number of examples per label: 1000
# Example file tensor: tf.Tensor(b'data/mini_speech_commands/down/b2fbe484_nohash_0.wav', shape=(), dtype=string)

# %%
train_files = filenames[:6400]
val_files = filenames[6400: 6400 + 800]
test_files = filenames[-800:]

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Training set size 6400
# Validation set size 800
# Test set size 800

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)

  # Note: You'll use indexing here instead of tuple unpacking to enable this 
  # to work in a TensorFlow graph.
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path)
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %%
AUTOTUNE = tf.data.AUTOTUNE
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
  # Padding for files with less than 16000 samples
  zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)

  # Concatenate audio with padding so that all audio clips will be of the 
  # same length
  waveform = tf.cast(waveform, tf.float32)
  equal_length = tf.concat([waveform, zero_padding], 0)
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
      
  spectrogram = tf.abs(spectrogram)

  return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: down
# Waveform shape: (16000,)
# Spectrogram shape: (124, 129)
# Audio playback
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
  # Convert to frequencies to log scale and transpose so that the time is
  # represented in the x-axis (columns).
  log_spec = np.log(spectrogram.T)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec)


fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])
plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

# %% [markdown]
# Now transform the waveform dataset to have spectrogram images and their corresponding labels as integer IDs.

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  spectrogram = tf.expand_dims(spectrogram, -1)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %%
spectrogram_ds = waveform_ds.map(
    get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
for i, (spectrogram, label_id) in enumerate(spectrogram_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  plot_spectrogram(np.squeeze(spectrogram.numpy()), ax)
  ax.set_title(commands[label_id.numpy()])
  ax.axis('off')
  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(
      get_spectrogram_and_label_id,  num_parallel_calls=AUTOTUNE)
  return output_ds

# %%
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)

# %%
def mymodel():
  for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
  print('Input shape:', input_shape)
  num_labels = len(commands)

  norm_layer = preprocessing.Normalization()
  norm_layer.adapt(spectrogram_ds.map(lambda x, _: x))

  model = models.Sequential([
      layers.Input(shape=input_shape),
      preprocessing.Resizing(32, 32), 
      norm_layer,
      layers.Conv2D(32, 3, activation='relu'),
      layers.Conv2D(64, 3, activation='relu'),
      layers.MaxPooling2D(),
      layers.Dropout(0.25),
      layers.Flatten(),
      layers.Dense(128, activation='relu'),
      layers.Dropout(0.5),
      layers.Dense(num_labels),
  ])

  model.summary()

  model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
  )

  return model

# %%
from random import random,randint,randrange,uniform
lr = []
epoo = 150
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = random() * batch_size/10000
  lr.append(LR)
 
lord_LR = lr

plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
EPOCHS = 150
model = mymodel()
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=EPOCHS,
)

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
metrics = history.history
plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = mymodel()
from random import random
from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo),range(5,10000,5)):

  # if (z%2 == 0):
  LR = random() * batch_size/10000
  # lr.append(LR)
  # else:
  #   LR = random() * z/10000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.009):
      LR = 0.009
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  # history = model.fit(
  #           datagen.flow(x_train, y_train), 
  #           validation_data=(x_test, y_test),
  #           epochs=epoch,
  #           batch_size=batch_size,
  #           callbacks=call
  #           )
  
  history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=epoch,
    batch_size=batch_size,
    callbacks=call
  )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(150):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = mymodel()
# epoo = 1
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
def setLR(step):
  global LR
  lr = initial_learning_rate * decay_rate **(step / decay_steps)
  LR.append(lr)
  print("called here")
  return lr

call = [ LearningRateScheduler(setLR,verbose=1) ]


history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    # batch_size = batch_size, 
    epochs=epoo,
    callbacks=call,
  )
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_12 (Resizing)       (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_14 (Normalizat (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               1605760
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
# Epoch 1/150
# called here
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 100/100 [==============================] - 2s 14ms/step - loss: 2.1168 - accuracy: 0.1202 - val_loss: 2.0816 - val_accuracy: 0.1238
# Epoch 2/150
# called here
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.007834955069665117.
# 100/100 [==============================] - 1s 11ms/step - loss: 2.0806 - accuracy: 0.1227 - val_loss: 2.0813 - val_accuracy: 0.1213
# Epoch 3/150
# called here
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.006820724549296791.
# 100/100 [==============================] - 1s 11ms/step - loss: 2.0804 - accuracy: 0.1219 - val_loss: 2.0811 - val_accuracy: 0.1213
# Epoch 4/150
# called here
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.005937785598478023.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.9995 - accuracy: 0.2077 - val_loss: 1.7282 - val_accuracy: 0.3837
# Epoch 5/150
# called here
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.005169142597486656.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.6820 - accuracy: 0.3695 - val_loss: 1.4406 - val_accuracy: 0.4650
# Epoch 6/150
# called here
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0045.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.4671 - accuracy: 0.4661 - val_loss: 1.3016 - val_accuracy: 0.5512
# Epoch 7/150
# called here
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.003917477534832558.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.3846 - accuracy: 0.4952 - val_loss: 1.2269 - val_accuracy: 0.5763
# Epoch 8/150
# called here
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0034103622746483957.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.2988 - accuracy: 0.5266 - val_loss: 1.1928 - val_accuracy: 0.5863
# Epoch 9/150
# called here
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0029688927992390117.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.2811 - accuracy: 0.5292 - val_loss: 1.1511 - val_accuracy: 0.6050
# Epoch 10/150
# called here
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.002584571298743328.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.2333 - accuracy: 0.5462 - val_loss: 1.1484 - val_accuracy: 0.6012
# Epoch 11/150
# called here
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00225.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.2080 - accuracy: 0.5619 - val_loss: 1.0957 - val_accuracy: 0.6263
# Epoch 12/150
# called here
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0019587387674162788.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1844 - accuracy: 0.5689 - val_loss: 1.0798 - val_accuracy: 0.6288
# Epoch 13/150
# called here
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0017051811373241979.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1801 - accuracy: 0.5777 - val_loss: 1.0634 - val_accuracy: 0.6363
# Epoch 14/150
# called here
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0014844463996195058.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1572 - accuracy: 0.5809 - val_loss: 1.0483 - val_accuracy: 0.6388
# Epoch 15/150
# called here
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0012922856493716643.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1255 - accuracy: 0.5941 - val_loss: 1.0401 - val_accuracy: 0.6438
# Epoch 16/150
# called here
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001125.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1212 - accuracy: 0.5902 - val_loss: 1.0324 - val_accuracy: 0.6425
# Epoch 17/150
# called here
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009793693837081394.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1068 - accuracy: 0.5994 - val_loss: 1.0283 - val_accuracy: 0.6488
# Epoch 18/150
# called here
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0008525905686620989.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1262 - accuracy: 0.5931 - val_loss: 1.0341 - val_accuracy: 0.6525
# Epoch 19/150
# called here
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007422231998097529.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1203 - accuracy: 0.5964 - val_loss: 1.0325 - val_accuracy: 0.6363
# Epoch 20/150
# called here
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0006461428246858322.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.1094 - accuracy: 0.6033 - val_loss: 1.0157 - val_accuracy: 0.6575
# Epoch 21/150
# called here
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005625.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0866 - accuracy: 0.6136 - val_loss: 1.0118 - val_accuracy: 0.6550
# Epoch 22/150
# called here
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0004896846918540697.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0945 - accuracy: 0.6083 - val_loss: 1.0138 - val_accuracy: 0.6600
# Epoch 23/150
# called here
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00042629528433104936.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0882 - accuracy: 0.6145 - val_loss: 1.0071 - val_accuracy: 0.6550
# Epoch 24/150
# called here
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00037111159990487657.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0732 - accuracy: 0.6098 - val_loss: 1.0114 - val_accuracy: 0.6562
# Epoch 25/150
# called here
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003230714123429161.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0722 - accuracy: 0.6137 - val_loss: 1.0164 - val_accuracy: 0.6450
# Epoch 26/150
# called here
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00028125.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0770 - accuracy: 0.6108 - val_loss: 1.0110 - val_accuracy: 0.6450
# Epoch 27/150
# called here
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00024484234592703485.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0770 - accuracy: 0.6144 - val_loss: 1.0070 - val_accuracy: 0.6550
# Epoch 28/150
# called here
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00021314764216552468.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0826 - accuracy: 0.6084 - val_loss: 1.0035 - val_accuracy: 0.6575
# Epoch 29/150
# called here
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00018555579995243828.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0696 - accuracy: 0.6220 - val_loss: 1.0095 - val_accuracy: 0.6513
# Epoch 30/150
# called here
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00016153570617145804.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0631 - accuracy: 0.6192 - val_loss: 1.0042 - val_accuracy: 0.6562
# Epoch 31/150
# called here
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.000140625.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0681 - accuracy: 0.6125 - val_loss: 1.0029 - val_accuracy: 0.6562
# Epoch 32/150
# called here
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012242117296351742.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0495 - accuracy: 0.6145 - val_loss: 1.0021 - val_accuracy: 0.6538
# Epoch 33/150
# called here
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.00010657382108276234.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0760 - accuracy: 0.6148 - val_loss: 1.0012 - val_accuracy: 0.6575
# Epoch 34/150
# called here
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 9.277789997621914e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0631 - accuracy: 0.6141 - val_loss: 0.9980 - val_accuracy: 0.6550
# Epoch 35/150
# called here
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 8.076785308572902e-05.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0695 - accuracy: 0.6167 - val_loss: 0.9995 - val_accuracy: 0.6562
# Epoch 36/150
# called here
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 7.03125e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0674 - accuracy: 0.6120 - val_loss: 1.0007 - val_accuracy: 0.6550
# Epoch 37/150
# called here
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.121058648175871e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0565 - accuracy: 0.6206 - val_loss: 0.9996 - val_accuracy: 0.6600
# Epoch 38/150
# called here
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 5.328691054138117e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0612 - accuracy: 0.6148 - val_loss: 0.9989 - val_accuracy: 0.6587
# Epoch 39/150
# called here
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 4.638894998810957e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0483 - accuracy: 0.6237 - val_loss: 1.0014 - val_accuracy: 0.6562
# Epoch 40/150
# called here
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.038392654286451e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0516 - accuracy: 0.6158 - val_loss: 0.9999 - val_accuracy: 0.6612
# Epoch 41/150
# called here
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 3.515625e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0604 - accuracy: 0.6217 - val_loss: 0.9982 - val_accuracy: 0.6600
# Epoch 42/150
# called here
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 3.0605293240879376e-05.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0485 - accuracy: 0.6212 - val_loss: 0.9976 - val_accuracy: 0.6575
# Epoch 43/150
# called here
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.6643455270690585e-05.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0615 - accuracy: 0.6112 - val_loss: 0.9972 - val_accuracy: 0.6600
# Epoch 44/150
# called here
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.3194474994054785e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0502 - accuracy: 0.6206 - val_loss: 0.9970 - val_accuracy: 0.6612
# Epoch 45/150
# called here
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.0191963271432245e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0562 - accuracy: 0.6075 - val_loss: 0.9970 - val_accuracy: 0.6612
# Epoch 46/150
# called here
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.7578125e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0456 - accuracy: 0.6283 - val_loss: 0.9979 - val_accuracy: 0.6612
# Epoch 47/150
# called here
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.5302646620439688e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0745 - accuracy: 0.6148 - val_loss: 0.9972 - val_accuracy: 0.6625
# Epoch 48/150
# called here
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3321727635345292e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0352 - accuracy: 0.6266 - val_loss: 0.9971 - val_accuracy: 0.6625
# Epoch 49/150
# called here
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.1597237497027393e-05.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0731 - accuracy: 0.6042 - val_loss: 0.9970 - val_accuracy: 0.6625
# Epoch 50/150
# called here
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0095981635716122e-05.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0743 - accuracy: 0.6205 - val_loss: 0.9968 - val_accuracy: 0.6612
# Epoch 51/150
# called here
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 8.7890625e-06.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0650 - accuracy: 0.6094 - val_loss: 0.9973 - val_accuracy: 0.6612
# Epoch 52/150
# called here
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 7.651323310219844e-06.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.0514 - accuracy: 0.6178 - val_loss: 0.9970 - val_accuracy: 0.6612
# Epoch 53/150
# called here
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 6.660863817672646e-06.
# 100/100 [==============================] - 1s 11ms/step - loss: 1.
- val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 126/150
# called here
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 2.682209014892578e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0448 - accuracy: 0.6172 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 127/150
# called here
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 2.334998568792677e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0605 - accuracy: 0.6153 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 128/150
# called here
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 2.0327343193581097e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0391 - accuracy: 0.6253 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 129/150
# called here
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 1.7695980067485622e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0591 - accuracy: 0.6177 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 130/150
# called here
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 1.5405245415826603e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0477 - accuracy: 0.6222 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 131/150
# called here
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 1.341104507446289e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0618 - accuracy: 0.6180 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 132/150
# called here
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 1.1674992843963385e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0572 - accuracy: 0.6212 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 133/150
# called here
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 1.0163671596790548e-10.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0502 - accuracy: 0.6227 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 134/150
# called here
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 8.847990033742811e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0300 - accuracy: 0.6281 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 135/150
# called here
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 7.702622707913301e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0592 - accuracy: 0.6245 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 136/150
# called here
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 6.705522537231445e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0644 - accuracy: 0.6233 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 137/150
# called here
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 5.837496421981692e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0500 - accuracy: 0.6189 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 138/150
# called here
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 5.081835798395274e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0534 - accuracy: 0.6239 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 139/150
# called here
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 4.4239950168714056e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0504 - accuracy: 0.6200 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 140/150
# called here
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 3.8513113539566506e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0616 - accuracy: 0.6134 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 141/150
# called here
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 3.3527612686157224e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0639 - accuracy: 0.6181 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 142/150
# called here
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 2.918748210990846e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0553 - accuracy: 0.6261 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 143/150
# called here
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 2.540917899197637e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0684 - accuracy: 0.6273 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 144/150
# called here
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 2.2119975084357028e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0574 - accuracy: 0.6194 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 145/150
# called here
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 1.9256556769783253e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0739 - accuracy: 0.6128 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 146/150
# called here
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 1.6763806343078612e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0536 - accuracy: 0.6134 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 147/150
# called here
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 1.459374105495423e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0466 - accuracy: 0.6206 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 148/150
# called here
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 1.2704589495988186e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0685 - accuracy: 0.6117 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 149/150
# called here
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 1.1059987542178514e-11.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0619 - accuracy: 0.6209 - val_loss: 0.9965 - val_accuracy: 0.6625
# Epoch 150/150
# called here
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 9.628278384891627e-12.
# 100/100 [==============================] - 1s 12ms/step - loss: 1.0592 - accuracy: 0.6209 - val_loss: 0.9965 - val_accuracy: 0.6625

# %%
acc_3 = acc
val_acc_3 = val_acc

# %%
Plotter(acc_3,val_acc_3,loss,val_loss,LR)

# %% [markdown]
# **LR constant**

# %%
model = mymodel()

from keras.callbacks import LearningRateScheduler

LR = 0.01

epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            train_ds,
            validation_data = val_ds,
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# Input shape: (124, 129, 1)
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resizing_13 (Resizing)       (None, 32, 32, 1)         0
# _________________________________________________________________
# normalization_15 (Normalizat (None, 32, 32, 1)         3
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 30, 30, 32)        320
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_26 (Dense)             (None, 128)               1605760
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 8)                 1032
# =================================================================
# Total params: 1,625,611
# Trainable params: 1,625,608
# Non-trainable params: 3
# _________________________________________________________________
#
#
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 100/100 [==============================] - 2s 14ms/step - loss: 1.7891 - accuracy: 0.3553 - val_loss: 1.3859 - val_accuracy: 0.5525
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 100/100 [==============================] - 1s 11ms/step - loss: 1.2229 - accuracy: 0.5822 - val_loss: 0.9825 - val_accuracy: 0.6575
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 100/100 [==============================] - 1s 11ms/step - loss: 0.9095 - accuracy: 0.6805 - val_loss: 0.7986 - val_accuracy: 0.7337
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 100/100 [==============================] - 1s 11ms/step - loss: 0.7483 - accuracy: 0.7373 - val_loss: 0.6896 - val_accuracy: 0.7663
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 100/100 [==============================] - 1s 11ms/step - loss: 0.6294 - accuracy: 0.7763 - val_loss: 0.6475 - val_accuracy: 0.7850
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0659 - accuracy: 0.9800 - val_loss: 0.7775 - val_accuracy: 0.8612
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0642 - accuracy: 0.9798 - val_loss: 0.7336 - val_accuracy: 0.8737
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0624 - accuracy: 0.9814 - val_loss: 0.6690 - val_accuracy: 0.8700
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0643 - accuracy: 0.9819 - val_loss: 0.7275 - val_accuracy: 0.8775
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0553 - accuracy: 0.9845 - val_loss: 0.7295 - val_accuracy: 0.8750
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0540 - accuracy: 0.9847 - val_loss: 0.7661 - val_accuracy: 0.8750
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.8594 - val_accuracy: 0.8700
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0481 - accuracy: 0.9858 - val_loss: 0.7897 - val_accuracy: 0.8737
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0478 - accuracy: 0.9866 - val_loss: 0.7567 - val_accuracy: 0.8737
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0496 - accuracy: 0.9825 - val_loss: 0.7481 - val_accuracy: 0.8725
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0540 - accuracy: 0.9834 - val_loss: 0.8111 - val_accuracy: 0.8625
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.8081 - val_accuracy: 0.8775
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0615 - accuracy: 0.9795 - val_loss: 0.8482 - val_accuracy: 0.8850
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0654 - accuracy: 0.9809 - val_loss: 0.7495 - val_accuracy: 0.8750
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0602 - accuracy: 0.9805 - val_loss: 0.7250 - val_accuracy: 0.8763
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0501 - accuracy: 0.9845 - val_loss: 0.7783 - val_accuracy: 0.8763
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0515 - accuracy: 0.9831 - val_loss: 0.9315 - val_accuracy: 0.8612
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0505 - accuracy: 0.9853 - val_loss: 0.8732 - val_accuracy: 0.8737
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0525 - accuracy: 0.9822 - val_loss: 0.7579 - val_accuracy: 0.8825
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0483 - accuracy: 0.9848 - val_loss: 0.7795 - val_accuracy: 0.8750
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.7544 - val_accuracy: 0.8813
#
#
# epoch 101, Learning Rate 0.0007659689172843453, Batch Size  505
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0424 - accuracy: 0.9869 - val_loss: 0.8316 - val_accuracy: 0.8813
#
#
# epoch 102, Learning Rate 0.0007623148238224963, Batch Size  510
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0528 - accuracy: 0.9847 - val_loss: 0.8458 - val_accuracy: 0.8625
#
#
# epoch 103, Learning Rate 0.0007587125119904205, Batch Size  515
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0644 - accuracy: 0.9817 - val_loss: 0.7298 - val_accuracy: 0.8813
#
#
# epoch 104, Learning Rate 0.000755160770733984, Batch Size  520
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0574 - accuracy: 0.9819 - val_loss: 0.7866 - val_accuracy: 0.8838
#
#
# epoch 105, Learning Rate 0.0007516584282688145, Batch Size  525
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0560 - accuracy: 0.9814 - val_loss: 0.7696 - val_accuracy: 0.8913
#
#
# epoch 106, Learning Rate 0.0007482043504588227, Batch Size  530
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0536 - accuracy: 0.9812 - val_loss: 0.7930 - val_accuracy: 0.8850
#
#
# epoch 107, Learning Rate 0.0007447974392757759, Batch Size  535
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0581 - accuracy: 0.9836 - val_loss: 0.7387 - val_accuracy: 0.8750
#
#
# epoch 108, Learning Rate 0.0007414366313351803, Batch Size  540
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0434 - accuracy: 0.9847 - val_loss: 0.8430 - val_accuracy: 0.8813
#
#
# epoch 109, Learning Rate 0.0007381208965040452, Batch Size  545
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0461 - accuracy: 0.9852 - val_loss: 0.8945 - val_accuracy: 0.8775
#
#
# epoch 110, Learning Rate 0.0007348492365763997, Batch Size  550
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0487 - accuracy: 0.9859 - val_loss: 0.8095 - val_accuracy: 0.8863
#
#
# epoch 111, Learning Rate 0.0007316206840126991, Batch Size  555
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0555 - accuracy: 0.9837 - val_loss: 0.7585 - val_accuracy: 0.8900
#
#
# epoch 112, Learning Rate 0.0007284343007395112, Batch Size  560
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0465 - accuracy: 0.9844 - val_loss: 0.7640 - val_accuracy: 0.8875
#
#
# epoch 113, Learning Rate 0.0007252891770061089, Batch Size  565
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0424 - accuracy: 0.9862 - val_loss: 0.8209 - val_accuracy: 0.8788
#
#
# epoch 114, Learning Rate 0.0007221844302948083, Batch Size  570
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.8189 - val_accuracy: 0.8913
#
#
# epoch 115, Learning Rate 0.0007191192042820906, Batch Size  575
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 0.8212 - val_accuracy: 0.8875
#
#
# epoch 116, Learning Rate 0.0007160926678477406, Batch Size  580
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0380 - accuracy: 0.9875 - val_loss: 0.8265 - val_accuracy: 0.8700
#
#
# epoch 117, Learning Rate 0.0007131040141293951, Batch Size  585
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0494 - accuracy: 0.9844 - val_loss: 0.8208 - val_accuracy: 0.8737
#
#
# epoch 118, Learning Rate 0.0007101524596200692, Batch Size  590
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.8754 - val_accuracy: 0.8813
#
#
# epoch 119, Learning Rate 0.0007072372433063668, Batch Size  595
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0455 - accuracy: 0.9867 - val_loss: 0.7823 - val_accuracy: 0.8888
#
#
# epoch 120, Learning Rate 0.0007043576258452291, Batch Size  600
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0491 - accuracy: 0.9853 - val_loss: 0.8372 - val_accuracy: 0.8838
#
#
# epoch 121, Learning Rate 0.0007015128887771992, Batch Size  605
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.8567 - val_accuracy: 0.8775
#
#
# epoch 122, Learning Rate 0.0006987023337743061, Batch Size  610
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.8943 - val_accuracy: 0.8838
#
#
# epoch 123, Learning Rate 0.0006959252819207823, Batch Size  615
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0445 - accuracy: 0.9866 - val_loss: 0.7855 - val_accuracy: 0.8788
#
#
# epoch 124, Learning Rate 0.0006931810730249348, Batch Size  620
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0451 - accuracy: 0.9842 - val_loss: 0.9228 - val_accuracy: 0.8813
#
#
# epoch 125, Learning Rate 0.0006904690649605871, Batch Size  625
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0397 - accuracy: 0.9883 - val_loss: 0.9292 - val_accuracy: 0.8750
#
#
# epoch 126, Learning Rate 0.000687788633036604, Batch Size  630
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0439 - accuracy: 0.9870 - val_loss: 0.8585 - val_accuracy: 0.8850
#
#
# epoch 127, Learning Rate 0.0006851391693930934, Batch Size  635
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0380 - accuracy: 0.9873 - val_loss: 0.9658 - val_accuracy: 0.8788
#
#
# epoch 128, Learning Rate 0.0006825200824229642, Batch Size  640
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0427 - accuracy: 0.9861 - val_loss: 1.0995 - val_accuracy: 0.8712
#
#
# epoch 129, Learning Rate 0.0006799307962175887, Batch Size  645
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0477 - accuracy: 0.9845 - val_loss: 0.8366 - val_accuracy: 0.8813
#
#
# epoch 130, Learning Rate 0.0006773707500353944, Batch Size  650
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0362 - accuracy: 0.9862 - val_loss: 0.9634 - val_accuracy: 0.8737
#
#
# epoch 131, Learning Rate 0.0006748393977922708, Batch Size  655
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0383 - accuracy: 0.9864 - val_loss: 0.8472 - val_accuracy: 0.8888
#
#
# epoch 132, Learning Rate 0.0006723362075727433, Batch Size  660
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0469 - accuracy: 0.9852 - val_loss: 0.9789 - val_accuracy: 0.8838
#
#
# epoch 133, Learning Rate 0.0006698606611609194, Batch Size  665
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.8251 - val_accuracy: 0.8813
#
#
# epoch 134, Learning Rate 0.0006674122535902699, Batch Size  670
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0469 - accuracy: 0.9844 - val_loss: 0.7681 - val_accuracy: 0.8863
#
#
# epoch 135, Learning Rate 0.0006649904927113595, Batch Size  675
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0522 - accuracy: 0.9844 - val_loss: 0.8476 - val_accuracy: 0.8850
#
#
# epoch 136, Learning Rate 0.0006625948987766851, Batch Size  680
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0415 - accuracy: 0.9866 - val_loss: 0.8543 - val_accuracy: 0.8825
#
#
# epoch 137, Learning Rate 0.0006602250040418284, Batch Size  685
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0373 - accuracy: 0.9881 - val_loss: 0.9577 - val_accuracy: 0.8813
#
#
# epoch 138, Learning Rate 0.0006578803523821717, Batch Size  690
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0421 - accuracy: 0.9881 - val_loss: 0.9065 - val_accuracy: 0.8913
#
#
# epoch 139, Learning Rate 0.0006555604989244632, Batch Size  695
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0429 - accuracy: 0.9878 - val_loss: 0.9683 - val_accuracy: 0.8662
#
#
# epoch 140, Learning Rate 0.0006532650096925569, Batch Size  700
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0351 - accuracy: 0.9906 - val_loss: 1.0461 - val_accuracy: 0.8800
#
#
# epoch 141, Learning Rate 0.0006509934612666877, Batch Size  705
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0374 - accuracy: 0.9889 - val_loss: 0.9996 - val_accuracy: 0.8763
#
#
# epoch 142, Learning Rate 0.0006487454404556758, Batch Size  710
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0360 - accuracy: 0.9894 - val_loss: 1.0319 - val_accuracy: 0.8750
#
#
# epoch 143, Learning Rate 0.0006465205439814815, Batch Size  715
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0341 - accuracy: 0.9903 - val_loss: 1.1082 - val_accuracy: 0.8763
#
#
# epoch 144, Learning Rate 0.0006443183781755687, Batch Size  720
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 1.2217 - val_accuracy: 0.8737
#
#
# epoch 145, Learning Rate 0.0006421385586865547, Batch Size  725
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0435 - accuracy: 0.9861 - val_loss: 1.1792 - val_accuracy: 0.8775
#
#
# epoch 146, Learning Rate 0.0006399807101986559, Batch Size  730
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 1.0038 - val_accuracy: 0.8650
#
#
# epoch 147, Learning Rate 0.0006378444661604604, Batch Size  735
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0483 - accuracy: 0.9870 - val_loss: 0.9174 - val_accuracy: 0.8687
#
#
# epoch 148, Learning Rate 0.0006357294685235842, Batch Size  740
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0518 - accuracy: 0.9825 - val_loss: 1.0077 - val_accuracy: 0.8737
#
#
# epoch 149, Learning Rate 0.0006336353674907874, Batch Size  745
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0410 - accuracy: 0.9869 - val_loss: 1.0661 - val_accuracy: 0.8700
#
#
# epoch 150, Learning Rate 0.0006315618212731474, Batch Size  750
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0487 - accuracy: 0.9867 - val_loss: 1.1676 - val_accuracy: 0.8712

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0
