# %% [markdown]
# *Save and Load results from here*

# %%
def record_Results(key,results):
  import json
  from google.colab import drive


  drive.mount('/content/drive')

  dictionary ={
      key : results
  } 
  json_object = json.dumps(dictionary)

  FILE_PATH = "/content/drive/My Drive/Results/"+"Mnist_Experiment_4A"+str(key)+".json"
  f = open(FILE_PATH, "w")
  f.write(json_object)
  print("recorded")

def Get_Results(file):
  import json
  from google.colab import drive

  drive.mount('/content/drive')

  FILE_PATH = "/content/drive/My Drive/Results/"+"Mnist_Experiment_4A"+str(file)+".json"
  f = open(FILE_PATH, "r")
  json_object = json.load(f)
  
  return json_object

# %% [markdown]
# # **BS increasing with each epoch and hence the LR**

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# **Starting GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.115046150000012
# GPU (s):
# 0.03932099099998254
# GPU speedup over CPU: 79x

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

sh = train_images.shape
sh
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
def simple_model():
  model = tf.keras.Sequential([
      tf.keras.layers.Flatten(input_shape=(28, 28)),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(10)
  ])

  model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
  
  return model

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  # plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
model = simple_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
history = model.fit(train_images, train_labels, epochs=100, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4398 - accuracy: 0.8751 - val_loss: 0.1387 - val_accuracy: 0.9603
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1271 - accuracy: 0.9634 - val_loss: 0.0980 - val_accuracy: 0.9691
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0791 - accuracy: 0.9756 - val_loss: 0.0820 - val_accuracy: 0.9730
# Epoch 4/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0601 - accuracy: 0.9807 - val_loss: 0.0877 - val_accuracy: 0.9731
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0430 - accuracy: 0.9870 - val_loss: 0.0716 - val_accuracy: 0.9781
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.0747 - val_accuracy: 0.9776
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.0825 - val_accuracy: 0.9753
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0814 - val_accuracy: 0.9766
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0764 - val_accuracy: 0.9795
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.0760 - val_accuracy: 0.9795
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0968 - val_accuracy: 0.9757
# Epoch 12/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0802 - val_accuracy: 0.9792
# Epoch 13/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0846 - val_accuracy: 0.9793
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0971 - val_accuracy: 0.9779
# Epoch 15/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1026 - val_accuracy: 0.9763
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0934 - val_accuracy: 0.9786
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0964 - val_accuracy: 0.9762
# Epoch 18/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.1133 - val_accuracy: 0.9746
# Epoch 19/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1080 - val_accuracy: 0.9780
# Epoch 20/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.1146 - val_accuracy: 0.9787
# Epoch 21/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.1274 - val_accuracy: 0.9750
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1227 - val_accuracy: 0.9759
# Epoch 23/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1151 - val_accuracy: 0.9777
# Epoch 24/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1208 - val_accuracy: 0.9774
# Epoch 25/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1174 - val_accuracy: 0.9802
# Epoch 26/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1191 - val_accuracy: 0.9785
# Epoch 27/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.1312 - val_accuracy: 0.9774
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.1168 - val_accuracy: 0.9794
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.1202 - val_accuracy: 0.9788
# Epoch 30/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1271 - val_accuracy: 0.9797
# Epoch 31/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.1342 - val_accuracy: 0.9790
# Epoch 32/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1382 - val_accuracy: 0.9783
# Epoch 33/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.1332 - val_accuracy: 0.9781
# Epoch 34/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1304 - val_accuracy: 0.9769
# Epoch 35/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.1319 - val_accuracy: 0.9797
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1530 - val_accuracy: 0.9781
# Epoch 37/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1514 - val_accuracy: 0.9776
# Epoch 38/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1414 - val_accuracy: 0.9791
# Epoch 39/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.1448 - val_accuracy: 0.9773
# Epoch 40/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1311 - val_accuracy: 0.9797
# Epoch 41/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1535 - val_accuracy: 0.9787
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1514 - val_accuracy: 0.9782
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1493 - val_accuracy: 0.9790
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1474 - val_accuracy: 0.9793
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1487 - val_accuracy: 0.9801
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1461 - val_accuracy: 0.9805
# Epoch 47/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1470 - val_accuracy: 0.9799
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.1548 - val_accuracy: 0.9783
# Epoch 49/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1550 - val_accuracy: 0.9799
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.1479 - val_accuracy: 0.9808
# Epoch 51/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1538 - val_accuracy: 0.9794
# Epoch 52/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.0359e-04 - accuracy: 0.9997 - val_loss: 0.1684 - val_accuracy: 0.9788
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1743 - val_accuracy: 0.9792
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.1532 - val_accuracy: 0.9798
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1699 - val_accuracy: 0.9798
# Epoch 56/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1900 - val_accuracy: 0.9769
# Epoch 57/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1817 - val_accuracy: 0.9782
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1811 - val_accuracy: 0.9772
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1751 - val_accuracy: 0.9788
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.1931 - val_accuracy: 0.9780
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1711 - val_accuracy: 0.9791
# Epoch 62/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1954 - val_accuracy: 0.9757
# Epoch 63/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.1664 - val_accuracy: 0.9795
# Epoch 64/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1814 - val_accuracy: 0.9793
# Epoch 65/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.2042 - val_accuracy: 0.9774
# Epoch 66/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1827 - val_accuracy: 0.9801
# Epoch 67/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1851 - val_accuracy: 0.9782
# Epoch 68/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 0.1964 - val_accuracy: 0.9788
# Epoch 69/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.2069 - val_accuracy: 0.9783
# Epoch 70/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.1933 - val_accuracy: 0.9791
# Epoch 71/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.2013 - val_accuracy: 0.9789
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1837 - val_accuracy: 0.9805
# Epoch 73/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1830 - val_accuracy: 0.9802
# Epoch 74/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1978 - val_accuracy: 0.9797
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.2112 - val_accuracy: 0.9777
# Epoch 76/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.2199 - val_accuracy: 0.9793
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1880 - val_accuracy: 0.9798
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.5712e-04 - accuracy: 0.9999 - val_loss: 0.2204 - val_accuracy: 0.9778
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.2018 - val_accuracy: 0.9785
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.2006 - val_accuracy: 0.9807
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.5078e-05 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9811
# Epoch 82/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.2012 - val_accuracy: 0.9793
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.2020 - val_accuracy: 0.9795
# Epoch 84/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 7.4069e-04 - accuracy: 0.9997 - val_loss: 0.1986 - val_accuracy: 0.9801
# Epoch 85/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.1017e-04 - accuracy: 0.9999 - val_loss: 0.2309 - val_accuracy: 0.9778
# Epoch 86/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1953 - val_accuracy: 0.9799
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2062 - val_accuracy: 0.9795
# Epoch 88/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.4617e-04 - accuracy: 0.9999 - val_loss: 0.2271 - val_accuracy: 0.9785
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2155 - val_accuracy: 0.9784
# Epoch 90/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1982 - val_accuracy: 0.9818
# Epoch 91/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.9653e-04 - accuracy: 0.9999 - val_loss: 0.2132 - val_accuracy: 0.9799
# Epoch 92/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.2268 - val_accuracy: 0.9796
# Epoch 93/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.5393e-04 - accuracy: 0.9999 - val_loss: 0.2277 - val_accuracy: 0.9792
# Epoch 94/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.2316 - val_accuracy: 0.9792
# Epoch 95/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.2343e-04 - accuracy: 0.9997 - val_loss: 0.2286 - val_accuracy: 0.9785
# Epoch 96/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.2027 - val_accuracy: 0.9802
# Epoch 97/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.0977e-04 - accuracy: 0.9998 - val_loss: 0.2158 - val_accuracy: 0.9797
# Epoch 98/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.2218 - val_accuracy: 0.9781
# Epoch 99/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.2297 - val_accuracy: 0.9793
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.2187 - val_accuracy: 0.9807

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_1",acc_1)
record_Results("val_acc_1",val_acc_1)
# Out:
# Mounted at /content/drive
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_1 = Get_Results("acc_1")["acc_1"]
val_acc_1 = Get_Results("val_acc_1")["val_acc_1"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# 313/313 - 0s - loss: 0.2187 - accuracy: 0.9807

# %% [markdown]
# **Test for LR**

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=100
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)
  


  # if (z%2 == 0):
  LR = random() * batch_size/10000
  lr.append(LR)
  # else:
  #   LR = random() * z/10000
  #   lr.append(LR)

# lr = lr[::-1] 
lord_LR = lr
# print(min(lr))


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()


# lr = []
# epoo=150
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   # print(z,(batch_size)/((z+1)**(3/2))/80)
  

#   LR = random() * z/10000
#   # LR=LR/8
#   lr.append(LR)

# plt.plot(lr, label='Learning Rate')
# plt.xlabel('Epoch')
# plt.ylabel('LR')
# plt.legend(loc='lower right')
# plt.show()

# %%
model = simple_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo),range(5,10000,5)):

  # if (z%2 == 0):
  LR = random() * batch_size/10000
  lr.append(LR)
  # else:
    # LR = random() * z/10000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.009):
      LR = 0.009
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            train_images, train_labels, 
            validation_data=(test_images, test_labels),
            epochs=epoch,
            batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# epoch 1, Learning Rate 6.350175562446336e-05, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0004366065462528211.
# 12000/12000 [==============================] - 21s 2ms/step - loss: 0.3956 - accuracy: 0.8864 - val_loss: 0.1283 - val_accuracy: 0.9603
#
#
# epoch 2, Learning Rate 0.0008333910866088531, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.567461844508492e-05.
# 6000/6000 [==============================] - 13s 2ms/step - loss: 0.0980 - accuracy: 0.9714 - val_loss: 0.1005 - val_accuracy: 0.9705
#
#
# epoch 3, Learning Rate 0.0008476872241069604, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001141772862033512.
# 4000/4000 [==============================] - 10s 2ms/step - loss: 0.1059 - accuracy: 0.9685 - val_loss: 0.0852 - val_accuracy: 0.9730
#
#
# epoch 4, Learning Rate 0.00179541646166697, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0004413191174565796.
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.0507 - accuracy: 0.9848 - val_loss: 0.0701 - val_accuracy: 0.9785
#
#
# epoch 5, Learning Rate 0.0014496670414182765, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006499084413529716.
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.0426 - accuracy: 0.9875 - val_loss: 0.0700 - val_accuracy: 0.9779
#
#
# epoch 6, Learning Rate 0.0029865058616545467, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00023046938865827683.
# 2000/2000 [==============================] - 5s 2ms/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 0.0612 - val_accuracy: 0.9809
#
#
# epoch 7, Learning Rate 0.0028564770690331074, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016052309748535085.
# 1715/1715 [==============================] - 4s 2ms/step - loss: 0.0535 - accuracy: 0.9825 - val_loss: 0.0908 - val_accuracy: 0.9734
#
#
# epoch 8, Learning Rate 0.0020873663703608715, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0019971850650199172.
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0434 - accuracy: 0.9859 - val_loss: 0.0900 - val_accuracy: 0.9753
#
#
# epoch 9, Learning Rate 0.0031046989297839177, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0043179533920405236.
# 1334/1334 [==============================] - 3s 3ms/step - loss: 0.0869 - accuracy: 0.9727 - val_loss: 0.1126 - val_accuracy: 0.9728
#
#
# epoch 10, Learning Rate 0.001994385665146589, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0004354234812167129.
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0288 - accuracy: 0.9904 - val_loss: 0.0698 - val_accuracy: 0.9813
#
#
# epoch 11, Learning Rate 0.00270182791649296, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005063067743210206.
# 1091/1091 [==============================] - 3s 3ms/step - loss: 0.0788 - accuracy: 0.9761 - val_loss: 0.1226 - val_accuracy: 0.9714
#
#
# epoch 12, Learning Rate 0.0026078303741196903, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005956162014709905.
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0694 - accuracy: 0.9795 - val_loss: 0.1311 - val_accuracy: 0.9709
#
#
# epoch 13, Learning Rate 0.00400826944031877, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004320232550017504.
# 924/924 [==============================] - 2s 3ms/step - loss: 0.0366 - accuracy: 0.9885 - val_loss: 0.1030 - val_accuracy: 0.9745
#
#
# epoch 14, Learning Rate 0.00410346503987024, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010048244101190204.
# 858/858 [==============================] - 2s 3ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0760 - val_accuracy: 0.9814
#
#
# epoch 15, Learning Rate 0.0001732468206200424, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004883687910102718.
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0391 - accuracy: 0.9882 - val_loss: 0.1407 - val_accuracy: 0.9724
#
#
# epoch 16, Learning Rate 0.0010733330925694888, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007396093913164942.
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0795 - accuracy: 0.9790 - val_loss: 0.1663 - val_accuracy: 0.9667
#
#
# epoch 17, Learning Rate 0.0059213925726660345, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00786003691084402.
# 706/706 [==============================] - 2s 3ms/step - loss: 0.0583 - accuracy: 0.9838 - val_loss: 0.1581 - val_accuracy: 0.9697
#
#
# epoch 18, Learning Rate 0.008088220191909197, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007705388908638133.
# 667/667 [==============================] - 2s 3ms/step - loss: 0.0483 - accuracy: 0.9869 - val_loss: 0.1549 - val_accuracy: 0.9731
#
#
# epoch 19, Learning Rate 0.003659588832808685, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023872525228727914.
# 632/632 [==============================] - 2s 3ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.1157 - val_accuracy: 0.9786
#
#
# epoch 20, Learning Rate 0.00475804218771938, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004886438522214273.
# 600/600 [==============================] - 2s 3ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.1390 - val_accuracy: 0.9777
#
#
# epoch 21, Learning Rate 0.007075021657261169, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014162638599294827.
# 572/572 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.1189 - val_accuracy: 0.9817
#
#
# epoch 22, Learning Rate 0.009733664792760994, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.006489144578993754.
# 546/546 [==============================] - 2s 3ms/step - loss: 0.0343 - accuracy: 0.9910 - val_loss: 0.1922 - val_accuracy: 0.9707
#
#
# epoch 23, Learning Rate 0.0040652032184106965, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008712598509078436.
# 522/522 [==============================] - 2s 3ms/step - loss: 0.0823 - accuracy: 0.9819 - val_loss: 0.1932 - val_accuracy: 0.9706
#
#
# epoch 24, Learning Rate 0.011866253752129595, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007023382705173144.
# 500/500 [==============================] - 1s 3ms/step - loss: 0.0299 - accuracy: 0.9915 - val_loss: 0.1699 - val_accuracy: 0.9752
#
#
# epoch 25, Learning Rate 0.004246870595258634, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 480/480 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9890 - val_loss: 0.2158 - val_accuracy: 0.9726
#
#
# epoch 26, Learning Rate 0.0023094644561220466, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007545407518929038.
# 462/462 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9933 - val_loss: 0.1787 - val_accuracy: 0.9759
#
#
# epoch 27, Learning Rate 0.0057135103607894, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 445/445 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.9929 - val_loss: 0.1976 - val_accuracy: 0.9746
#
#
# epoch 28, Learning Rate 0.0014720951279264894, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007675249267310553.
# 429/429 [==============================] - 1s 3ms/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 0.1973 - val_accuracy: 0.9762
#
#
# epoch 29, Learning Rate 0.010081122510701567, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004844255768665469.
# 414/414 [==============================] - 1s 3ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.1882 - val_accuracy: 0.9781
#
#
# epoch 30, Learning Rate 0.009333527188418117, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0196 - accuracy: 0.9952 - val_loss: 0.2455 - val_accuracy: 0.9714
#
#
# epoch 31, Learning Rate 0.012914921703323, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 388/388 [==============================] - 1s 3ms/step - loss: 0.0463 - accuracy: 0.9900 - val_loss: 0.2612 - val_accuracy: 0.9721
#
#
# epoch 32, Learning Rate 0.012945584267200806, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0387 - accuracy: 0.9921 - val_loss: 0.2442 - val_accuracy: 0.9763
#
#
# epoch 33, Learning Rate 0.014417258396087212, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016089935532267083.
# 364/364 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.2034 - val_accuracy: 0.9788
#
#
# epoch 34, Learning Rate 0.006444548022737143, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 353/353 [==============================] - 1s 3ms/step - loss: 0.0150 - accuracy: 0.9964 - val_loss: 0.2530 - val_accuracy: 0.9747
#
#
# epoch 35, Learning Rate 0.009641131959575205, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00284131201006696.
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.2126 - val_accuracy: 0.9799
#
#
# epoch 36, Learning Rate 0.004000676405121374, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008932029569103548.
# 334/334 [==============================] - 1s 3ms/step - loss: 8.1572e-04 - accuracy: 0.9998 - val_loss: 0.2091 - val_accuracy: 0.9800
#
#
# epoch 37, Learning Rate 0.008779277366891311, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0172 - accuracy: 0.9961 - val_loss: 0.3126 - val_accuracy: 0.9680
#
#
# epoch 38, Learning Rate 0.002265077604322924, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0584 - accuracy: 0.9894 - val_loss: 0.2813 - val_accuracy: 0.9737
#
#
# epoch 39, Learning Rate 0.00713512350436498, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001618290331871646.
# 308/308 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 0.2370 - val_accuracy: 0.9780
#
#
# epoch 40, Learning Rate 0.003738141651347833, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9960 - val_loss: 0.2929 - val_accuracy: 0.9735
#
#
# epoch 41, Learning Rate 0.003089693322861017, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 293/293 [==============================] - 1s 3ms/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 0.2932 - val_accuracy: 0.9743
#
#
# epoch 42, Learning Rate 0.009146838897396927, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007331495004795876.
# 286/286 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.2756 - val_accuracy: 0.9790
#
#
# epoch 43, Learning Rate 0.015631951048768043, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 280/280 [==============================] - 1s 3ms/step - loss: 0.0145 - accuracy: 0.9966 - val_loss: 0.2904 - val_accuracy: 0.9760
#
#
# epoch 44, Learning Rate 0.018295338646595462, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 273/273 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 0.9955 - val_loss: 0.3492 - val_accuracy: 0.9733
#
#
# epoch 45, Learning Rate 0.020124881485900113, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00858065456223552.
# 267/267 [==============================] - 1s 3ms/step - loss: 0.0150 - accuracy: 0.9965 - val_loss: 0.3456 - val_accuracy: 0.9767
#
#
# epoch 46, Learning Rate 0.01757934238756882, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 261/261 [==============================] - 1s 3ms/step - loss: 0.0212 - accuracy: 0.9959 - val_loss: 0.2992 - val_accuracy: 0.9778
#
#
# epoch 47, Learning Rate 0.011955000676069952, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00726070422105103.
# 256/256 [==============================] - 1s 3ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.3073 - val_accuracy: 0.9767
#
#
# epoch 48, Learning Rate 0.002331835308539018, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00834311831319405.
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.3089 - val_accuracy: 0.9769
#
#
# epoch 49, Learning Rate 0.008107636172393722, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005913187558414218.
# 245/245 [==============================] - 1s 3ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.3007 - val_accuracy: 0.9781
#
#
# epoch 50, Learning Rate 0.021703013739081754, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 240/240 [==============================] - 1s 3ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.3124 - val_accuracy: 0.9783
#
#
# epoch 51, Learning Rate 0.006550223634552294, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005109241686143961.
# 236/236 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.2903 - val_accuracy: 0.9798
#
#
# epoch 52, Learning Rate 0.006523884197526061, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004141311183238506.
# 231/231 [==============================] - 1s 4ms/step - loss: 4.1676e-04 - accuracy: 0.9998 - val_loss: 0.2887 - val_accuracy: 0.9805
#
#
# epoch 53, Learning Rate 0.0152668326096048, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 227/227 [==============================] - 1s 3ms/step - loss: 6.5846e-04 - accuracy: 0.9999 - val_loss: 0.2965 - val_accuracy: 0.9800
#
#
# epoch 54, Learning Rate 0.009632414172812302, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002135102795340451.
# 223/223 [==============================] - 1s 3ms/step - loss: 3.4162e-04 - accuracy: 0.9999 - val_loss: 0.2834 - val_accuracy: 0.9805
#
#
# epoch 55, Learning Rate 0.020684161943519144, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 219/219 [==============================] - 1s 3ms/step - loss: 2.3007e-05 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9803
#
#
# epoch 56, Learning Rate 0.013610177735508017, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 215/215 [==============================] - 1s 4ms/step - loss: 8.6523e-06 - accuracy: 1.0000 - val_loss: 0.2815 - val_accuracy: 0.9803
#
#
# epoch 57, Learning Rate 0.002453778508109677, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 211/211 [==============================] - 1s 3ms/step - loss: 6.8702e-06 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9806
#
#
# epoch 58, Learning Rate 0.019083202963853678, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 207/207 [==============================] - 1s 4ms/step - loss: 5.8774e-06 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9807
#
#
# epoch 59, Learning Rate 0.01621995953137172, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005457149817655302.
# 204/204 [==============================] - 1s 3ms/step - loss: 5.1650e-06 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9807
#
#
# epoch 60, Learning Rate 0.026147545507157564, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 200/200 [==============================] - 1s 4ms/step - loss: 4.8261e-06 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9808
#
#
# epoch 61, Learning Rate 0.006464064026889493, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013587002816803273.
# 197/197 [==============================] - 1s 4ms/step - loss: 4.2970e-06 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9808
#
#
# epoch 62, Learning Rate 0.0076332276984954804, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 194/194 [==============================] - 1s 4ms/step - loss: 4.2947e-06 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.9808
#
#
# epoch 63, Learning Rate 0.011643448708730773, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 191/191 [==============================] - 1s 4ms/step - loss: 3.8862e-06 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9808
#
#
# epoch 64, Learning Rate 0.010393022862697901, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0042158688527275355.
# 188/188 [==============================] - 1s 3ms/step - loss: 3.4931e-06 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9808
#
#
# epoch 65, Learning Rate 0.01669426093228078, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0021835897669412268.
# 185/185 [==============================] - 1s 4ms/step - loss: 3.3328e-06 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9807
#
#
# epoch 66, Learning Rate 0.005752973324133924, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008692291465896389.
# 182/182 [==============================] - 1s 4ms/step - loss: 3.2999e-06 - accuracy: 1.0000 - val_loss: 0.2813 - val_accuracy: 0.9807
#
#
# epoch 67, Learning Rate 0.031920116618325056, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 180/180 [==============================] - 1s 4ms/step - loss: 3.0514e-06 - accuracy: 1.0000 - val_loss: 0.2816 - val_accuracy: 0.9807
#
#
# epoch 68, Learning Rate 0.03127341883523728, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 177/177 [==============================] - 1s 3ms/step - loss: 2.7766e-06 - accuracy: 1.0000 - val_loss: 0.2817 - val_accuracy: 0.9807
#
#
# epoch 69, Learning Rate 0.018710816197968314, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00824755530006763.
# 174/174 [==============================] - 1s 3ms/step - loss: 2.5381e-06 - accuracy: 1.0000 - val_loss: 0.2818 - val_accuracy: 0.9808
#
#
# epoch 70, Learning Rate 0.026957801564158224, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 172/172 [==============================] - 1s 4ms/step - loss: 2.3702e-06 - accuracy: 1.0000 - val_loss: 0.2821 - val_accuracy: 0.9806
#
#
# epoch 71, Learning Rate 0.02009124942844652, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 170/170 [==============================] - 1s 4ms/step - loss: 2.2026e-06 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9806
#
#
# epoch 72, Learning Rate 0.008226943630966103, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 167/167 [==============================] - 1s 4ms/step - loss: 2.0571e-06 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9807
#
#
# epoch 73, Learning Rate 0.017908215673189128, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004210988699034283.
# 165/165 [==============================] - 1s 4ms/step - loss: 1.8796e-06 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9807
#
#
# epoch 74, Learning Rate 0.019957595948501404, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 163/163 [==============================] - 1s 4ms/step - loss: 1.8394e-06 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9807
#
#
# epoch 75, Learning Rate 0.009165957499094338, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 160/160 [==============================] - 1s 4ms/step - loss: 1.7074e-06 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9808
#
#
# epoch 76, Learning Rate 0.03234679941896481, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0004676446783133327.
# 158/158 [==============================] - 1s 4ms/step - loss: 1.5616e-06 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9808
#
#
# epoch 77, Learning Rate 0.00799110201122006, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00308982229401863.
# 156/156 [==============================] - 1s 4ms/step - loss: 1.5637e-06 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9808
#
#
# epoch 78, Learning Rate 0.037577354526166264, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 154/154 [==============================] - 1s 4ms/step - loss: 1.5362e-06 - accuracy: 1.0000 - val_loss: 0.2837 - val_accuracy: 0.9808
#
#
# epoch 79, Learning Rate 0.025236764510346406, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001841971030567403.
# 152/152 [==============================] - 1s 4ms/step - loss: 1.4034e-06 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9808
#
#
# epoch 80, Learning Rate 0.026962093474453677, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 150/150 [==============================] - 1s 4ms/step - loss: 1.4135e-06 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9809
#
#
# epoch 81, Learning Rate 0.03696709335029036, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 149/149 [==============================] - 1s 4ms/step - loss: 1.3073e-06 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9808
#
#
# epoch 82, Learning Rate 0.039571371679396304, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 147/147 [==============================] - 1s 4ms/step - loss: 1.2013e-06 - accuracy: 1.0000 - val_loss: 0.2847 - val_accuracy: 0.9806
#
#
# epoch 83, Learning Rate 0.0053877692793483445, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 145/145 [==============================] - 1s 4ms/step - loss: 1.0850e-06 - accuracy: 1.0000 - val_loss: 0.2850 - val_accuracy: 0.9806
#
#
# epoch 84, Learning Rate 0.020367603315975414, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 143/143 [==============================] - 1s 4ms/step - loss: 9.9557e-07 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9806
#
#
# epoch 85, Learning Rate 0.025202354757172366, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 142/142 [==============================] - 1s 4ms/step - loss: 9.2848e-07 - accuracy: 1.0000 - val_loss: 0.2855 - val_accuracy: 0.9806
#
#
# epoch 86, Learning Rate 0.02294099957791266, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 140/140 [==============================] - 1s 4ms/step - loss: 8.6632e-07 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9806
#
#
# epoch 87, Learning Rate 0.036356431360023006, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 138/138 [==============================] - 1s 4ms/step - loss: 8.0938e-07 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9806
#
#
# epoch 88, Learning Rate 0.003140537598871454, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 137/137 [==============================] - 1s 4ms/step - loss: 7.6049e-07 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9806
#
#
# epoch 89, Learning Rate 0.018181901735004037, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 135/135 [==============================] - 1s 4ms/step - loss: 7.1419e-07 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9806
#
#
# epoch 90, Learning Rate 0.039162011908652324, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 134/134 [==============================] - 1s 4ms/step - loss: 6.7527e-07 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9806
#
#
# epoch 91, Learning Rate 0.019100586641280577, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 132/132 [==============================] - 1s 4ms/step - loss: 6.3700e-07 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9806
#
#
# epoch 92, Learning Rate 0.03532130684037182, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 131/131 [==============================] - 1s 4ms/step - loss: 6.0024e-07 - accuracy: 1.0000 - val_loss: 0.2868 - val_accuracy: 0.9805
#
#
# epoch 93, Learning Rate 0.040958102501913674, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 130/130 [==============================] - 1s 4ms/step - loss: 5.6807e-07 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9805
#
#
# epoch 94, Learning Rate 0.01703760975428653, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 128/128 [==============================] - 1s 4ms/step - loss: 5.3819e-07 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9805
#
#
# epoch 95, Learning Rate 0.02992141423240796, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 127/127 [==============================] - 1s 4ms/step - loss: 5.0981e-07 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9806
#
#
# epoch 96, Learning Rate 0.0053114723325140235, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 125/125 [==============================] - 1s 4ms/step - loss: 4.8386e-07 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9806
#
#
# epoch 97, Learning Rate 0.0011349932493685145, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 124/124 [==============================] - 1s 4ms/step - loss: 4.5880e-07 - accuracy: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9807
#
#
# epoch 98, Learning Rate 0.013899488760806556, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0051326855608016305.
# 123/123 [==============================] - 0s 4ms/step - loss: 4.3384e-07 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.9807
#
#
# epoch 99, Learning Rate 0.008513005882886159, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002983678606606399.
# 122/122 [==============================] - 1s 4ms/step - loss: 4.2011e-07 - accuracy: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.9808

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_2",acc_2)
record_Results("val_acc_2",val_acc_2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_2 = Get_Results("acc_2")["acc_2"]
val_acc_2 = Get_Results("val_acc_2")["val_acc_2"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
model = simple_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
# epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            train_images, train_labels, 
            validation_data=(test_images, test_labels),
            epochs=epoch,
            # batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002762135864009951.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3421 - accuracy: 0.8995 - val_loss: 0.1247 - val_accuracy: 0.9616
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003007032652029301.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1026 - accuracy: 0.9687 - val_loss: 0.0860 - val_accuracy: 0.9720
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0029296875.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0726 - accuracy: 0.9768 - val_loss: 0.1095 - val_accuracy: 0.9686
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002795084971874737.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0570 - accuracy: 0.9815 - val_loss: 0.0819 - val_accuracy: 0.9770
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0026578664743741078.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0452 - accuracy: 0.9851 - val_loss: 0.0857 - val_accuracy: 0.9745
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0025310120960439324.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0367 - accuracy: 0.9883 - val_loss: 0.0960 - val_accuracy: 0.9759
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0024168688810087074.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0298 - accuracy: 0.9902 - val_loss: 0.0951 - val_accuracy: 0.9780
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023148148148148147.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0236 - accuracy: 0.9919 - val_loss: 0.1064 - val_accuracy: 0.9746
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002223476479805892.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.0926 - val_accuracy: 0.9783
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0021414157995579804.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.1041 - val_accuracy: 0.9785
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0020673349482701444.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.1167 - val_accuracy: 0.9773
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0020001208998505857.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0962 - val_accuracy: 0.9784
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0019388371344093286.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.1201 - val_accuracy: 0.9780
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0018827002377397163.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.1077 - val_accuracy: 0.9817
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0018310546875.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.1100 - val_accuracy: 0.9795
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0017833501840906836.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.1310 - val_accuracy: 0.9782
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0017391225810433025.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.1392 - val_accuracy: 0.9791
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016979782934498815.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.1322 - val_accuracy: 0.9799
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016595817020506251.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.1355 - val_accuracy: 0.9791
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016236450166368479.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.1544 - val_accuracy: 0.9783
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0015899201148678337.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.1383 - val_accuracy: 0.9801
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001558191952872162.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.1362 - val_accuracy: 0.9820
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001528273222765112.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.1396 - val_accuracy: 0.9807
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0015.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.1336 - val_accuracy: 0.9821
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014732281786221757.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.1527 - val_accuracy: 0.9816
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014478305361622559.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1590 - val_accuracy: 0.9807
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014236943040247117.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1487 - val_accuracy: 0.9815
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014007191457320722.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1423 - val_accuracy: 0.9818
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013788154659418242.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.1689 - val_accuracy: 0.9791
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013579029891137217.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1501 - val_accuracy: 0.9818
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00133790955912982.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1600 - val_accuracy: 0.9811
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013187701208764986.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1570 - val_accuracy: 0.9801
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013004258524133253.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.1819 - val_accuracy: 0.9793
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001282823422355784.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1731 - val_accuracy: 0.9806
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0012659143518518518.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1735 - val_accuracy: 0.9794
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0012496544643143715.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1689 - val_accuracy: 0.9802
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0012340034090950276.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1674 - val_accuracy: 0.9804
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0012189242477150062.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.4810e-04 - accuracy: 0.9998 - val_loss: 0.1680 - val_accuracy: 0.9820
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0012043830932281915.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1839 - val_accuracy: 0.9801
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011903487948826683.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1792 - val_accuracy: 0.9804
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011767926615412515.
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1686 - val_accuracy: 0.9825
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011636882183810675.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1763 - val_accuracy: 0.9818
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011510109922624144.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.5172e-04 - accuracy: 0.9998 - val_loss: 0.1928 - val_accuracy: 0.9816
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011387383218748929.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1843 - val_accuracy: 0.9818
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011268491893631745.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.4760e-04 - accuracy: 0.9999 - val_loss: 0.1801 - val_accuracy: 0.9818
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001115324070628848.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.8772e-05 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9825
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001104144801917009.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.2520e-06 - accuracy: 1.0000 - val_loss: 0.1704 - val_accuracy: 0.9829
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010932944606413995.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.1840e-06 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9830
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010827572586919007.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.1445e-06 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9834
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00107251844671263.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.1540e-06 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9828
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010625642280456236.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1778 - val_accuracy: 0.9824
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00105288168121047.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.2922e-04 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9827
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010434586899394646.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.2043 - val_accuracy: 0.9807
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010342838799152008.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.8024e-04 - accuracy: 0.9998 - val_loss: 0.2013 - val_accuracy: 0.9822
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001025346561466472.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.6964e-04 - accuracy: 0.9998 - val_loss: 0.2001 - val_accuracy: 0.9809
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010166366775718537.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1821 - val_accuracy: 0.9826
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010081447566007793.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3522e-04 - accuracy: 1.0000 - val_loss: 0.1812 - val_accuracy: 0.9821
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009998618692912851.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.3888e-04 - accuracy: 0.9997 - val_loss: 0.1817 - val_accuracy: 0.9832
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009917795895236007.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.6095e-05 - accuracy: 1.0000 - val_loss: 0.1753 - val_accuracy: 0.9835
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009838899585007375.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.5955e-06 - accuracy: 1.0000 - val_loss: 0.1778 - val_accuracy: 0.9830
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009761854519923916.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.9712e-06 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9833
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009686589503378012.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3280e-06 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9827
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009613037109375.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0095e-06 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9827
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009541133429939111.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.3301e-04 - accuracy: 0.9998 - val_loss: 0.2358 - val_accuracy: 0.9789
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009470817842870061.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.2047 - val_accuracy: 0.9807
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009402032797943266.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.5302e-04 - accuracy: 0.9999 - val_loss: 0.1945 - val_accuracy: 0.9818
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009334723619849673.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.2421e-06 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9820
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009268838326349984.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2100e-06 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9821
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009204327460276023.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3201e-06 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9821
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009141143934151601.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.3467e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9821
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009079242886329006.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.2269e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9824
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009018581547647048.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.2017 - val_accuracy: 0.9813
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008959119117714114.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.4440e-04 - accuracy: 0.9998 - val_loss: 0.2062 - val_accuracy: 0.9814
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000890081665000673.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.6864e-06 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9818
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008843636945051466.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.9238e-06 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9823
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008787544451027277.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.1117e-06 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9823
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008732505171187287.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.7971e-07 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9825
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008678486577554378.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.2295e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9827
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008625457530394697.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.8073e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9828
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008573388203017832.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.2205 - val_accuracy: 0.9811
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008522250011492539.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.0085e-04 - accuracy: 1.0000 - val_loss: 0.2195 - val_accuracy: 0.9814
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008472015548903057.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.3303e-06 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9829
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008422658523803649.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.1233e-06 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9826
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008374153702558418.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.1029e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9823
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008326476855280037.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 4.0006e-07 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9824
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008279604705105097.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.6012e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9822
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008233514880565567.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.8170e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9828
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008188185870835646.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3071e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9825
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008143596983651208.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.8314e-04 - accuracy: 0.9997 - val_loss: 0.2028 - val_accuracy: 0.9815
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008099728305715373.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.9858e-05 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9820
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008056560665418565.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.9680e-05 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9810
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000801407559771498.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6964e-05 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9819
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007972255311009624.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.4756e-07 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9820
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007931082655921421.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.3855e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9819
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007890541095798133.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.0815e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9821
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007850614678868189.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3264e-07 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9822
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007811288011923186.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 8.6762e-08 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9820
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007772546235432669.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.8828e-08 - accuracy: 1.0000 - val_loss: 0.2176 - val_accuracy: 0.9820
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007734375.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.8286e-08 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 0.9822
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0007696760444074793.
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.6010e-04 - accuracy: 0.9998 - val_loss: 0.2493 - val_accuracy: 0.9808

# %%
acc_3 = acc
val_acc_3 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_3",acc_3)
record_Results("val_acc_3",val_acc_3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_3 = Get_Results("acc_3")["acc_3"]
val_acc_3 = Get_Results("val_acc_3")["val_acc_3"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **LR constant**

# %%
model = simple_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            train_images, train_labels, 
            validation_data=(test_images, test_labels),
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 12000/12000 [==============================] - 21s 2ms/step - loss: 0.3201 - accuracy: 0.9069 - val_loss: 0.1205 - val_accuracy: 0.9634
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 6000/6000 [==============================] - 13s 2ms/step - loss: 0.0779 - accuracy: 0.9765 - val_loss: 0.0719 - val_accuracy: 0.9774
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 4000/4000 [==============================] - 10s 2ms/step - loss: 0.0506 - accuracy: 0.9843 - val_loss: 0.0708 - val_accuracy: 0.9786
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 3000/3000 [==============================] - 7s 2ms/step - loss: 0.0341 - accuracy: 0.9899 - val_loss: 0.0673 - val_accuracy: 0.9809
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 2400/2400 [==============================] - 6s 3ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.0736 - val_accuracy: 0.9781
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0170 - accuracy: 0.9955 - val_loss: 0.0703 - val_accuracy: 0.9806
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
# 1715/1715 [==============================] - 4s 3ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0676 - val_accuracy: 0.9812
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0091 - accuracy: 0.9978 - val_loss: 0.0721 - val_accuracy: 0.9817
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
# 1334/1334 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0734 - val_accuracy: 0.9822
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.0784 - val_accuracy: 0.9812
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
# 1091/1091 [==============================] - 3s 3ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0746 - val_accuracy: 0.9830
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.0815 - val_accuracy: 0.9817
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
# 924/924 [==============================] - 2s 3ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0871 - val_accuracy: 0.9806
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
# 858/858 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0918 - val_accuracy: 0.9804
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
# 800/800 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0853 - val_accuracy: 0.9825
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
# 750/750 [==============================] - 2s 3ms/step - loss: 6.6358e-04 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9836
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
# 706/706 [==============================] - 2s 3ms/step - loss: 4.6056e-04 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9831
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
# 667/667 [==============================] - 2s 3ms/step - loss: 3.5778e-04 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9835
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
# 632/632 [==============================] - 2s 3ms/step - loss: 3.4323e-04 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9834
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
# 600/600 [==============================] - 2s 3ms/step - loss: 6.8299e-04 - accuracy: 0.9999 - val_loss: 0.0982 - val_accuracy: 0.9811
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
# 572/572 [==============================] - 2s 3ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0918 - val_accuracy: 0.9813
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
# 546/546 [==============================] - 2s 3ms/step - loss: 6.0547e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9819
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
# 522/522 [==============================] - 1s 3ms/step - loss: 2.6043e-04 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9825
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
# 500/500 [==============================] - 1s 3ms/step - loss: 1.9093e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9826
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
# 480/480 [==============================] - 1s 3ms/step - loss: 1.6268e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9822
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
# 462/462 [==============================] - 1s 3ms/step - loss: 1.4248e-04 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9827
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
# 445/445 [==============================] - 1s 3ms/step - loss: 1.2664e-04 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9828
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
# 429/429 [==============================] - 1s 3ms/step - loss: 1.1184e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9826
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
# 414/414 [==============================] - 1s 3ms/step - loss: 1.0120e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9832
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
# 400/400 [==============================] - 1s 3ms/step - loss: 9.2667e-05 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9827
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
# 388/388 [==============================] - 1s 3ms/step - loss: 8.3141e-05 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9828
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
# 375/375 [==============================] - 1s 3ms/step - loss: 8.5945e-05 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9827
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
# 364/364 [==============================] - 1s 3ms/step - loss: 6.5460e-05 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9827
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
# 353/353 [==============================] - 1s 3ms/step - loss: 5.7448e-05 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9829
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
# 343/343 [==============================] - 1s 3ms/step - loss: 5.0928e-05 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9826
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
# 334/334 [==============================] - 1s 3ms/step - loss: 4.5422e-05 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9827
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
# 325/325 [==============================] - 1s 3ms/step - loss: 4.0523e-05 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9831
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
# 316/316 [==============================] - 1s 3ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.1107 - val_accuracy: 0.9807
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
# 308/308 [==============================] - 1s 3ms/step - loss: 9.5879e-04 - accuracy: 0.9998 - val_loss: 0.1058 - val_accuracy: 0.9819
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
# 300/300 [==============================] - 1s 3ms/step - loss: 1.4480e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9830
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
# 293/293 [==============================] - 1s 3ms/step - loss: 8.9966e-05 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9826
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
# 286/286 [==============================] - 1s 3ms/step - loss: 7.4724e-05 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9826
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
# 280/280 [==============================] - 1s 3ms/step - loss: 6.5748e-05 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9829
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
# 273/273 [==============================] - 1s 3ms/step - loss: 5.9146e-05 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9828
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
# 267/267 [==============================] - 1s 3ms/step - loss: 5.4044e-05 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9828
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
# 261/261 [==============================] - 1s 3ms/step - loss: 4.9750e-05 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9827
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
# 256/256 [==============================] - 1s 3ms/step - loss: 4.6027e-05 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9828
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
# 250/250 [==============================] - 1s 3ms/step - loss: 4.2841e-05 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9829
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
# 245/245 [==============================] - 1s 3ms/step - loss: 3.9970e-05 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9829
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
# 240/240 [==============================] - 1s 3ms/step - loss: 3.7393e-05 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9827
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
# 236/236 [==============================] - 1s 3ms/step - loss: 3.5124e-05 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9825
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
# 231/231 [==============================] - 1s 4ms/step - loss: 3.2951e-05 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9824
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
# 227/227 [==============================] - 1s 3ms/step - loss: 3.1024e-05 - accuracy: 1.0000 - val_loss: 0.1068 - val_accuracy: 0.9824
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
# 223/223 [==============================] - 1s 3ms/step - loss: 2.9185e-05 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9826
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
# 219/219 [==============================] - 1s 3ms/step - loss: 2.7575e-05 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9826
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
# 215/215 [==============================] - 1s 3ms/step - loss: 2.6193e-05 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9827
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
# 211/211 [==============================] - 1s 3ms/step - loss: 2.4660e-05 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9826
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
# 207/207 [==============================] - 1s 4ms/step - loss: 2.3422e-05 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9824
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
# 204/204 [==============================] - 1s 3ms/step - loss: 2.1979e-05 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9824
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
# 200/200 [==============================] - 1s 4ms/step - loss: 2.0839e-05 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9825
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
# 197/197 [==============================] - 1s 4ms/step - loss: 1.9781e-05 - accuracy: 1.0000 - val_loss: 0.1090 - val_accuracy: 0.9827
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
# 194/194 [==============================] - 1s 4ms/step - loss: 1.8759e-05 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9823
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
# 191/191 [==============================] - 1s 3ms/step - loss: 1.7745e-05 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9825
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
# 188/188 [==============================] - 1s 3ms/step - loss: 1.6829e-05 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9826
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
# 185/185 [==============================] - 1s 4ms/step - loss: 1.5898e-05 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9826
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
# 182/182 [==============================] - 1s 4ms/step - loss: 1.4993e-05 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9826
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
# 180/180 [==============================] - 1s 4ms/step - loss: 1.4279e-05 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9825
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
# 177/177 [==============================] - 1s 4ms/step - loss: 1.3491e-05 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9825
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
# 174/174 [==============================] - 1s 4ms/step - loss: 1.2771e-05 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9825
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
# 172/172 [==============================] - 1s 4ms/step - loss: 1.2089e-05 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9826
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
# 170/170 [==============================] - 1s 4ms/step - loss: 1.1398e-05 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9828
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
# 167/167 [==============================] - 1s 4ms/step - loss: 1.0887e-05 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9825
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
# 165/165 [==============================] - 1s 4ms/step - loss: 1.0288e-05 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9825
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
# 163/163 [==============================] - 1s 4ms/step - loss: 9.7350e-06 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9824
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
# 160/160 [==============================] - 1s 4ms/step - loss: 9.1456e-06 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9823
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
# 158/158 [==============================] - 1s 4ms/step - loss: 8.6960e-06 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9822
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
# 156/156 [==============================] - 1s 4ms/step - loss: 8.2128e-06 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9828
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
# 154/154 [==============================] - 1s 5ms/step - loss: 7.7825e-06 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9825
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 152/152 [==============================] - 1s 4ms/step - loss: 7.3453e-06 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9825
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 150/150 [==============================] - 1s 4ms/step - loss: 6.9666e-06 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9825
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 149/149 [==============================] - 1s 4ms/step - loss: 6.5746e-06 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9825
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 147/147 [==============================] - 1s 4ms/step - loss: 6.2220e-06 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9825
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 145/145 [==============================] - 1s 4ms/step - loss: 5.8979e-06 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9829
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 143/143 [==============================] - 1s 4ms/step - loss: 5.5252e-06 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9824
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 142/142 [==============================] - 1s 4ms/step - loss: 5.2640e-06 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9828
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 140/140 [==============================] - 1s 4ms/step - loss: 4.9787e-06 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9825
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 138/138 [==============================] - 1s 4ms/step - loss: 4.7097e-06 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9828
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 137/137 [==============================] - 1s 4ms/step - loss: 4.4583e-06 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9828
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 135/135 [==============================] - 1s 4ms/step - loss: 4.2447e-06 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9825
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 134/134 [==============================] - 1s 4ms/step - loss: 4.0045e-06 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9828
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 132/132 [==============================] - 1s 4ms/step - loss: 3.7638e-06 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9829
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 131/131 [==============================] - 0s 4ms/step - loss: 3.5609e-06 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9827
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 130/130 [==============================] - 1s 4ms/step - loss: 3.3689e-06 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9827
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 128/128 [==============================] - 0s 4ms/step - loss: 3.3379e-06 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9826
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 127/127 [==============================] - 1s 4ms/step - loss: 3.0409e-06 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9829
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 125/125 [==============================] - 0s 4ms/step - loss: 2.8851e-06 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9828
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 124/124 [==============================] - 0s 4ms/step - loss: 2.7274e-06 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9828
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 123/123 [==============================] - 1s 4ms/step - loss: 2.5708e-06 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9826
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 122/122 [==============================] - 0s 4ms/step - loss: 2.4427e-06 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9828
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 120/120 [==============================] - 0s 4ms/step - loss: 2.3165e-06 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9826

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_4",acc_4)
record_Results("val_acc_4",val_acc_4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_4 = Get_Results("acc_4")["acc_4"]
val_acc_4 = Get_Results("val_acc_4")["val_acc_4"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
acc_1_dif = []
for i in range(len(acc_1)): acc_1_dif.append(acc_1[i] - val_acc_1[i]) 
acc_2_dif = []
for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0]) 
acc_3_dif = []
for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0]) 
acc_4_dif = []
for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
# plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
# plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3_dif, label='BS = const acc',ls='-.',c='g')
# plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4_dif, label='LR = const acc',ls='-.',c='y')
# plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
