# %% [markdown]
# *Save and Load results from here*

# %%
def record_Results(key,results):
  import json
  from google.colab import drive


  drive.mount('/content/drive')

  dictionary ={
      key : results
  } 
  json_object = json.dumps(dictionary)

  FILE_PATH = "/content/drive/My Drive/Results/"+"Cats_vs_Dogs_Experiment_4A"+str(key)+".json"
  f = open(FILE_PATH, "w")
  f.write(json_object)
  print("recorded")

def Get_Results(file):
  import json
  from google.colab import drive

  drive.mount('/content/drive')

  FILE_PATH = "/content/drive/My Drive/Results/"+"Cats_vs_Dogs_Experiment_4A"+str(file)+".json"
  f = open(FILE_PATH, "r")
  json_object = json.load(f)
  
  return json_object

# %% [markdown]
# # **BS increasing with each epoch and hence the LR**

# %% [markdown]
# **STARTING GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.5450917860000004
# GPU (s):
# 0.050656844000002366
# GPU speedup over CPU: 69x

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-05-07 05:08:33--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.167.128, 74.125.71.128, 64.233.184.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.167.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  31.2MB/s    in 2.1s
#
# 2021-05-07 05:08:36 (31.2 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])

print('total training cat images:', len(os.listdir(train_cats_dir)))
print('total training dog images:', len(os.listdir(train_dogs_dir)))
print('total validation cat images:', len(os.listdir(validation_cats_dir)))
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow validation images in batches of 20 using val_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# ['cat.657.jpg', 'cat.639.jpg', 'cat.776.jpg', 'cat.411.jpg', 'cat.298.jpg', 'cat.375.jpg', 'cat.188.jpg', 'cat.751.jpg', 'cat.973.jpg', 'cat.678.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# from tensorflow.python.keras import backend
# from tensorflow.python.keras.datasets.cifar import load_batch
# from tensorflow.python.keras.utils.data_utils import get_file
# from tensorflow.python.util.tf_export import keras_export

# dirname = 'cifar-10-batches-py'
# origin = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip '
# path = get_file(
#     dirname,
#     origin=origin,
#     untar=True,
#     file_hash=
#     '6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce')

# num_train_samples = 50000

# x_train = np.empty((num_train_samples, 3, 32, 32), dtype='uint8')
# y_train = np.empty((num_train_samples,), dtype='uint8')

# for i in range(1, 6):
#   fpath = os.path.join(path, 'data_batch_' + str(i))
#   (x_train[(i - 1) * 10000:i * 10000, :, :, :],
#     y_train[(i - 1) * 10000:i * 10000]) = load_batch(fpath)

# fpath = os.path.join(path, 'test_batch')
# x_test, y_test = load_batch(fpath)

# y_train = np.reshape(y_train, (len(y_train), 1))
# y_test = np.reshape(y_test, (len(y_test), 1))

# if backend.image_data_format() == 'channels_last':
#   x_train = x_train.transpose(0, 2, 3, 1)
#   x_test = x_test.transpose(0, 2, 3, 1)

# x_test = x_test.astype(x_train.dtype)
# y_test = y_test.astype(y_train.dtype)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop

def cat_model():

  img_input = layers.Input(shape=(150, 150, 3))

  x = layers.Conv2D(16, 3, activation='relu')(img_input)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(32, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(64, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(512, activation='relu')(x)

  output = layers.Dense(1, activation='sigmoid')(x)

  model = Model(img_input, output)



  model.compile(loss='binary_crossentropy',
                optimizer=RMSprop(lr=0.001),
                metrics=['accuracy'])
  
  return model 

model = cat_model()

# %%
cat_model().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Test for LR**

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=100
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)
  


  # if (z%2 == 0):
  LR = random() * batch_size/10000
  lr.append(LR)
  # else:
  #   LR = random() * z/10000
  #   lr.append(LR)

# lr = lr[::-1] 
lord_LR = lr
# print(min(lr))


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()


# lr = []
# epoo=150
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   # print(z,(batch_size)/((z+1)**(3/2))/80)
  

#   LR = random() * z/10000
#   # LR=LR/8
#   lr.append(LR)

# plt.plot(lr, label='Learning Rate')
# plt.xlabel('Epoch')
# plt.ylabel('LR')
# plt.legend(loc='lower right')
# plt.show()

# %%
# baseline model with dropout for the dogs vs cats dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
 
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(150, 150, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.5))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
	return model

# model = define_model()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
# epoch=1
# for i in range(5,100,5):

#   print("epoch ",epoch)
#   epoch+=1
#   train_generator.batch_size=i
#   validation_generator.batch_size=i

# train_generator.batch_size=i
# validation_generator.batch_size=i

history = model.fit(
      train_generator,
      epochs=100,
      validation_data=validation_generator,
      verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 12s 106ms/step - loss: 1.4369 - accuracy: 0.5131 - val_loss: 0.6871 - val_accuracy: 0.6020
# Epoch 2/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.7039 - accuracy: 0.6231 - val_loss: 0.6333 - val_accuracy: 0.6060
# Epoch 3/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.6170 - accuracy: 0.6704 - val_loss: 0.5886 - val_accuracy: 0.6980
# Epoch 4/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5308 - accuracy: 0.7466 - val_loss: 0.5896 - val_accuracy: 0.6830
# Epoch 5/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.4332 - accuracy: 0.7973 - val_loss: 0.5903 - val_accuracy: 0.7250
# Epoch 6/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.3357 - accuracy: 0.8637 - val_loss: 0.7203 - val_accuracy: 0.6830
# Epoch 7/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2738 - accuracy: 0.8889 - val_loss: 0.8373 - val_accuracy: 0.7170
# Epoch 8/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.1984 - accuracy: 0.9299 - val_loss: 0.8528 - val_accuracy: 0.7270
# Epoch 9/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.1139 - accuracy: 0.9584 - val_loss: 1.0147 - val_accuracy: 0.7060
# Epoch 10/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0792 - accuracy: 0.9685 - val_loss: 1.1256 - val_accuracy: 0.7020
# Epoch 11/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0704 - accuracy: 0.9843 - val_loss: 1.5133 - val_accuracy: 0.7310
# Epoch 12/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0720 - accuracy: 0.9792 - val_loss: 1.1625 - val_accuracy: 0.7160
# Epoch 13/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0493 - accuracy: 0.9874 - val_loss: 1.6234 - val_accuracy: 0.7240
# Epoch 14/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0426 - accuracy: 0.9837 - val_loss: 1.5445 - val_accuracy: 0.7090
# Epoch 15/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0295 - accuracy: 0.9938 - val_loss: 1.8456 - val_accuracy: 0.6890
# Epoch 16/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0185 - accuracy: 0.9960 - val_loss: 1.9267 - val_accuracy: 0.7200
# Epoch 17/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 1.9007 - val_accuracy: 0.7250
# Epoch 18/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0923 - accuracy: 0.9868 - val_loss: 2.0824 - val_accuracy: 0.7240
# Epoch 19/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0252 - accuracy: 0.9948 - val_loss: 2.4939 - val_accuracy: 0.7090
# Epoch 20/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0255 - accuracy: 0.9938 - val_loss: 2.3913 - val_accuracy: 0.7120
# Epoch 21/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0316 - accuracy: 0.9950 - val_loss: 2.1112 - val_accuracy: 0.7190
# Epoch 22/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 2.8266 - val_accuracy: 0.7370
# Epoch 23/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0228 - accuracy: 0.9980 - val_loss: 3.1156 - val_accuracy: 0.7270
# Epoch 24/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0367 - accuracy: 0.9953 - val_loss: 3.1223 - val_accuracy: 0.7110
# Epoch 25/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0110 - accuracy: 0.9979 - val_loss: 3.0350 - val_accuracy: 0.7240
# Epoch 26/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0465 - accuracy: 0.9952 - val_loss: 2.6490 - val_accuracy: 0.7200
# Epoch 27/100
# 100/100 [==============================] - 10s 99ms/step - loss: 2.3807e-04 - accuracy: 1.0000 - val_loss: 5.4624 - val_accuracy: 0.6110
# Epoch 28/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.1714 - accuracy: 0.9766 - val_loss: 3.1693 - val_accuracy: 0.7250
# Epoch 29/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0234 - accuracy: 0.9984 - val_loss: 3.2658 - val_accuracy: 0.7090
# Epoch 30/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 3.5901 - val_accuracy: 0.7060
# Epoch 31/100
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 2.8876 - val_accuracy: 0.7110
# Epoch 32/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.3471 - val_accuracy: 0.7140
# Epoch 33/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0596 - accuracy: 0.9959 - val_loss: 3.4443 - val_accuracy: 0.7120
# Epoch 34/100
# 100/100 [==============================] - 10s 99ms/step - loss: 1.4958e-04 - accuracy: 1.0000 - val_loss: 3.8397 - val_accuracy: 0.7210
# Epoch 35/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0368 - accuracy: 0.9964 - val_loss: 3.7096 - val_accuracy: 0.7220
# Epoch 36/100
# 100/100 [==============================] - 10s 99ms/step - loss: 1.0917e-04 - accuracy: 1.0000 - val_loss: 4.0746 - val_accuracy: 0.7270
# Epoch 37/100
# 100/100 [==============================] - 10s 99ms/step - loss: 5.6970e-07 - accuracy: 1.0000 - val_loss: 5.1711 - val_accuracy: 0.7350
# Epoch 38/100
# 100/100 [==============================] - 10s 101ms/step - loss: 0.7752 - accuracy: 0.9619 - val_loss: 4.3215 - val_accuracy: 0.7110
# Epoch 39/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 4.9304 - val_accuracy: 0.7110
# Epoch 40/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.1201 - accuracy: 0.9913 - val_loss: 5.0725 - val_accuracy: 0.6880
# Epoch 41/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.1043 - accuracy: 0.9936 - val_loss: 4.0801 - val_accuracy: 0.7160
# Epoch 42/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0288 - accuracy: 0.9943 - val_loss: 3.6223 - val_accuracy: 0.7060
# Epoch 43/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0085 - accuracy: 0.9993 - val_loss: 3.6727 - val_accuracy: 0.7200
# Epoch 44/100
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 4.6501 - val_accuracy: 0.7000
# Epoch 45/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0244 - accuracy: 0.9952 - val_loss: 3.8411 - val_accuracy: 0.7140
# Epoch 46/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 5.3912 - val_accuracy: 0.7140
# Epoch 47/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 4.3171 - val_accuracy: 0.6860
# Epoch 48/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0021 - accuracy: 0.9987 - val_loss: 4.8401 - val_accuracy: 0.7010
# Epoch 49/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0256 - accuracy: 0.9962 - val_loss: 4.8335 - val_accuracy: 0.7090
# Epoch 50/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0173 - accuracy: 0.9982 - val_loss: 4.2489 - val_accuracy: 0.6970
# Epoch 51/100
# 100/100 [==============================] - 10s 97ms/step - loss: 1.0860e-04 - accuracy: 1.0000 - val_loss: 4.5606 - val_accuracy: 0.7070
# Epoch 52/100
# 100/100 [==============================] - 10s 97ms/step - loss: 9.0676e-07 - accuracy: 1.0000 - val_loss: 4.8612 - val_accuracy: 0.7110
# Epoch 53/100
# 100/100 [==============================] - 10s 98ms/step - loss: 1.2659e-08 - accuracy: 1.0000 - val_loss: 5.9029 - val_accuracy: 0.7200
# Epoch 54/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.1044 - accuracy: 0.9917 - val_loss: 5.3912 - val_accuracy: 0.7150
# Epoch 55/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0195 - accuracy: 0.9968 - val_loss: 6.1514 - val_accuracy: 0.7190
# Epoch 56/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0402 - accuracy: 0.9972 - val_loss: 5.3402 - val_accuracy: 0.7140
# Epoch 57/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 4.9134 - val_accuracy: 0.7090
# Epoch 58/100
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0483 - accuracy: 0.9948 - val_loss: 5.5907 - val_accuracy: 0.7080
# Epoch 59/100
# 100/100 [==============================] - 10s 99ms/step - loss: 3.9139e-04 - accuracy: 1.0000 - val_loss: 5.3851 - val_accuracy: 0.7090
# Epoch 60/100
# 100/100 [==============================] - 10s 97ms/step - loss: 2.8169e-05 - accuracy: 1.0000 - val_loss: 6.8878 - val_accuracy: 0.6990
# Epoch 61/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0547 - accuracy: 0.9959 - val_loss: 6.0489 - val_accuracy: 0.7180
# Epoch 62/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0267 - accuracy: 0.9984 - val_loss: 6.2967 - val_accuracy: 0.7040
# Epoch 63/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0524 - accuracy: 0.9905 - val_loss: 6.1191 - val_accuracy: 0.7040
# Epoch 64/100
# 100/100 [==============================] - 10s 96ms/step - loss: 3.5188e-04 - accuracy: 1.0000 - val_loss: 6.0344 - val_accuracy: 0.7050
# Epoch 65/100
# 100/100 [==============================] - 10s 98ms/step - loss: 1.5862e-07 - accuracy: 1.0000 - val_loss: 7.0589 - val_accuracy: 0.6990
# Epoch 66/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.1284 - accuracy: 0.9878 - val_loss: 6.3348 - val_accuracy: 0.7180
# Epoch 67/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0109 - accuracy: 0.9994 - val_loss: 6.4125 - val_accuracy: 0.7210
# Epoch 68/100
# 100/100 [==============================] - 10s 98ms/step - loss: 8.2859e-05 - accuracy: 1.0000 - val_loss: 6.5388 - val_accuracy: 0.7130
# Epoch 69/100
# 100/100 [==============================] - 10s 97ms/step - loss: 9.6655e-08 - accuracy: 1.0000 - val_loss: 6.2104 - val_accuracy: 0.7140
# Epoch 70/100
# 100/100 [==============================] - 10s 96ms/step - loss: 4.5404e-04 - accuracy: 0.9999 - val_loss: 7.4015 - val_accuracy: 0.7100
# Epoch 71/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0958 - accuracy: 0.9939 - val_loss: 6.9364 - val_accuracy: 0.6970
# Epoch 72/100
# 100/100 [==============================] - 10s 97ms/step - loss: 1.5695e-06 - accuracy: 1.0000 - val_loss: 6.8390 - val_accuracy: 0.6980
# Epoch 73/100
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 7.8662 - val_accuracy: 0.7050
# Epoch 74/100
# 100/100 [==============================] - 10s 97ms/step - loss: 7.0277e-06 - accuracy: 1.0000 - val_loss: 7.4288 - val_accuracy: 0.7020
# Epoch 75/100
# 100/100 [==============================] - 10s 99ms/step - loss: 5.0354e-08 - accuracy: 1.0000 - val_loss: 7.4511 - val_accuracy: 0.7010
# Epoch 76/100
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0115 - accuracy: 0.9989 - val_loss: 7.4967 - val_accuracy: 0.7330
# Epoch 77/100
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0137 - accuracy: 0.9972 - val_loss: 6.8856 - val_accuracy: 0.7010
# Epoch 78/100
# 100/100 [==============================] - 10s 97ms/step - loss: 8.1215e-04 - accuracy: 1.0000 - val_loss: 7.2542 - val_accuracy: 0.6940
# Epoch 79/100
# 100/100 [==============================] - 10s 98ms/step - loss: 9.4508e-04 - accuracy: 1.0000 - val_loss: 7.8500 - val_accuracy: 0.6950
# Epoch 80/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0471 - accuracy: 0.9968 - val_loss: 6.7910 - val_accuracy: 0.7080
# Epoch 81/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 6.2946 - val_accuracy: 0.7050
# Epoch 82/100
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 6.1670 - val_accuracy: 0.7150
# Epoch 83/100
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 6.2773 - val_accuracy: 0.7060
# Epoch 84/100
# 100/100 [==============================] - 10s 97ms/step - loss: 1.7929e-08 - accuracy: 1.0000 - val_loss: 6.3442 - val_accuracy: 0.7110
# Epoch 85/100
# 100/100 [==============================] - 10s 98ms/step - loss: 2.2411e-09 - accuracy: 1.0000 - val_loss: 6.6615 - val_accuracy: 0.7150
# Epoch 86/100
# 100/100 [==============================] - 10s 99ms/step - loss: 1.8299e-10 - accuracy: 1.0000 - val_loss: 6.7822 - val_accuracy: 0.7130
# Epoch 87/100
# 100/100 [==============================] - 10s 99ms/step - loss: 4.2096e-11 - accuracy: 1.0000 - val_loss: 6.8111 - val_accuracy: 0.7160
# Epoch 88/100
# 100/100 [==============================] - 10s 101ms/step - loss: 3.8656e-11 - accuracy: 1.0000 - val_loss: 6.8336 - val_accuracy: 0.7170
# Epoch 89/100
# 100/100 [==============================] - 11s 106ms/step - loss: 2.6695e-11 - accuracy: 1.0000 - val_loss: 6.8516 - val_accuracy: 0.7190
# Epoch 90/100
# 100/100 [==============================] - 11s 105ms/step - loss: 5.0311e-11 - accuracy: 1.0000 - val_loss: 6.8665 - val_accuracy: 0.7180
# Epoch 91/100
# 100/100 [==============================] - 11s 108ms/step - loss: 5.8873e-11 - accuracy: 1.0000 - val_loss: 6.8799 - val_accuracy: 0.7180
# Epoch 92/100
# 100/100 [==============================] - 11s 107ms/step - loss: 4.6289e-11 - accuracy: 1.0000 - val_loss: 6.8912 - val_accuracy: 0.7180
# Epoch 93/100
# 100/100 [==============================] - 11s 107ms/step - loss: 5.0301e-11 - accuracy: 1.0000 - val_loss: 6.9011 - val_accuracy: 0.7180
# Epoch 94/100
# 100/100 [==============================] - 11s 107ms/step - loss: 3.0211e-11 - accuracy: 1.0000 - val_loss: 6.9103 - val_accuracy: 0.7180
# Epoch 95/100
# 100/100 [==============================] - 11s 105ms/step - loss: 8.8330e-11 - accuracy: 1.0000 - val_loss: 6.9188 - val_accuracy: 0.7180
# Epoch 96/100
# 100/100 [==============================] - 11s 106ms/step - loss: 5.4751e-11 - accuracy: 1.0000 - val_loss: 6.9260 - val_accuracy: 0.7180
# Epoch 97/100
# 100/100 [==============================] - 10s 105ms/step - loss: 2.8135e-11 - accuracy: 1.0000 - val_loss: 6.9329 - val_accuracy: 0.7180
# Epoch 98/100
# 100/100 [==============================] - 10s 104ms/step - loss: 6.3023e-11 - accuracy: 1.0000 - val_loss: 6.9392 - val_accuracy: 0.7180
# Epoch 99/100
# 100/100 [==============================] - 10s 103ms/step - loss: 8.5233e-11 - accuracy: 1.0000 - val_loss: 6.9451 - val_accuracy: 0.7180
# Epoch 100/100
# 100/100 [==============================] - 10s 104ms/step - loss: 3.7800e-11 - accuracy: 1.0000 - val_loss: 6.9508 - val_accuracy: 0.7180

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_1",acc_1)
record_Results("val_acc_1",val_acc_1)
# Out:
# Mounted at /content/drive
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_1 = Get_Results("acc_1")["acc_1"]
val_acc_1 = Get_Results("val_acc_1")["val_acc_1"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # if (z%2 == 0):
  LR = random() * batch_size/100000
  # lr.append(LR)
  # else:
  #   LR = random() * z/100000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# epoch 1, Learning Rate 8.750442057885566e-06, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00036895024409655617.
# 400/400 [==============================] - 13s 31ms/step - loss: 0.7696 - accuracy: 0.5527 - val_loss: 0.5831 - val_accuracy: 0.7100
#
#
# epoch 2, Learning Rate 9.269844865080834e-05, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009839058983278132.
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6419 - accuracy: 0.6760 - val_loss: 0.5939 - val_accuracy: 0.6640
#
#
# epoch 3, Learning Rate 0.00011277153992329906, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006530666000086704.
# 134/134 [==============================] - 11s 79ms/step - loss: 0.4826 - accuracy: 0.7625 - val_loss: 0.5554 - val_accuracy: 0.7270
#
#
# epoch 4, Learning Rate 0.00015383754983942173, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001358542790008823.
# 100/100 [==============================] - 10s 103ms/step - loss: 0.4958 - accuracy: 0.7545 - val_loss: 0.5980 - val_accuracy: 0.7080
#
#
# epoch 5, Learning Rate 0.0001209776050560146, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00010440218760510907.
# 80/80 [==============================] - 10s 124ms/step - loss: 0.2962 - accuracy: 0.8810 - val_loss: 0.5696 - val_accuracy: 0.7480
#
#
# epoch 6, Learning Rate 0.00014161752303278006, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00017707034212883222.
# 67/67 [==============================] - 10s 150ms/step - loss: 0.2562 - accuracy: 0.9000 - val_loss: 0.5857 - val_accuracy: 0.7470
#
#
# epoch 7, Learning Rate 7.753256310743922e-06, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011854063126047827.
# 58/58 [==============================] - 10s 173ms/step - loss: 0.3734 - accuracy: 0.8390 - val_loss: 0.6116 - val_accuracy: 0.7390
#
#
# epoch 8, Learning Rate 3.721737133696768e-05, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000802555900266757.
# 50/50 [==============================] - 10s 195ms/step - loss: 0.2154 - accuracy: 0.9170 - val_loss: 0.7073 - val_accuracy: 0.7220
#
#
# epoch 9, Learning Rate 7.957694143453311e-05, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0025877018980767635.
# 45/45 [==============================] - 10s 215ms/step - loss: 0.7206 - accuracy: 0.6695 - val_loss: 0.6850 - val_accuracy: 0.6190
#
#
# epoch 10, Learning Rate 3.2875022885351936e-06, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 40/40 [==============================] - 10s 242ms/step - loss: 0.8056 - accuracy: 0.5975 - val_loss: 0.6621 - val_accuracy: 0.5310
#
#
# epoch 11, Learning Rate 0.0005411445134572903, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005097061235428742.
# 37/37 [==============================] - 10s 262ms/step - loss: 0.3837 - accuracy: 0.8275 - val_loss: 0.6657 - val_accuracy: 0.7180
#
#
# epoch 12, Learning Rate 0.00045881793232635857, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 34/34 [==============================] - 10s 282ms/step - loss: 0.9856 - accuracy: 0.6220 - val_loss: 0.6566 - val_accuracy: 0.6210
#
#
# epoch 13, Learning Rate 0.00041784132937642746, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 31/31 [==============================] - 10s 311ms/step - loss: 0.6216 - accuracy: 0.7020 - val_loss: 0.7048 - val_accuracy: 0.6190
#
#
# epoch 14, Learning Rate 8.718817631689861e-05, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 29/29 [==============================] - 10s 330ms/step - loss: 0.7311 - accuracy: 0.7310 - val_loss: 0.6599 - val_accuracy: 0.5890
#
#
# epoch 15, Learning Rate 1.4982887803194372e-05, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0030107077390059654.
# 27/27 [==============================] - 10s 358ms/step - loss: 0.4253 - accuracy: 0.8120 - val_loss: 1.1119 - val_accuracy: 0.6770
#
#
# epoch 16, Learning Rate 0.0006235963212517561, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0018347984288382484.
# 25/25 [==============================] - 10s 384ms/step - loss: 0.2305 - accuracy: 0.9095 - val_loss: 0.8029 - val_accuracy: 0.7210
#
#
# epoch 17, Learning Rate 0.0005160990916062333, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 24/24 [==============================] - 10s 398ms/step - loss: 0.7782 - accuracy: 0.7805 - val_loss: 0.7379 - val_accuracy: 0.6680
#
#
# epoch 18, Learning Rate 0.0006268991077377438, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 23/23 [==============================] - 10s 416ms/step - loss: 0.5634 - accuracy: 0.8490 - val_loss: 1.4664 - val_accuracy: 0.5040
#
#
# epoch 19, Learning Rate 0.0008743278670324301, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014036832412968007.
# 22/22 [==============================] - 10s 439ms/step - loss: 0.3125 - accuracy: 0.8775 - val_loss: 0.9769 - val_accuracy: 0.7070
#
#
# epoch 20, Learning Rate 0.00014044538935948747, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014314629099366105.
# 20/20 [==============================] - 10s 483ms/step - loss: 0.0789 - accuracy: 0.9720 - val_loss: 1.1706 - val_accuracy: 0.7010
#
#
# epoch 21, Learning Rate 0.00029933129553520293, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 20/20 [==============================] - 10s 538ms/step - loss: 1.1768 - accuracy: 0.7530 - val_loss: 1.5541 - val_accuracy: 0.5760
#
#
# epoch 22, Learning Rate 0.0001010814282399718, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 19/19 [==============================] - 10s 505ms/step - loss: 0.2256 - accuracy: 0.9125 - val_loss: 1.2103 - val_accuracy: 0.6930
#
#
# epoch 23, Learning Rate 0.0009776776299078825, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 18/18 [==============================] - 10s 535ms/step - loss: 0.7983 - accuracy: 0.8810 - val_loss: 0.6485 - val_accuracy: 0.6720
#
#
# epoch 24, Learning Rate 0.00113928529042353, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0024634418130737214.
# 17/17 [==============================] - 10s 568ms/step - loss: 0.1513 - accuracy: 0.9515 - val_loss: 1.2228 - val_accuracy: 0.6990
#
#
# epoch 25, Learning Rate 0.0004420116012952268, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 16/16 [==============================] - 10s 601ms/step - loss: 0.0202 - accuracy: 0.9965 - val_loss: 1.8721 - val_accuracy: 0.7080
#
#
# epoch 26, Learning Rate 0.0010858221287648902, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 16/16 [==============================] - 10s 600ms/step - loss: 3.3617 - accuracy: 0.8040 - val_loss: 1.4204 - val_accuracy: 0.5360
#
#
# epoch 27, Learning Rate 0.0012414720484481671, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 15/15 [==============================] - 10s 642ms/step - loss: 0.4496 - accuracy: 0.8430 - val_loss: 0.9729 - val_accuracy: 0.6600
#
#
# epoch 28, Learning Rate 0.0008164371553884935, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 15/15 [==============================] - 11s 645ms/step - loss: 0.1714 - accuracy: 0.9435 - val_loss: 1.5258 - val_accuracy: 0.6860
#
#
# epoch 29, Learning Rate 4.947227849905411e-06, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003203026396839821.
# 14/14 [==============================] - 11s 705ms/step - loss: 0.0281 - accuracy: 0.9950 - val_loss: 1.8827 - val_accuracy: 0.7060
#
#
# epoch 30, Learning Rate 0.0010269986947868852, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0017093529206320785.
# 14/14 [==============================] - 11s 692ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 2.2250 - val_accuracy: 0.6980
#
#
# epoch 31, Learning Rate 0.0013443200560924354, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002038712828842146.
# 13/13 [==============================] - 11s 746ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.5327 - val_accuracy: 0.6980
#
#
# epoch 32, Learning Rate 0.000428459193449185, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 13/13 [==============================] - 10s 738ms/step - loss: 3.2560e-04 - accuracy: 1.0000 - val_loss: 2.6100 - val_accuracy: 0.7020
#
#
# epoch 33, Learning Rate 0.00046763229036790073, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 13/13 [==============================] - 11s 733ms/step - loss: 7.2799e-05 - accuracy: 1.0000 - val_loss: 2.9939 - val_accuracy: 0.7080
#
#
# epoch 34, Learning Rate 0.000535022102212558, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 12/12 [==============================] - 11s 806ms/step - loss: 2.7254e-05 - accuracy: 1.0000 - val_loss: 3.1108 - val_accuracy: 0.7020
#
#
# epoch 35, Learning Rate 0.00043222917608468076, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 12/12 [==============================] - 11s 795ms/step - loss: 1.3162e-05 - accuracy: 1.0000 - val_loss: 3.2579 - val_accuracy: 0.7140
#
#
# epoch 36, Learning Rate 0.0003298692399563404, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 12/12 [==============================] - 11s 788ms/step - loss: 7.4725e-06 - accuracy: 1.0000 - val_loss: 3.3955 - val_accuracy: 0.7080
#
#
# epoch 37, Learning Rate 0.0014320086247056228, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 11/11 [==============================] - 11s 878ms/step - loss: 4.1417e-06 - accuracy: 1.0000 - val_loss: 3.5722 - val_accuracy: 0.7010
#
#
# epoch 38, Learning Rate 0.0007729760338038492, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 11/11 [==============================] - 11s 899ms/step - loss: 2.4970e-06 - accuracy: 1.0000 - val_loss: 3.5589 - val_accuracy: 0.7130
#
#
# epoch 39, Learning Rate 0.00021267236124371575, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 11/11 [==============================] - 11s 872ms/step - loss: 1.3506e-06 - accuracy: 1.0000 - val_loss: 3.7279 - val_accuracy: 0.7100
#
#
# epoch 40, Learning Rate 0.0008122073638856679, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 11s 971ms/step - loss: 8.8415e-07 - accuracy: 1.0000 - val_loss: 3.8535 - val_accuracy: 0.7130
#
#
# epoch 41, Learning Rate 0.001471851712450127, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 11s 965ms/step - loss: 5.1958e-07 - accuracy: 1.0000 - val_loss: 3.9782 - val_accuracy: 0.7050
#
#
# epoch 42, Learning Rate 0.0008796845808718596, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 11s 974ms/step - loss: 5.9856 - accuracy: 0.8060 - val_loss: 5.5339 - val_accuracy: 0.5000
#
#
# epoch 43, Learning Rate 0.0003765682309230544, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 11s 962ms/step - loss: 1.0373 - accuracy: 0.7180 - val_loss: 0.6894 - val_accuracy: 0.6590
#
#
# epoch 44, Learning Rate 0.0008381114068561112, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 11s 964ms/step - loss: 0.3348 - accuracy: 0.8630 - val_loss: 1.1508 - val_accuracy: 0.7030
#
#
# epoch 45, Learning Rate 0.0003367352457716446, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.8228242757879772e-05.
# 9/9 [==============================] - 11s 1s/step - loss: 0.0562 - accuracy: 0.9900 - val_loss: 1.1604 - val_accuracy: 0.7020
#
#
# epoch 46, Learning Rate 0.0016058935989952763, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 11s 1s/step - loss: 0.0285 - accuracy: 0.9935 - val_loss: 2.5237 - val_accuracy: 0.7070
#
#
# epoch 47, Learning Rate 0.0018573239689943562, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 11s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.3502 - val_accuracy: 0.7090
#
#
# epoch 48, Learning Rate 0.0009184985795258553, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 11s 1s/step - loss: 4.5592e-04 - accuracy: 1.0000 - val_loss: 2.8951 - val_accuracy: 0.7100
#
#
# epoch 49, Learning Rate 0.0007872304180612619, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 11s 1s/step - loss: 1.3227e-04 - accuracy: 1.0000 - val_loss: 3.0013 - val_accuracy: 0.7120
#
#
# epoch 50, Learning Rate 0.002335576175662286, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 6.8561e-05 - accuracy: 1.0000 - val_loss: 3.1243 - val_accuracy: 0.7110
#
#
# epoch 51, Learning Rate 0.00236552356325329, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 4.2484e-05 - accuracy: 1.0000 - val_loss: 3.1648 - val_accuracy: 0.7110
#
#
# epoch 52, Learning Rate 0.0010875775276413045, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005169505655125497.
# 8/8 [==============================] - 11s 1s/step - loss: 2.8575e-05 - accuracy: 1.0000 - val_loss: 3.1907 - val_accuracy: 0.7100
#
#
# epoch 53, Learning Rate 0.00047096876630186023, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 2.6625e-05 - accuracy: 1.0000 - val_loss: 3.2964 - val_accuracy: 0.7100
#
#
# epoch 54, Learning Rate 0.0002191508132653723, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 12s 1s/step - loss: 1.4916e-05 - accuracy: 1.0000 - val_loss: 3.3958 - val_accuracy: 0.7100
#
#
# epoch 55, Learning Rate 0.0005417408775381601, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 9.3938e-06 - accuracy: 1.0000 - val_loss: 3.4398 - val_accuracy: 0.7090
#
#
# epoch 56, Learning Rate 0.0009601786092802384, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 8.6711e-06 - accuracy: 1.0000 - val_loss: 3.6062 - val_accuracy: 0.7100
#
#
# epoch 57, Learning Rate 0.000956992353009204, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 11s 1s/step - loss: 3.9432e-06 - accuracy: 1.0000 - val_loss: 3.6577 - val_accuracy: 0.7110
#
#
# epoch 58, Learning Rate 0.001388316925014268, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 3.0664e-06 - accuracy: 1.0000 - val_loss: 3.7159 - val_accuracy: 0.7090
#
#
# epoch 59, Learning Rate 0.0006093355963091443, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 2.0318e-06 - accuracy: 1.0000 - val_loss: 3.8331 - val_accuracy: 0.7100
#
#
# epoch 60, Learning Rate 0.0018692738543575433, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.821469590414744e-05.
# 7/7 [==============================] - 11s 1s/step - loss: 1.5850e-06 - accuracy: 1.0000 - val_loss: 3.8323 - val_accuracy: 0.7100
#
#
# epoch 61, Learning Rate 0.0019121370139533417, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 1.6213e-06 - accuracy: 1.0000 - val_loss: 3.7782 - val_accuracy: 0.7050
#
#
# epoch 62, Learning Rate 0.001959700471713752, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 12s 1s/step - loss: 1.0352e-06 - accuracy: 1.0000 - val_loss: 4.0063 - val_accuracy: 0.7090
#
#
# epoch 63, Learning Rate 0.0019092221556375702, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 6.5731e-07 - accuracy: 1.0000 - val_loss: 4.0578 - val_accuracy: 0.7100
#
#
# epoch 64, Learning Rate 0.001816789398490366, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 4.6219e-07 - accuracy: 1.0000 - val_loss: 4.1775 - val_accuracy: 0.7090
#
#
# epoch 65, Learning Rate 0.00044787922898398925, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 1.7835e-06 - accuracy: 1.0000 - val_loss: 5.8109 - val_accuracy: 0.5830
#
#
# epoch 66, Learning Rate 0.002650258126122166, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 11s 1s/step - loss: 17.6419 - accuracy: 0.6265 - val_loss: 0.7344 - val_accuracy: 0.6610
#
#
# epoch 67, Learning Rate 0.003212237159988748, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 0.4723 - accuracy: 0.7735 - val_loss: 0.6987 - val_accuracy: 0.7130
#
#
# epoch 68, Learning Rate 0.00019486417951759442, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 0.1196 - accuracy: 0.9745 - val_loss: 2.1665 - val_accuracy: 0.5930
#
#
# epoch 69, Learning Rate 0.00045632712253601787, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 0.1686 - accuracy: 0.9380 - val_loss: 1.4171 - val_accuracy: 0.7080
#
#
# epoch 70, Learning Rate 0.0015331217697708915, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 0.0090 - accuracy: 0.9985 - val_loss: 1.9190 - val_accuracy: 0.7120
#
#
# epoch 71, Learning Rate 0.0033602150920853495, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 1.9656 - val_accuracy: 0.7070
#
#
# epoch 72, Learning Rate 4.405217672622008e-06, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 9.0298e-04 - accuracy: 1.0000 - val_loss: 2.1487 - val_accuracy: 0.7020
#
#
# epoch 73, Learning Rate 0.0012150683972056231, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 4.6532e-04 - accuracy: 1.0000 - val_loss: 2.2934 - val_accuracy: 0.7060
#
#
# epoch 74, Learning Rate 0.00010947011252211308, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 2.6680e-04 - accuracy: 1.0000 - val_loss: 2.4133 - val_accuracy: 0.7120
#
#
# epoch 75, Learning Rate 0.0027612729387810476, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 1.5746e-04 - accuracy: 1.0000 - val_loss: 2.5215 - val_accuracy: 0.7140
#
#
# epoch 76, Learning Rate 0.0007690289497780562, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0026103457741429113.
# 6/6 [==============================] - 11s 2s/step - loss: 1.0080e-04 - accuracy: 1.0000 - val_loss: 2.5882 - val_accuracy: 0.7120
#
#
# epoch 77, Learning Rate 0.0026433100275364183, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 11s 2s/step - loss: 7.4701e-05 - accuracy: 1.0000 - val_loss: 2.7061 - val_accuracy: 0.7080
#
#
# epoch 78, Learning Rate 0.0016657714210530164, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0013936317033026524.
# 6/6 [==============================] - 12s 2s/step - loss: 5.0923e-05 - accuracy: 1.0000 - val_loss: 2.7308 - val_accuracy: 0.7110
#
#
# epoch 79, Learning Rate 4.507506803593578e-05, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 12s 2s/step - loss: 4.3933e-05 - accuracy: 1.0000 - val_loss: 2.7935 - val_accuracy: 0.7110
#
#
# epoch 80, Learning Rate 0.003737233222415403, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 2.8649e-05 - accuracy: 1.0000 - val_loss: 2.8669 - val_accuracy: 0.7110
#
#
# epoch 81, Learning Rate 0.003513985890947334, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 2.0825e-05 - accuracy: 1.0000 - val_loss: 2.9358 - val_accuracy: 0.7120
#
#
# epoch 82, Learning Rate 0.0007585293348651062, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 1.4559e-05 - accuracy: 1.0000 - val_loss: 3.0070 - val_accuracy: 0.7120
#
#
# epoch 83, Learning Rate 0.003443082244476068, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 1.0884e-05 - accuracy: 1.0000 - val_loss: 3.0719 - val_accuracy: 0.7110
#
#
# epoch 84, Learning Rate 0.003106413774943303, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 8.3574e-06 - accuracy: 1.0000 - val_loss: 3.1405 - val_accuracy: 0.7110
#
#
# epoch 85, Learning Rate 0.0033689718822194448, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 6.3057e-06 - accuracy: 1.0000 - val_loss: 3.1952 - val_accuracy: 0.7100
#
#
# epoch 86, Learning Rate 0.0017370994330282049, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 4.9654e-06 - accuracy: 1.0000 - val_loss: 3.2640 - val_accuracy: 0.7120
#
#
# epoch 87, Learning Rate 0.003127755951421368, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 3.8344e-06 - accuracy: 1.0000 - val_loss: 3.3285 - val_accuracy: 0.7110
#
#
# epoch 88, Learning Rate 0.003831180205804664, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 2.9696e-06 - accuracy: 1.0000 - val_loss: 3.3702 - val_accuracy: 0.7100
#
#
# epoch 89, Learning Rate 0.0016046098564402528, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 2.3661e-06 - accuracy: 1.0000 - val_loss: 3.4219 - val_accuracy: 0.7080
#
#
# epoch 90, Learning Rate 0.0038808468090820196, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 1.8568e-06 - accuracy: 1.0000 - val_loss: 3.4980 - val_accuracy: 0.7060
#
#
# epoch 91, Learning Rate 0.003166059575339663, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 3s/step - loss: 1.4471e-06 - accuracy: 1.0000 - val_loss: 3.5415 - val_accuracy: 0.7080
#
#
# epoch 92, Learning Rate 0.0018421593111418704, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 1.1684e-06 - accuracy: 1.0000 - val_loss: 3.6064 - val_accuracy: 0.7040
#
#
# epoch 93, Learning Rate 0.002352664524312266, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 13s 2s/step - loss: 9.2195e-07 - accuracy: 1.0000 - val_loss: 3.6592 - val_accuracy: 0.7050
#
#
# epoch 94, Learning Rate 0.0020592667577899923, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 13s 2s/step - loss: 7.3203e-07 - accuracy: 1.0000 - val_loss: 3.7226 - val_accuracy: 0.7040
#
#
# epoch 95, Learning Rate 0.002303789614588611, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 5.9477e-07 - accuracy: 1.0000 - val_loss: 3.8141 - val_accuracy: 0.7030
#
#
# epoch 96, Learning Rate 0.003651588810391402, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 4.8750e-07 - accuracy: 1.0000 - val_loss: 3.8347 - val_accuracy: 0.7020
#
#
# epoch 97, Learning Rate 0.0013184168124138944, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 13s 2s/step - loss: 3.8226e-07 - accuracy: 1.0000 - val_loss: 3.9029 - val_accuracy: 0.7020
#
#
# epoch 98, Learning Rate 0.001422422664254404, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 13s 2s/step - loss: 3.1163e-07 - accuracy: 1.0000 - val_loss: 3.9462 - val_accuracy: 0.7020
#
#
# epoch 99, Learning Rate 0.00392772445500584, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 12s 2s/step - loss: 3.0052e-07 - accuracy: 1.0000 - val_loss: 3.9087 - val_accuracy: 0.7080
#
#
# epoch 100, Learning Rate 0.0007105804820262473, Batch Size  500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 12s 3s/step - loss: 2.0957e-07 - accuracy: 1.0000 - val_loss: 4.0616 - val_accuracy: 0.7050

# %%
#@title
# model = cat_model()
# from keras.callbacks import LearningRateScheduler
# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []

# num = 0

# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR



#   call = [ LearningRateScheduler(set_LR,verbose=1) ]



#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size



#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_2",acc_2)
record_Results("val_acc_2",val_acc_2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_2 = Get_Results("acc_2")["acc_2"]
val_acc_2 = Get_Results("val_acc_2")["val_acc_2"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = cat_model()
# epoo = 50
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
l_r = []
x=0
def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

call = [ LearningRateScheduler(set_LR,verbose=1) ]

history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoo,
            callbacks=call
            )
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00036895024409655617.
# 4/4 [==============================] - 12s 3s/step - loss: 1.5105 - accuracy: 0.5151 - val_loss: 0.7267 - val_accuracy: 0.5000
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009839058983278132.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7397 - accuracy: 0.4974 - val_loss: 0.6952 - val_accuracy: 0.5000
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0006530666000086704.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6882 - accuracy: 0.5296 - val_loss: 0.6760 - val_accuracy: 0.5530
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001358542790008823.
# 4/4 [==============================] - 9s 3s/step - loss: 1.2372 - accuracy: 0.5754 - val_loss: 0.6898 - val_accuracy: 0.5000
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.00010440218760510907.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6882 - accuracy: 0.5066 - val_loss: 0.6884 - val_accuracy: 0.5060
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.00017707034212883222.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6860 - accuracy: 0.5349 - val_loss: 0.6844 - val_accuracy: 0.6200
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0011854063126047827.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6829 - accuracy: 0.5731 - val_loss: 0.6846 - val_accuracy: 0.5240
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.000802555900266757.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6740 - accuracy: 0.5598 - val_loss: 0.7245 - val_accuracy: 0.5000
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0025877018980767635.
# 4/4 [==============================] - 9s 3s/step - loss: 1.0348 - accuracy: 0.5216 - val_loss: 0.6970 - val_accuracy: 0.5000
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7855 - accuracy: 0.5083 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0005097061235428742.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6973 - accuracy: 0.4867 - val_loss: 0.6901 - val_accuracy: 0.5000
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6944 - accuracy: 0.5198 - val_loss: 13.6420 - val_accuracy: 0.5000
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 6.8552 - accuracy: 0.5015 - val_loss: 0.6921 - val_accuracy: 0.5460
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6894 - accuracy: 0.5645 - val_loss: 0.6932 - val_accuracy: 0.5050
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0030107077390059654.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6933 - accuracy: 0.4943 - val_loss: 0.6873 - val_accuracy: 0.5560
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0018347984288382484.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6831 - accuracy: 0.5671 - val_loss: 0.6784 - val_accuracy: 0.6170
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7897 - accuracy: 0.5879 - val_loss: 0.6894 - val_accuracy: 0.5000
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6872 - accuracy: 0.5312 - val_loss: 0.7091 - val_accuracy: 0.5000
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0014036832412968007.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6955 - accuracy: 0.4950 - val_loss: 0.6851 - val_accuracy: 0.5840
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0014314629099366105.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6762 - accuracy: 0.5687 - val_loss: 0.6788 - val_accuracy: 0.5640
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7011 - accuracy: 0.5588 - val_loss: 0.6925 - val_accuracy: 0.5510
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6902 - accuracy: 0.6064 - val_loss: 0.6876 - val_accuracy: 0.5270
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6804 - accuracy: 0.5647 - val_loss: 0.6991 - val_accuracy: 0.5060
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0024634418130737214.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6729 - accuracy: 0.5797 - val_loss: 0.6849 - val_accuracy: 0.5210
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6573 - accuracy: 0.5877 - val_loss: 1.1148 - val_accuracy: 0.5000
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.8543 - accuracy: 0.5524 - val_loss: 0.8194 - val_accuracy: 0.5080
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7432 - accuracy: 0.5271 - val_loss: 0.6762 - val_accuracy: 0.5620
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7273 - accuracy: 0.5847 - val_loss: 0.6884 - val_accuracy: 0.5360
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.003203026396839821.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6681 - accuracy: 0.6086 - val_loss: 0.6947 - val_accuracy: 0.5580
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0017093529206320785.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6359 - accuracy: 0.6055 - val_loss: 0.6741 - val_accuracy: 0.5950
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.002038712828842146.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5954 - accuracy: 0.6961 - val_loss: 1.6806 - val_accuracy: 0.5000
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.1038 - accuracy: 0.5217 - val_loss: 0.6786 - val_accuracy: 0.5780
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.9489 - accuracy: 0.5730 - val_loss: 0.7020 - val_accuracy: 0.5020
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6745 - accuracy: 0.5723 - val_loss: 0.6824 - val_accuracy: 0.5470
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6272 - accuracy: 0.6552 - val_loss: 0.6846 - val_accuracy: 0.6020
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.7431 - accuracy: 0.6306 - val_loss: 0.6882 - val_accuracy: 0.5850
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6746 - accuracy: 0.6228 - val_loss: 0.6858 - val_accuracy: 0.5860
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6097 - accuracy: 0.6815 - val_loss: 0.7768 - val_accuracy: 0.5670
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5844 - accuracy: 0.6718 - val_loss: 0.6986 - val_accuracy: 0.5910
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5361 - accuracy: 0.7353 - val_loss: 0.6951 - val_accuracy: 0.5870
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5503 - accuracy: 0.7376 - val_loss: 0.8890 - val_accuracy: 0.5950
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.4767 - accuracy: 0.7495 - val_loss: 1.1701 - val_accuracy: 0.5250
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.8552 - accuracy: 0.5829 - val_loss: 0.7585 - val_accuracy: 0.5670
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.4565 - accuracy: 0.7762 - val_loss: 0.8965 - val_accuracy: 0.5380
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.8228242757879772e-05.
# 4/4 [==============================] - 9s 3s/step - loss: 0.4703 - accuracy: 0.7281 - val_loss: 0.8893 - val_accuracy: 0.5410
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.4132 - accuracy: 0.7814 - val_loss: 0.9263 - val_accuracy: 0.5280
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3939 - accuracy: 0.7971 - val_loss: 1.4783 - val_accuracy: 0.5670
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5985 - accuracy: 0.6492 - val_loss: 0.7442 - val_accuracy: 0.5520
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5340 - accuracy: 0.7289 - val_loss: 1.6807 - val_accuracy: 0.5180
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6615 - accuracy: 0.6629 - val_loss: 0.9435 - val_accuracy: 0.6060
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.2631 - accuracy: 0.8961 - val_loss: 1.1517 - val_accuracy: 0.5960
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0005169505655125497.
# 4/4 [==============================] - 9s 3s/step - loss: 0.1940 - accuracy: 0.9228 - val_loss: 1.1363 - val_accuracy: 0.5960
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.2099 - accuracy: 0.9058 - val_loss: 0.9969 - val_accuracy: 0.5570
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3842 - accuracy: 0.8161 - val_loss: 1.3011 - val_accuracy: 0.5940
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3285 - accuracy: 0.8859 - val_loss: 0.7376 - val_accuracy: 0.5470
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.5124 - accuracy: 0.7519 - val_loss: 0.9387 - val_accuracy: 0.5740
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.2433 - accuracy: 0.9158 - val_loss: 1.2845 - val_accuracy: 0.5910
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.1183 - accuracy: 0.9583 - val_loss: 1.4819 - val_accuracy: 0.5960
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0677 - accuracy: 0.9785 - val_loss: 1.8048 - val_accuracy: 0.5930
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 9.821469590414744e-05.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0518 - accuracy: 0.9909 - val_loss: 1.7691 - val_accuracy: 0.6000
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.1155 - accuracy: 0.9651 - val_loss: 2.2680 - val_accuracy: 0.5190
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.0290 - accuracy: 0.6576 - val_loss: 1.2461 - val_accuracy: 0.5330
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3360 - accuracy: 0.8324 - val_loss: 1.3036 - val_accuracy: 0.5950
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0803 - accuracy: 0.9835 - val_loss: 1.6372 - val_accuracy: 0.5610
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0527 - accuracy: 0.9911 - val_loss: 1.8148 - val_accuracy: 0.5890
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0295 - accuracy: 0.9925 - val_loss: 2.1420 - val_accuracy: 0.5850
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0164 - accuracy: 0.9977 - val_loss: 2.4374 - val_accuracy: 0.5790
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3469 - accuracy: 0.8875 - val_loss: 1.1463 - val_accuracy: 0.5650
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3546 - accuracy: 0.8606 - val_loss: 1.4318 - val_accuracy: 0.5800
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 10s 3s/step - loss: 0.1433 - accuracy: 0.9597 - val_loss: 1.6742 - val_accuracy: 0.6080
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 10s 3s/step - loss: 0.0573 - accuracy: 0.9853 - val_loss: 1.9720 - val_accuracy: 0.5950
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 2.2213 - val_accuracy: 0.5950
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 10s 3s/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 2.5156 - val_accuracy: 0.5960
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0088 - accuracy: 0.9977 - val_loss: 2.6630 - val_accuracy: 0.6020
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 4.6489 - val_accuracy: 0.5330
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.0026103457741429113.
# 4/4 [==============================] - 9s 3s/step - loss: 0.3444 - accuracy: 0.8719 - val_loss: 2.1251 - val_accuracy: 0.5840
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0275 - accuracy: 0.9984 - val_loss: 2.5372 - val_accuracy: 0.5810
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.0013936317033026524.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 2.6148 - val_accuracy: 0.5800
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 2.8266 - val_accuracy: 0.5700
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.0512 - val_accuracy: 0.5680
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.2353 - val_accuracy: 0.5740
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 5.9118e-04 - accuracy: 1.0000 - val_loss: 3.3844 - val_accuracy: 0.5760
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 3.1568e-04 - accuracy: 1.0000 - val_loss: 3.5373 - val_accuracy: 0.5720
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 2.1249e-04 - accuracy: 1.0000 - val_loss: 3.6035 - val_accuracy: 0.5770
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.1473e-04 - accuracy: 1.0000 - val_loss: 3.7413 - val_accuracy: 0.5740
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 9.6330e-05 - accuracy: 1.0000 - val_loss: 3.7877 - val_accuracy: 0.5780
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 6.1285e-05 - accuracy: 1.0000 - val_loss: 3.8649 - val_accuracy: 0.5740
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 4.0230e-05 - accuracy: 1.0000 - val_loss: 3.9509 - val_accuracy: 0.5740
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 3.0057e-05 - accuracy: 1.0000 - val_loss: 3.9881 - val_accuracy: 0.5760
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 2.3902e-05 - accuracy: 1.0000 - val_loss: 4.0878 - val_accuracy: 0.5730
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.8058e-05 - accuracy: 1.0000 - val_loss: 4.1542 - val_accuracy: 0.5730
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.3436e-05 - accuracy: 1.0000 - val_loss: 4.2174 - val_accuracy: 0.5730
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 1.1265e-05 - accuracy: 1.0000 - val_loss: 4.2824 - val_accuracy: 0.5720
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 8.8613e-06 - accuracy: 1.0000 - val_loss: 4.3395 - val_accuracy: 0.5770
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 6.9764e-06 - accuracy: 1.0000 - val_loss: 4.4239 - val_accuracy: 0.5780
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 4.7248e-06 - accuracy: 1.0000 - val_loss: 4.4680 - val_accuracy: 0.5790
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 4.5275e-06 - accuracy: 1.0000 - val_loss: 4.5295 - val_accuracy: 0.5780
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 3.5696e-06 - accuracy: 1.0000 - val_loss: 4.5766 - val_accuracy: 0.5760
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 2.6465e-06 - accuracy: 1.0000 - val_loss: 4.6221 - val_accuracy: 0.5770
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.004.
# 4/4 [==============================] - 9s 3s/step - loss: 2.2373e-06 - accuracy: 1.0000 - val_loss: 4.7127 - val_accuracy: 0.5770

# %%
acc_3 = history.history['accuracy']
val_acc_3 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_3",acc_3)
record_Results("val_acc_3",val_acc_3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_3 = Get_Results("acc_3")["acc_3"]
val_acc_3 = Get_Results("val_acc_3")["val_acc_3"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,[],[],l_r)

# %% [markdown]
# **LR constant**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
# epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 400/400 [==============================] - 13s 31ms/step - loss: 0.9707 - accuracy: 0.5352 - val_loss: 0.6589 - val_accuracy: 0.6350
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6200 - accuracy: 0.6685 - val_loss: 0.6022 - val_accuracy: 0.7030
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 134/134 [==============================] - 11s 80ms/step - loss: 0.5131 - accuracy: 0.7570 - val_loss: 0.5740 - val_accuracy: 0.7000
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 100/100 [==============================] - 11s 109ms/step - loss: 0.4238 - accuracy: 0.7990 - val_loss: 0.5821 - val_accuracy: 0.7270
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 80/80 [==============================] - 11s 134ms/step - loss: 0.3284 - accuracy: 0.8560 - val_loss: 0.6616 - val_accuracy: 0.7310
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
# 67/67 [==============================] - 11s 158ms/step - loss: 0.2587 - accuracy: 0.8880 - val_loss: 0.7495 - val_accuracy: 0.7090
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
# 58/58 [==============================] - 10s 183ms/step - loss: 0.1982 - accuracy: 0.9165 - val_loss: 0.7241 - val_accuracy: 0.7260
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
# 50/50 [==============================] - 10s 208ms/step - loss: 0.1367 - accuracy: 0.9510 - val_loss: 0.9506 - val_accuracy: 0.7260
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
# 45/45 [==============================] - 10s 231ms/step - loss: 0.0851 - accuracy: 0.9730 - val_loss: 1.0908 - val_accuracy: 0.7190
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
# 40/40 [==============================] - 10s 257ms/step - loss: 0.0720 - accuracy: 0.9790 - val_loss: 1.1135 - val_accuracy: 0.7320
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
# 37/37 [==============================] - 10s 276ms/step - loss: 0.0314 - accuracy: 0.9910 - val_loss: 2.1560 - val_accuracy: 0.5870
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0569 - accuracy: 0.9795 - val_loss: 1.4333 - val_accuracy: 0.7310
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
# 31/31 [==============================] - 10s 329ms/step - loss: 0.1262 - accuracy: 0.9670 - val_loss: 1.2528 - val_accuracy: 0.7270
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
# 29/29 [==============================] - 10s 349ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.5662 - val_accuracy: 0.7290
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
# 27/27 [==============================] - 10s 374ms/step - loss: 0.1048 - accuracy: 0.9720 - val_loss: 1.2612 - val_accuracy: 0.7240
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
# 25/25 [==============================] - 10s 404ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.5308 - val_accuracy: 0.7340
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
# 24/24 [==============================] - 10s 419ms/step - loss: 0.1335 - accuracy: 0.9760 - val_loss: 1.2452 - val_accuracy: 0.7320
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
# 23/23 [==============================] - 10s 440ms/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 1.5129 - val_accuracy: 0.7390
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
# 22/22 [==============================] - 10s 460ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 2.5181 - val_accuracy: 0.6530
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
# 20/20 [==============================] - 10s 513ms/step - loss: 0.0479 - accuracy: 0.9860 - val_loss: 1.4930 - val_accuracy: 0.7300
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
# 20/20 [==============================] - 10s 509ms/step - loss: 8.8287e-04 - accuracy: 1.0000 - val_loss: 1.6715 - val_accuracy: 0.7390
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
# 19/19 [==============================] - 10s 535ms/step - loss: 3.0565e-04 - accuracy: 1.0000 - val_loss: 1.8656 - val_accuracy: 0.7320
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
# 18/18 [==============================] - 10s 576ms/step - loss: 1.5648e-04 - accuracy: 1.0000 - val_loss: 1.9817 - val_accuracy: 0.7350
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
# 17/17 [==============================] - 10s 591ms/step - loss: 7.1168e-05 - accuracy: 1.0000 - val_loss: 2.1376 - val_accuracy: 0.7410
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
# 16/16 [==============================] - 10s 635ms/step - loss: 0.5289 - accuracy: 0.9710 - val_loss: 1.4283 - val_accuracy: 0.6870
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
# 16/16 [==============================] - 10s 650ms/step - loss: 0.0304 - accuracy: 0.9920 - val_loss: 1.5142 - val_accuracy: 0.7160
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
# 15/15 [==============================] - 10s 665ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 1.8193 - val_accuracy: 0.7180
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
# 15/15 [==============================] - 10s 661ms/step - loss: 9.9299e-04 - accuracy: 1.0000 - val_loss: 1.9016 - val_accuracy: 0.7270
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
# 14/14 [==============================] - 10s 714ms/step - loss: 0.1796 - accuracy: 0.9560 - val_loss: 1.1843 - val_accuracy: 0.7070
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
# 14/14 [==============================] - 10s 714ms/step - loss: 0.0103 - accuracy: 0.9995 - val_loss: 1.4704 - val_accuracy: 0.7200
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
# 13/13 [==============================] - 10s 777ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.6493 - val_accuracy: 0.7180
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
# 13/13 [==============================] - 10s 770ms/step - loss: 7.9113e-04 - accuracy: 1.0000 - val_loss: 1.7661 - val_accuracy: 0.7250
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
# 13/13 [==============================] - 10s 771ms/step - loss: 3.5006e-04 - accuracy: 1.0000 - val_loss: 1.8624 - val_accuracy: 0.7240
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
# 12/12 [==============================] - 10s 832ms/step - loss: 1.8048e-04 - accuracy: 1.0000 - val_loss: 1.9738 - val_accuracy: 0.7280
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
# 12/12 [==============================] - 10s 836ms/step - loss: 9.9207e-05 - accuracy: 1.0000 - val_loss: 2.0607 - val_accuracy: 0.7300
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
# 12/12 [==============================] - 10s 839ms/step - loss: 5.9889e-05 - accuracy: 1.0000 - val_loss: 2.1425 - val_accuracy: 0.7250
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
# 11/11 [==============================] - 10s 919ms/step - loss: 3.6518e-05 - accuracy: 1.0000 - val_loss: 2.2448 - val_accuracy: 0.7310
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
# 11/11 [==============================] - 10s 911ms/step - loss: 2.0172e-05 - accuracy: 1.0000 - val_loss: 2.3191 - val_accuracy: 0.7310
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
# 11/11 [==============================] - 10s 964ms/step - loss: 1.2772e-05 - accuracy: 1.0000 - val_loss: 2.4166 - val_accuracy: 0.7320
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
# 10/10 [==============================] - 10s 1s/step - loss: 8.1951e-06 - accuracy: 1.0000 - val_loss: 2.5375 - val_accuracy: 0.7390
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
# 10/10 [==============================] - 10s 1s/step - loss: 4.7598e-06 - accuracy: 1.0000 - val_loss: 2.6052 - val_accuracy: 0.7370
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
# 10/10 [==============================] - 10s 1s/step - loss: 3.1318e-06 - accuracy: 1.0000 - val_loss: 2.6617 - val_accuracy: 0.7380
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
# 10/10 [==============================] - 10s 1s/step - loss: 1.0536 - accuracy: 0.9400 - val_loss: 1.3814 - val_accuracy: 0.6970
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
# 10/10 [==============================] - 10s 1s/step - loss: 0.0124 - accuracy: 0.9985 - val_loss: 1.5564 - val_accuracy: 0.6980
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
# 9/9 [==============================] - 10s 1s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6864 - val_accuracy: 0.6980
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
# 9/9 [==============================] - 10s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.7743 - val_accuracy: 0.7020
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
# 9/9 [==============================] - 10s 1s/step - loss: 6.1108e-04 - accuracy: 1.0000 - val_loss: 1.8470 - val_accuracy: 0.7070
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
# 9/9 [==============================] - 10s 1s/step - loss: 3.3987e-04 - accuracy: 1.0000 - val_loss: 1.9277 - val_accuracy: 0.7080
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
# 9/9 [==============================] - 10s 1s/step - loss: 2.1768e-04 - accuracy: 1.0000 - val_loss: 1.9912 - val_accuracy: 0.7150
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
# 8/8 [==============================] - 10s 1s/step - loss: 1.3952e-04 - accuracy: 1.0000 - val_loss: 2.0821 - val_accuracy: 0.7140
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
# 8/8 [==============================] - 10s 1s/step - loss: 1.0108e-04 - accuracy: 1.0000 - val_loss: 2.1351 - val_accuracy: 0.7150
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
# 8/8 [==============================] - 10s 1s/step - loss: 6.3516e-05 - accuracy: 1.0000 - val_loss: 2.2060 - val_accuracy: 0.7240
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
# 8/8 [==============================] - 10s 1s/step - loss: 4.3047e-05 - accuracy: 1.0000 - val_loss: 2.2438 - val_accuracy: 0.7240
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
# 8/8 [==============================] - 10s 1s/step - loss: 3.0797e-05 - accuracy: 1.0000 - val_loss: 2.3246 - val_accuracy: 0.7260
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
# 8/8 [==============================] - 10s 1s/step - loss: 2.1731e-05 - accuracy: 1.0000 - val_loss: 2.3701 - val_accuracy: 0.7280
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
# 8/8 [==============================] - 10s 1s/step - loss: 1.5428e-05 - accuracy: 1.0000 - val_loss: 2.4204 - val_accuracy: 0.7270
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
# 8/8 [==============================] - 10s 1s/step - loss: 1.0111e-05 - accuracy: 1.0000 - val_loss: 2.4970 - val_accuracy: 0.7280
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
# 7/7 [==============================] - 10s 1s/step - loss: 7.4896e-06 - accuracy: 1.0000 - val_loss: 2.5558 - val_accuracy: 0.7290
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
# 7/7 [==============================] - 10s 1s/step - loss: 5.6225e-06 - accuracy: 1.0000 - val_loss: 2.5762 - val_accuracy: 0.7280
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
# 7/7 [==============================] - 10s 2s/step - loss: 4.1873e-06 - accuracy: 1.0000 - val_loss: 2.6317 - val_accuracy: 0.7360
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
# 7/7 [==============================] - 10s 1s/step - loss: 2.8306e-06 - accuracy: 1.0000 - val_loss: 2.7212 - val_accuracy: 0.7310
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
# 7/7 [==============================] - 10s 2s/step - loss: 2.1050e-06 - accuracy: 1.0000 - val_loss: 2.7604 - val_accuracy: 0.7370
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
# 7/7 [==============================] - 10s 1s/step - loss: 1.6209e-06 - accuracy: 1.0000 - val_loss: 2.7802 - val_accuracy: 0.7370
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
# 7/7 [==============================] - 10s 1s/step - loss: 1.7591e-06 - accuracy: 1.0000 - val_loss: 2.8061 - val_accuracy: 0.7370
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
# 7/7 [==============================] - 10s 2s/step - loss: 8.5050e-07 - accuracy: 1.0000 - val_loss: 2.9298 - val_accuracy: 0.7340
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
# 7/7 [==============================] - 10s 2s/step - loss: 0.0488 - accuracy: 0.9810 - val_loss: 9.0498 - val_accuracy: 0.5290
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
# 6/6 [==============================] - 10s 2s/step - loss: 0.8702 - accuracy: 0.9230 - val_loss: 1.8852 - val_accuracy: 0.7090
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
# 6/6 [==============================] - 10s 2s/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 1.6461 - val_accuracy: 0.7070
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
# 6/6 [==============================] - 10s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.9203 - val_accuracy: 0.7130
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
# 6/6 [==============================] - 10s 2s/step - loss: 7.5475e-04 - accuracy: 1.0000 - val_loss: 1.9865 - val_accuracy: 0.7190
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
# 6/6 [==============================] - 10s 2s/step - loss: 4.7614e-04 - accuracy: 1.0000 - val_loss: 2.0535 - val_accuracy: 0.7190
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
# 6/6 [==============================] - 10s 2s/step - loss: 3.3998e-04 - accuracy: 1.0000 - val_loss: 2.1276 - val_accuracy: 0.7190
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
# 6/6 [==============================] - 10s 2s/step - loss: 2.5811e-04 - accuracy: 1.0000 - val_loss: 2.1702 - val_accuracy: 0.7180
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
# 6/6 [==============================] - 10s 2s/step - loss: 1.8888e-04 - accuracy: 1.0000 - val_loss: 2.2488 - val_accuracy: 0.7200
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
# 6/6 [==============================] - 10s 2s/step - loss: 1.5036e-04 - accuracy: 1.0000 - val_loss: 2.2836 - val_accuracy: 0.7170
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
# 6/6 [==============================] - 10s 2s/step - loss: 1.0082e-04 - accuracy: 1.0000 - val_loss: 2.3146 - val_accuracy: 0.7190
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
# 6/6 [==============================] - 10s 2s/step - loss: 7.4640e-05 - accuracy: 1.0000 - val_loss: 2.3702 - val_accuracy: 0.7180
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
# 6/6 [==============================] - 10s 2s/step - loss: 6.0467e-05 - accuracy: 1.0000 - val_loss: 2.3768 - val_accuracy: 0.7170
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 6/6 [==============================] - 10s 2s/step - loss: 5.0042e-05 - accuracy: 1.0000 - val_loss: 2.4511 - val_accuracy: 0.7190
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 5/5 [==============================] - 10s 2s/step - loss: 3.3745e-05 - accuracy: 1.0000 - val_loss: 2.4937 - val_accuracy: 0.7200
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 5/5 [==============================] - 10s 2s/step - loss: 2.3969e-05 - accuracy: 1.0000 - val_loss: 2.5348 - val_accuracy: 0.7210
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 5/5 [==============================] - 10s 2s/step - loss: 1.9152e-05 - accuracy: 1.0000 - val_loss: 2.5709 - val_accuracy: 0.7210
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 5/5 [==============================] - 10s 2s/step - loss: 1.5427e-05 - accuracy: 1.0000 - val_loss: 2.6161 - val_accuracy: 0.7250
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 5/5 [==============================] - 10s 2s/step - loss: 1.2789e-05 - accuracy: 1.0000 - val_loss: 2.6322 - val_accuracy: 0.7210
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 5/5 [==============================] - 10s 2s/step - loss: 9.8219e-06 - accuracy: 1.0000 - val_loss: 2.6888 - val_accuracy: 0.7240
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 5/5 [==============================] - 10s 2s/step - loss: 7.9645e-06 - accuracy: 1.0000 - val_loss: 2.6983 - val_accuracy: 0.7290
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 5/5 [==============================] - 10s 2s/step - loss: 6.6643e-06 - accuracy: 1.0000 - val_loss: 2.7784 - val_accuracy: 0.7250
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 5/5 [==============================] - 10s 2s/step - loss: 4.8801e-06 - accuracy: 1.0000 - val_loss: 2.8104 - val_accuracy: 0.7280
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 5/5 [==============================] - 10s 2s/step - loss: 3.9319e-06 - accuracy: 1.0000 - val_loss: 2.8365 - val_accuracy: 0.7280
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 5/5 [==============================] - 10s 2s/step - loss: 3.0741e-06 - accuracy: 1.0000 - val_loss: 2.8672 - val_accuracy: 0.7320
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 5/5 [==============================] - 11s 2s/step - loss: 2.4479e-06 - accuracy: 1.0000 - val_loss: 2.9247 - val_accuracy: 0.7310
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 5/5 [==============================] - 11s 2s/step - loss: 1.9711e-06 - accuracy: 1.0000 - val_loss: 2.9125 - val_accuracy: 0.7330
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 5/5 [==============================] - 11s 3s/step - loss: 2.0179e-06 - accuracy: 1.0000 - val_loss: 2.9691 - val_accuracy: 0.7320
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 5/5 [==============================] - 11s 3s/step - loss: 1.1947e-06 - accuracy: 1.0000 - val_loss: 3.0305 - val_accuracy: 0.7320
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 5/5 [==============================] - 11s 2s/step - loss: 9.3293e-07 - accuracy: 1.0000 - val_loss: 3.0549 - val_accuracy: 0.7310
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 5/5 [==============================] - 11s 3s/step - loss: 7.6138e-07 - accuracy: 1.0000 - val_loss: 3.0468 - val_accuracy: 0.7360
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 5/5 [==============================] - 11s 2s/step - loss: 6.0452e-07 - accuracy: 1.0000 - val_loss: 3.1716 - val_accuracy: 0.7350
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 5/5 [==============================] - 11s 2s/step - loss: 4.9791e-07 - accuracy: 1.0000 - val_loss: 3.1746 - val_accuracy: 0.7350
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 5/5 [==============================] - 11s 2s/step - loss: 1.6768e-06 - accuracy: 1.0000 - val_loss: 2.7448 - val_accuracy: 0.6960
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 4/4 [==============================] - 11s 3s/step - loss: 3.4961 - accuracy: 0.8535 - val_loss: 1.5607 - val_accuracy: 0.7010

# %%
# @title
# model = cat_model()

# from keras.callbacks import LearningRateScheduler

# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR

#   call = [ LearningRateScheduler(set_LR,verbose=1) ]

#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size

#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             # callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_4",acc_4)
record_Results("val_acc_4",val_acc_4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_4 = Get_Results("acc_4")["acc_4"]
val_acc_4 = Get_Results("val_acc_4")["val_acc_4"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0

# %%
# acc_1_dif = []
# for i in range(len(acc_1)): acc_1_dif.append(acc_1[i] - val_acc_1[i]) 
# acc_2_dif = []
# for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0]) 
# acc_3_dif = []
# for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0]) 
# acc_4_dif = []
# for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
# plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
# plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3_dif, label='BS = const acc',ls='-.',c='g')
# plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4_dif, label='LR = const acc',ls='-.',c='y')
# plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7941dee67196> in <module>()
#       1 plt.figure(figsize=(15, 10))
#       2
# ----> 3 plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
#       4 # plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
#       5 plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
#
# NameError: name 'acc_1_dif' is not defined

# %%
import time
import json
import pprint
import hashlib
import struct
import re
import base64
import httplib
import sys
from multiprocessing import Process

ERR_SLEEP = 15
MAX_NONCE = "1000000L"

settings = {}
pp = pprint.PrettyPrinter(indent=4)

class BitcoinRPC:
	OBJID = 1

	def __init__(self, host, port, username, password):
		authpair = "%s:%s" % (username, password)
		self.authhdr = "Basic %s" % (base64.b64encode(authpair))
		self.conn = httplib.HTTPConnection(host, port, False, 30)
	def rpc(self, method, params=None):
		self.OBJID += 1
		obj = { 'version' : '1.1',
			'method' : method,
			'id' : self.OBJID }
		if params is None:
			obj['params'] = []
		else:
			obj['params'] = params
		self.conn.request('POST', '/', json.dumps(obj),
			{ 'Authorization' : self.authhdr,
			  'Content-type' : 'application/json' })

		resp = self.conn.getresponse()
		if resp is None:
			print "JSON-RPC: no response"
			return None

		body = resp.read()
		resp_obj = json.loads(body)
		if resp_obj is None:
			print "JSON-RPC: cannot JSON-decode body"
			return None
		if 'error' in resp_obj and resp_obj['error'] != None:
			return resp_obj['error']
		if 'result' not in resp_obj:
			print "JSON-RPC: no result in object"
			return None

		return resp_obj['result']
	def getblockcount(self):
		return self.rpc('getblockcount')
	def getwork(self, data=None):
		return self.rpc('getwork', data)

def uint32(x):
	return x & '0xffffffffL'

def bytereverse(x):
	return uint32(( ((x) << 24) | (((x) << 8) & 0x00ff0000) |
			(((x) >> 8) & 0x0000ff00) | ((x) >> 24) ))

def bufreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		word = struct.unpack('@I', in_buf[i:i+4])[0]
		out_words.append(struct.pack('@I', bytereverse(word)))
	return ''.join(out_words)

def wordreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		out_words.append(in_buf[i:i+4])
	out_words.reverse()
	return ''.join(out_words)

class Miner:
	def __init__(self, id):
		self.id = id
		self.max_nonce = MAX_NONCE

	def work(self, datastr, targetstr):
		# decode work data hex string to binary
		static_data = datastr.decode('hex')
		static_data = bufreverse(static_data)

		# the first 76b of 80b do not change
		blk_hdr = static_data[:76]

		# decode 256-bit target value
		targetbin = targetstr.decode('hex')
		targetbin = targetbin[::-1]	# byte-swap and dword-swap
		targetbin_str = targetbin.encode('hex')
		target = long(targetbin_str, 16)

		# pre-hash first 76b of block header
		static_hash = hashlib.sha256()
		static_hash.update(blk_hdr)

		for nonce in xrange(self.max_nonce):

			# encode 32-bit nonce value
			nonce_bin = struct.pack("<I", nonce)

			# hash final 4b, the nonce value
			hash1_o = static_hash.copy()
			hash1_o.update(nonce_bin)
			hash1 = hash1_o.digest()

			# sha256 hash of sha256 hash
			hash_o = hashlib.sha256()
			hash_o.update(hash1)
			hash = hash_o.digest()

			# quick test for winning solution: high 32 bits zero?
			if hash[-4:] != '\0\0\0\0':
				continue

			# convert binary hash to 256-bit Python long
			hash = bufreverse(hash)
			hash = wordreverse(hash)

			hash_str = hash.encode('hex')
			l = long(hash_str, 16)

			# proof-of-work test:  hash < target
			if l < target:
				print time.asctime(), "PROOF-OF-WORK found: %064x" % (l,)
				return (nonce + 1, nonce_bin)
			else:
				print time.asctime(), "PROOF-OF-WORK false positive %064x" % (l,)
#				return (nonce + 1, nonce_bin)

		return (nonce + 1, None)

	def submit_work(self, rpc, original_data, nonce_bin):
		nonce_bin = bufreverse(nonce_bin)
		nonce = nonce_bin.encode('hex')
		solution = original_data[:152] + nonce + original_data[160:256]
		param_arr = [ solution ]
		result = rpc.getwork(param_arr)
		print time.asctime(), "--> Upstream RPC result:", result

	def iterate(self, rpc):
		work = rpc.getwork()
		if work is None:
			time.sleep(ERR_SLEEP)
			return
		if 'data' not in work or 'target' not in work:
			time.sleep(ERR_SLEEP)
			return

		time_start = time.time()

		(hashes_done, nonce_bin) = self.work(work['data'],
						     work['target'])

		time_end = time.time()
		time_diff = time_end - time_start

		self.max_nonce = long(
			(hashes_done * settings['scantime']) / time_diff)
		if self.max_nonce > '0xfffffffaL':
			self.max_nonce = '0xfffffffaL'

		if settings['hashmeter']:
			print "HashMeter(%d): %d hashes, %.2f Khash/sec" % (
			      self.id, hashes_done,
			      (hashes_done / 1000.0) / time_diff)

		if nonce_bin is not None:
			self.submit_work(rpc, work['data'], nonce_bin)

	def loop(self):
		rpc = BitcoinRPC(settings['host'], settings['port'],
				 settings['rpcuser'], settings['rpcpass'])
		if rpc is None:
			return

		while True:
			self.iterate(rpc)

def miner_thread(id):
	miner = Miner(id)
	miner.loop()

if __name__ == '__main__':
	if len(sys.argv) != 2:
		print "Usage: pyminer.py CONFIG-FILE"
		sys.exit(1)

	f = open(sys.argv[1])
	for line in f:
		# skip comment lines
		m = re.search('^\s*#', line)
		if m:
			continue

		# parse key=value lines
		m = re.search('^(\w+)\s*=\s*(\S.*)$', line)
		if m is None:
			continue
		settings[m.group(1)] = m.group(2)
	f.close()

	if 'host' not in settings:
		settings['host'] = '127.0.0.1'
	if 'port' not in settings:
		settings['port'] = 8332
	if 'threads' not in settings:
		settings['threads'] = 1
	if 'hashmeter' not in settings:
		settings['hashmeter'] = 0
	if 'scantime' not in settings:
		settings['scantime'] = "30L"
	if 'rpcuser' not in settings or 'rpcpass' not in settings:
		print "Missing username and/or password in cfg file"
		sys.exit(1)

	settings['port'] = int(settings['port'])
	settings['threads'] = int(settings['threads'])
	settings['hashmeter'] = int(settings['hashmeter'])
	settings['scantime'] = long(settings['scantime'])

	thr_list = []
	for thr_id in range(settings['threads']):
		p = Process(target=miner_thread, args=(thr_id,))
		p.start()
		thr_list.append(p)
		time.sleep(1)			# stagger threads

	print settings['threads'], "mining threads started"

	print time.asctime(), "Miner Starts - %s:%s" % (settings['host'], settings['port'])
	try:
		for thr_proc in thr_list:
			thr_proc.join()
	except KeyboardInterrupt:
		pass
	print time.asctime(), "Miner Stops - %s:%s" % (settings['host'], settings['port'])
