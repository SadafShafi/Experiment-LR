# %% [markdown]
# # *LR decresing wrt epoch (inverse relationship) with random fluctutions *
#
#
# ---
#
#
#
# ---

# %% [markdown]
# *Save and Load results from here*

# %%
def record_Results(key,results):
  import json
  from google.colab import drive


  drive.mount('/content/drive')

  dictionary ={
      key : results
  } 
  json_object = json.dumps(dictionary)

  FILE_PATH = "/content/drive/My Drive/Results/"+"Cats_vs_Dogs_Experiment_4C"+str(key)+".json"
  f = open(FILE_PATH, "w")
  f.write(json_object)
  print("recorded")

def Get_Results(file):
  import json
  from google.colab import drive

  drive.mount('/content/drive')

  FILE_PATH = "/content/drive/My Drive/Results/"+"Cats_vs_Dogs_Experiment_4C"+str(file)+".json"
  f = open(FILE_PATH, "r")
  json_object = json.load(f)
  
  return json_object

# %% [markdown]
# **STARTING GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.8728713579999976
# GPU (s):
# 0.04977853099998697
# GPU speedup over CPU: 77x

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-05-06 07:41:41--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.189.128, 108.177.125.128, 74.125.23.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.189.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   101MB/s    in 0.7s
#
# 2021-05-06 07:41:42 (101 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])

print('total training cat images:', len(os.listdir(train_cats_dir)))
print('total training dog images:', len(os.listdir(train_dogs_dir)))
print('total validation cat images:', len(os.listdir(validation_cats_dir)))
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow validation images in batches of 20 using val_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# ['cat.691.jpg', 'cat.385.jpg', 'cat.620.jpg', 'cat.905.jpg', 'cat.433.jpg', 'cat.373.jpg', 'cat.155.jpg', 'cat.973.jpg', 'cat.514.jpg', 'cat.458.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# from tensorflow.python.keras import backend
# from tensorflow.python.keras.datasets.cifar import load_batch
# from tensorflow.python.keras.utils.data_utils import get_file
# from tensorflow.python.util.tf_export import keras_export

# dirname = 'cifar-10-batches-py'
# origin = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip '
# path = get_file(
#     dirname,
#     origin=origin,
#     untar=True,
#     file_hash=
#     '6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce')

# num_train_samples = 50000

# x_train = np.empty((num_train_samples, 3, 32, 32), dtype='uint8')
# y_train = np.empty((num_train_samples,), dtype='uint8')

# for i in range(1, 6):
#   fpath = os.path.join(path, 'data_batch_' + str(i))
#   (x_train[(i - 1) * 10000:i * 10000, :, :, :],
#     y_train[(i - 1) * 10000:i * 10000]) = load_batch(fpath)

# fpath = os.path.join(path, 'test_batch')
# x_test, y_test = load_batch(fpath)

# y_train = np.reshape(y_train, (len(y_train), 1))
# y_test = np.reshape(y_test, (len(y_test), 1))

# if backend.image_data_format() == 'channels_last':
#   x_train = x_train.transpose(0, 2, 3, 1)
#   x_test = x_test.transpose(0, 2, 3, 1)

# x_test = x_test.astype(x_train.dtype)
# y_test = y_test.astype(y_train.dtype)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop

def cat_model():

  img_input = layers.Input(shape=(150, 150, 3))

  x = layers.Conv2D(16, 3, activation='relu')(img_input)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(32, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(64, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(512, activation='relu')(x)

  output = layers.Dense(1, activation='sigmoid')(x)

  model = Model(img_input, output)



  model.compile(loss='binary_crossentropy',
                optimizer=RMSprop(lr=0.001),
                metrics=['accuracy'])
  
  return model 

model = cat_model()

# %%
cat_model().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Test for LR**

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=100
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)
  


  # if (z%2 == 0):
  #   LR = random() * batch_size/10000
  #   lr.append(LR)
  # else:
  LR = random() / (z*10000)
  lr.append(LR)

lr = lr[::-1] 
lord_LR = lr
# print(min(lr))


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()


# lr = []
# epoo=150
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   # print(z,(batch_size)/((z+1)**(3/2))/80)
  

#   LR = random() * z/10000
#   # LR=LR/8
#   lr.append(LR)

# plt.plot(lr, label='Learning Rate')
# plt.xlabel('Epoch')
# plt.ylabel('LR')
# plt.legend(loc='lower right')
# plt.show()

# %%
# baseline model with dropout for the dogs vs cats dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
 
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(150, 150, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.5))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
	return model

# model = define_model()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
# epoch=1
# for i in range(5,100,5):

#   print("epoch ",epoch)
#   epoch+=1
#   train_generator.batch_size=i
#   validation_generator.batch_size=i

# train_generator.batch_size=i
# validation_generator.batch_size=i

history = model.fit(
      train_generator,
      epochs=100,
      validation_data=validation_generator,
      verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 13s 112ms/step - loss: 1.2946 - accuracy: 0.5388 - val_loss: 0.6569 - val_accuracy: 0.5440
# Epoch 2/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.6280 - accuracy: 0.6587 - val_loss: 0.5727 - val_accuracy: 0.7080
# Epoch 3/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.5374 - accuracy: 0.7320 - val_loss: 0.5708 - val_accuracy: 0.7080
# Epoch 4/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.4805 - accuracy: 0.7559 - val_loss: 0.5408 - val_accuracy: 0.7290
# Epoch 5/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3677 - accuracy: 0.8304 - val_loss: 1.2476 - val_accuracy: 0.6400
# Epoch 6/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.3394 - accuracy: 0.8495 - val_loss: 0.6282 - val_accuracy: 0.7250
# Epoch 7/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.2122 - accuracy: 0.9220 - val_loss: 0.8049 - val_accuracy: 0.7040
# Epoch 8/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.1413 - accuracy: 0.9509 - val_loss: 0.7176 - val_accuracy: 0.7230
# Epoch 9/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.1000 - accuracy: 0.9664 - val_loss: 0.9841 - val_accuracy: 0.7380
# Epoch 10/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0575 - accuracy: 0.9792 - val_loss: 1.0184 - val_accuracy: 0.7550
# Epoch 11/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0382 - accuracy: 0.9882 - val_loss: 1.3588 - val_accuracy: 0.7630
# Epoch 12/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0446 - accuracy: 0.9867 - val_loss: 1.1884 - val_accuracy: 0.7350
# Epoch 13/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0134 - accuracy: 0.9975 - val_loss: 1.8806 - val_accuracy: 0.6870
# Epoch 14/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0337 - accuracy: 0.9935 - val_loss: 1.4483 - val_accuracy: 0.7300
# Epoch 15/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0185 - accuracy: 0.9972 - val_loss: 1.5470 - val_accuracy: 0.7420
# Epoch 16/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0196 - accuracy: 0.9962 - val_loss: 1.7984 - val_accuracy: 0.7220
# Epoch 17/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 1.8812 - val_accuracy: 0.7430
# Epoch 18/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0156 - accuracy: 0.9972 - val_loss: 1.9540 - val_accuracy: 0.7440
# Epoch 19/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0262 - accuracy: 0.9972 - val_loss: 1.8732 - val_accuracy: 0.7440
# Epoch 20/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 2.6623 - val_accuracy: 0.7320
# Epoch 21/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.1217 - accuracy: 0.9916 - val_loss: 2.4467 - val_accuracy: 0.7190
# Epoch 22/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0274 - accuracy: 0.9940 - val_loss: 1.9737 - val_accuracy: 0.7340
# Epoch 23/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0524 - accuracy: 0.9924 - val_loss: 2.5723 - val_accuracy: 0.7350
# Epoch 24/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0750 - accuracy: 0.9936 - val_loss: 2.2934 - val_accuracy: 0.7380
# Epoch 25/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0267 - accuracy: 0.9965 - val_loss: 2.1745 - val_accuracy: 0.7340
# Epoch 26/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0110 - accuracy: 0.9977 - val_loss: 2.0584 - val_accuracy: 0.7500
# Epoch 27/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0339 - accuracy: 0.9945 - val_loss: 2.3780 - val_accuracy: 0.7390
# Epoch 28/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0210 - accuracy: 0.9942 - val_loss: 3.0235 - val_accuracy: 0.7440
# Epoch 29/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.1089 - accuracy: 0.9850 - val_loss: 2.9030 - val_accuracy: 0.7280
# Epoch 30/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0111 - accuracy: 0.9942 - val_loss: 3.1623 - val_accuracy: 0.7410
# Epoch 31/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 2.3800 - val_accuracy: 0.7440
# Epoch 32/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 2.6666 - val_accuracy: 0.7180
# Epoch 33/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 2.6248 - val_accuracy: 0.7440
# Epoch 34/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 2.9684 - val_accuracy: 0.7120
# Epoch 35/100
# 100/100 [==============================] - 11s 108ms/step - loss: 7.9151e-04 - accuracy: 0.9999 - val_loss: 3.3372 - val_accuracy: 0.7370
# Epoch 36/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0822 - accuracy: 0.9872 - val_loss: 3.3306 - val_accuracy: 0.7590
# Epoch 37/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 3.2723 - val_accuracy: 0.7320
# Epoch 38/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0244 - accuracy: 0.9937 - val_loss: 3.2543 - val_accuracy: 0.7300
# Epoch 39/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 3.3202 - val_accuracy: 0.7410
# Epoch 40/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 3.5083 - val_accuracy: 0.7390
# Epoch 41/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 3.8344 - val_accuracy: 0.7190
# Epoch 42/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0276 - accuracy: 0.9970 - val_loss: 4.0591 - val_accuracy: 0.7220
# Epoch 43/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 3.5343 - val_accuracy: 0.7320
# Epoch 44/100
# 100/100 [==============================] - 11s 107ms/step - loss: 7.7584e-06 - accuracy: 1.0000 - val_loss: 4.0524 - val_accuracy: 0.7530
# Epoch 45/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0130 - accuracy: 0.9982 - val_loss: 4.1822 - val_accuracy: 0.7260
# Epoch 46/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 4.6030 - val_accuracy: 0.7240
# Epoch 47/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0334 - accuracy: 0.9941 - val_loss: 3.7394 - val_accuracy: 0.7370
# Epoch 48/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0096 - accuracy: 0.9981 - val_loss: 3.3629 - val_accuracy: 0.7380
# Epoch 49/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0135 - accuracy: 0.9967 - val_loss: 3.2707 - val_accuracy: 0.7440
# Epoch 50/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 3.5557 - val_accuracy: 0.7360
# Epoch 51/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0158 - accuracy: 0.9971 - val_loss: 3.8273 - val_accuracy: 0.7450
# Epoch 52/100
# 100/100 [==============================] - 11s 107ms/step - loss: 3.0871e-06 - accuracy: 1.0000 - val_loss: 4.0848 - val_accuracy: 0.7370
# Epoch 53/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 4.9223 - val_accuracy: 0.7170
# Epoch 54/100
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.4211 - val_accuracy: 0.7190
# Epoch 55/100
# 100/100 [==============================] - 11s 108ms/step - loss: 1.2925e-04 - accuracy: 1.0000 - val_loss: 5.1914 - val_accuracy: 0.7280
# Epoch 56/100
# 100/100 [==============================] - 11s 107ms/step - loss: 3.2626e-07 - accuracy: 1.0000 - val_loss: 5.4452 - val_accuracy: 0.7290
# Epoch 57/100
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 5.3416 - val_accuracy: 0.7270
# Epoch 58/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0201 - accuracy: 0.9965 - val_loss: 5.0271 - val_accuracy: 0.7230
# Epoch 59/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0317 - accuracy: 0.9970 - val_loss: 4.6257 - val_accuracy: 0.7270
# Epoch 60/100
# 100/100 [==============================] - 11s 105ms/step - loss: 9.1222e-06 - accuracy: 1.0000 - val_loss: 4.7618 - val_accuracy: 0.7250
# Epoch 61/100
# 100/100 [==============================] - 11s 105ms/step - loss: 8.2657e-08 - accuracy: 1.0000 - val_loss: 5.5205 - val_accuracy: 0.7310
# Epoch 62/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0454 - accuracy: 0.9939 - val_loss: 5.5021 - val_accuracy: 0.7240
# Epoch 63/100
# 100/100 [==============================] - 10s 105ms/step - loss: 4.9128e-07 - accuracy: 1.0000 - val_loss: 5.4255 - val_accuracy: 0.7330
# Epoch 64/100
# 100/100 [==============================] - 10s 105ms/step - loss: 5.1507e-08 - accuracy: 1.0000 - val_loss: 6.4636 - val_accuracy: 0.7350
# Epoch 65/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0381 - accuracy: 0.9945 - val_loss: 6.2015 - val_accuracy: 0.7320
# Epoch 66/100
# 100/100 [==============================] - 10s 105ms/step - loss: 6.0936e-07 - accuracy: 1.0000 - val_loss: 6.1582 - val_accuracy: 0.7310
# Epoch 67/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0183 - accuracy: 0.9989 - val_loss: 6.2745 - val_accuracy: 0.7410
# Epoch 68/100
# 100/100 [==============================] - 11s 106ms/step - loss: 1.4030e-04 - accuracy: 1.0000 - val_loss: 6.4195 - val_accuracy: 0.7430
# Epoch 69/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0299 - accuracy: 0.9945 - val_loss: 5.8889 - val_accuracy: 0.7400
# Epoch 70/100
# 100/100 [==============================] - 11s 107ms/step - loss: 5.9833e-07 - accuracy: 1.0000 - val_loss: 6.5957 - val_accuracy: 0.7400
# Epoch 71/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0818 - accuracy: 0.9920 - val_loss: 5.8770 - val_accuracy: 0.7430
# Epoch 72/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0142 - accuracy: 0.9984 - val_loss: 5.8385 - val_accuracy: 0.7350
# Epoch 73/100
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 5.2938 - val_accuracy: 0.7510
# Epoch 74/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 5.7484 - val_accuracy: 0.7340
# Epoch 75/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 6.7458 - val_accuracy: 0.7300
# Epoch 76/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0546 - accuracy: 0.9940 - val_loss: 5.7452 - val_accuracy: 0.7430
# Epoch 77/100
# 100/100 [==============================] - 10s 105ms/step - loss: 6.8206e-06 - accuracy: 1.0000 - val_loss: 5.7385 - val_accuracy: 0.7390
# Epoch 78/100
# 100/100 [==============================] - 10s 105ms/step - loss: 7.4030e-08 - accuracy: 1.0000 - val_loss: 6.9789 - val_accuracy: 0.7360
# Epoch 79/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0674 - accuracy: 0.9938 - val_loss: 6.4493 - val_accuracy: 0.7240
# Epoch 80/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0088 - accuracy: 0.9992 - val_loss: 7.0491 - val_accuracy: 0.7230
# Epoch 81/100
# 100/100 [==============================] - 10s 105ms/step - loss: 1.9003e-04 - accuracy: 1.0000 - val_loss: 5.8573 - val_accuracy: 0.7300
# Epoch 82/100
# 100/100 [==============================] - 10s 104ms/step - loss: 4.4561e-06 - accuracy: 1.0000 - val_loss: 6.4525 - val_accuracy: 0.7330
# Epoch 83/100
# 100/100 [==============================] - 11s 105ms/step - loss: 3.5074e-08 - accuracy: 1.0000 - val_loss: 6.6195 - val_accuracy: 0.7350
# Epoch 84/100
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 8.1415 - val_accuracy: 0.7360
# Epoch 85/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0081 - accuracy: 0.9993 - val_loss: 6.3069 - val_accuracy: 0.7360
# Epoch 86/100
# 100/100 [==============================] - 11s 106ms/step - loss: 1.0165e-05 - accuracy: 1.0000 - val_loss: 6.3455 - val_accuracy: 0.7390
# Epoch 87/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 14.4272 - val_accuracy: 0.6800
# Epoch 88/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0187 - accuracy: 0.9963 - val_loss: 7.6393 - val_accuracy: 0.7390
# Epoch 89/100
# 100/100 [==============================] - 11s 106ms/step - loss: 2.4893e-07 - accuracy: 1.0000 - val_loss: 8.0647 - val_accuracy: 0.7340
# Epoch 90/100
# 100/100 [==============================] - 11s 106ms/step - loss: 5.9792e-04 - accuracy: 0.9998 - val_loss: 6.9984 - val_accuracy: 0.7330
# Epoch 91/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 7.5743 - val_accuracy: 0.7280
# Epoch 92/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0143 - accuracy: 0.9964 - val_loss: 5.7395 - val_accuracy: 0.7240
# Epoch 93/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0126 - accuracy: 0.9981 - val_loss: 6.1198 - val_accuracy: 0.7380
# Epoch 94/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 6.5353 - val_accuracy: 0.7300
# Epoch 95/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 7.1384 - val_accuracy: 0.7180
# Epoch 96/100
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0399 - accuracy: 0.9966 - val_loss: 7.6379 - val_accuracy: 0.7150
# Epoch 97/100
# 100/100 [==============================] - 11s 105ms/step - loss: 2.5120e-04 - accuracy: 1.0000 - val_loss: 7.2629 - val_accuracy: 0.7160
# Epoch 98/100
# 100/100 [==============================] - 11s 105ms/step - loss: 7.5007e-08 - accuracy: 1.0000 - val_loss: 7.5023 - val_accuracy: 0.7220
# Epoch 99/100
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 8.4641 - val_accuracy: 0.7050
# Epoch 100/100
# 100/100 [==============================] - 11s 105ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 7.5483 - val_accuracy: 0.7060

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_1",acc_1)
record_Results("val_acc_1",val_acc_1)
# Out:
# Mounted at /content/drive
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_1 = Get_Results("acc_1")["acc_1"]
val_acc_1 = Get_Results("val_acc_1")["val_acc_1"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # if (z%2 == 0):
  #   LR = random() * batch_size/100000
  # # lr.append(LR)
  # else:
  LR = random() / (z*10000)
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# epoch 1, Learning Rate 2.746713373393761e-05, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.5919922688215636e-09.
# 400/400 [==============================] - 14s 31ms/step - loss: 0.6920 - accuracy: 0.5172 - val_loss: 0.6921 - val_accuracy: 0.5120
#
#
# epoch 2, Learning Rate 4.4870642234598004e-05, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.706741683966022e-07.
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6920 - accuracy: 0.5195 - val_loss: 0.6914 - val_accuracy: 0.5100
#
#
# epoch 3, Learning Rate 1.7195542295335184e-05, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.016105663430322e-07.
# 134/134 [==============================] - 11s 78ms/step - loss: 0.6912 - accuracy: 0.5145 - val_loss: 0.6905 - val_accuracy: 0.5230
#
#
# epoch 4, Learning Rate 3.0336212463371287e-06, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.3356189215714805e-07.
# 100/100 [==============================] - 10s 102ms/step - loss: 0.6902 - accuracy: 0.5285 - val_loss: 0.6901 - val_accuracy: 0.5160
#
#
# epoch 5, Learning Rate 1.3012493826179745e-05, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.065835680886097e-07.
# 80/80 [==============================] - 10s 126ms/step - loss: 0.6898 - accuracy: 0.5375 - val_loss: 0.6891 - val_accuracy: 0.5120
#
#
# epoch 6, Learning Rate 2.0249082060334045e-07, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.6434920583165243e-07.
# 67/67 [==============================] - 10s 155ms/step - loss: 0.6888 - accuracy: 0.5235 - val_loss: 0.6889 - val_accuracy: 0.5140
#
#
# epoch 7, Learning Rate 8.51441049125912e-06, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.794954252917869e-07.
# 58/58 [==============================] - 10s 169ms/step - loss: 0.6885 - accuracy: 0.5295 - val_loss: 0.6886 - val_accuracy: 0.5260
#
#
# epoch 8, Learning Rate 1.179645740579902e-05, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.0056004236874874e-06.
# 50/50 [==============================] - 10s 196ms/step - loss: 0.6880 - accuracy: 0.5300 - val_loss: 0.6878 - val_accuracy: 0.5460
#
#
# epoch 9, Learning Rate 5.301243159809732e-06, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.06070409310209e-07.
# 45/45 [==============================] - 10s 216ms/step - loss: 0.6872 - accuracy: 0.5625 - val_loss: 0.6871 - val_accuracy: 0.5380
#
#
# epoch 10, Learning Rate 9.349839895532022e-06, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.997645992035227e-07.
# 40/40 [==============================] - 10s 240ms/step - loss: 0.6865 - accuracy: 0.5415 - val_loss: 0.6866 - val_accuracy: 0.5590
#
#
# epoch 11, Learning Rate 7.169621445082564e-06, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.3544051189068254e-07.
# 37/37 [==============================] - 10s 262ms/step - loss: 0.6859 - accuracy: 0.5760 - val_loss: 0.6864 - val_accuracy: 0.5600
#
#
# epoch 12, Learning Rate 6.453157514319611e-07, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.244468608195217e-07.
# 34/34 [==============================] - 10s 282ms/step - loss: 0.6857 - accuracy: 0.5820 - val_loss: 0.6857 - val_accuracy: 0.5500
#
#
# epoch 13, Learning Rate 3.7772165153548114e-06, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.644942421021723e-07.
# 31/31 [==============================] - 10s 308ms/step - loss: 0.6850 - accuracy: 0.5600 - val_loss: 0.6852 - val_accuracy: 0.5610
#
#
# epoch 14, Learning Rate 5.719377938831285e-06, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.0873834006715234e-06.
# 29/29 [==============================] - 10s 329ms/step - loss: 0.6845 - accuracy: 0.5810 - val_loss: 0.6846 - val_accuracy: 0.5650
#
#
# epoch 15, Learning Rate 5.425173237097213e-06, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.737451612418517e-07.
# 27/27 [==============================] - 10s 378ms/step - loss: 0.6838 - accuracy: 0.5835 - val_loss: 0.6843 - val_accuracy: 0.5640
#
#
# epoch 16, Learning Rate 4.154561097894729e-06, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.271469387552754e-07.
# 25/25 [==============================] - 10s 376ms/step - loss: 0.6835 - accuracy: 0.5855 - val_loss: 0.6839 - val_accuracy: 0.5670
#
#
# epoch 17, Learning Rate 2.2404558450949587e-08, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.277928850099237e-07.
# 24/24 [==============================] - 10s 395ms/step - loss: 0.6831 - accuracy: 0.6035 - val_loss: 0.6837 - val_accuracy: 0.5660
#
#
# epoch 18, Learning Rate 2.4708885068035966e-06, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.2008354644400068e-06.
# 23/23 [==============================] - 10s 422ms/step - loss: 0.6829 - accuracy: 0.5605 - val_loss: 0.6831 - val_accuracy: 0.5750
#
#
# epoch 19, Learning Rate 4.7505187541852534e-06, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.572799053577547e-07.
# 22/22 [==============================] - 10s 480ms/step - loss: 0.6823 - accuracy: 0.6210 - val_loss: 0.6829 - val_accuracy: 0.5950
#
#
# epoch 20, Learning Rate 4.28744230762172e-06, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.987184382031158e-07.
# 20/20 [==============================] - 10s 483ms/step - loss: 0.6819 - accuracy: 0.6000 - val_loss: 0.6825 - val_accuracy: 0.5890
#
#
# epoch 21, Learning Rate 5.12485648332519e-07, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.964754033193204e-07.
# 20/20 [==============================] - 10s 476ms/step - loss: 0.6816 - accuracy: 0.6020 - val_loss: 0.6822 - val_accuracy: 0.5740
#
#
# epoch 22, Learning Rate 2.4287096869841535e-06, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.215370947965796e-07.
# 19/19 [==============================] - 10s 506ms/step - loss: 0.6812 - accuracy: 0.6050 - val_loss: 0.6818 - val_accuracy: 0.5810
#
#
# epoch 23, Learning Rate 3.697683115133362e-06, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.364656051798368e-07.
# 18/18 [==============================] - 10s 535ms/step - loss: 0.6808 - accuracy: 0.6040 - val_loss: 0.6816 - val_accuracy: 0.5810
#
#
# epoch 24, Learning Rate 2.1090936964467894e-06, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.230629923826491e-06.
# 17/17 [==============================] - 10s 564ms/step - loss: 0.6806 - accuracy: 0.5960 - val_loss: 0.6811 - val_accuracy: 0.5930
#
#
# epoch 25, Learning Rate 3.9361904855014e-06, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.7546217909585065e-07.
# 16/16 [==============================] - 10s 605ms/step - loss: 0.6800 - accuracy: 0.6085 - val_loss: 0.6810 - val_accuracy: 0.5920
#
#
# epoch 26, Learning Rate 1.6105960604196783e-06, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3269536818420835e-06.
# 16/16 [==============================] - 11s 600ms/step - loss: 0.6800 - accuracy: 0.5995 - val_loss: 0.6804 - val_accuracy: 0.5880
#
#
# epoch 27, Learning Rate 3.0876709061069902e-06, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.492923798416617e-07.
# 15/15 [==============================] - 10s 632ms/step - loss: 0.6793 - accuracy: 0.6005 - val_loss: 0.6802 - val_accuracy: 0.5950
#
#
# epoch 28, Learning Rate 1.5570936225470885e-06, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.86614814175641e-07.
# 15/15 [==============================] - 10s 631ms/step - loss: 0.6790 - accuracy: 0.6145 - val_loss: 0.6800 - val_accuracy: 0.5970
#
#
# epoch 29, Learning Rate 3.32069611260996e-06, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.092667540328584e-06.
# 14/14 [==============================] - 10s 681ms/step - loss: 0.6788 - accuracy: 0.6140 - val_loss: 0.6796 - val_accuracy: 0.5950
#
#
# epoch 30, Learning Rate 7.803969650229211e-07, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.046889163351535e-06.
# 14/14 [==============================] - 11s 698ms/step - loss: 0.6784 - accuracy: 0.6205 - val_loss: 0.6793 - val_accuracy: 0.6090
#
#
# epoch 31, Learning Rate 9.850840083817934e-07, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3430211439965944e-06.
# 13/13 [==============================] - 10s 726ms/step - loss: 0.6780 - accuracy: 0.6325 - val_loss: 0.6788 - val_accuracy: 0.5960
#
#
# epoch 32, Learning Rate 1.3133110679866209e-07, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.450846144565603e-07.
# 13/13 [==============================] - 10s 723ms/step - loss: 0.6775 - accuracy: 0.6230 - val_loss: 0.6785 - val_accuracy: 0.5980
#
#
# epoch 33, Learning Rate 1.832931622137946e-06, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3658826967286307e-06.
# 13/13 [==============================] - 11s 760ms/step - loss: 0.6772 - accuracy: 0.6065 - val_loss: 0.6781 - val_accuracy: 0.5920
#
#
# epoch 34, Learning Rate 3.068753224787626e-07, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.200816333244302e-07.
# 12/12 [==============================] - 10s 907ms/step - loss: 0.6768 - accuracy: 0.6145 - val_loss: 0.6779 - val_accuracy: 0.5930
#
#
# epoch 35, Learning Rate 1.353973673515577e-07, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.692921751075448e-07.
# 12/12 [==============================] - 11s 793ms/step - loss: 0.6765 - accuracy: 0.6090 - val_loss: 0.6778 - val_accuracy: 0.5950
#
#
# epoch 36, Learning Rate 1.6348950517497438e-06, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.937670403958219e-07.
# 12/12 [==============================] - 10s 780ms/step - loss: 0.6765 - accuracy: 0.6170 - val_loss: 0.6775 - val_accuracy: 0.6000
#
#
# epoch 37, Learning Rate 1.1714373420795835e-06, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.300208414096683e-07.
# 11/11 [==============================] - 11s 867ms/step - loss: 0.6761 - accuracy: 0.6200 - val_loss: 0.6774 - val_accuracy: 0.6000
#
#
# epoch 38, Learning Rate 8.357053373380309e-07, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.0096310376350955e-07.
# 11/11 [==============================] - 11s 867ms/step - loss: 0.6760 - accuracy: 0.6205 - val_loss: 0.6774 - val_accuracy: 0.5980
#
#
# epoch 39, Learning Rate 4.279058485266734e-07, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.196720256250007e-08.
# 11/11 [==============================] - 11s 883ms/step - loss: 0.6760 - accuracy: 0.6215 - val_loss: 0.6774 - val_accuracy: 0.5990
#
#
# epoch 40, Learning Rate 1.961931268988269e-06, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.010190459181885e-07.
# 10/10 [==============================] - 11s 981ms/step - loss: 0.6759 - accuracy: 0.6190 - val_loss: 0.6773 - val_accuracy: 0.6090
#
#
# epoch 41, Learning Rate 1.434642212214462e-06, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.5693822060547865e-07.
# 10/10 [==============================] - 11s 989ms/step - loss: 0.6759 - accuracy: 0.6255 - val_loss: 0.6772 - val_accuracy: 0.6110
#
#
# epoch 42, Learning Rate 2.2734605253730814e-06, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.463800683832065e-07.
# 10/10 [==============================] - 11s 962ms/step - loss: 0.6757 - accuracy: 0.6245 - val_loss: 0.6770 - val_accuracy: 0.6110
#
#
# epoch 43, Learning Rate 1.5981839108381385e-06, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.402481439309847e-07.
# 10/10 [==============================] - 11s 970ms/step - loss: 0.6755 - accuracy: 0.6290 - val_loss: 0.6768 - val_accuracy: 0.6170
#
#
# epoch 44, Learning Rate 1.7222880798765555e-06, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3634214461740162e-06.
# 10/10 [==============================] - 11s 976ms/step - loss: 0.6753 - accuracy: 0.6430 - val_loss: 0.6764 - val_accuracy: 0.6180
#
#
# epoch 45, Learning Rate 8.9787883204657e-07, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.965807856648375e-07.
# 9/9 [==============================] - 11s 1s/step - loss: 0.6748 - accuracy: 0.6390 - val_loss: 0.6763 - val_accuracy: 0.6180
#
#
# epoch 46, Learning Rate 6.387977100635003e-07, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.1579022263888967e-06.
# 9/9 [==============================] - 11s 1s/step - loss: 0.6747 - accuracy: 0.6415 - val_loss: 0.6759 - val_accuracy: 0.6100
#
#
# epoch 47, Learning Rate 6.31645550103605e-07, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.2273197008074674e-06.
# 9/9 [==============================] - 11s 1s/step - loss: 0.6743 - accuracy: 0.6365 - val_loss: 0.6756 - val_accuracy: 0.6200
#
#
# epoch 48, Learning Rate 2.5311683547151443e-07, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.373629341455116e-07.
# 9/9 [==============================] - 11s 1s/step - loss: 0.6739 - accuracy: 0.6290 - val_loss: 0.6754 - val_accuracy: 0.6170
#
#
# epoch 49, Learning Rate 1.3500818913221235e-07, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.0837163466829285e-06.
# 9/9 [==============================] - 11s 1s/step - loss: 0.6738 - accuracy: 0.6240 - val_loss: 0.6751 - val_accuracy: 0.6050
#
#
# epoch 50, Learning Rate 4.434040066083484e-07, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.2963449374943505e-07.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6735 - accuracy: 0.6240 - val_loss: 0.6751 - val_accuracy: 0.6070
#
#
# epoch 51, Learning Rate 5.17360337429371e-07, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.075893018037851e-07.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6735 - accuracy: 0.6255 - val_loss: 0.6749 - val_accuracy: 0.6120
#
#
# epoch 52, Learning Rate 1.6155866500237374e-06, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.5090449980836335e-06.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6734 - accuracy: 0.6410 - val_loss: 0.6745 - val_accuracy: 0.6130
#
#
# epoch 53, Learning Rate 1.1136581611450463e-06, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3659278632633058e-06.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6728 - accuracy: 0.6310 - val_loss: 0.6742 - val_accuracy: 0.6070
#
#
# epoch 54, Learning Rate 2.875708978546636e-07, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.154432976934982e-06.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6724 - accuracy: 0.6365 - val_loss: 0.6740 - val_accuracy: 0.6300
#
#
# epoch 55, Learning Rate 1.1373737843729296e-06, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.5774063106778734e-07.
# 8/8 [==============================] - 12s 1s/step - loss: 0.6721 - accuracy: 0.6410 - val_loss: 0.6739 - val_accuracy: 0.6290
#
#
# epoch 56, Learning Rate 6.098460849316032e-07, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.51440939454846e-07.
# 8/8 [==============================] - 11s 2s/step - loss: 0.6720 - accuracy: 0.6450 - val_loss: 0.6738 - val_accuracy: 0.6240
#
#
# epoch 57, Learning Rate 8.432825683272272e-07, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.5123651123473866e-06.
# 8/8 [==============================] - 11s 1s/step - loss: 0.6720 - accuracy: 0.6415 - val_loss: 0.6735 - val_accuracy: 0.6150
#
#
# epoch 58, Learning Rate 9.585446063581654e-07, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.9265968518574977e-07.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6716 - accuracy: 0.6295 - val_loss: 0.6734 - val_accuracy: 0.6190
#
#
# epoch 59, Learning Rate 5.68660397285183e-07, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.129189332427561e-07.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6716 - accuracy: 0.6295 - val_loss: 0.6733 - val_accuracy: 0.6290
#
#
# epoch 60, Learning Rate 1.176863562751207e-06, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.219786251833477e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6714 - accuracy: 0.6380 - val_loss: 0.6730 - val_accuracy: 0.6270
#
#
# epoch 61, Learning Rate 3.966501442615874e-07, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.1502386726984135e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6710 - accuracy: 0.6395 - val_loss: 0.6728 - val_accuracy: 0.6240
#
#
# epoch 62, Learning Rate 4.763453886701796e-07, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.3801765217519569e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6707 - accuracy: 0.6490 - val_loss: 0.6724 - val_accuracy: 0.6220
#
#
# epoch 63, Learning Rate 1.3829876449226944e-06, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.6338480478185377e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6706 - accuracy: 0.6205 - val_loss: 0.6721 - val_accuracy: 0.6360
#
#
# epoch 64, Learning Rate 3.6044919531588936e-07, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.8947020859136933e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6700 - accuracy: 0.6450 - val_loss: 0.6717 - val_accuracy: 0.6240
#
#
# epoch 65, Learning Rate 5.610443966728648e-07, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.5661882651067183e-06.
# 7/7 [==============================] - 11s 1s/step - loss: 0.6693 - accuracy: 0.6525 - val_loss: 0.6711 - val_accuracy: 0.6290
#
#
# epoch 66, Learning Rate 1.1949794392642006e-06, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.211693050728477e-06.
# 7/7 [==============================] - 11s 2s/step - loss: 0.6688 - accuracy: 0.6520 - val_loss: 0.6707 - val_accuracy: 0.6230
#
#
# epoch 67, Learning Rate 8.850689994302058e-08, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.462786124361608e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6684 - accuracy: 0.6450 - val_loss: 0.6703 - val_accuracy: 0.6220
#
#
# epoch 68, Learning Rate 5.375721751740224e-07, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.870470999738977e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6681 - accuracy: 0.6455 - val_loss: 0.6696 - val_accuracy: 0.6230
#
#
# epoch 69, Learning Rate 1.2836779165104822e-06, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.4222616740359175e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6672 - accuracy: 0.6515 - val_loss: 0.6695 - val_accuracy: 0.6250
#
#
# epoch 70, Learning Rate 2.7859305705752506e-07, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.7610599598326773e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6674 - accuracy: 0.6500 - val_loss: 0.6691 - val_accuracy: 0.6270
#
#
# epoch 71, Learning Rate 6.550766478941155e-07, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.045856920111274e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6665 - accuracy: 0.6575 - val_loss: 0.6690 - val_accuracy: 0.6280
#
#
# epoch 72, Learning Rate 2.0819841503901137e-07, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 8.418614877482005e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6665 - accuracy: 0.6560 - val_loss: 0.6688 - val_accuracy: 0.6240
#
#
# epoch 73, Learning Rate 8.647536724296312e-07, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.2429652330195736e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6662 - accuracy: 0.6515 - val_loss: 0.6684 - val_accuracy: 0.6190
#
#
# epoch 74, Learning Rate 7.949749770266554e-07, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.86816211261374e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6659 - accuracy: 0.6510 - val_loss: 0.6683 - val_accuracy: 0.6250
#
#
# epoch 75, Learning Rate 6.694763899460116e-07, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.658559371764534e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6659 - accuracy: 0.6525 - val_loss: 0.6682 - val_accuracy: 0.6260
#
#
# epoch 76, Learning Rate 7.232953536639356e-07, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.266054684531093e-07.
# 6/6 [==============================] - 11s 2s/step - loss: 0.6656 - accuracy: 0.6540 - val_loss: 0.6681 - val_accuracy: 0.6230
#
#
# epoch 77, Learning Rate 5.623001223231629e-07, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.026083727939523e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6655 - accuracy: 0.6425 - val_loss: 0.6676 - val_accuracy: 0.6280
#
#
# epoch 78, Learning Rate 1.0125776671631057e-07, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.5910122948865625e-07.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6648 - accuracy: 0.6570 - val_loss: 0.6676 - val_accuracy: 0.6290
#
#
# epoch 79, Learning Rate 1.0301601106393018e-06, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.8807171363560652e-06.
# 6/6 [==============================] - 12s 2s/step - loss: 0.6649 - accuracy: 0.6400 - val_loss: 0.6672 - val_accuracy: 0.6420
#
#
# epoch 80, Learning Rate 3.8924146876807286e-08, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.042081617236838e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6644 - accuracy: 0.6515 - val_loss: 0.6662 - val_accuracy: 0.6250
#
#
# epoch 81, Learning Rate 5.833174186005053e-07, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.1756223717695026e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6637 - accuracy: 0.6460 - val_loss: 0.6656 - val_accuracy: 0.6340
#
#
# epoch 82, Learning Rate 4.0487063567143944e-07, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.435993620446286e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6626 - accuracy: 0.6575 - val_loss: 0.6651 - val_accuracy: 0.6280
#
#
# epoch 83, Learning Rate 7.75616605443907e-08, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.64022127329956e-07.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6621 - accuracy: 0.6565 - val_loss: 0.6651 - val_accuracy: 0.6280
#
#
# epoch 84, Learning Rate 2.6801624996160817e-07, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.287361312343339e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6625 - accuracy: 0.6450 - val_loss: 0.6642 - val_accuracy: 0.6360
#
#
# epoch 85, Learning Rate 1.1032873697506958e-06, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.7268965763414964e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6608 - accuracy: 0.6555 - val_loss: 0.6631 - val_accuracy: 0.6270
#
#
# epoch 86, Learning Rate 8.067692995907724e-07, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.588405708720374e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6605 - accuracy: 0.6365 - val_loss: 0.6631 - val_accuracy: 0.6380
#
#
# epoch 87, Learning Rate 1.510499658473827e-07, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.4913620303516994e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6589 - accuracy: 0.6470 - val_loss: 0.6613 - val_accuracy: 0.6310
#
#
# epoch 88, Learning Rate 6.956064008530382e-07, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.891678471763902e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6581 - accuracy: 0.6555 - val_loss: 0.6606 - val_accuracy: 0.6280
#
#
# epoch 89, Learning Rate 4.3537074439616717e-07, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.488067691524092e-07.
# 5/5 [==============================] - 13s 2s/step - loss: 0.6571 - accuracy: 0.6585 - val_loss: 0.6605 - val_accuracy: 0.6290
#
#
# epoch 90, Learning Rate 1.0837599853050065e-06, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 4.169035760491316e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6571 - accuracy: 0.6585 - val_loss: 0.6597 - val_accuracy: 0.6300
#
#
# epoch 91, Learning Rate 1.0854932485215047e-06, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.980654346320836e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6563 - accuracy: 0.6580 - val_loss: 0.6586 - val_accuracy: 0.6470
#
#
# epoch 92, Learning Rate 5.989270341941894e-07, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.788144025779642e-07.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6548 - accuracy: 0.6590 - val_loss: 0.6584 - val_accuracy: 0.6470
#
#
# epoch 93, Learning Rate 6.777742398911675e-07, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.1977367412666826e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6552 - accuracy: 0.6500 - val_loss: 0.6572 - val_accuracy: 0.6420
#
#
# epoch 94, Learning Rate 1.0001781974762824e-06, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.1626973059452177e-05.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6594 - accuracy: 0.6205 - val_loss: 0.6563 - val_accuracy: 0.6420
#
#
# epoch 95, Learning Rate 8.035076466372254e-07, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 6.936510056071212e-06.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6517 - accuracy: 0.6570 - val_loss: 0.6553 - val_accuracy: 0.6440
#
#
# epoch 96, Learning Rate 1.006201322265584e-06, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.1366290025805225e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6507 - accuracy: 0.6590 - val_loss: 0.6550 - val_accuracy: 0.6470
#
#
# epoch 97, Learning Rate 2.009499071257637e-07, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.567464747430578e-05.
# 5/5 [==============================] - 12s 2s/step - loss: 0.6495 - accuracy: 0.6625 - val_loss: 0.6524 - val_accuracy: 0.6540
#
#
# epoch 98, Learning Rate 4.8539762442086275e-08, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.7053244520769613e-05.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6529 - accuracy: 0.6260 - val_loss: 0.6513 - val_accuracy: 0.6400
#
#
# epoch 99, Learning Rate 2.9593914740289733e-07, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 5.963884972804884e-06.
# 5/5 [==============================] - 12s 3s/step - loss: 0.6468 - accuracy: 0.6590 - val_loss: 0.6506 - val_accuracy: 0.6500
#
#
# epoch 100, Learning Rate 1.2772185785108414e-07, Batch Size  500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 7.436002642948844e-05.
# 4/4 [==============================] - 12s 3s/step - loss: 0.7287 - accuracy: 0.5545 - val_loss: 0.6693 - val_accuracy: 0.5850

# %%
# model = cat_model()
# from keras.callbacks import LearningRateScheduler
# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []

# num = 0

# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR



#   call = [ LearningRateScheduler(set_LR,verbose=1) ]



#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size



#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_2",acc_2)
record_Results("val_acc_2",val_acc_2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_2 = Get_Results("acc_2")["acc_2"]
val_acc_2 = Get_Results("val_acc_2")["val_acc_2"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = cat_model()
# epoo = 50
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
l_r = []
x=0
def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

call = [ LearningRateScheduler(set_LR,verbose=1) ]

history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoo,
            callbacks=call
            )
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.5919922688215636e-09.
# 4/4 [==============================] - 12s 3s/step - loss: 0.6979 - accuracy: 0.4948 - val_loss: 0.6986 - val_accuracy: 0.4940
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 2.706741683966022e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6982 - accuracy: 0.4889 - val_loss: 0.6977 - val_accuracy: 0.4930
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 6.016105663430322e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6970 - accuracy: 0.4873 - val_loss: 0.6967 - val_accuracy: 0.4870
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 2.3356189215714805e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6949 - accuracy: 0.5029 - val_loss: 0.6965 - val_accuracy: 0.4860
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 8.065835680886097e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6949 - accuracy: 0.4949 - val_loss: 0.6959 - val_accuracy: 0.4910
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1.6434920583165243e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6950 - accuracy: 0.4984 - val_loss: 0.6958 - val_accuracy: 0.4870
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 3.794954252917869e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6939 - accuracy: 0.4998 - val_loss: 0.6955 - val_accuracy: 0.4790
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1.0056004236874874e-06.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6937 - accuracy: 0.5064 - val_loss: 0.6950 - val_accuracy: 0.4850
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 7.06070409310209e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6938 - accuracy: 0.4961 - val_loss: 0.6947 - val_accuracy: 0.4960
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 8.997645992035227e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6922 - accuracy: 0.5129 - val_loss: 0.6942 - val_accuracy: 0.4980
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 2.3544051189068254e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6918 - accuracy: 0.5293 - val_loss: 0.6941 - val_accuracy: 0.5010
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 9.244468608195217e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6926 - accuracy: 0.5094 - val_loss: 0.6936 - val_accuracy: 0.5060
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 8.644942421021723e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6907 - accuracy: 0.5258 - val_loss: 0.6932 - val_accuracy: 0.5080
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1.0873834006715234e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6915 - accuracy: 0.5320 - val_loss: 0.6927 - val_accuracy: 0.5130
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 5.737451612418517e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6910 - accuracy: 0.5254 - val_loss: 0.6925 - val_accuracy: 0.5180
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 6.271469387552754e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6898 - accuracy: 0.5342 - val_loss: 0.6922 - val_accuracy: 0.5290
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 5.277928850099237e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6902 - accuracy: 0.5386 - val_loss: 0.6920 - val_accuracy: 0.5300
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1.2008354644400068e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6899 - accuracy: 0.5437 - val_loss: 0.6916 - val_accuracy: 0.5300
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.572799053577547e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6891 - accuracy: 0.5420 - val_loss: 0.6912 - val_accuracy: 0.5260
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 8.987184382031158e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6883 - accuracy: 0.5637 - val_loss: 0.6909 - val_accuracy: 0.5320
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 4.964754033193204e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6888 - accuracy: 0.5537 - val_loss: 0.6907 - val_accuracy: 0.5330
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 9.215370947965796e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6882 - accuracy: 0.5630 - val_loss: 0.6903 - val_accuracy: 0.5380
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 5.364656051798368e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6883 - accuracy: 0.5508 - val_loss: 0.6901 - val_accuracy: 0.5400
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.230629923826491e-06.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6869 - accuracy: 0.5594 - val_loss: 0.6897 - val_accuracy: 0.5400
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.7546217909585065e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6864 - accuracy: 0.5646 - val_loss: 0.6896 - val_accuracy: 0.5400
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.3269536818420835e-06.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6880 - accuracy: 0.5670 - val_loss: 0.6892 - val_accuracy: 0.5450
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 7.492923798416617e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6865 - accuracy: 0.5651 - val_loss: 0.6889 - val_accuracy: 0.5460
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 4.86614814175641e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6868 - accuracy: 0.5693 - val_loss: 0.6887 - val_accuracy: 0.5500
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1.092667540328584e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6859 - accuracy: 0.5766 - val_loss: 0.6883 - val_accuracy: 0.5600
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.046889163351535e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6846 - accuracy: 0.5905 - val_loss: 0.6880 - val_accuracy: 0.5580
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.3430211439965944e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6856 - accuracy: 0.5878 - val_loss: 0.6876 - val_accuracy: 0.5590
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 7.450846144565603e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6849 - accuracy: 0.5800 - val_loss: 0.6873 - val_accuracy: 0.5620
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 1.3658826967286307e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6844 - accuracy: 0.5821 - val_loss: 0.6869 - val_accuracy: 0.5640
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 8.200816333244302e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6837 - accuracy: 0.5875 - val_loss: 0.6866 - val_accuracy: 0.5600
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 1.692921751075448e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6831 - accuracy: 0.5868 - val_loss: 0.6866 - val_accuracy: 0.5610
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 8.937670403958219e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6829 - accuracy: 0.5893 - val_loss: 0.6863 - val_accuracy: 0.5630
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 3.300208414096683e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6819 - accuracy: 0.6019 - val_loss: 0.6862 - val_accuracy: 0.5620
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 1.0096310376350955e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6835 - accuracy: 0.5909 - val_loss: 0.6862 - val_accuracy: 0.5620
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 9.196720256250007e-08.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6815 - accuracy: 0.6105 - val_loss: 0.6862 - val_accuracy: 0.5630
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.010190459181885e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6828 - accuracy: 0.5957 - val_loss: 0.6861 - val_accuracy: 0.5610
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 3.5693822060547865e-07.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6818 - accuracy: 0.5976 - val_loss: 0.6859 - val_accuracy: 0.5640
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 7.463800683832065e-07.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6832 - accuracy: 0.5903 - val_loss: 0.6857 - val_accuracy: 0.5650
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 5.402481439309847e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6824 - accuracy: 0.5962 - val_loss: 0.6856 - val_accuracy: 0.5680
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 1.3634214461740162e-06.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6816 - accuracy: 0.5949 - val_loss: 0.6852 - val_accuracy: 0.5710
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 4.965807856648375e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6800 - accuracy: 0.6177 - val_loss: 0.6850 - val_accuracy: 0.5710
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.1579022263888967e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6824 - accuracy: 0.5977 - val_loss: 0.6847 - val_accuracy: 0.5760
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.2273197008074674e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6827 - accuracy: 0.5771 - val_loss: 0.6844 - val_accuracy: 0.5730
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 5.373629341455116e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6812 - accuracy: 0.5895 - val_loss: 0.6842 - val_accuracy: 0.5760
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.0837163466829285e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6791 - accuracy: 0.6102 - val_loss: 0.6840 - val_accuracy: 0.5750
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.2963449374943505e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6807 - accuracy: 0.6032 - val_loss: 0.6839 - val_accuracy: 0.5780
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 7.075893018037851e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6812 - accuracy: 0.5900 - val_loss: 0.6837 - val_accuracy: 0.5770
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.5090449980836335e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6788 - accuracy: 0.6114 - val_loss: 0.6836 - val_accuracy: 0.5730
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.3659278632633058e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6795 - accuracy: 0.5993 - val_loss: 0.6830 - val_accuracy: 0.5820
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.154432976934982e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6797 - accuracy: 0.6005 - val_loss: 0.6829 - val_accuracy: 0.5810
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 4.5774063106778734e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6780 - accuracy: 0.6105 - val_loss: 0.6827 - val_accuracy: 0.5810
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 4.51440939454846e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6780 - accuracy: 0.6037 - val_loss: 0.6826 - val_accuracy: 0.5820
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.5123651123473866e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6789 - accuracy: 0.6018 - val_loss: 0.6823 - val_accuracy: 0.5810
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9265968518574977e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6785 - accuracy: 0.5893 - val_loss: 0.6822 - val_accuracy: 0.5790
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 8.129189332427561e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6774 - accuracy: 0.6135 - val_loss: 0.6820 - val_accuracy: 0.5810
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 1.219786251833477e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6781 - accuracy: 0.5957 - val_loss: 0.6817 - val_accuracy: 0.5860
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1.1502386726984135e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6766 - accuracy: 0.6151 - val_loss: 0.6815 - val_accuracy: 0.5920
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1.3801765217519569e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6781 - accuracy: 0.6091 - val_loss: 0.6812 - val_accuracy: 0.5880
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1.6338480478185377e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6775 - accuracy: 0.6106 - val_loss: 0.6809 - val_accuracy: 0.5920
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1.8947020859136933e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6761 - accuracy: 0.6119 - val_loss: 0.6805 - val_accuracy: 0.5930
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.5661882651067183e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6773 - accuracy: 0.6042 - val_loss: 0.6802 - val_accuracy: 0.5830
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1.211693050728477e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6747 - accuracy: 0.5998 - val_loss: 0.6799 - val_accuracy: 0.5970
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.462786124361608e-06.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6735 - accuracy: 0.6335 - val_loss: 0.6793 - val_accuracy: 0.6040
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.870470999738977e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6719 - accuracy: 0.6223 - val_loss: 0.6790 - val_accuracy: 0.6020
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.4222616740359175e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6736 - accuracy: 0.6150 - val_loss: 0.6788 - val_accuracy: 0.5970
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.7610599598326773e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6741 - accuracy: 0.6147 - val_loss: 0.6784 - val_accuracy: 0.5880
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 2.045856920111274e-07.
# 4/4 [==============================] - 10s 3s/step - loss: 0.6728 - accuracy: 0.6142 - val_loss: 0.6783 - val_accuracy: 0.6000
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 8.418614877482005e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6725 - accuracy: 0.6242 - val_loss: 0.6781 - val_accuracy: 0.6000
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.2429652330195736e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6713 - accuracy: 0.6221 - val_loss: 0.6778 - val_accuracy: 0.6040
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 4.86816211261374e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6738 - accuracy: 0.6115 - val_loss: 0.6777 - val_accuracy: 0.6060
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 6.658559371764534e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6725 - accuracy: 0.6177 - val_loss: 0.6776 - val_accuracy: 0.6020
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 6.266054684531093e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6720 - accuracy: 0.6279 - val_loss: 0.6774 - val_accuracy: 0.6040
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 3.026083727939523e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6713 - accuracy: 0.6273 - val_loss: 0.6774 - val_accuracy: 0.5790
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.5910122948865625e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6719 - accuracy: 0.5999 - val_loss: 0.6772 - val_accuracy: 0.5860
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 2.8807171363560652e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6746 - accuracy: 0.6023 - val_loss: 0.6765 - val_accuracy: 0.6050
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 4.042081617236838e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6722 - accuracy: 0.6185 - val_loss: 0.6761 - val_accuracy: 0.5960
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 4.1756223717695026e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6690 - accuracy: 0.6248 - val_loss: 0.6753 - val_accuracy: 0.6050
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 2.435993620446286e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6690 - accuracy: 0.6312 - val_loss: 0.6748 - val_accuracy: 0.6180
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 2.64022127329956e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6688 - accuracy: 0.6343 - val_loss: 0.6747 - val_accuracy: 0.6140
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 5.287361312343339e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6704 - accuracy: 0.6099 - val_loss: 0.6746 - val_accuracy: 0.5930
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 4.7268965763414964e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6667 - accuracy: 0.6338 - val_loss: 0.6732 - val_accuracy: 0.6110
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.588405708720374e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6671 - accuracy: 0.6331 - val_loss: 0.6724 - val_accuracy: 0.6040
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 3.4913620303516994e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6660 - accuracy: 0.6327 - val_loss: 0.6723 - val_accuracy: 0.6030
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 3.891678471763902e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6626 - accuracy: 0.6357 - val_loss: 0.6751 - val_accuracy: 0.5590
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 5.488067691524092e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6696 - accuracy: 0.5749 - val_loss: 0.6727 - val_accuracy: 0.5790
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 4.169035760491316e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6614 - accuracy: 0.6317 - val_loss: 0.6714 - val_accuracy: 0.6070
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 5.980654346320836e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6636 - accuracy: 0.6404 - val_loss: 0.6695 - val_accuracy: 0.6200
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 9.788144025779642e-07.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6580 - accuracy: 0.6563 - val_loss: 0.6693 - val_accuracy: 0.6280
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 6.1977367412666826e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6619 - accuracy: 0.6397 - val_loss: 0.6688 - val_accuracy: 0.6190
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 1.1626973059452177e-05.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6617 - accuracy: 0.6062 - val_loss: 0.6772 - val_accuracy: 0.5550
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 6.936510056071212e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6600 - accuracy: 0.6291 - val_loss: 0.6671 - val_accuracy: 0.6050
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 1.1366290025805225e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6559 - accuracy: 0.6511 - val_loss: 0.6665 - val_accuracy: 0.6200
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 1.567464747430578e-05.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6684 - accuracy: 0.6165 - val_loss: 0.6806 - val_accuracy: 0.5310
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 1.7053244520769613e-05.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6667 - accuracy: 0.5640 - val_loss: 0.6806 - val_accuracy: 0.5340
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 5.963884972804884e-06.
# 4/4 [==============================] - 9s 3s/step - loss: 0.6620 - accuracy: 0.5976 - val_loss: 0.6637 - val_accuracy: 0.6270
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 7.436002642948844e-05.
# 4/4 [==============================] - 9s 3s/step - loss: 0.9089 - accuracy: 0.5918 - val_loss: 0.6785 - val_accuracy: 0.6000

# %%
acc_3 = history.history['accuracy']
val_acc_3 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_3",acc_3)
record_Results("val_acc_3",val_acc_3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_1 = Get_Results("acc_3")["acc_3"]
val_acc_1 = Get_Results("val_acc_3")["val_acc_3"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,[],[],l_r)

# %% [markdown]
# **LR constant**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
# epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
#   4/400 [..............................] - ETA: 8s - loss: 3.6230 - accuracy: 0.4000

# %%
# @title
# model = cat_model()

# from keras.callbacks import LearningRateScheduler

# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR

#   call = [ LearningRateScheduler(set_LR,verbose=1) ]

#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size

#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             # callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
#Save these values in your jsonm
record_Results("acc_4",acc_4)
record_Results("val_acc_4",val_acc_4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_1 = Get_Results("acc_4")["acc_4"]
val_acc_1 = Get_Results("val_acc_4")["val_acc_4"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0

# %%
# acc_1_dif = []
# for i in range(len(acc_1)): acc_1_dif.append(acc_1[i] - val_acc_1[i]) 
# acc_2_dif = []
# for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0]) 
# acc_3_dif = []
# for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0]) 
# acc_4_dif = []
# for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
# plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
# plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3_dif, label='BS = const acc',ls='-.',c='g')
# plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4_dif, label='LR = const acc',ls='-.',c='y')
# plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import time
import json
import pprint
import hashlib
import struct
import re
import base64
import httplib
import sys
from multiprocessing import Process

ERR_SLEEP = 15
MAX_NONCE = "1000000L"

settings = {}
pp = pprint.PrettyPrinter(indent=4)

class BitcoinRPC:
	OBJID = 1

	def __init__(self, host, port, username, password):
		authpair = "%s:%s" % (username, password)
		self.authhdr = "Basic %s" % (base64.b64encode(authpair))
		self.conn = httplib.HTTPConnection(host, port, False, 30)
	def rpc(self, method, params=None):
		self.OBJID += 1
		obj = { 'version' : '1.1',
			'method' : method,
			'id' : self.OBJID }
		if params is None:
			obj['params'] = []
		else:
			obj['params'] = params
		self.conn.request('POST', '/', json.dumps(obj),
			{ 'Authorization' : self.authhdr,
			  'Content-type' : 'application/json' })

		resp = self.conn.getresponse()
		if resp is None:
			print "JSON-RPC: no response"
			return None

		body = resp.read()
		resp_obj = json.loads(body)
		if resp_obj is None:
			print "JSON-RPC: cannot JSON-decode body"
			return None
		if 'error' in resp_obj and resp_obj['error'] != None:
			return resp_obj['error']
		if 'result' not in resp_obj:
			print "JSON-RPC: no result in object"
			return None

		return resp_obj['result']
	def getblockcount(self):
		return self.rpc('getblockcount')
	def getwork(self, data=None):
		return self.rpc('getwork', data)

def uint32(x):
	return x & '0xffffffffL'

def bytereverse(x):
	return uint32(( ((x) << 24) | (((x) << 8) & 0x00ff0000) |
			(((x) >> 8) & 0x0000ff00) | ((x) >> 24) ))

def bufreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		word = struct.unpack('@I', in_buf[i:i+4])[0]
		out_words.append(struct.pack('@I', bytereverse(word)))
	return ''.join(out_words)

def wordreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		out_words.append(in_buf[i:i+4])
	out_words.reverse()
	return ''.join(out_words)

class Miner:
	def __init__(self, id):
		self.id = id
		self.max_nonce = MAX_NONCE

	def work(self, datastr, targetstr):
		# decode work data hex string to binary
		static_data = datastr.decode('hex')
		static_data = bufreverse(static_data)

		# the first 76b of 80b do not change
		blk_hdr = static_data[:76]

		# decode 256-bit target value
		targetbin = targetstr.decode('hex')
		targetbin = targetbin[::-1]	# byte-swap and dword-swap
		targetbin_str = targetbin.encode('hex')
		target = long(targetbin_str, 16)

		# pre-hash first 76b of block header
		static_hash = hashlib.sha256()
		static_hash.update(blk_hdr)

		for nonce in xrange(self.max_nonce):

			# encode 32-bit nonce value
			nonce_bin = struct.pack("<I", nonce)

			# hash final 4b, the nonce value
			hash1_o = static_hash.copy()
			hash1_o.update(nonce_bin)
			hash1 = hash1_o.digest()

			# sha256 hash of sha256 hash
			hash_o = hashlib.sha256()
			hash_o.update(hash1)
			hash = hash_o.digest()

			# quick test for winning solution: high 32 bits zero?
			if hash[-4:] != '\0\0\0\0':
				continue

			# convert binary hash to 256-bit Python long
			hash = bufreverse(hash)
			hash = wordreverse(hash)

			hash_str = hash.encode('hex')
			l = long(hash_str, 16)

			# proof-of-work test:  hash < target
			if l < target:
				print time.asctime(), "PROOF-OF-WORK found: %064x" % (l,)
				return (nonce + 1, nonce_bin)
			else:
				print time.asctime(), "PROOF-OF-WORK false positive %064x" % (l,)
#				return (nonce + 1, nonce_bin)

		return (nonce + 1, None)

	def submit_work(self, rpc, original_data, nonce_bin):
		nonce_bin = bufreverse(nonce_bin)
		nonce = nonce_bin.encode('hex')
		solution = original_data[:152] + nonce + original_data[160:256]
		param_arr = [ solution ]
		result = rpc.getwork(param_arr)
		print time.asctime(), "--> Upstream RPC result:", result

	def iterate(self, rpc):
		work = rpc.getwork()
		if work is None:
			time.sleep(ERR_SLEEP)
			return
		if 'data' not in work or 'target' not in work:
			time.sleep(ERR_SLEEP)
			return

		time_start = time.time()

		(hashes_done, nonce_bin) = self.work(work['data'],
						     work['target'])

		time_end = time.time()
		time_diff = time_end - time_start

		self.max_nonce = long(
			(hashes_done * settings['scantime']) / time_diff)
		if self.max_nonce > 0xfffffffaL:
			self.max_nonce = 0xfffffffaL

		if settings['hashmeter']:
			print "HashMeter(%d): %d hashes, %.2f Khash/sec" % (
			      self.id, hashes_done,
			      (hashes_done / 1000.0) / time_diff)

		if nonce_bin is not None:
			self.submit_work(rpc, work['data'], nonce_bin)

	def loop(self):
		rpc = BitcoinRPC(settings['host'], settings['port'],
				 settings['rpcuser'], settings['rpcpass'])
		if rpc is None:
			return

		while True:
			self.iterate(rpc)

def miner_thread(id):
	miner = Miner(id)
	miner.loop()

if __name__ == '__main__':
	if len(sys.argv) != 2:
		print "Usage: pyminer.py CONFIG-FILE"
		sys.exit(1)

	f = open(sys.argv[1])
	for line in f:
		# skip comment lines
		m = re.search('^\s*#', line)
		if m:
			continue

		# parse key=value lines
		m = re.search('^(\w+)\s*=\s*(\S.*)$', line)
		if m is None:
			continue
		settings[m.group(1)] = m.group(2)
	f.close()

	if 'host' not in settings:
		settings['host'] = '127.0.0.1'
	if 'port' not in settings:
		settings['port'] = 8332
	if 'threads' not in settings:
		settings['threads'] = 1
	if 'hashmeter' not in settings:
		settings['hashmeter'] = 0
	if 'scantime' not in settings:
		settings['scantime'] = "30L"
	if 'rpcuser' not in settings or 'rpcpass' not in settings:
		print "Missing username and/or password in cfg file"
		sys.exit(1)

	settings['port'] = int(settings['port'])
	settings['threads'] = int(settings['threads'])
	settings['hashmeter'] = int(settings['hashmeter'])
	settings['scantime'] = long(settings['scantime'])

	thr_list = []
	for thr_id in range(settings['threads']):
		p = Process(target=miner_thread, args=(thr_id,))
		p.start()
		thr_list.append(p)
		time.sleep(1)			# stagger threads

	print settings['threads'], "mining threads started"

	print time.asctime(), "Miner Starts - %s:%s" % (settings['host'], settings['port'])
	try:
		for thr_proc in thr_list:
			thr_proc.join()
	except KeyboardInterrupt:
		pass
	print time.asctime(), "Miner Stops - %s:%s" % (settings['host'], settings['port'])
