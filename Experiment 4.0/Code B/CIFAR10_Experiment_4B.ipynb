# %% [markdown]
# # **BS increasing with each epoch and hence the LR**

# %% [markdown]
# *Save and Load results from here*

# %%
def record_Results(key,results):
  import json
  from google.colab import drive


  drive.mount('/content/drive')

  dictionary ={
      key : results
  } 
  json_object = json.dumps(dictionary)

  FILE_PATH = "/content/drive/My Drive/Results/"+str(key)+".json"
  f = open(FILE_PATH, "w")
  f.write(json_object)
  print("recorded")

def Get_Results(file):
  import json
  from google.colab import drive

  drive.mount('/content/drive')

  FILE_PATH = "/content/drive/My Drive/Results/"+str(file)+".json"
  f = open(FILE_PATH, "r")
  json_object = json.load(f)
  
  return json_object

# %% [markdown]
# **STARTING GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.736065257000007
# GPU (s):
# 0.04755610600000182
# GPU speedup over CPU: 78x

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

baseMapNum = 32
weight_decay = 1e-4
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
def cifar10_model():
  model = Sequential()
  model.add(Conv2D(baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.2))

  model.add(Conv2D(2*baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(2*baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.3))

  model.add(Conv2D(4*baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Conv2D(4*baseMapNum, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2,2)))
  model.add(Dropout(0.4))

  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))

  # model.summary()

  #data augmentation



  model.compile(loss='categorical_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])
  
  return model

datagen = ImageDataGenerator(
  featurewise_center=False,
  samplewise_center=False,
  featurewise_std_normalization=False,
  samplewise_std_normalization=False,
  zca_whitening=False,
  rotation_range=15,
  width_shift_range=0.1,
  height_shift_range=0.1,
  horizontal_flip=True,
  vertical_flip=False
  )
datagen.fit(x_train)

# %%
model = cifar10_model()

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_80 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_36 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_37 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_38 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_39 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_40 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_41 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  # plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %% [markdown]
# **Test for LR**

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=80
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)
  


  # if (z%2 == 0):
  LR = random() * batch_size/10000
  lr.append(LR)
  # else:
  #   LR = random() * z/10000
  #   lr.append(LR)

lr = lr[::-1] 
lord_LR = lr
# print(min(lr))


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()


# lr = []
# epoo=150
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   # print(z,(batch_size)/((z+1)**(3/2))/80)
  

#   LR = random() * z/10000
#   # LR=LR/8
#   lr.append(LR)

# plt.plot(lr, label='Learning Rate')
# plt.xlabel('Epoch')
# plt.ylabel('LR')
# plt.legend(loc='lower right')
# plt.show()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default
#
#
# ---
# Running them in parts

# %%
# import os

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

# history = model.fit(datagen.flow(x_train, y_train),
#                     epochs=50,validation_data=(x_test,y_test),
#                     callbacks = cp_callback)

# %%
# acc_1 = []
# val_acc_1 = []
# loss = []
# Vloss = []

# acc_1.append(history.history['accuracy'])
# val_acc_1.append(history.history['val_accuracy'])

# loss.append(history.history['loss'])
# Vloss.append(history.history['val_loss'])

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# model = cifar10_model()

# # Load the previously saved weights
# model.load_weights(checkpoint_path)

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

# history = model.fit(datagen.flow(x_train, y_train),
#                     epochs=50,validation_data=(x_test,y_test),
#                     callbacks = cp_callback)

# %%
# acc_1.append(history.history['accuracy'])
# val_acc_1.append(history.history['val_accuracy'])

# loss.append(history.history['loss'])
# Vloss.append(history.history['val_loss'])

# %%
# model = cifar10_model()

# # Load the previously saved weights
# model.load_weights(checkpoint_path)

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

# history = model.fit(datagen.flow(x_train, y_train),
#                     epochs=50,validation_data=(x_test,y_test),
#                     callbacks = cp_callback)

# %%
# acc_1.append(history.history['accuracy'])
# val_acc_1.append(history.history['val_accuracy'])

# loss.append(history.history['loss'])
# Vloss.append(history.history['val_loss'])

# %%
# model = cifar10_model()

# # Load the previously saved weights
# model.load_weights(checkpoint_path)

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

# history = model.fit(datagen.flow(x_train, y_train),
#                     epochs=50,validation_data=(x_test,y_test),
#                     callbacks = cp_callback)

# %%
# acc_1.append(history.history['accuracy'])
# val_acc_1.append(history.history['val_accuracy'])

# loss.append(history.history['loss'])
# Vloss.append(history.history['val_loss'])

# %%
model = cifar10_model()

# Load the previously saved weights
# model.load_weights(checkpoint_path)

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

history = model.fit(datagen.flow(x_train, y_train),
                    epochs=epoo,
                    validation_data=(x_test,y_test),
                    # callbacks = cp_callback
                    )

# %%
# acc_1.append(history.history['accuracy'])
# val_acc_1.append(history.history['val_accuracy'])

# loss.append(history.history['loss'])
# Vloss.append(history.history['val_loss'])

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
#Save these values in your jsonm
record_Results("acc_1",acc_1)
record_Results("val_acc_1",val_acc_1)

# %%
#Get the saved results
acc_1 = Get_Results("acc_1")["acc_1"]
val_acc_1 = Get_Results("val_acc_1")["vaml_acc_1"]

# %%
plt.plot(acc_1, label='accuracy')
plt.plot(val_acc_1, label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# plt.plot(loss, label='loss')
# plt.plot(Vloss, label = 'val_loss')
# plt.xlabel('Epoch')
# plt.ylabel('loss')
# plt.legend(loc='lower right')
# plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = cifar10_model()
from random import random
from keras.callbacks import LearningRateScheduler

from time import time
print(time())
LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo),range(5,10000,5)):

  # if (z%2 == 0):
  LR = random() * batch_size/10000
  # lr.append(LR)
  # else:
  #   LR = random() * z/10000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.009):
      LR = 0.009
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            datagen.flow(x_train, y_train), 
            validation_data=(x_test, y_test),
            epochs=epoch,
            batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# epoch 1, Learning Rate 4.36000617321623e-05, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 45s 28ms/step - loss: 2.8490 - accuracy: 0.3241 - val_loss: 1.4076 - val_accuracy: 0.5347
#
#
# epoch 2, Learning Rate 0.00099486885612166, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.4941 - accuracy: 0.5453 - val_loss: 1.3312 - val_accuracy: 0.6394
#
#
# epoch 3, Learning Rate 0.0009557036100986409, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005098580006993347.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.3193 - accuracy: 0.6278 - val_loss: 1.4076 - val_accuracy: 0.6184
#
#
# epoch 4, Learning Rate 0.00022038212493917265, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.5447 - accuracy: 0.5859 - val_loss: 1.6391 - val_accuracy: 0.5954
#
#
# epoch 5, Learning Rate 0.0006754427678206382, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.5282 - accuracy: 0.5933 - val_loss: 1.3576 - val_accuracy: 0.6475
#
#
# epoch 6, Learning Rate 0.002634077535816301, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0022580971305101727.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1920 - accuracy: 0.6754 - val_loss: 1.0379 - val_accuracy: 0.7159
#
#
# epoch 7, Learning Rate 0.00032599510610946365, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0051202465330366185.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2403 - accuracy: 0.6542 - val_loss: 1.0999 - val_accuracy: 0.7032
#
#
# epoch 8, Learning Rate 0.0020934354606597203, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4726 - accuracy: 0.6076 - val_loss: 1.5668 - val_accuracy: 0.6071
#
#
# epoch 9, Learning Rate 0.0024154346501593523, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.4648 - accuracy: 0.6147 - val_loss: 1.4317 - val_accuracy: 0.6273
#
#
# epoch 10, Learning Rate 0.00020850888882302963, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4610 - accuracy: 0.6161 - val_loss: 1.3088 - val_accuracy: 0.6612
#
#
# epoch 11, Learning Rate 0.0015952191927146452, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.4606 - accuracy: 0.6151 - val_loss: 1.6695 - val_accuracy: 0.5901
#
#
# epoch 12, Learning Rate 0.005256057670933534, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004268667768473816.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2120 - accuracy: 0.6707 - val_loss: 1.0043 - val_accuracy: 0.7347
#
#
# epoch 13, Learning Rate 0.0020429127244537175, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4518 - accuracy: 0.6156 - val_loss: 1.5327 - val_accuracy: 0.6426
#
#
# epoch 14, Learning Rate 0.002099195274397391, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.4276 - accuracy: 0.6220 - val_loss: 1.2949 - val_accuracy: 0.6732
#
#
# epoch 15, Learning Rate 0.005693347977423423, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.4330 - accuracy: 0.6197 - val_loss: 1.2612 - val_accuracy: 0.6763
#
#
# epoch 16, Learning Rate 0.0012433687802610534, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.4155 - accuracy: 0.6247 - val_loss: 1.2771 - val_accuracy: 0.6840
#
#
# epoch 17, Learning Rate 0.005933470700651926, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3983 - accuracy: 0.6265 - val_loss: 1.3728 - val_accuracy: 0.6564
#
#
# epoch 18, Learning Rate 0.0044171030508124215, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3889 - accuracy: 0.6254 - val_loss: 1.8163 - val_accuracy: 0.5775
#
#
# epoch 19, Learning Rate 0.004228807817546634, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3904 - accuracy: 0.6245 - val_loss: 1.1868 - val_accuracy: 0.6896
#
#
# epoch 20, Learning Rate 0.008711954452157594, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3595 - accuracy: 0.6326 - val_loss: 1.4405 - val_accuracy: 0.6260
#
#
# epoch 21, Learning Rate 0.010275127764625303, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3782 - accuracy: 0.6268 - val_loss: 1.5272 - val_accuracy: 0.6063
#
#
# epoch 22, Learning Rate 0.007762091648894761, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.3567 - accuracy: 0.6301 - val_loss: 1.3087 - val_accuracy: 0.6654
#
#
# epoch 23, Learning Rate 0.00810814789675829, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3540 - accuracy: 0.6311 - val_loss: 1.2947 - val_accuracy: 0.6601
#
#
# epoch 24, Learning Rate 0.011689038351081624, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3531 - accuracy: 0.6313 - val_loss: 1.3878 - val_accuracy: 0.6476
#
#
# epoch 25, Learning Rate 0.010997862556370476, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.3489 - accuracy: 0.6316 - val_loss: 1.2115 - val_accuracy: 0.6856
#
#
# epoch 26, Learning Rate 0.0051710404119721335, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0043424523400601425.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.1577 - accuracy: 0.6801 - val_loss: 1.2083 - val_accuracy: 0.6766
#
#
# epoch 27, Learning Rate 0.0015172235002958124, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3333 - accuracy: 0.6279 - val_loss: 1.1929 - val_accuracy: 0.6921
#
#
# epoch 28, Learning Rate 0.0013696633149176479, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3278 - accuracy: 0.6325 - val_loss: 1.2315 - val_accuracy: 0.6801
#
#
# epoch 29, Learning Rate 0.013716969568917563, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3320 - accuracy: 0.6341 - val_loss: 1.2743 - val_accuracy: 0.6618
#
#
# epoch 30, Learning Rate 0.007913270226773506, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007997149168856361.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.2855 - accuracy: 0.6466 - val_loss: 1.3167 - val_accuracy: 0.6563
#
#
# epoch 31, Learning Rate 0.009802965768136308, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00876073371464844.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3061 - accuracy: 0.6397 - val_loss: 1.1024 - val_accuracy: 0.7085
#
#
# epoch 32, Learning Rate 0.011305548568241031, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3199 - accuracy: 0.6376 - val_loss: 1.1773 - val_accuracy: 0.6864
#
#
# epoch 33, Learning Rate 0.011051567446093778, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3340 - accuracy: 0.6339 - val_loss: 1.2116 - val_accuracy: 0.6723
#
#
# epoch 34, Learning Rate 0.00011830174097780543, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005563994353482997.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.1183 - accuracy: 0.6991 - val_loss: 1.0005 - val_accuracy: 0.7370
#
#
# epoch 35, Learning Rate 0.0013779604927235815, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.3399 - accuracy: 0.6310 - val_loss: 1.3357 - val_accuracy: 0.6584
#
#
# epoch 36, Learning Rate 0.008078601297138952, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.3302 - accuracy: 0.6328 - val_loss: 1.3232 - val_accuracy: 0.6346
#
#
# epoch 37, Learning Rate 0.007687614800252071, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007123915319664317.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 1.2433 - accuracy: 0.6544 - val_loss: 1.0900 - val_accuracy: 0.7108
#
#
# epoch 38, Learning Rate 0.011564758349707015, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3145 - accuracy: 0.6366 - val_loss: 1.4582 - val_accuracy: 0.6316
#
#
# epoch 39, Learning Rate 0.0014519680568289694, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004651806736771397.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.1407 - accuracy: 0.6832 - val_loss: 1.0796 - val_accuracy: 0.7083
#
#
# epoch 40, Learning Rate 0.0016159923530871055, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002174266832070452.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.0055 - accuracy: 0.7152 - val_loss: 0.9979 - val_accuracy: 0.7261
#
#
# epoch 41, Learning Rate 0.013740470297747493, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005351590415625673.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.9264 - accuracy: 0.7367 - val_loss: 0.8664 - val_accuracy: 0.7579
#
#
# epoch 42, Learning Rate 0.012855609466390791, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.2912 - accuracy: 0.6366 - val_loss: 1.3980 - val_accuracy: 0.6343
#
#
# epoch 43, Learning Rate 0.016300237933719222, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00181609311218161.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0629 - accuracy: 0.7092 - val_loss: 0.9087 - val_accuracy: 0.7554
#
#
# epoch 44, Learning Rate 0.005543116769456628, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.3070 - accuracy: 0.6355 - val_loss: 1.4448 - val_accuracy: 0.6141
#
#
# epoch 45, Learning Rate 0.010536274502285031, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002333587183791126.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0748 - accuracy: 0.7035 - val_loss: 0.9222 - val_accuracy: 0.7527
#
#
# epoch 46, Learning Rate 0.017506550978501834, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007150717604024699.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.2171 - accuracy: 0.6563 - val_loss: 1.1166 - val_accuracy: 0.6965
#
#
# epoch 47, Learning Rate 0.0024400250261574037, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2993 - accuracy: 0.6379 - val_loss: 1.1707 - val_accuracy: 0.6922
#
#
# epoch 48, Learning Rate 0.015417302022692638, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.008169856206827461.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2607 - accuracy: 0.6511 - val_loss: 1.1485 - val_accuracy: 0.6922
#
#
# epoch 49, Learning Rate 0.01187837155559056, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2992 - accuracy: 0.6388 - val_loss: 1.1392 - val_accuracy: 0.6902
#
#
# epoch 50, Learning Rate 0.01162533753514586, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3089 - accuracy: 0.6389 - val_loss: 1.3804 - val_accuracy: 0.6482
#
#
# epoch 51, Learning Rate 0.003139416823065789, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023327535682941716.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.0863 - accuracy: 0.7033 - val_loss: 0.9184 - val_accuracy: 0.7523
#
#
# epoch 52, Learning Rate 0.005307194389629756, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2999 - accuracy: 0.6385 - val_loss: 1.2430 - val_accuracy: 0.6806
#
#
# epoch 53, Learning Rate 0.017337870379172973, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.3003 - accuracy: 0.6392 - val_loss: 1.3887 - val_accuracy: 0.6350
#
#
# epoch 54, Learning Rate 0.01959806463499511, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007461273130164945.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2476 - accuracy: 0.6518 - val_loss: 1.1195 - val_accuracy: 0.7074
#
#
# epoch 55, Learning Rate 0.012903881136740418, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00013743396461742474.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.0962 - accuracy: 0.7015 - val_loss: 0.9945 - val_accuracy: 0.7419
#
#
# epoch 56, Learning Rate 0.003991171036500657, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007499110345180774.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.2446 - accuracy: 0.6514 - val_loss: 1.0751 - val_accuracy: 0.7125
#
#
# epoch 57, Learning Rate 0.014733362314652299, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007429067625656062.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.2282 - accuracy: 0.6551 - val_loss: 1.4105 - val_accuracy: 0.6370
#
#
# epoch 58, Learning Rate 0.02113690192139907, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.2889 - accuracy: 0.6416 - val_loss: 1.3218 - val_accuracy: 0.6589
#
#
# epoch 59, Learning Rate 0.01315721375269673, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005237328032783637.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.1454 - accuracy: 0.6790 - val_loss: 0.9772 - val_accuracy: 0.7378
#
#
# epoch 60, Learning Rate 0.01633852239064106, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0028922632055865135.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.0279 - accuracy: 0.7078 - val_loss: 1.0445 - val_accuracy: 0.7077
#
#
# epoch 61, Learning Rate 0.012197226319753283, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.007658831927437124.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2128 - accuracy: 0.6519 - val_loss: 1.1740 - val_accuracy: 0.6722
#
#
# epoch 62, Learning Rate 0.01809681188783896, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004280924151332015.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.0856 - accuracy: 0.6933 - val_loss: 1.0401 - val_accuracy: 0.7139
#
#
# epoch 63, Learning Rate 0.012024606087250813, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.005637335035817683.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.1225 - accuracy: 0.6803 - val_loss: 1.0679 - val_accuracy: 0.7009
#
#
# epoch 64, Learning Rate 0.00017375735832335338, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00012735877873391388.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 1.0120 - accuracy: 0.7151 - val_loss: 0.9493 - val_accuracy: 0.7399
#
#
# epoch 65, Learning Rate 0.027614266661388446, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004299770544737495.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0639 - accuracy: 0.6945 - val_loss: 0.9536 - val_accuracy: 0.7396
#
#
# epoch 66, Learning Rate 0.030006432597978704, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023240598807983547.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.9759 - accuracy: 0.7200 - val_loss: 0.8839 - val_accuracy: 0.7545
#
#
# epoch 67, Learning Rate 0.024731465419788844, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0027438820305944033.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.9615 - accuracy: 0.7189 - val_loss: 0.8719 - val_accuracy: 0.7575
#
#
# epoch 68, Learning Rate 0.014080002493906384, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0021752347497607503.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.9266 - accuracy: 0.7284 - val_loss: 0.8151 - val_accuracy: 0.7654
#
#
# epoch 69, Learning Rate 0.018069775274055067, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004848868589119588.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0349 - accuracy: 0.6966 - val_loss: 0.9842 - val_accuracy: 0.7270
#
#
# epoch 70, Learning Rate 0.03247829408314991, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023166278811423105.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.9590 - accuracy: 0.7206 - val_loss: 0.8744 - val_accuracy: 0.7530
#
#
# epoch 71, Learning Rate 0.01520926432916351, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00279151805870543.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.9478 - accuracy: 0.7222 - val_loss: 0.8747 - val_accuracy: 0.7519
#
#
# epoch 72, Learning Rate 0.0204101780739072, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0036070676482122996.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9789 - accuracy: 0.7146 - val_loss: 0.8832 - val_accuracy: 0.7523
#
#
# epoch 73, Learning Rate 0.009615287455646266, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002633953829338121.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.9402 - accuracy: 0.7243 - val_loss: 0.8735 - val_accuracy: 0.7545
#
#
# epoch 74, Learning Rate 0.016174691676900287, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00058789220665291.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.8641 - accuracy: 0.7498 - val_loss: 0.7962 - val_accuracy: 0.7777
#
#
# epoch 75, Learning Rate 0.030591925095736296, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0028988792695054323.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9435 - accuracy: 0.7205 - val_loss: 0.9260 - val_accuracy: 0.7332
#
#
# epoch 76, Learning Rate 0.021959332216650914, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002155036637552473.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9027 - accuracy: 0.7326 - val_loss: 0.8762 - val_accuracy: 0.7475
#
#
# epoch 77, Learning Rate 0.030377193283380222, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00036371224180226514.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.8367 - accuracy: 0.7545 - val_loss: 0.7634 - val_accuracy: 0.7835
#
#
# epoch 78, Learning Rate 0.01908337670967911, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001274690409302117.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.8427 - accuracy: 0.7500 - val_loss: 0.7611 - val_accuracy: 0.7812
#
#
# epoch 79, Learning Rate 0.02644105494696432, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006226668384812762.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.8134 - accuracy: 0.7584 - val_loss: 0.7517 - val_accuracy: 0.7876

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
#Save these values in your json
record_Results("acc_2",acc_2)
record_Results("val_acc_2",val_acc_2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_2 = Get_Results("acc_2")["acc_2"]
val_acc_2 = Get_Results("val_acc_2")["val_acc_2"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = cifar10_model()
from time import time
print(time())

# epoo = 1
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
def setLR(step):
  global LR
  lr = initial_learning_rate * decay_rate **(step / decay_steps)
  LR.append(lr)

  # sleep(20)
  print("called here")
  return lr

call = [ LearningRateScheduler(setLR,verbose=1) ]

history = model.fit(
            datagen.flow(x_train, y_train), 
            validation_data=(x_test, y_test),
            epochs=epoo,
            callbacks=call
            )
# Out:
# Epoch 1/80
# called here
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 2.9030 - accuracy: 0.3149 - val_loss: 1.5534 - val_accuracy: 0.4907
# Epoch 2/80
# called here
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.007834955069665117.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.4963 - accuracy: 0.5236 - val_loss: 1.4107 - val_accuracy: 0.6006
# Epoch 3/80
# called here
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.006820724549296791.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.4139 - accuracy: 0.5909 - val_loss: 1.7699 - val_accuracy: 0.5513
# Epoch 4/80
# called here
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.005937785598478023.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.3643 - accuracy: 0.6224 - val_loss: 1.5146 - val_accuracy: 0.6163
# Epoch 5/80
# called here
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.005169142597486656.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.2842 - accuracy: 0.6468 - val_loss: 1.5939 - val_accuracy: 0.5787
# Epoch 6/80
# called here
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0045.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.2185 - accuracy: 0.6683 - val_loss: 1.1616 - val_accuracy: 0.6976
# Epoch 7/80
# called here
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.003917477534832558.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.1586 - accuracy: 0.6840 - val_loss: 1.1494 - val_accuracy: 0.6934
# Epoch 8/80
# called here
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0034103622746483957.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.1033 - accuracy: 0.6952 - val_loss: 1.0005 - val_accuracy: 0.7291
# Epoch 9/80
# called here
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0029688927992390117.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.0540 - accuracy: 0.7082 - val_loss: 0.9249 - val_accuracy: 0.7561
# Epoch 10/80
# called here
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.002584571298743328.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.0170 - accuracy: 0.7216 - val_loss: 0.8903 - val_accuracy: 0.7584
# Epoch 11/80
# called here
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00225.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9724 - accuracy: 0.7297 - val_loss: 0.9039 - val_accuracy: 0.7554
# Epoch 12/80
# called here
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0019587387674162788.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9384 - accuracy: 0.7367 - val_loss: 0.9394 - val_accuracy: 0.7433
# Epoch 13/80
# called here
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0017051811373241979.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9047 - accuracy: 0.7463 - val_loss: 0.7836 - val_accuracy: 0.7872
# Epoch 14/80
# called here
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0014844463996195058.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.8683 - accuracy: 0.7582 - val_loss: 0.7815 - val_accuracy: 0.7893
# Epoch 15/80
# called here
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0012922856493716643.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.8360 - accuracy: 0.7630 - val_loss: 0.7662 - val_accuracy: 0.7904
# Epoch 16/80
# called here
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001125.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.8229 - accuracy: 0.7662 - val_loss: 0.8129 - val_accuracy: 0.7775
# Epoch 17/80
# called here
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009793693837081394.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7852 - accuracy: 0.7777 - val_loss: 0.7311 - val_accuracy: 0.7991
# Epoch 18/80
# called here
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0008525905686620989.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7635 - accuracy: 0.7857 - val_loss: 0.7260 - val_accuracy: 0.8001
# Epoch 19/80
# called here
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007422231998097529.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7494 - accuracy: 0.7850 - val_loss: 0.7120 - val_accuracy: 0.8021
# Epoch 20/80
# called here
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0006461428246858322.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7334 - accuracy: 0.7920 - val_loss: 0.7082 - val_accuracy: 0.8088
# Epoch 21/80
# called here
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005625.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7195 - accuracy: 0.7933 - val_loss: 0.7162 - val_accuracy: 0.8059
# Epoch 22/80
# called here
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0004896846918540697.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.7083 - accuracy: 0.7956 - val_loss: 0.6562 - val_accuracy: 0.8172
# Epoch 23/80
# called here
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00042629528433104936.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6825 - accuracy: 0.8056 - val_loss: 0.6455 - val_accuracy: 0.8242
# Epoch 24/80
# called here
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00037111159990487657.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6804 - accuracy: 0.8025 - val_loss: 0.6367 - val_accuracy: 0.8258
# Epoch 25/80
# called here
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003230714123429161.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6702 - accuracy: 0.8068 - val_loss: 0.6403 - val_accuracy: 0.8240
# Epoch 26/80
# called here
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00028125.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6676 - accuracy: 0.8072 - val_loss: 0.6235 - val_accuracy: 0.8278
# Epoch 27/80
# called here
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00024484234592703485.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6482 - accuracy: 0.8147 - val_loss: 0.6341 - val_accuracy: 0.8267
# Epoch 28/80
# called here
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00021314764216552468.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6394 - accuracy: 0.8143 - val_loss: 0.6144 - val_accuracy: 0.8273
# Epoch 29/80
# called here
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00018555579995243828.
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6412 - accuracy: 0.8153 - val_loss: 0.5929 - val_accuracy: 0.8368
# Epoch 30/80
# called here
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00016153570617145804.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6383 - accuracy: 0.8118 - val_loss: 0.6019 - val_accuracy: 0.8316
# Epoch 31/80
# called here
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.000140625.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6234 - accuracy: 0.8194 - val_loss: 0.6061 - val_accuracy: 0.8323
# Epoch 32/80
# called here
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012242117296351742.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6317 - accuracy: 0.8183 - val_loss: 0.5980 - val_accuracy: 0.8327
# Epoch 33/80
# called here
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.00010657382108276234.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6019 - accuracy: 0.8265 - val_loss: 0.5958 - val_accuracy: 0.8341
# Epoch 34/80
# called here
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 9.277789997621914e-05.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6063 - accuracy: 0.8234 - val_loss: 0.6061 - val_accuracy: 0.8325
# Epoch 35/80
# called here
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 8.076785308572902e-05.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6133 - accuracy: 0.8239 - val_loss: 0.6018 - val_accuracy: 0.8311
# Epoch 36/80
# called here
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 7.03125e-05.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6004 - accuracy: 0.8258 - val_loss: 0.5841 - val_accuracy: 0.8370
# Epoch 37/80
# called here
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.121058648175871e-05.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6078 - accuracy: 0.8199 - val_loss: 0.5800 - val_accuracy: 0.8375
# Epoch 38/80
# called here
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 5.328691054138117e-05.
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6048 - accuracy: 0.8261 - val_loss: 0.5864 - val_accuracy: 0.8359
# Epoch 39/80
# called here
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 4.638894998810957e-05.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.5929 - accuracy: 0.8254 - val_loss: 0.5822 - val_accuracy: 0.8363
# Epoch 40/80
# called here
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.038392654286451e-05.
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6001 - accuracy: 0.8270 - val_loss: 0.5789 - val_accuracy: 0.8382
# Epoch 41/80
# called here
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 3.515625e-05.
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.5891 - accuracy: 0.8264 - val_loss: 0.5773 - val_accuracy: 0.8388
# Epoch 42/80
# called here
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 3.0605293240879376e-05.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5985 - accuracy: 0.8271 - val_loss: 0.5794 - val_accuracy: 0.8378
# Epoch 43/80
# called here
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.6643455270690585e-05.
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6004 - accuracy: 0.8222 - val_loss: 0.5833 - val_accuracy: 0.8359
# Epoch 44/80
# called here
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.3194474994054785e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5950 - accuracy: 0.8283 - val_loss: 0.5826 - val_accuracy: 0.8361
# Epoch 45/80
# called here
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.0191963271432245e-05.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5978 - accuracy: 0.8281 - val_loss: 0.5785 - val_accuracy: 0.8379
# Epoch 46/80
# called here
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.7578125e-05.
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5890 - accuracy: 0.8283 - val_loss: 0.5723 - val_accuracy: 0.8394
# Epoch 47/80
# called here
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.5302646620439688e-05.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5953 - accuracy: 0.8280 - val_loss: 0.5767 - val_accuracy: 0.8377
# Epoch 48/80
# called here
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3321727635345292e-05.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5963 - accuracy: 0.8243 - val_loss: 0.5744 - val_accuracy: 0.8386
# Epoch 49/80
# called here
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.1597237497027393e-05.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5922 - accuracy: 0.8289 - val_loss: 0.5762 - val_accuracy: 0.8391
# Epoch 50/80
# called here
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0095981635716122e-05.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5983 - accuracy: 0.8242 - val_loss: 0.5765 - val_accuracy: 0.8373
# Epoch 51/80
# called here
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 8.7890625e-06.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5920 - accuracy: 0.8261 - val_loss: 0.5742 - val_accuracy: 0.8387
# Epoch 52/80
# called here
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 7.651323310219844e-06.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5874 - accuracy: 0.8280 - val_loss: 0.5763 - val_accuracy: 0.8388
# Epoch 53/80
# called here
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 6.660863817672646e-06.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5889 - accuracy: 0.8271 - val_loss: 0.5760 - val_accuracy: 0.8384
# Epoch 54/80
# called here
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 5.798618748513696e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5988 - accuracy: 0.8267 - val_loss: 0.5762 - val_accuracy: 0.8385
# Epoch 55/80
# called here
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 5.047990817858061e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5969 - accuracy: 0.8258 - val_loss: 0.5712 - val_accuracy: 0.8393
# Epoch 56/80
# called here
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 4.39453125e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5917 - accuracy: 0.8271 - val_loss: 0.5769 - val_accuracy: 0.8379
# Epoch 57/80
# called here
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 3.825661655109922e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5877 - accuracy: 0.8308 - val_loss: 0.5756 - val_accuracy: 0.8394
# Epoch 58/80
# called here
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 3.330431908836323e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5974 - accuracy: 0.8255 - val_loss: 0.5738 - val_accuracy: 0.8388
# Epoch 59/80
# called here
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.899309374256848e-06.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.5889 - accuracy: 0.8275 - val_loss: 0.5741 - val_accuracy: 0.8391
# Epoch 60/80
# called here
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.5239954089290306e-06.
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.5865 - accuracy: 0.8279 - val_loss: 0.5726 - val_accuracy: 0.8393
# Epoch 61/80
# called here
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.197265625e-06.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5884 - accuracy: 0.8316 - val_loss: 0.5756 - val_accuracy: 0.8382
# Epoch 62/80
# called here
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1.912830827554961e-06.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5883 - accuracy: 0.8284 - val_loss: 0.5745 - val_accuracy: 0.8381
# Epoch 63/80
# called here
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1.6652159544181615e-06.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5868 - accuracy: 0.8305 - val_loss: 0.5734 - val_accuracy: 0.8388
# Epoch 64/80
# called here
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1.449654687128424e-06.
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.5994 - accuracy: 0.8233 - val_loss: 0.5750 - val_accuracy: 0.8384
# Epoch 65/80
# called here
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1.2619977044645153e-06.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5837 - accuracy: 0.8277 - val_loss: 0.5744 - val_accuracy: 0.8384
# Epoch 66/80
# called here
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1.0986328125e-06.
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5899 - accuracy: 0.8262 - val_loss: 0.5759 - val_accuracy: 0.8378
# Epoch 67/80
# called here
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 9.564154137774805e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5886 - accuracy: 0.8274 - val_loss: 0.5710 - val_accuracy: 0.8396
# Epoch 68/80
# called here
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 8.326079772090808e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6018 - accuracy: 0.8247 - val_loss: 0.5721 - val_accuracy: 0.8388
# Epoch 69/80
# called here
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 7.24827343564212e-07.
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5968 - accuracy: 0.8270 - val_loss: 0.5732 - val_accuracy: 0.8389
# Epoch 70/80
# called here
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 6.309988522322576e-07.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5810 - accuracy: 0.8275 - val_loss: 0.5748 - val_accuracy: 0.8387
# Epoch 71/80
# called here
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 5.4931640625e-07.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5881 - accuracy: 0.8290 - val_loss: 0.5763 - val_accuracy: 0.8378
# Epoch 72/80
# called here
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 4.782077068887402e-07.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5967 - accuracy: 0.8236 - val_loss: 0.5777 - val_accuracy: 0.8371
# Epoch 73/80
# called here
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 4.163039886045404e-07.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5861 - accuracy: 0.8292 - val_loss: 0.5757 - val_accuracy: 0.8377
# Epoch 74/80
# called here
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 3.62413671782106e-07.
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.5944 - accuracy: 0.8283 - val_loss: 0.5721 - val_accuracy: 0.8391
# Epoch 75/80
# called here
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 3.154994261161288e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5874 - accuracy: 0.8290 - val_loss: 0.5732 - val_accuracy: 0.8397
# Epoch 76/80
# called here
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 2.74658203125e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5851 - accuracy: 0.8298 - val_loss: 0.5720 - val_accuracy: 0.8395
# Epoch 77/80
# called here
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 2.391038534443701e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5945 - accuracy: 0.8275 - val_loss: 0.5764 - val_accuracy: 0.8381
# Epoch 78/80
# called here
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 2.081519943022702e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5835 - accuracy: 0.8292 - val_loss: 0.5712 - val_accuracy: 0.8392
# Epoch 79/80
# called here
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.81206835891053e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5911 - accuracy: 0.8264 - val_loss: 0.5719 - val_accuracy: 0.8392
# Epoch 80/80
# called here
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 1.577497130580644e-07.
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5841 - accuracy: 0.8322 - val_loss: 0.5782 - val_accuracy: 0.8370

# %%
acc_3 = history.history["accuracy"]
val_acc_3 = history.history["val_accuracy"]

# %%
#Save these values in your json
record_Results("acc_3",acc_3)
record_Results("val_acc_3",val_acc_3)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_3 = Get_Results("acc_3")["acc_3"]
val_acc_3 = Get_Results("val_acc_3")["val_acc_3"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc_3,val_acc_3,loss,val_loss,l_r)

# %% [markdown]
# **LR constant**

# %%
model = cifar10_model()
# for i in range(1000):
#   print(i)
#   sleep(7)

# %%
model = cifar10_model()
from time import time
print(time())

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  history = model.fit(
            datagen.flow(x_train, y_train), 
            validation_data=(x_test, y_test),
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# 1620217120.2977848
#
#
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 1563/1563 [==============================] - 44s 27ms/step - loss: 2.3952 - accuracy: 0.3402 - val_loss: 1.4242 - val_accuracy: 0.5348
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.2868 - accuracy: 0.5747 - val_loss: 1.0788 - val_accuracy: 0.6594
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0617 - accuracy: 0.6526 - val_loss: 0.9355 - val_accuracy: 0.7146
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9658 - accuracy: 0.6901 - val_loss: 0.9173 - val_accuracy: 0.7190
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9092 - accuracy: 0.7176 - val_loss: 0.8976 - val_accuracy: 0.7399
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8730 - accuracy: 0.7367 - val_loss: 0.8782 - val_accuracy: 0.7427
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8459 - accuracy: 0.7489 - val_loss: 0.8073 - val_accuracy: 0.7698
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8304 - accuracy: 0.7593 - val_loss: 0.7333 - val_accuracy: 0.7969
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8158 - accuracy: 0.7676 - val_loss: 0.8048 - val_accuracy: 0.7783
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.8043 - accuracy: 0.7741 - val_loss: 0.7471 - val_accuracy: 0.7976
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7947 - accuracy: 0.7812 - val_loss: 0.7604 - val_accuracy: 0.8033
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7864 - accuracy: 0.7856 - val_loss: 0.7589 - val_accuracy: 0.8034
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7799 - accuracy: 0.7885 - val_loss: 0.7164 - val_accuracy: 0.8159
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7674 - accuracy: 0.7957 - val_loss: 0.7767 - val_accuracy: 0.8067
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7649 - accuracy: 0.7967 - val_loss: 0.7311 - val_accuracy: 0.8071
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7588 - accuracy: 0.8004 - val_loss: 0.7310 - val_accuracy: 0.8183
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7564 - accuracy: 0.8011 - val_loss: 0.7573 - val_accuracy: 0.8123
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7558 - accuracy: 0.8016 - val_loss: 0.7263 - val_accuracy: 0.8234
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7504 - accuracy: 0.8056 - val_loss: 0.6714 - val_accuracy: 0.8376
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7482 - accuracy: 0.8064 - val_loss: 0.6962 - val_accuracy: 0.8268
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7465 - accuracy: 0.8078 - val_loss: 0.7293 - val_accuracy: 0.8204
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7410 - accuracy: 0.8094 - val_loss: 0.6954 - val_accuracy: 0.8303
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7401 - accuracy: 0.8118 - val_loss: 0.6899 - val_accuracy: 0.8306
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7419 - accuracy: 0.8100 - val_loss: 0.7202 - val_accuracy: 0.8198
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7331 - accuracy: 0.8137 - val_loss: 0.7186 - val_accuracy: 0.8284
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7317 - accuracy: 0.8155 - val_loss: 0.7000 - val_accuracy: 0.8291
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7354 - accuracy: 0.8148 - val_loss: 0.6934 - val_accuracy: 0.8320
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7303 - accuracy: 0.8179 - val_loss: 0.7010 - val_accuracy: 0.8279
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7290 - accuracy: 0.8164 - val_loss: 0.7958 - val_accuracy: 0.8102
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7328 - accuracy: 0.8161 - val_loss: 0.6705 - val_accuracy: 0.8438
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7227 - accuracy: 0.8199 - val_loss: 0.6850 - val_accuracy: 0.8376
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7209 - accuracy: 0.8210 - val_loss: 0.7394 - val_accuracy: 0.8244
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7195 - accuracy: 0.8221 - val_loss: 0.6718 - val_accuracy: 0.8433
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7222 - accuracy: 0.8202 - val_loss: 0.7352 - val_accuracy: 0.8204
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7164 - accuracy: 0.8238 - val_loss: 0.7349 - val_accuracy: 0.8244
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7151 - accuracy: 0.8231 - val_loss: 0.7010 - val_accuracy: 0.8384
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7136 - accuracy: 0.8227 - val_loss: 0.7283 - val_accuracy: 0.8313
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7200 - accuracy: 0.8233 - val_loss: 0.6639 - val_accuracy: 0.8495
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7155 - accuracy: 0.8241 - val_loss: 0.6519 - val_accuracy: 0.8482
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7109 - accuracy: 0.8260 - val_loss: 0.6414 - val_accuracy: 0.8534
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7142 - accuracy: 0.8245 - val_loss: 0.7278 - val_accuracy: 0.8249
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7060 - accuracy: 0.8276 - val_loss: 0.7496 - val_accuracy: 0.8282
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7167 - accuracy: 0.8249 - val_loss: 0.6705 - val_accuracy: 0.8477
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7103 - accuracy: 0.8275 - val_loss: 0.6620 - val_accuracy: 0.8484
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7045 - accuracy: 0.8273 - val_loss: 0.7442 - val_accuracy: 0.8228
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7018 - accuracy: 0.8302 - val_loss: 0.6569 - val_accuracy: 0.8479
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7126 - accuracy: 0.8264 - val_loss: 0.6737 - val_accuracy: 0.8426
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6986 - accuracy: 0.8305 - val_loss: 0.7265 - val_accuracy: 0.8353
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7033 - accuracy: 0.8288 - val_loss: 0.6523 - val_accuracy: 0.8463
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.7038 - accuracy: 0.8288 - val_loss: 0.6656 - val_accuracy: 0.8456
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6984 - accuracy: 0.8308 - val_loss: 0.6612 - val_accuracy: 0.8528
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.7022 - accuracy: 0.8287 - val_loss: 0.6602 - val_accuracy: 0.8528
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6976 - accuracy: 0.8315 - val_loss: 0.6653 - val_accuracy: 0.8481
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7016 - accuracy: 0.8311 - val_loss: 0.6742 - val_accuracy: 0.8461
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.6926 - accuracy: 0.8325 - val_loss: 0.7210 - val_accuracy: 0.8309
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6988 - accuracy: 0.8323 - val_loss: 0.6607 - val_accuracy: 0.8527
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6994 - accuracy: 0.8322 - val_loss: 0.5905 - val_accuracy: 0.8684
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6938 - accuracy: 0.8329 - val_loss: 0.6554 - val_accuracy: 0.8469
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.6963 - accuracy: 0.8316 - val_loss: 0.7238 - val_accuracy: 0.8332
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6944 - accuracy: 0.8338 - val_loss: 0.6621 - val_accuracy: 0.8547
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6993 - accuracy: 0.8317 - val_loss: 0.7015 - val_accuracy: 0.8379
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6975 - accuracy: 0.8325 - val_loss: 0.6629 - val_accuracy: 0.8497
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.6915 - accuracy: 0.8340 - val_loss: 0.6305 - val_accuracy: 0.8623
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
# 1563/1563 [==============================] - 37s 23ms/step - loss: 0.6978 - accuracy: 0.8308 - val_loss: 0.6614 - val_accuracy: 0.8525
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.6910 - accuracy: 0.8338 - val_loss: 0.6490 - val_accuracy: 0.8510
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6921 - accuracy: 0.8351 - val_loss: 0.6500 - val_accuracy: 0.8522
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6909 - accuracy: 0.8350 - val_loss: 0.6361 - val_accuracy: 0.8567
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6929 - accuracy: 0.8337 - val_loss: 0.6603 - val_accuracy: 0.8496
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6889 - accuracy: 0.8364 - val_loss: 0.6255 - val_accuracy: 0.8613
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6904 - accuracy: 0.8360 - val_loss: 0.6420 - val_accuracy: 0.8556
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6895 - accuracy: 0.8348 - val_loss: 0.6347 - val_accuracy: 0.8627
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6881 - accuracy: 0.8344 - val_loss: 0.6569 - val_accuracy: 0.8536
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6893 - accuracy: 0.8352 - val_loss: 0.6440 - val_accuracy: 0.8533
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6830 - accuracy: 0.8377 - val_loss: 0.6626 - val_accuracy: 0.8503
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6852 - accuracy: 0.8359 - val_loss: 0.6768 - val_accuracy: 0.8482
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6914 - accuracy: 0.8346 - val_loss: 0.6610 - val_accuracy: 0.8519
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6869 - accuracy: 0.8366 - val_loss: 0.6719 - val_accuracy: 0.8470
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6835 - accuracy: 0.8359 - val_loss: 0.6898 - val_accuracy: 0.8430
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6899 - accuracy: 0.8353 - val_loss: 0.6397 - val_accuracy: 0.8585
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6882 - accuracy: 0.8346 - val_loss: 0.7801 - val_accuracy: 0.8261

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
#Save these values in your json
record_Results("acc_4",acc_4)
record_Results("val_acc_4",val_acc_4)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# recorded

# %%
#Get the saved results
acc_4 = Get_Results("acc_4")["acc_4"]
val_acc_4 = Get_Results("val_acc_4")["val_acc_4"]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0

# %%
#

# %%
acc_1_dif = []
# for i in range(len(acc_1)): acc_1_dif.append(acc_1[i] - val_acc_1[i]) 
# acc_2_dif = []
# for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0]) 
# acc_3_dif = []
# for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0]) 
# acc_4_dif = []
# for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
# plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
# plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3_dif, label='BS = const acc',ls='-.',c='g')
# plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4_dif, label='LR = const acc',ls='-.',c='y')
# plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
# !pip install youtube-dl

# %%
# !youtube-dl "https://www.youtube.com/watch?v=PXDQFBmg1GI&ab_channel=%C3%87erkesTV"
