# %% [markdown]
# **STARTING GPU**

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.606943981000086
# GPU (s):
# 0.049184205000074144
# GPU speedup over CPU: 73x

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2021-04-21 14:54:54--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.5.128, 74.125.206.128, 64.233.167.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.5.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  63.3MB/s    in 1.0s
#
# 2021-04-21 14:54:55 (63.3 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

train_cat_fnames = os.listdir(train_cats_dir)
print(train_cat_fnames[:10])

train_dog_fnames = os.listdir(train_dogs_dir)
train_dog_fnames.sort()
print(train_dog_fnames[:10])

print('total training cat images:', len(os.listdir(train_cats_dir)))
print('total training dog images:', len(os.listdir(train_dogs_dir)))
print('total validation cat images:', len(os.listdir(validation_cats_dir)))
print('total validation dog images:', len(os.listdir(validation_dogs_dir)))

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow validation images in batches of 20 using val_datagen generator
validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# ['cat.843.jpg', 'cat.963.jpg', 'cat.57.jpg', 'cat.191.jpg', 'cat.167.jpg', 'cat.222.jpg', 'cat.76.jpg', 'cat.218.jpg', 'cat.372.jpg', 'cat.630.jpg']
# ['dog.0.jpg', 'dog.1.jpg', 'dog.10.jpg', 'dog.100.jpg', 'dog.101.jpg', 'dog.102.jpg', 'dog.103.jpg', 'dog.104.jpg', 'dog.105.jpg', 'dog.106.jpg']
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# from tensorflow.python.keras import backend
# from tensorflow.python.keras.datasets.cifar import load_batch
# from tensorflow.python.keras.utils.data_utils import get_file
# from tensorflow.python.util.tf_export import keras_export

# dirname = 'cifar-10-batches-py'
# origin = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip '
# path = get_file(
#     dirname,
#     origin=origin,
#     untar=True,
#     file_hash=
#     '6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce')

# num_train_samples = 50000

# x_train = np.empty((num_train_samples, 3, 32, 32), dtype='uint8')
# y_train = np.empty((num_train_samples,), dtype='uint8')

# for i in range(1, 6):
#   fpath = os.path.join(path, 'data_batch_' + str(i))
#   (x_train[(i - 1) * 10000:i * 10000, :, :, :],
#     y_train[(i - 1) * 10000:i * 10000]) = load_batch(fpath)

# fpath = os.path.join(path, 'test_batch')
# x_test, y_test = load_batch(fpath)

# y_train = np.reshape(y_train, (len(y_train), 1))
# y_test = np.reshape(y_test, (len(y_test), 1))

# if backend.image_data_format() == 'channels_last':
#   x_train = x_train.transpose(0, 2, 3, 1)
#   x_test = x_test.transpose(0, 2, 3, 1)

# x_test = x_test.astype(x_train.dtype)
# y_test = y_test.astype(y_train.dtype)

# %%
def Plotter(acc,val_acc,loss,val_loss,l_r):
  
  plt.plot(acc, label='accuracy')
  plt.plot(val_acc, label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')
  plt.show()


  plt.plot(loss, label='loss')
  plt.plot(val_loss, label = 'val_loss')
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.legend(loc='lower right')
  plt.show()

  plt.plot(l_r, label='Learning Rate')
  plt.xlabel('Epoch')
  plt.ylabel('LR')
  plt.legend(loc='lower right')
  plt.show()

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.optimizers import RMSprop

def cat_model():

  img_input = layers.Input(shape=(150, 150, 3))

  x = layers.Conv2D(16, 3, activation='relu')(img_input)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(32, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Conv2D(64, 3, activation='relu')(x)
  x = layers.MaxPooling2D(2)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(512, activation='relu')(x)

  output = layers.Dense(1, activation='sigmoid')(x)

  model = Model(img_input, output)



  model.compile(loss='binary_crossentropy',
                optimizer=RMSprop(lr=0.001),
                metrics=['accuracy'])
  
  return model 

model = cat_model()

# %%
cat_model().summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 18496)             0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               9470464
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Test for LR**

# %%
from random import random,randint,randrange,uniform
lr = []
epoo=100
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  # print(z,(batch_size)/((z+1)**(3/2))/80)
  


  if (z%2 == 0):
    LR = random() * batch_size/10000
    lr.append(LR)
  else:
    LR = random() * z/10000
    lr.append(LR)

lr = lr[::-1] 
lord_LR = lr
# print(min(lr))


plt.plot(lr, label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()


# lr = []
# epoo=150
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   # print(z,(batch_size)/((z+1)**(3/2))/80)
  

#   LR = random() * z/10000
#   # LR=LR/8
#   lr.append(LR)

# plt.plot(lr, label='Learning Rate')
# plt.xlabel('Epoch')
# plt.ylabel('LR')
# plt.legend(loc='lower right')
# plt.show()

# %%
# baseline model with dropout for the dogs vs cats dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
 
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(150, 150, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.5))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
	return model

# model = define_model()

# %% [markdown]
# **Normal default fit** : LR and Batch Size default

# %%
# epoch=1
# for i in range(5,100,5):

#   print("epoch ",epoch)
#   epoch+=1
#   train_generator.batch_size=i
#   validation_generator.batch_size=i

# train_generator.batch_size=i
# validation_generator.batch_size=i

history = model.fit(
      train_generator,
      epochs=100,
      validation_data=validation_generator,
      verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 10s 96ms/step - loss: 1.3325 - accuracy: 0.5470 - val_loss: 0.8310 - val_accuracy: 0.5010
# Epoch 2/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6577 - accuracy: 0.6475 - val_loss: 0.9433 - val_accuracy: 0.5270
# Epoch 3/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.5890 - accuracy: 0.6958 - val_loss: 0.5525 - val_accuracy: 0.7250
# Epoch 4/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4996 - accuracy: 0.7477 - val_loss: 0.7111 - val_accuracy: 0.6520
# Epoch 5/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4495 - accuracy: 0.7900 - val_loss: 0.5457 - val_accuracy: 0.7170
# Epoch 6/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.3510 - accuracy: 0.8535 - val_loss: 0.5919 - val_accuracy: 0.7150
# Epoch 7/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.2510 - accuracy: 0.8920 - val_loss: 0.7126 - val_accuracy: 0.7250
# Epoch 8/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.1865 - accuracy: 0.9304 - val_loss: 0.7126 - val_accuracy: 0.7280
# Epoch 9/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.1341 - accuracy: 0.9517 - val_loss: 1.0899 - val_accuracy: 0.6930
# Epoch 10/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0855 - accuracy: 0.9716 - val_loss: 1.0809 - val_accuracy: 0.7250
# Epoch 11/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.1213 - accuracy: 0.9794 - val_loss: 1.2012 - val_accuracy: 0.7290
# Epoch 12/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0507 - accuracy: 0.9808 - val_loss: 1.2267 - val_accuracy: 0.7280
# Epoch 13/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0470 - accuracy: 0.9874 - val_loss: 1.2023 - val_accuracy: 0.7240
# Epoch 14/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0435 - accuracy: 0.9862 - val_loss: 1.3944 - val_accuracy: 0.7320
# Epoch 15/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 1.9729 - val_accuracy: 0.7070
# Epoch 16/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0130 - accuracy: 0.9941 - val_loss: 2.0398 - val_accuracy: 0.7170
# Epoch 17/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0605 - accuracy: 0.9859 - val_loss: 1.9838 - val_accuracy: 0.7210
# Epoch 18/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 2.0814 - val_accuracy: 0.7230
# Epoch 19/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0269 - accuracy: 0.9893 - val_loss: 1.9740 - val_accuracy: 0.6940
# Epoch 20/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.0105 - accuracy: 0.9974 - val_loss: 2.1469 - val_accuracy: 0.7140
# Epoch 21/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0076 - accuracy: 0.9991 - val_loss: 2.3028 - val_accuracy: 0.7270
# Epoch 22/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0118 - accuracy: 0.9973 - val_loss: 2.3593 - val_accuracy: 0.7340
# Epoch 23/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0315 - accuracy: 0.9953 - val_loss: 2.5789 - val_accuracy: 0.7320
# Epoch 24/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 2.6134 - val_accuracy: 0.7230
# Epoch 25/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 2.7117 - val_accuracy: 0.7400
# Epoch 26/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0220 - accuracy: 0.9963 - val_loss: 2.8794 - val_accuracy: 0.7180
# Epoch 27/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0905 - accuracy: 0.9864 - val_loss: 4.6903 - val_accuracy: 0.6310
# Epoch 28/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.1554 - accuracy: 0.9756 - val_loss: 2.2926 - val_accuracy: 0.7170
# Epoch 29/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 2.1761 - val_accuracy: 0.7400
# Epoch 30/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 2.5423 - val_accuracy: 0.7090
# Epoch 31/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0234 - accuracy: 0.9923 - val_loss: 3.1267 - val_accuracy: 0.7230
# Epoch 32/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 3.4903 - val_accuracy: 0.7340
# Epoch 33/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0506 - accuracy: 0.9872 - val_loss: 3.3107 - val_accuracy: 0.7340
# Epoch 34/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 3.0287 - val_accuracy: 0.7320
# Epoch 35/100
# 100/100 [==============================] - 9s 90ms/step - loss: 2.2862e-05 - accuracy: 1.0000 - val_loss: 3.6652 - val_accuracy: 0.7330
# Epoch 36/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0510 - accuracy: 0.9953 - val_loss: 3.8300 - val_accuracy: 0.7260
# Epoch 37/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0231 - accuracy: 0.9969 - val_loss: 3.8471 - val_accuracy: 0.7220
# Epoch 38/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.0132e-05 - accuracy: 1.0000 - val_loss: 4.2145 - val_accuracy: 0.7260
# Epoch 39/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.3457e-06 - accuracy: 1.0000 - val_loss: 5.0787 - val_accuracy: 0.7210
# Epoch 40/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0774 - accuracy: 0.9888 - val_loss: 3.7799 - val_accuracy: 0.7230
# Epoch 41/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0601 - accuracy: 0.9912 - val_loss: 3.5414 - val_accuracy: 0.7290
# Epoch 42/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.9926e-06 - accuracy: 1.0000 - val_loss: 4.1075 - val_accuracy: 0.7370
# Epoch 43/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 5.0384 - val_accuracy: 0.7170
# Epoch 44/100
# 100/100 [==============================] - 9s 89ms/step - loss: 8.3501e-04 - accuracy: 1.0000 - val_loss: 4.5289 - val_accuracy: 0.7170
# Epoch 45/100
# 100/100 [==============================] - 9s 88ms/step - loss: 1.0885e-06 - accuracy: 1.0000 - val_loss: 4.8725 - val_accuracy: 0.7300
# Epoch 46/100
# 100/100 [==============================] - 9s 90ms/step - loss: 6.7926e-04 - accuracy: 0.9998 - val_loss: 4.8596 - val_accuracy: 0.7130
# Epoch 47/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 3.9934 - val_accuracy: 0.7140
# Epoch 48/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 4.5666 - val_accuracy: 0.7270
# Epoch 49/100
# 100/100 [==============================] - 9s 88ms/step - loss: 8.3739e-07 - accuracy: 1.0000 - val_loss: 4.8154 - val_accuracy: 0.7350
# Epoch 50/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0054 - accuracy: 0.9992 - val_loss: 4.1533 - val_accuracy: 0.7310
# Epoch 51/100
# 100/100 [==============================] - 9s 91ms/step - loss: 2.8812e-05 - accuracy: 1.0000 - val_loss: 5.0970 - val_accuracy: 0.7240
# Epoch 52/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 4.1339 - val_accuracy: 0.7030
# Epoch 53/100
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 6.4037 - val_accuracy: 0.7050
# Epoch 54/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0217 - accuracy: 0.9946 - val_loss: 4.3185 - val_accuracy: 0.7270
# Epoch 55/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0248 - accuracy: 0.9957 - val_loss: 4.5274 - val_accuracy: 0.6890
# Epoch 56/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0122 - accuracy: 0.9986 - val_loss: 4.9206 - val_accuracy: 0.7130
# Epoch 57/100
# 100/100 [==============================] - 9s 91ms/step - loss: 0.0169 - accuracy: 0.9985 - val_loss: 4.2830 - val_accuracy: 0.7300
# Epoch 58/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 4.8482 - val_accuracy: 0.7130
# Epoch 59/100
# 100/100 [==============================] - 9s 91ms/step - loss: 3.8237e-05 - accuracy: 1.0000 - val_loss: 4.5873 - val_accuracy: 0.7330
# Epoch 60/100
# 100/100 [==============================] - 9s 91ms/step - loss: 1.1070e-07 - accuracy: 1.0000 - val_loss: 4.9996 - val_accuracy: 0.7290
# Epoch 61/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 5.8453 - val_accuracy: 0.7010
# Epoch 62/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0034 - accuracy: 0.9980 - val_loss: 5.6613 - val_accuracy: 0.7210
# Epoch 63/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 5.8117 - val_accuracy: 0.6990
# Epoch 64/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 5.9164 - val_accuracy: 0.7230
# Epoch 65/100
# 100/100 [==============================] - 9s 89ms/step - loss: 1.6181e-08 - accuracy: 1.0000 - val_loss: 5.9402 - val_accuracy: 0.7240
# Epoch 66/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.0240 - accuracy: 0.9974 - val_loss: 5.3341 - val_accuracy: 0.7220
# Epoch 67/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 5.1303 - val_accuracy: 0.7340
# Epoch 68/100
# 100/100 [==============================] - 9s 88ms/step - loss: 7.0865e-04 - accuracy: 0.9998 - val_loss: 6.4286 - val_accuracy: 0.7200
# Epoch 69/100
# 100/100 [==============================] - 9s 90ms/step - loss: 0.0162 - accuracy: 0.9978 - val_loss: 5.8342 - val_accuracy: 0.7270
# Epoch 70/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0044 - accuracy: 0.9996 - val_loss: 6.7872 - val_accuracy: 0.7350
# Epoch 71/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 6.5610 - val_accuracy: 0.7130
# Epoch 72/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0294 - accuracy: 0.9947 - val_loss: 6.2484 - val_accuracy: 0.7040
# Epoch 73/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0091 - accuracy: 0.9992 - val_loss: 6.7572 - val_accuracy: 0.7170
# Epoch 74/100
# 100/100 [==============================] - 9s 92ms/step - loss: 0.0261 - accuracy: 0.9982 - val_loss: 6.7345 - val_accuracy: 0.6920
# Epoch 75/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 6.5903 - val_accuracy: 0.7000
# Epoch 76/100
# 100/100 [==============================] - 9s 94ms/step - loss: 8.4309e-08 - accuracy: 1.0000 - val_loss: 6.7309 - val_accuracy: 0.7140
# Epoch 77/100
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 5.9284 - val_accuracy: 0.7080
# Epoch 78/100
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 7.1784 - val_accuracy: 0.7040
# Epoch 79/100
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0198 - accuracy: 0.9974 - val_loss: 8.4351 - val_accuracy: 0.7080
# Epoch 80/100
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0472 - accuracy: 0.9973 - val_loss: 7.3073 - val_accuracy: 0.6990
# Epoch 81/100
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0427 - accuracy: 0.9957 - val_loss: 6.1784 - val_accuracy: 0.7240
# Epoch 82/100
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0018 - accuracy: 0.9999 - val_loss: 6.2716 - val_accuracy: 0.6940
# Epoch 83/100
# 100/100 [==============================] - 10s 96ms/step - loss: 8.6962e-05 - accuracy: 1.0000 - val_loss: 6.1944 - val_accuracy: 0.7280
# Epoch 84/100
# 100/100 [==============================] - 9s 94ms/step - loss: 3.6861e-07 - accuracy: 1.0000 - val_loss: 6.4726 - val_accuracy: 0.7240
# Epoch 85/100
# 100/100 [==============================] - 10s 96ms/step - loss: 1.8843e-09 - accuracy: 1.0000 - val_loss: 6.7214 - val_accuracy: 0.7230
# Epoch 86/100
# 100/100 [==============================] - 10s 96ms/step - loss: 2.0479e-09 - accuracy: 1.0000 - val_loss: 7.7388 - val_accuracy: 0.7220
# Epoch 87/100
# 100/100 [==============================] - 9s 95ms/step - loss: 2.1994e-10 - accuracy: 1.0000 - val_loss: 7.6149 - val_accuracy: 0.7220
# Epoch 88/100
# 100/100 [==============================] - 9s 93ms/step - loss: 1.7884e-12 - accuracy: 1.0000 - val_loss: 7.6153 - val_accuracy: 0.7220
# Epoch 89/100
# 100/100 [==============================] - 9s 93ms/step - loss: 3.7613e-12 - accuracy: 1.0000 - val_loss: 7.6157 - val_accuracy: 0.7220
# Epoch 90/100
# 100/100 [==============================] - 9s 94ms/step - loss: 4.1236e-12 - accuracy: 1.0000 - val_loss: 7.6161 - val_accuracy: 0.7220
# Epoch 91/100
# 100/100 [==============================] - 9s 93ms/step - loss: 1.8205e-12 - accuracy: 1.0000 - val_loss: 7.6165 - val_accuracy: 0.7210
# Epoch 92/100
# 100/100 [==============================] - 9s 94ms/step - loss: 1.4309e-11 - accuracy: 1.0000 - val_loss: 7.6169 - val_accuracy: 0.7210
# Epoch 93/100
# 100/100 [==============================] - 9s 93ms/step - loss: 3.4486e-12 - accuracy: 1.0000 - val_loss: 7.6172 - val_accuracy: 0.7220
# Epoch 94/100
# 100/100 [==============================] - 9s 93ms/step - loss: 2.5443e-12 - accuracy: 1.0000 - val_loss: 7.6176 - val_accuracy: 0.7220
# Epoch 95/100
# 100/100 [==============================] - 9s 93ms/step - loss: 2.8167e-12 - accuracy: 1.0000 - val_loss: 7.6180 - val_accuracy: 0.7220
# Epoch 96/100
# 100/100 [==============================] - 9s 94ms/step - loss: 1.8413e-12 - accuracy: 1.0000 - val_loss: 7.6184 - val_accuracy: 0.7220
# Epoch 97/100
# 100/100 [==============================] - 9s 95ms/step - loss: 5.4136e-12 - accuracy: 1.0000 - val_loss: 7.6187 - val_accuracy: 0.7220
# Epoch 98/100
# 100/100 [==============================] - 9s 92ms/step - loss: 2.9300e-12 - accuracy: 1.0000 - val_loss: 7.6191 - val_accuracy: 0.7220
# Epoch 99/100
# 100/100 [==============================] - 9s 91ms/step - loss: 5.0212e-12 - accuracy: 1.0000 - val_loss: 7.6194 - val_accuracy: 0.7220
# Epoch 100/100
# 100/100 [==============================] - 9s 91ms/step - loss: 9.2083e-12 - accuracy: 1.0000 - val_loss: 7.6198 - val_accuracy: 0.7230

# %%
acc_1 = history.history['accuracy']
val_acc_1 = history.history['val_accuracy']

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **LR ∝ BS/Epoch**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []

num = 0

x = 0
# kr = lr
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  if (z%2 == 0):
    LR = random() * batch_size/100000
  # lr.append(LR)
  else:
    LR = random() * z/100000
  # lr.append(LR)

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])

  # if(num >= 50 ):
  #   x = input("type anything if you want to continue >  ")
  #   num = 0
  # num += 1
# Out:
# epoch 1, Learning Rate 2.809934615283206e-06, Batch Size  5
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 400/400 [==============================] - 11s 26ms/step - loss: 2.2164 - accuracy: 0.4782 - val_loss: 0.6930 - val_accuracy: 0.5030
#
#
# epoch 2, Learning Rate 6.740765970225729e-05, Batch Size  10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 200/200 [==============================] - 9s 47ms/step - loss: 0.7291 - accuracy: 0.5525 - val_loss: 0.6651 - val_accuracy: 0.6080
#
#
# epoch 3, Learning Rate 2.165868316244966e-05, Batch Size  15
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 134/134 [==============================] - 9s 68ms/step - loss: 0.6810 - accuracy: 0.6110 - val_loss: 1.3043 - val_accuracy: 0.5030
#
#
# epoch 4, Learning Rate 9.482233678915286e-05, Batch Size  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 100/100 [==============================] - 9s 92ms/step - loss: 0.6568 - accuracy: 0.6700 - val_loss: 0.6188 - val_accuracy: 0.6690
#
#
# epoch 5, Learning Rate 3.38863109021574e-05, Batch Size  25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 80/80 [==============================] - 9s 113ms/step - loss: 0.5354 - accuracy: 0.7255 - val_loss: 0.5873 - val_accuracy: 0.6950
#
#
# epoch 6, Learning Rate 0.00023311896178223134, Batch Size  30
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 67/67 [==============================] - 9s 135ms/step - loss: 0.4363 - accuracy: 0.7900 - val_loss: 0.6342 - val_accuracy: 0.6490
#
#
# epoch 7, Learning Rate 5.5358202875437105e-06, Batch Size  35
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 58/58 [==============================] - 9s 155ms/step - loss: 0.3449 - accuracy: 0.8425 - val_loss: 0.7031 - val_accuracy: 0.7030
#
#
# epoch 8, Learning Rate 0.0003333848880552899, Batch Size  40
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 50/50 [==============================] - 9s 183ms/step - loss: 0.2116 - accuracy: 0.9130 - val_loss: 0.8658 - val_accuracy: 0.7080
#
#
# epoch 9, Learning Rate 3.606726582489687e-05, Batch Size  45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 45/45 [==============================] - 9s 198ms/step - loss: 0.1407 - accuracy: 0.9495 - val_loss: 1.3642 - val_accuracy: 0.6870
#
#
# epoch 10, Learning Rate 0.00047777936703375116, Batch Size  50
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 40/40 [==============================] - 9s 224ms/step - loss: 0.1349 - accuracy: 0.9560 - val_loss: 1.4918 - val_accuracy: 0.6890
#
#
# epoch 11, Learning Rate 6.098912166535446e-05, Batch Size  55
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 37/37 [==============================] - 9s 248ms/step - loss: 0.1329 - accuracy: 0.9615 - val_loss: 1.4094 - val_accuracy: 0.6920
#
#
# epoch 12, Learning Rate 0.0005165042800409872, Batch Size  60
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 34/34 [==============================] - 9s 274ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.1736 - val_accuracy: 0.6900
#
#
# epoch 13, Learning Rate 8.549705308884434e-05, Batch Size  65
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 31/31 [==============================] - 9s 299ms/step - loss: 0.2953 - accuracy: 0.9680 - val_loss: 1.1998 - val_accuracy: 0.6490
#
#
# epoch 14, Learning Rate 0.00016050350758082984, Batch Size  70
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 29/29 [==============================] - 9s 317ms/step - loss: 0.0255 - accuracy: 0.9945 - val_loss: 1.8296 - val_accuracy: 0.6870
#
#
# epoch 15, Learning Rate 3.992823532182598e-05, Batch Size  75
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 27/27 [==============================] - 9s 340ms/step - loss: 7.9588e-04 - accuracy: 1.0000 - val_loss: 2.4033 - val_accuracy: 0.6970
#
#
# epoch 16, Learning Rate 0.0004643513924626639, Batch Size  80
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 25/25 [==============================] - 9s 370ms/step - loss: 0.1571 - accuracy: 0.9725 - val_loss: 1.2342 - val_accuracy: 0.6740
#
#
# epoch 17, Learning Rate 7.233975036710329e-05, Batch Size  85
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 24/24 [==============================] - 9s 383ms/step - loss: 0.0529 - accuracy: 0.9815 - val_loss: 2.0803 - val_accuracy: 0.6980
#
#
# epoch 18, Learning Rate 0.00019047664695494895, Batch Size  90
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 23/23 [==============================] - 9s 397ms/step - loss: 4.6375e-04 - accuracy: 1.0000 - val_loss: 2.4836 - val_accuracy: 0.7040
#
#
# epoch 19, Learning Rate 0.00015399577709971518, Batch Size  95
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 22/22 [==============================] - 9s 428ms/step - loss: 7.4103e-05 - accuracy: 1.0000 - val_loss: 2.7749 - val_accuracy: 0.7090
#
#
# epoch 20, Learning Rate 0.0006754648020001476, Batch Size  100
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 20/20 [==============================] - 9s 456ms/step - loss: 2.7001e-05 - accuracy: 1.0000 - val_loss: 2.8920 - val_accuracy: 0.7030
#
#
# epoch 21, Learning Rate 7.810246488538808e-05, Batch Size  105
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 20/20 [==============================] - 9s 463ms/step - loss: 1.0164e-05 - accuracy: 1.0000 - val_loss: 3.1544 - val_accuracy: 0.7040
#
#
# epoch 22, Learning Rate 0.00033952688938261545, Batch Size  110
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 19/19 [==============================] - 9s 491ms/step - loss: 3.9257e-06 - accuracy: 1.0000 - val_loss: 3.2618 - val_accuracy: 0.7060
#
#
# epoch 23, Learning Rate 9.453875384277651e-05, Batch Size  115
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 18/18 [==============================] - 9s 513ms/step - loss: 1.5435e-06 - accuracy: 1.0000 - val_loss: 3.4633 - val_accuracy: 0.6950
#
#
# epoch 24, Learning Rate 0.00017516441867752256, Batch Size  120
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.201906211529547e-05.
# 17/17 [==============================] - 9s 543ms/step - loss: 9.2267e-07 - accuracy: 1.0000 - val_loss: 3.4740 - val_accuracy: 0.6980
#
#
# epoch 25, Learning Rate 0.0001964500216719373, Batch Size  125
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 16/16 [==============================] - 9s 579ms/step - loss: 6.2536e-07 - accuracy: 1.0000 - val_loss: 3.7923 - val_accuracy: 0.7010
#
#
# epoch 26, Learning Rate 0.0008108063445462861, Batch Size  130
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001789407791228114.
# 16/16 [==============================] - 9s 581ms/step - loss: 2.1949e-07 - accuracy: 1.0000 - val_loss: 3.8895 - val_accuracy: 0.7040
#
#
# epoch 27, Learning Rate 8.234524933403967e-05, Batch Size  135
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 15/15 [==============================] - 9s 614ms/step - loss: 1.3523e-07 - accuracy: 1.0000 - val_loss: 4.1230 - val_accuracy: 0.7030
#
#
# epoch 28, Learning Rate 0.000484251438332635, Batch Size  140
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0033900505585588237.
# 15/15 [==============================] - 9s 605ms/step - loss: 5.1159e-08 - accuracy: 1.0000 - val_loss: 4.3416 - val_accuracy: 0.7000
#
#
# epoch 29, Learning Rate 1.3833354666586697e-05, Batch Size  145
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 14/14 [==============================] - 9s 660ms/step - loss: 2.8631e-08 - accuracy: 1.0000 - val_loss: 4.4874 - val_accuracy: 0.7000
#
#
# epoch 30, Learning Rate 0.0005721217136379456, Batch Size  150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00358329682823225.
# 14/14 [==============================] - 9s 658ms/step - loss: 1.5070e-08 - accuracy: 1.0000 - val_loss: 4.6119 - val_accuracy: 0.7020
#
#
# epoch 31, Learning Rate 5.646821518399411e-05, Batch Size  155
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 13/13 [==============================] - 9s 702ms/step - loss: 9.4827e-09 - accuracy: 1.0000 - val_loss: 4.6431 - val_accuracy: 0.7030
#
#
# epoch 32, Learning Rate 0.0005767936455514678, Batch Size  160
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0023188746073258214.
# 13/13 [==============================] - 9s 699ms/step - loss: 6.2441e-09 - accuracy: 1.0000 - val_loss: 4.8254 - val_accuracy: 0.7020
#
#
# epoch 33, Learning Rate 2.532771784877274e-05, Batch Size  165
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 13/13 [==============================] - 9s 693ms/step - loss: 4.7434e-09 - accuracy: 1.0000 - val_loss: 4.9937 - val_accuracy: 0.7060
#
#
# epoch 34, Learning Rate 0.000893890972886713, Batch Size  170
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 12/12 [==============================] - 9s 772ms/step - loss: 3.7300e-09 - accuracy: 1.0000 - val_loss: 4.9211 - val_accuracy: 0.7020
#
#
# epoch 35, Learning Rate 6.927142283751304e-05, Batch Size  175
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 12/12 [==============================] - 10s 779ms/step - loss: 2.4739e-09 - accuracy: 1.0000 - val_loss: 5.1319 - val_accuracy: 0.7050
#
#
# epoch 36, Learning Rate 0.000544517434747253, Batch Size  180
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0008285136523677009.
# 12/12 [==============================] - 9s 851ms/step - loss: 2.0030e-09 - accuracy: 1.0000 - val_loss: 5.1041 - val_accuracy: 0.7040
#
#
# epoch 37, Learning Rate 0.0002446188129146725, Batch Size  185
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001749332230558462.
# 11/11 [==============================] - 9s 887ms/step - loss: 1.9243e-09 - accuracy: 1.0000 - val_loss: 5.1632 - val_accuracy: 0.7070
#
#
# epoch 38, Learning Rate 0.001544069066702736, Batch Size  190
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002725012132140974.
# 11/11 [==============================] - 9s 825ms/step - loss: 1.9073e-09 - accuracy: 1.0000 - val_loss: 5.1478 - val_accuracy: 0.7080
#
#
# epoch 39, Learning Rate 0.00018935427748411617, Batch Size  195
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 11/11 [==============================] - 10s 853ms/step - loss: 1.7118e-09 - accuracy: 1.0000 - val_loss: 5.3156 - val_accuracy: 0.7080
#
#
# epoch 40, Learning Rate 0.0010429609756751085, Batch Size  200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 9s 940ms/step - loss: 1.9823e-09 - accuracy: 1.0000 - val_loss: 5.1963 - val_accuracy: 0.7050
#
#
# epoch 41, Learning Rate 9.569214434790824e-05, Batch Size  205
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 9s 920ms/step - loss: 1.3394e-09 - accuracy: 1.0000 - val_loss: 5.2902 - val_accuracy: 0.7050
#
#
# epoch 42, Learning Rate 0.00039173243552335273, Batch Size  210
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 9s 929ms/step - loss: 1.2414e-09 - accuracy: 1.0000 - val_loss: 5.2543 - val_accuracy: 0.7070
#
#
# epoch 43, Learning Rate 0.00021101244414846928, Batch Size  215
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 10/10 [==============================] - 9s 915ms/step - loss: 1.4022e-09 - accuracy: 1.0000 - val_loss: 5.2419 - val_accuracy: 0.7030
#
#
# epoch 44, Learning Rate 0.0002791102573892324, Batch Size  220
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0027592512215328722.
# 10/10 [==============================] - 9s 1s/step - loss: 1.2859e-09 - accuracy: 1.0000 - val_loss: 5.3244 - val_accuracy: 0.7080
#
#
# epoch 45, Learning Rate 0.0002786252580241839, Batch Size  225
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 9s 1s/step - loss: 1.2289e-09 - accuracy: 1.0000 - val_loss: 5.3388 - val_accuracy: 0.7080
#
#
# epoch 46, Learning Rate 0.0011438751837841957, Batch Size  230
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 10s 1s/step - loss: 1.1720e-09 - accuracy: 1.0000 - val_loss: 5.3797 - val_accuracy: 0.7070
#
#
# epoch 47, Learning Rate 9.098603544009734e-05, Batch Size  235
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 9s 1s/step - loss: 1.2892e-09 - accuracy: 1.0000 - val_loss: 5.4219 - val_accuracy: 0.7100
#
#
# epoch 48, Learning Rate 0.0013163237336100988, Batch Size  240
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0011054716238229553.
# 9/9 [==============================] - 10s 1s/step - loss: 1.1254e-09 - accuracy: 1.0000 - val_loss: 5.3858 - val_accuracy: 0.7090
#
#
# epoch 49, Learning Rate 0.00022394628342774946, Batch Size  245
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 9/9 [==============================] - 10s 1s/step - loss: 1.1983e-09 - accuracy: 1.0000 - val_loss: 5.4075 - val_accuracy: 0.7090
#
#
# epoch 50, Learning Rate 0.0019475450878016403, Batch Size  250
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 10s 1s/step - loss: 1.1774e-09 - accuracy: 1.0000 - val_loss: 5.3888 - val_accuracy: 0.7060
#
#
# epoch 51, Learning Rate 0.00012763447555414403, Batch Size  255
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006434451261426583.
# 8/8 [==============================] - 9s 1s/step - loss: 1.2092e-09 - accuracy: 1.0000 - val_loss: 5.3964 - val_accuracy: 0.7080
#
#
# epoch 52, Learning Rate 0.0012740490555580276, Batch Size  260
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003192438954060919.
# 8/8 [==============================] - 10s 1s/step - loss: 1.0829e-09 - accuracy: 1.0000 - val_loss: 5.4190 - val_accuracy: 0.7100
#
#
# epoch 53, Learning Rate 0.0001818982961952136, Batch Size  265
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 10s 1s/step - loss: 9.8442e-10 - accuracy: 1.0000 - val_loss: 5.4175 - val_accuracy: 0.7080
#
#
# epoch 54, Learning Rate 0.0017210535819617626, Batch Size  270
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010503426554343584.
# 8/8 [==============================] - 10s 1s/step - loss: 9.8073e-10 - accuracy: 1.0000 - val_loss: 5.4331 - val_accuracy: 0.7080
#
#
# epoch 55, Learning Rate 8.686455234959504e-05, Batch Size  275
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 10s 1s/step - loss: 9.9096e-10 - accuracy: 1.0000 - val_loss: 5.4152 - val_accuracy: 0.7080
#
#
# epoch 56, Learning Rate 0.001512393975315478, Batch Size  280
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 10s 1s/step - loss: 9.5156e-10 - accuracy: 1.0000 - val_loss: 5.4726 - val_accuracy: 0.7090
#
#
# epoch 57, Learning Rate 0.0004651955470434327, Batch Size  285
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 8/8 [==============================] - 10s 1s/step - loss: 9.8717e-10 - accuracy: 1.0000 - val_loss: 5.4901 - val_accuracy: 0.7090
#
#
# epoch 58, Learning Rate 0.0006306744993314456, Batch Size  290
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002438628505254085.
# 7/7 [==============================] - 10s 1s/step - loss: 1.0263e-09 - accuracy: 1.0000 - val_loss: 5.4734 - val_accuracy: 0.7090
#
#
# epoch 59, Learning Rate 0.00015879481894550063, Batch Size  295
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.003910285446642176.
# 7/7 [==============================] - 10s 1s/step - loss: 9.7551e-10 - accuracy: 1.0000 - val_loss: 5.4978 - val_accuracy: 0.7090
#
#
# epoch 60, Learning Rate 0.00043871228106534863, Batch Size  300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016859488407157158.
# 7/7 [==============================] - 10s 1s/step - loss: 9.6384e-10 - accuracy: 1.0000 - val_loss: 5.4820 - val_accuracy: 0.7060
#
#
# epoch 61, Learning Rate 2.8131369134481613e-05, Batch Size  305
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 10s 1s/step - loss: 9.9167e-10 - accuracy: 1.0000 - val_loss: 5.4893 - val_accuracy: 0.7090
#
#
# epoch 62, Learning Rate 0.0022842138004329367, Batch Size  310
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005483762646259317.
# 7/7 [==============================] - 10s 1s/step - loss: 8.8531e-10 - accuracy: 1.0000 - val_loss: 5.4892 - val_accuracy: 0.7090
#
#
# epoch 63, Learning Rate 0.0002469374316049866, Batch Size  315
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 7/7 [==============================] - 10s 1s/step - loss: 9.7224e-10 - accuracy: 1.0000 - val_loss: 5.4705 - val_accuracy: 0.7090
#
#
# epoch 64, Learning Rate 0.0028716538806638475, Batch Size  320
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0029900690798846294.
# 7/7 [==============================] - 10s 1s/step - loss: 9.1389e-10 - accuracy: 1.0000 - val_loss: 5.5092 - val_accuracy: 0.7060
#
#
# epoch 65, Learning Rate 0.00023679094516460832, Batch Size  325
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0020191621894044844.
# 7/7 [==============================] - 10s 1s/step - loss: 9.7884e-10 - accuracy: 1.0000 - val_loss: 5.5115 - val_accuracy: 0.7050
#
#
# epoch 66, Learning Rate 0.0027159197425268367, Batch Size  330
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0034868320264407316.
# 7/7 [==============================] - 10s 1s/step - loss: 1.0794e-09 - accuracy: 1.0000 - val_loss: 5.5170 - val_accuracy: 0.7050
#
#
# epoch 67, Learning Rate 0.00018080453263218165, Batch Size  335
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0020157646780936352.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0770e-09 - accuracy: 1.0000 - val_loss: 5.5077 - val_accuracy: 0.7060
#
#
# epoch 68, Learning Rate 0.00209901642823439, Batch Size  340
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005777047631806538.
# 6/6 [==============================] - 10s 2s/step - loss: 9.7250e-10 - accuracy: 1.0000 - val_loss: 5.5111 - val_accuracy: 0.7060
#
#
# epoch 69, Learning Rate 0.0002207020209865539, Batch Size  345
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0182e-09 - accuracy: 1.0000 - val_loss: 5.4595 - val_accuracy: 0.7070
#
#
# epoch 70, Learning Rate 0.0031924909021004335, Batch Size  350
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003025814065042192.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0535e-09 - accuracy: 1.0000 - val_loss: 5.4646 - val_accuracy: 0.7070
#
#
# epoch 71, Learning Rate 0.00041197831194784274, Batch Size  355
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0193e-09 - accuracy: 1.0000 - val_loss: 5.5184 - val_accuracy: 0.7070
#
#
# epoch 72, Learning Rate 0.0012159920710241112, Batch Size  360
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0018743979385181476.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0695e-09 - accuracy: 1.0000 - val_loss: 5.5109 - val_accuracy: 0.7060
#
#
# epoch 73, Learning Rate 0.00026313609990404567, Batch Size  365
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0693e-09 - accuracy: 1.0000 - val_loss: 5.5195 - val_accuracy: 0.7060
#
#
# epoch 74, Learning Rate 0.0007101237385993162, Batch Size  370
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00194627137805681.
# 6/6 [==============================] - 10s 2s/step - loss: 1.1534e-09 - accuracy: 1.0000 - val_loss: 5.5287 - val_accuracy: 0.7060
#
#
# epoch 75, Learning Rate 0.0005848452707088486, Batch Size  375
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0022136547567309863.
# 6/6 [==============================] - 10s 2s/step - loss: 1.0816e-09 - accuracy: 1.0000 - val_loss: 5.5308 - val_accuracy: 0.7060
#
#
# epoch 76, Learning Rate 0.0005474719255518893, Batch Size  380
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0020111088779545742.
# 6/6 [==============================] - 10s 2s/step - loss: 1.1374e-09 - accuracy: 1.0000 - val_loss: 5.5317 - val_accuracy: 0.7070
#
#
# epoch 77, Learning Rate 0.0006155193741345461, Batch Size  385
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0035405193757239452.
# 6/6 [==============================] - 10s 2s/step - loss: 1.1679e-09 - accuracy: 1.0000 - val_loss: 5.4717 - val_accuracy: 0.7070
#
#
# epoch 78, Learning Rate 0.0028483841028110485, Batch Size  390
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00037260575428029277.
# 6/6 [==============================] - 10s 2s/step - loss: 8.6136e-10 - accuracy: 1.0000 - val_loss: 5.4759 - val_accuracy: 0.7060
#
#
# epoch 79, Learning Rate 0.0003196764050636198, Batch Size  395
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 6/6 [==============================] - 10s 2s/step - loss: 8.7235e-10 - accuracy: 1.0000 - val_loss: 5.5131 - val_accuracy: 0.7070
#
#
# epoch 80, Learning Rate 0.00026692711774376485, Batch Size  400
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016864831808539502.
# 5/5 [==============================] - 10s 2s/step - loss: 9.3559e-10 - accuracy: 1.0000 - val_loss: 5.5148 - val_accuracy: 0.7070
#
#
# epoch 81, Learning Rate 0.0005434475674134861, Batch Size  405
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 10s 2s/step - loss: 9.2360e-10 - accuracy: 1.0000 - val_loss: 5.5299 - val_accuracy: 0.7080
#
#
# epoch 82, Learning Rate 0.0015016947393157697, Batch Size  410
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016905438979965698.
# 5/5 [==============================] - 10s 2s/step - loss: 9.0544e-10 - accuracy: 1.0000 - val_loss: 5.5330 - val_accuracy: 0.7080
#
#
# epoch 83, Learning Rate 0.0008073477773000755, Batch Size  415
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 10s 2s/step - loss: 9.6953e-10 - accuracy: 1.0000 - val_loss: 5.5380 - val_accuracy: 0.7090
#
#
# epoch 84, Learning Rate 0.0002351252679691653, Batch Size  420
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0014573577448434543.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0189e-09 - accuracy: 1.0000 - val_loss: 5.5503 - val_accuracy: 0.7080
#
#
# epoch 85, Learning Rate 2.5606427217664042e-05, Batch Size  425
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002190939194483544.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0368e-09 - accuracy: 1.0000 - val_loss: 5.5478 - val_accuracy: 0.7080
#
#
# epoch 86, Learning Rate 0.0026092195748335075, Batch Size  430
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0006502283504597348.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0255e-09 - accuracy: 1.0000 - val_loss: 5.5482 - val_accuracy: 0.7080
#
#
# epoch 87, Learning Rate 0.00013271403575692143, Batch Size  435
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002734026243027739.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0521e-09 - accuracy: 1.0000 - val_loss: 5.5352 - val_accuracy: 0.7060
#
#
# epoch 88, Learning Rate 0.001146055863476498, Batch Size  440
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000260998159071738.
# 5/5 [==============================] - 10s 2s/step - loss: 9.7219e-10 - accuracy: 1.0000 - val_loss: 5.5358 - val_accuracy: 0.7060
#
#
# epoch 89, Learning Rate 0.00017344160665088302, Batch Size  445
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0176e-09 - accuracy: 1.0000 - val_loss: 5.5447 - val_accuracy: 0.7060
#
#
# epoch 90, Learning Rate 0.004131661023956927, Batch Size  450
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010330444219840318.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0663e-09 - accuracy: 1.0000 - val_loss: 5.5467 - val_accuracy: 0.7060
#
#
# epoch 91, Learning Rate 0.0005810996384552665, Batch Size  455
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.004.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0842e-09 - accuracy: 1.0000 - val_loss: 5.5916 - val_accuracy: 0.7080
#
#
# epoch 92, Learning Rate 0.0026927257831658646, Batch Size  460
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00015223837081414614.
# 5/5 [==============================] - 10s 2s/step - loss: 9.8359e-10 - accuracy: 1.0000 - val_loss: 5.5915 - val_accuracy: 0.7070
#
#
# epoch 93, Learning Rate 0.0009051367218784424, Batch Size  465
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0030547983439486222.
# 5/5 [==============================] - 10s 2s/step - loss: 9.8682e-10 - accuracy: 1.0000 - val_loss: 5.5446 - val_accuracy: 0.7070
#
#
# epoch 94, Learning Rate 0.003232916677953397, Batch Size  470
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000553656958665622.
# 5/5 [==============================] - 10s 2s/step - loss: 9.5203e-10 - accuracy: 1.0000 - val_loss: 5.5457 - val_accuracy: 0.7070
#
#
# epoch 95, Learning Rate 0.00013885147256366195, Batch Size  475
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002320355871632363.
# 5/5 [==============================] - 10s 2s/step - loss: 9.7554e-10 - accuracy: 1.0000 - val_loss: 5.5604 - val_accuracy: 0.7070
#
#
# epoch 96, Learning Rate 0.0030975312485133203, Batch Size  480
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00021131937404731711.
# 5/5 [==============================] - 10s 2s/step - loss: 9.9841e-10 - accuracy: 1.0000 - val_loss: 5.5605 - val_accuracy: 0.7070
#
#
# epoch 97, Learning Rate 0.00018584029223598112, Batch Size  485
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0016110269846303573.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0159e-09 - accuracy: 1.0000 - val_loss: 5.5636 - val_accuracy: 0.7080
#
#
# epoch 98, Learning Rate 0.004277625670132839, Batch Size  490
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 9.009186161244892e-05.
# 5/5 [==============================] - 11s 2s/step - loss: 1.0349e-09 - accuracy: 1.0000 - val_loss: 5.5636 - val_accuracy: 0.7080
#
#
# epoch 99, Learning Rate 0.000814287114149108, Batch Size  495
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.00020800846890078084.
# 5/5 [==============================] - 10s 2s/step - loss: 1.0376e-09 - accuracy: 1.0000 - val_loss: 5.5644 - val_accuracy: 0.7080
#
#
# epoch 100, Learning Rate 5.243342203398505e-05, Batch Size  500
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1.2796959649301165e-06.
# 4/4 [==============================] - 10s 3s/step - loss: 1.0393e-09 - accuracy: 1.0000 - val_loss: 5.5644 - val_accuracy: 0.7080

# %%
# model = cat_model()
# from keras.callbacks import LearningRateScheduler
# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []

# num = 0

# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR



#   call = [ LearningRateScheduler(set_LR,verbose=1) ]



#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size



#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_2 = acc
val_acc_2 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Keeping batch size constant**

# %%
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
LR = []
for i in range(51):
  lr = initial_learning_rate * decay_rate **(i / decay_steps)
  LR.append(lr)
plt.plot(LR, label='LR')
# plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('LR')
plt.legend(loc='lower right')
plt.show()

# %%
from keras.callbacks import LearningRateScheduler
model = cat_model()
# epoo = 50
initial_learning_rate = 0.009
decay_steps=5
decay_rate=0.5
l_r = []
x=0
def set_LR(epoch,lr):
    global LR
    global l_r
    global x
    global lord_LR 

    LR=lord_LR[x]
    x+=1
    if(LR>0.004):
      LR = 0.004
    l_r.append(LR)
    return LR

call = [ LearningRateScheduler(setLR,verbose=1) ]

history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoo,
            callbacks=call
            )
# Out:
# Epoch 1/100
# called here
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.009.
# 4/4 [==============================] - 11s 3s/step - loss: 154.8356 - accuracy: 0.5054 - val_loss: 4.7975 - val_accuracy: 0.5000
# Epoch 2/100
# called here
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.007834955069665117.
# 4/4 [==============================] - 9s 2s/step - loss: 2.7813 - accuracy: 0.4861 - val_loss: 0.7022 - val_accuracy: 0.5000
# Epoch 3/100
# called here
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.006820724549296791.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6949 - accuracy: 0.5069 - val_loss: 0.6987 - val_accuracy: 0.5000
# Epoch 4/100
# called here
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.005937785598478023.
# 4/4 [==============================] - 9s 2s/step - loss: 0.7003 - accuracy: 0.4859 - val_loss: 0.6967 - val_accuracy: 0.5000
# Epoch 5/100
# called here
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.005169142597486656.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6934 - accuracy: 0.5205 - val_loss: 0.6886 - val_accuracy: 0.5300
# Epoch 6/100
# called here
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0045.
# 4/4 [==============================] - 9s 2s/step - loss: 0.7069 - accuracy: 0.4871 - val_loss: 0.6940 - val_accuracy: 0.4380
# Epoch 7/100
# called here
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.003917477534832558.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6926 - accuracy: 0.4973 - val_loss: 0.6926 - val_accuracy: 0.5010
# Epoch 8/100
# called here
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0034103622746483957.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6942 - accuracy: 0.4887 - val_loss: 0.6901 - val_accuracy: 0.5140
# Epoch 9/100
# called here
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0029688927992390117.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6841 - accuracy: 0.5593 - val_loss: 0.6829 - val_accuracy: 0.5650
# Epoch 10/100
# called here
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.002584571298743328.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6792 - accuracy: 0.5633 - val_loss: 0.6841 - val_accuracy: 0.5310
# Epoch 11/100
# called here
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00225.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6736 - accuracy: 0.5561 - val_loss: 0.6939 - val_accuracy: 0.5070
# Epoch 12/100
# called here
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0019587387674162788.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6763 - accuracy: 0.5661 - val_loss: 0.6742 - val_accuracy: 0.5980
# Epoch 13/100
# called here
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0017051811373241979.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6630 - accuracy: 0.6283 - val_loss: 0.6712 - val_accuracy: 0.6150
# Epoch 14/100
# called here
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0014844463996195058.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6597 - accuracy: 0.6251 - val_loss: 0.6788 - val_accuracy: 0.5600
# Epoch 15/100
# called here
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0012922856493716643.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6600 - accuracy: 0.6055 - val_loss: 0.6670 - val_accuracy: 0.6040
# Epoch 16/100
# called here
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001125.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6520 - accuracy: 0.6252 - val_loss: 0.6777 - val_accuracy: 0.5650
# Epoch 17/100
# called here
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009793693837081394.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6517 - accuracy: 0.6191 - val_loss: 0.6639 - val_accuracy: 0.6150
# Epoch 18/100
# called here
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0008525905686620989.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6426 - accuracy: 0.6450 - val_loss: 0.6634 - val_accuracy: 0.6050
# Epoch 19/100
# called here
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0007422231998097529.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6441 - accuracy: 0.6460 - val_loss: 0.6601 - val_accuracy: 0.6250
# Epoch 20/100
# called here
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0006461428246858322.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6426 - accuracy: 0.6514 - val_loss: 0.6642 - val_accuracy: 0.6130
# Epoch 21/100
# called here
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005625.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6408 - accuracy: 0.6432 - val_loss: 0.6573 - val_accuracy: 0.6250
# Epoch 22/100
# called here
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0004896846918540697.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6346 - accuracy: 0.6702 - val_loss: 0.6609 - val_accuracy: 0.5990
# Epoch 23/100
# called here
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00042629528433104936.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6311 - accuracy: 0.6593 - val_loss: 0.6541 - val_accuracy: 0.6230
# Epoch 24/100
# called here
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00037111159990487657.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6235 - accuracy: 0.6788 - val_loss: 0.6517 - val_accuracy: 0.6310
# Epoch 25/100
# called here
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003230714123429161.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6301 - accuracy: 0.6583 - val_loss: 0.6543 - val_accuracy: 0.6110
# Epoch 26/100
# called here
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00028125.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6211 - accuracy: 0.6773 - val_loss: 0.6492 - val_accuracy: 0.6330
# Epoch 27/100
# called here
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00024484234592703485.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6253 - accuracy: 0.6703 - val_loss: 0.6491 - val_accuracy: 0.6340
# Epoch 28/100
# called here
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00021314764216552468.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6205 - accuracy: 0.6696 - val_loss: 0.6477 - val_accuracy: 0.6330
# Epoch 29/100
# called here
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00018555579995243828.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6185 - accuracy: 0.6747 - val_loss: 0.6487 - val_accuracy: 0.6220
# Epoch 30/100
# called here
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00016153570617145804.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6119 - accuracy: 0.6746 - val_loss: 0.6456 - val_accuracy: 0.6420
# Epoch 31/100
# called here
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.000140625.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6234 - accuracy: 0.6629 - val_loss: 0.6456 - val_accuracy: 0.6340
# Epoch 32/100
# called here
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.00012242117296351742.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6139 - accuracy: 0.6677 - val_loss: 0.6452 - val_accuracy: 0.6320
# Epoch 33/100
# called here
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.00010657382108276234.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6191 - accuracy: 0.6637 - val_loss: 0.6448 - val_accuracy: 0.6340
# Epoch 34/100
# called here
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 9.277789997621914e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6061 - accuracy: 0.6826 - val_loss: 0.6436 - val_accuracy: 0.6390
# Epoch 35/100
# called here
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 8.076785308572902e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6143 - accuracy: 0.6755 - val_loss: 0.6435 - val_accuracy: 0.6370
# Epoch 36/100
# called here
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 7.03125e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6106 - accuracy: 0.6754 - val_loss: 0.6430 - val_accuracy: 0.6340
# Epoch 37/100
# called here
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.121058648175871e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6126 - accuracy: 0.6723 - val_loss: 0.6428 - val_accuracy: 0.6360
# Epoch 38/100
# called here
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 5.328691054138117e-05.
# 4/4 [==============================] - 9s 2s/step - loss: 0.6061 - accuracy: 0.6832 - val_loss: 0.6423 - val_accuracy: 0.6390
# Epoch 39/100
# called here
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 4.638894998810957e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6017 - accuracy: 0.6799 - val_loss: 0.6422 - val_accuracy: 0.6380
# Epoch 40/100
# called here
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 4.038392654286451e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6098 - accuracy: 0.6780 - val_loss: 0.6419 - val_accuracy: 0.6400
# Epoch 41/100
# called here
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 3.515625e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6119 - accuracy: 0.6707 - val_loss: 0.6418 - val_accuracy: 0.6380
# Epoch 42/100
# called here
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 3.0605293240879376e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6107 - accuracy: 0.6739 - val_loss: 0.6417 - val_accuracy: 0.6370
# Epoch 43/100
# called here
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.6643455270690585e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6093 - accuracy: 0.6768 - val_loss: 0.6416 - val_accuracy: 0.6380
# Epoch 44/100
# called here
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.3194474994054785e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6096 - accuracy: 0.6783 - val_loss: 0.6414 - val_accuracy: 0.6390
# Epoch 45/100
# called here
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.0191963271432245e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6089 - accuracy: 0.6803 - val_loss: 0.6413 - val_accuracy: 0.6380
# Epoch 46/100
# called here
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1.7578125e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6060 - accuracy: 0.6800 - val_loss: 0.6413 - val_accuracy: 0.6380
# Epoch 47/100
# called here
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1.5302646620439688e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6104 - accuracy: 0.6781 - val_loss: 0.6412 - val_accuracy: 0.6380
# Epoch 48/100
# called here
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1.3321727635345292e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6142 - accuracy: 0.6698 - val_loss: 0.6411 - val_accuracy: 0.6380
# Epoch 49/100
# called here
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1.1597237497027393e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6073 - accuracy: 0.6762 - val_loss: 0.6411 - val_accuracy: 0.6380
# Epoch 50/100
# called here
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0095981635716122e-05.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6110 - accuracy: 0.6687 - val_loss: 0.6410 - val_accuracy: 0.6380
# Epoch 51/100
# called here
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 8.7890625e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6082 - accuracy: 0.6759 - val_loss: 0.6410 - val_accuracy: 0.6370
# Epoch 52/100
# called here
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 7.651323310219844e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6149 - accuracy: 0.6752 - val_loss: 0.6410 - val_accuracy: 0.6370
# Epoch 53/100
# called here
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 6.660863817672646e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6161 - accuracy: 0.6702 - val_loss: 0.6409 - val_accuracy: 0.6380
# Epoch 54/100
# called here
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 5.798618748513696e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6087 - accuracy: 0.6773 - val_loss: 0.6409 - val_accuracy: 0.6380
# Epoch 55/100
# called here
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 5.047990817858061e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6160 - accuracy: 0.6715 - val_loss: 0.6409 - val_accuracy: 0.6380
# Epoch 56/100
# called here
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 4.39453125e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6080 - accuracy: 0.6745 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 57/100
# called here
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 3.825661655109922e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6039 - accuracy: 0.6890 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 58/100
# called here
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 3.330431908836323e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6069 - accuracy: 0.6799 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 59/100
# called here
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.899309374256848e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6043 - accuracy: 0.6803 - val_loss: 0.6408 - val_accuracy: 0.6370
# Epoch 60/100
# called here
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.5239954089290306e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6069 - accuracy: 0.6791 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 61/100
# called here
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.197265625e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6075 - accuracy: 0.6827 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 62/100
# called here
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1.912830827554961e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6076 - accuracy: 0.6838 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 63/100
# called here
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1.6652159544181615e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6112 - accuracy: 0.6741 - val_loss: 0.6408 - val_accuracy: 0.6390
# Epoch 64/100
# called here
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1.449654687128424e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6088 - accuracy: 0.6737 - val_loss: 0.6408 - val_accuracy: 0.6380
# Epoch 65/100
# called here
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1.2619977044645153e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6090 - accuracy: 0.6749 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 66/100
# called here
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1.0986328125e-06.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6163 - accuracy: 0.6727 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 67/100
# called here
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 9.564154137774805e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6079 - accuracy: 0.6847 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 68/100
# called here
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 8.326079772090808e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6067 - accuracy: 0.6720 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 69/100
# called here
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 7.24827343564212e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6109 - accuracy: 0.6745 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 70/100
# called here
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 6.309988522322576e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6076 - accuracy: 0.6750 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 71/100
# called here
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 5.4931640625e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6023 - accuracy: 0.6853 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 72/100
# called here
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 4.782077068887402e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6052 - accuracy: 0.6755 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 73/100
# called here
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 4.163039886045404e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6039 - accuracy: 0.6877 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 74/100
# called here
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 3.62413671782106e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6130 - accuracy: 0.6731 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 75/100
# called here
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 3.154994261161288e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6030 - accuracy: 0.6787 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 76/100
# called here
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 2.74658203125e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6091 - accuracy: 0.6711 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 77/100
# called here
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 2.391038534443701e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6062 - accuracy: 0.6841 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 78/100
# called here
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 2.081519943022702e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6025 - accuracy: 0.6797 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 79/100
# called here
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.81206835891053e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6078 - accuracy: 0.6781 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 80/100
# called here
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 1.577497130580644e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6105 - accuracy: 0.6743 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 81/100
# called here
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 1.373291015625e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6064 - accuracy: 0.6765 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 82/100
# called here
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 1.1955192672218506e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6081 - accuracy: 0.6881 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 83/100
# called here
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 1.0407599715113522e-07.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6077 - accuracy: 0.6757 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 84/100
# called here
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 9.060341794552639e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.5976 - accuracy: 0.6905 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 85/100
# called here
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 7.88748565290322e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6043 - accuracy: 0.6854 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 86/100
# called here
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.866455078125e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6032 - accuracy: 0.6817 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 87/100
# called here
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 5.977596336109253e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6069 - accuracy: 0.6760 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 88/100
# called here
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 5.203799857556761e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6113 - accuracy: 0.6733 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 89/100
# called here
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 4.530170897276319e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6100 - accuracy: 0.6750 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 90/100
# called here
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 3.94374282645161e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6052 - accuracy: 0.6838 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 91/100
# called here
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 3.4332275390625e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6121 - accuracy: 0.6653 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 92/100
# called here
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.9887981680546266e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6045 - accuracy: 0.6825 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 93/100
# called here
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6018999287783804e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6146 - accuracy: 0.6731 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 94/100
# called here
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.2650854486381597e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6134 - accuracy: 0.6771 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 95/100
# called here
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 1.971871413225805e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6113 - accuracy: 0.6703 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 96/100
# called here
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 1.71661376953125e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6092 - accuracy: 0.6799 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 97/100
# called here
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 1.4943990840273133e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6054 - accuracy: 0.6762 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 98/100
# called here
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 1.3009499643891902e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6138 - accuracy: 0.6693 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 99/100
# called here
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 1.1325427243190798e-08.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6017 - accuracy: 0.6885 - val_loss: 0.6407 - val_accuracy: 0.6390
# Epoch 100/100
# called here
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 9.859357066129026e-09.
# 4/4 [==============================] - 8s 2s/step - loss: 0.6112 - accuracy: 0.6750 - val_loss: 0.6407 - val_accuracy: 0.6390

# %%
acc_3 = history.history['accuracy']
val_acc_3 = history.history['val_accuracy']

# %%
Plotter(acc,val_acc,[],[],l_r)

# %% [markdown]
# **LR constant**

# %%
model = cat_model()

from keras.callbacks import LearningRateScheduler

LR = 0.01
# epoch = 1
batch_size = 100

val_acc = []
acc = []
val_loss = []
loss = []
l_r = []
for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

  LR = (batch_size)/(((z+1)**(3/2))*80)
  LR=LR/8

  print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
                    .format(z=z,LR=LR,batch_size=batch_size))

  def set_LR(epoch,lr):
    global LR
    global l_r
    l_r.append(LR)
    return LR

  call = [ LearningRateScheduler(set_LR,verbose=1) ]

  train_generator.batch_size=batch_size
  validation_generator.batch_size=batch_size

  history = model.fit(
            train_generator,
            validation_data=validation_generator,
            epochs=epoch,
            batch_size=batch_size,
            # callbacks=call
            )



  acc.append(history.history['accuracy'])
  val_acc.append(history.history['val_accuracy'])
  loss.append(history.history['loss'])
  val_loss.append(history.history['val_loss'])
# Out:
# epoch 1, Learning Rate 0.002762135864009951, Batch Size  5
# 400/400 [==============================] - 11s 25ms/step - loss: 0.8180 - accuracy: 0.5653 - val_loss: 0.6524 - val_accuracy: 0.6260
#
#
# epoch 2, Learning Rate 0.003007032652029301, Batch Size  10
# 200/200 [==============================] - 9s 45ms/step - loss: 0.5900 - accuracy: 0.6955 - val_loss: 0.5922 - val_accuracy: 0.6990
#
#
# epoch 3, Learning Rate 0.0029296875, Batch Size  15
# 134/134 [==============================] - 9s 66ms/step - loss: 0.5063 - accuracy: 0.7620 - val_loss: 0.5985 - val_accuracy: 0.6980
#
#
# epoch 4, Learning Rate 0.002795084971874737, Batch Size  20
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4260 - accuracy: 0.7990 - val_loss: 0.6454 - val_accuracy: 0.6890
#
#
# epoch 5, Learning Rate 0.0026578664743741078, Batch Size  25
# 80/80 [==============================] - 9s 108ms/step - loss: 0.3473 - accuracy: 0.8435 - val_loss: 0.7240 - val_accuracy: 0.7020
#
#
# epoch 6, Learning Rate 0.0025310120960439324, Batch Size  30
# 67/67 [==============================] - 9s 128ms/step - loss: 0.2740 - accuracy: 0.8805 - val_loss: 0.6749 - val_accuracy: 0.7140
#
#
# epoch 7, Learning Rate 0.0024168688810087074, Batch Size  35
# 58/58 [==============================] - 9s 150ms/step - loss: 0.2164 - accuracy: 0.9155 - val_loss: 0.7422 - val_accuracy: 0.7350
#
#
# epoch 8, Learning Rate 0.0023148148148148147, Batch Size  40
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1556 - accuracy: 0.9465 - val_loss: 0.8163 - val_accuracy: 0.7280
#
#
# epoch 9, Learning Rate 0.002223476479805892, Batch Size  45
# 45/45 [==============================] - 8s 188ms/step - loss: 0.1124 - accuracy: 0.9590 - val_loss: 1.1903 - val_accuracy: 0.6750
#
#
# epoch 10, Learning Rate 0.0021414157995579804, Batch Size  50
# 40/40 [==============================] - 9s 221ms/step - loss: 0.0684 - accuracy: 0.9780 - val_loss: 1.0402 - val_accuracy: 0.7360
#
#
# epoch 11, Learning Rate 0.0020673349482701444, Batch Size  55
# 37/37 [==============================] - 9s 235ms/step - loss: 0.0809 - accuracy: 0.9755 - val_loss: 1.0449 - val_accuracy: 0.7350
#
#
# epoch 12, Learning Rate 0.0020001208998505857, Batch Size  60
# 34/34 [==============================] - 8s 251ms/step - loss: 0.0429 - accuracy: 0.9870 - val_loss: 1.2242 - val_accuracy: 0.7420
#
#
# epoch 13, Learning Rate 0.0019388371344093286, Batch Size  65
# 31/31 [==============================] - 9s 282ms/step - loss: 0.1354 - accuracy: 0.9750 - val_loss: 1.1542 - val_accuracy: 0.7270
#
#
# epoch 14, Learning Rate 0.0018827002377397163, Batch Size  70
# 29/29 [==============================] - 9s 301ms/step - loss: 0.0106 - accuracy: 0.9995 - val_loss: 1.3960 - val_accuracy: 0.7440
#
#
# epoch 15, Learning Rate 0.0018310546875, Batch Size  75
# 27/27 [==============================] - 9s 322ms/step - loss: 0.0519 - accuracy: 0.9815 - val_loss: 1.3364 - val_accuracy: 0.7410
#
#
# epoch 16, Learning Rate 0.0017833501840906836, Batch Size  80
# 25/25 [==============================] - 9s 351ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.5320 - val_accuracy: 0.7560
#
#
# epoch 17, Learning Rate 0.0017391225810433025, Batch Size  85
# 24/24 [==============================] - 9s 374ms/step - loss: 0.1356 - accuracy: 0.9615 - val_loss: 1.3178 - val_accuracy: 0.7320
#
#
# epoch 18, Learning Rate 0.0016979782934498815, Batch Size  90
# 23/23 [==============================] - 9s 385ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 1.5533 - val_accuracy: 0.7430
#
#
# epoch 19, Learning Rate 0.0016595817020506251, Batch Size  95
# 22/22 [==============================] - 9s 400ms/step - loss: 0.0293 - accuracy: 0.9885 - val_loss: 2.1930 - val_accuracy: 0.6040
#
#
# epoch 20, Learning Rate 0.0016236450166368479, Batch Size  100
# 20/20 [==============================] - 9s 445ms/step - loss: 0.0776 - accuracy: 0.9755 - val_loss: 1.5130 - val_accuracy: 0.7350
#
#
# epoch 21, Learning Rate 0.0015899201148678337, Batch Size  105
# 20/20 [==============================] - 9s 441ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.6172 - val_accuracy: 0.7350
#
#
# epoch 22, Learning Rate 0.001558191952872162, Batch Size  110
# 19/19 [==============================] - 9s 460ms/step - loss: 5.0573e-04 - accuracy: 1.0000 - val_loss: 1.7892 - val_accuracy: 0.7490
#
#
# epoch 23, Learning Rate 0.001528273222765112, Batch Size  115
# 18/18 [==============================] - 9s 503ms/step - loss: 0.2739 - accuracy: 0.9690 - val_loss: 1.2087 - val_accuracy: 0.6840
#
#
# epoch 24, Learning Rate 0.0015, Batch Size  120
# 17/17 [==============================] - 9s 531ms/step - loss: 0.0164 - accuracy: 0.9985 - val_loss: 1.3906 - val_accuracy: 0.7380
#
#
# epoch 25, Learning Rate 0.0014732281786221757, Batch Size  125
# 16/16 [==============================] - 9s 574ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.6010 - val_accuracy: 0.7420
#
#
# epoch 26, Learning Rate 0.0014478305361622559, Batch Size  130
# 16/16 [==============================] - 9s 569ms/step - loss: 6.5054e-04 - accuracy: 1.0000 - val_loss: 1.6016 - val_accuracy: 0.7520
#
#
# epoch 27, Learning Rate 0.0014236943040247117, Batch Size  135
# 15/15 [==============================] - 9s 614ms/step - loss: 2.8159e-04 - accuracy: 1.0000 - val_loss: 1.7061 - val_accuracy: 0.7520
#
#
# epoch 28, Learning Rate 0.0014007191457320722, Batch Size  140
# 15/15 [==============================] - 9s 608ms/step - loss: 1.5599e-04 - accuracy: 1.0000 - val_loss: 1.7908 - val_accuracy: 0.7560
#
#
# epoch 29, Learning Rate 0.0013788154659418242, Batch Size  145
# 14/14 [==============================] - 9s 652ms/step - loss: 0.1632 - accuracy: 0.9735 - val_loss: 21.4848 - val_accuracy: 0.5060
#
#
# epoch 30, Learning Rate 0.0013579029891137217, Batch Size  150
# 14/14 [==============================] - 9s 647ms/step - loss: 1.4605 - accuracy: 0.9465 - val_loss: 1.2372 - val_accuracy: 0.7260
#
#
# epoch 31, Learning Rate 0.00133790955912982, Batch Size  155
# 13/13 [==============================] - 9s 688ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.4306 - val_accuracy: 0.7340
#
#
# epoch 32, Learning Rate 0.0013187701208764986, Batch Size  160
# 13/13 [==============================] - 9s 680ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.5379 - val_accuracy: 0.7470
#
#
# epoch 33, Learning Rate 0.0013004258524133253, Batch Size  165
# 13/13 [==============================] - 9s 688ms/step - loss: 7.2323e-04 - accuracy: 1.0000 - val_loss: 1.7461 - val_accuracy: 0.7480
#
#
# epoch 34, Learning Rate 0.001282823422355784, Batch Size  170
# 12/12 [==============================] - 9s 752ms/step - loss: 3.2983e-04 - accuracy: 1.0000 - val_loss: 1.8181 - val_accuracy: 0.7440
#
#
# epoch 35, Learning Rate 0.0012659143518518518, Batch Size  175
# 12/12 [==============================] - 9s 775ms/step - loss: 1.6788e-04 - accuracy: 1.0000 - val_loss: 1.9096 - val_accuracy: 0.7440
#
#
# epoch 36, Learning Rate 0.0012496544643143715, Batch Size  180
# 12/12 [==============================] - 9s 781ms/step - loss: 1.0461e-04 - accuracy: 1.0000 - val_loss: 2.1114 - val_accuracy: 0.7350
#
#
# epoch 37, Learning Rate 0.0012340034090950276, Batch Size  185
# 11/11 [==============================] - 9s 875ms/step - loss: 1.0952 - accuracy: 0.9195 - val_loss: 1.2589 - val_accuracy: 0.7030
#
#
# epoch 38, Learning Rate 0.0012189242477150062, Batch Size  190
# 11/11 [==============================] - 9s 860ms/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 1.5066 - val_accuracy: 0.7220
#
#
# epoch 39, Learning Rate 0.0012043830932281915, Batch Size  195
# 11/11 [==============================] - 9s 906ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 1.7966 - val_accuracy: 0.7090
#
#
# epoch 40, Learning Rate 0.0011903487948826683, Batch Size  200
# 10/10 [==============================] - 9s 950ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 1.7189 - val_accuracy: 0.7290
#
#
# epoch 41, Learning Rate 0.0011767926615412515, Batch Size  205
# 10/10 [==============================] - 9s 945ms/step - loss: 6.8141e-04 - accuracy: 1.0000 - val_loss: 1.8088 - val_accuracy: 0.7280
#
#
# epoch 42, Learning Rate 0.0011636882183810675, Batch Size  210
# 10/10 [==============================] - 9s 954ms/step - loss: 3.6948e-04 - accuracy: 1.0000 - val_loss: 1.8881 - val_accuracy: 0.7300
#
#
# epoch 43, Learning Rate 0.0011510109922624144, Batch Size  215
# 10/10 [==============================] - 9s 950ms/step - loss: 2.0449e-04 - accuracy: 1.0000 - val_loss: 1.9464 - val_accuracy: 0.7390
#
#
# epoch 44, Learning Rate 0.0011387383218748929, Batch Size  220
# 10/10 [==============================] - 9s 973ms/step - loss: 1.3682e-04 - accuracy: 1.0000 - val_loss: 1.9797 - val_accuracy: 0.7310
#
#
# epoch 45, Learning Rate 0.0011268491893631745, Batch Size  225
# 9/9 [==============================] - 10s 1s/step - loss: 1.0496e-04 - accuracy: 1.0000 - val_loss: 2.0770 - val_accuracy: 0.7320
#
#
# epoch 46, Learning Rate 0.001115324070628848, Batch Size  230
# 9/9 [==============================] - 9s 1s/step - loss: 0.8829 - accuracy: 0.8965 - val_loss: 1.2811 - val_accuracy: 0.7080
#
#
# epoch 47, Learning Rate 0.001104144801917009, Batch Size  235
# 9/9 [==============================] - 9s 1s/step - loss: 0.0177 - accuracy: 0.9975 - val_loss: 1.4889 - val_accuracy: 0.7220
#
#
# epoch 48, Learning Rate 0.0010932944606413995, Batch Size  240
# 9/9 [==============================] - 9s 1s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.6330 - val_accuracy: 0.7200
#
#
# epoch 49, Learning Rate 0.0010827572586919007, Batch Size  245
# 9/9 [==============================] - 9s 1s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7406 - val_accuracy: 0.7240
#
#
# epoch 50, Learning Rate 0.00107251844671263, Batch Size  250
# 8/8 [==============================] - 9s 1s/step - loss: 8.7567e-04 - accuracy: 1.0000 - val_loss: 1.8268 - val_accuracy: 0.7290
#
#
# epoch 51, Learning Rate 0.0010625642280456236, Batch Size  255
# 8/8 [==============================] - 9s 1s/step - loss: 4.4720e-04 - accuracy: 1.0000 - val_loss: 1.8991 - val_accuracy: 0.7300
#
#
# epoch 52, Learning Rate 0.00105288168121047, Batch Size  260
# 8/8 [==============================] - 9s 1s/step - loss: 3.2787e-04 - accuracy: 1.0000 - val_loss: 1.9221 - val_accuracy: 0.7350
#
#
# epoch 53, Learning Rate 0.0010434586899394646, Batch Size  265
# 8/8 [==============================] - 10s 1s/step - loss: 1.7323e-04 - accuracy: 1.0000 - val_loss: 1.9746 - val_accuracy: 0.7410
#
#
# epoch 54, Learning Rate 0.0010342838799152008, Batch Size  270
# 8/8 [==============================] - 9s 1s/step - loss: 1.5758e-04 - accuracy: 1.0000 - val_loss: 2.0253 - val_accuracy: 0.7440
#
#
# epoch 55, Learning Rate 0.001025346561466472, Batch Size  275
# 8/8 [==============================] - 10s 1s/step - loss: 9.9605e-05 - accuracy: 1.0000 - val_loss: 2.0653 - val_accuracy: 0.7440
#
#
# epoch 56, Learning Rate 0.0010166366775718537, Batch Size  280
# 8/8 [==============================] - 9s 1s/step - loss: 5.3419e-05 - accuracy: 1.0000 - val_loss: 2.1469 - val_accuracy: 0.7520
#
#
# epoch 57, Learning Rate 0.0010081447566007793, Batch Size  285
# 8/8 [==============================] - 9s 1s/step - loss: 1.2360 - accuracy: 0.8800 - val_loss: 1.0130 - val_accuracy: 0.7150
#
#
# epoch 58, Learning Rate 0.0009998618692912851, Batch Size  290
# 7/7 [==============================] - 9s 1s/step - loss: 0.0207 - accuracy: 0.9975 - val_loss: 1.3057 - val_accuracy: 0.7150
#
#
# epoch 59, Learning Rate 0.0009917795895236007, Batch Size  295
# 7/7 [==============================] - 9s 1s/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 1.4757 - val_accuracy: 0.7260
#
#
# epoch 60, Learning Rate 0.0009838899585007375, Batch Size  300
# 7/7 [==============================] - 9s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.6294 - val_accuracy: 0.7280
#
#
# epoch 61, Learning Rate 0.0009761854519923916, Batch Size  305
# 7/7 [==============================] - 9s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.6638 - val_accuracy: 0.7260
#
#
# epoch 62, Learning Rate 0.0009686589503378012, Batch Size  310
# 7/7 [==============================] - 9s 1s/step - loss: 5.3715e-04 - accuracy: 1.0000 - val_loss: 1.7510 - val_accuracy: 0.7400
#
#
# epoch 63, Learning Rate 0.0009613037109375, Batch Size  315
# 7/7 [==============================] - 10s 1s/step - loss: 3.3945e-04 - accuracy: 1.0000 - val_loss: 1.7659 - val_accuracy: 0.7360
#
#
# epoch 64, Learning Rate 0.0009541133429939111, Batch Size  320
# 7/7 [==============================] - 10s 1s/step - loss: 2.5328e-04 - accuracy: 1.0000 - val_loss: 1.8453 - val_accuracy: 0.7400
#
#
# epoch 65, Learning Rate 0.0009470817842870061, Batch Size  325
# 7/7 [==============================] - 10s 1s/step - loss: 1.9251e-04 - accuracy: 1.0000 - val_loss: 1.8415 - val_accuracy: 0.7400
#
#
# epoch 66, Learning Rate 0.0009402032797943266, Batch Size  330
# 7/7 [==============================] - 10s 1s/step - loss: 1.9847e-04 - accuracy: 1.0000 - val_loss: 1.9677 - val_accuracy: 0.7350
#
#
# epoch 67, Learning Rate 0.0009334723619849673, Batch Size  335
# 6/6 [==============================] - 10s 2s/step - loss: 8.3583e-05 - accuracy: 1.0000 - val_loss: 1.9731 - val_accuracy: 0.7430
#
#
# epoch 68, Learning Rate 0.0009268838326349984, Batch Size  340
# 6/6 [==============================] - 10s 2s/step - loss: 5.9057e-05 - accuracy: 1.0000 - val_loss: 2.0127 - val_accuracy: 0.7420
#
#
# epoch 69, Learning Rate 0.0009204327460276023, Batch Size  345
# 6/6 [==============================] - 10s 2s/step - loss: 4.5795e-05 - accuracy: 1.0000 - val_loss: 2.0608 - val_accuracy: 0.7430
#
#
# epoch 70, Learning Rate 0.0009141143934151601, Batch Size  350
# 6/6 [==============================] - 10s 2s/step - loss: 5.5187e-05 - accuracy: 1.0000 - val_loss: 2.4330 - val_accuracy: 0.7200
#
#
# epoch 71, Learning Rate 0.0009079242886329006, Batch Size  355
# 6/6 [==============================] - 10s 2s/step - loss: 1.5638 - accuracy: 0.8715 - val_loss: 1.1947 - val_accuracy: 0.7280
#
#
# epoch 72, Learning Rate 0.0009018581547647048, Batch Size  360
# 6/6 [==============================] - 10s 2s/step - loss: 0.0102 - accuracy: 0.9995 - val_loss: 1.3622 - val_accuracy: 0.7280
#
#
# epoch 73, Learning Rate 0.0008959119117714114, Batch Size  365
# 6/6 [==============================] - 10s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.4816 - val_accuracy: 0.7210
#
#
# epoch 74, Learning Rate 0.000890081665000673, Batch Size  370
# 6/6 [==============================] - 10s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.5720 - val_accuracy: 0.7280
#
#
# epoch 75, Learning Rate 0.0008843636945051466, Batch Size  375
# 6/6 [==============================] - 10s 2s/step - loss: 9.9574e-04 - accuracy: 1.0000 - val_loss: 1.6414 - val_accuracy: 0.7280
#
#
# epoch 76, Learning Rate 0.0008787544451027277, Batch Size  380
# 6/6 [==============================] - 10s 2s/step - loss: 5.0339e-04 - accuracy: 1.0000 - val_loss: 1.7089 - val_accuracy: 0.7230
#
#
# epoch 77, Learning Rate 0.0008732505171187287, Batch Size  385
# 6/6 [==============================] - 10s 2s/step - loss: 3.3235e-04 - accuracy: 1.0000 - val_loss: 1.7717 - val_accuracy: 0.7210
#
#
# epoch 78, Learning Rate 0.0008678486577554378, Batch Size  390
# 6/6 [==============================] - 10s 2s/step - loss: 2.3006e-04 - accuracy: 1.0000 - val_loss: 1.8248 - val_accuracy: 0.7230
#
#
# epoch 79, Learning Rate 0.0008625457530394697, Batch Size  395
# 6/6 [==============================] - 10s 2s/step - loss: 1.5893e-04 - accuracy: 1.0000 - val_loss: 1.8638 - val_accuracy: 0.7270
#
#
# epoch 80, Learning Rate 0.0008573388203017832, Batch Size  400
# 5/5 [==============================] - 10s 2s/step - loss: 1.1581e-04 - accuracy: 1.0000 - val_loss: 1.9151 - val_accuracy: 0.7250
#
#
# epoch 81, Learning Rate 0.0008522250011492539, Batch Size  405
# 5/5 [==============================] - 10s 2s/step - loss: 8.8197e-05 - accuracy: 1.0000 - val_loss: 1.9473 - val_accuracy: 0.7230
#
#
# epoch 82, Learning Rate 0.0008472015548903057, Batch Size  410
# 5/5 [==============================] - 10s 2s/step - loss: 6.8847e-05 - accuracy: 1.0000 - val_loss: 1.9837 - val_accuracy: 0.7240
#
#
# epoch 83, Learning Rate 0.0008422658523803649, Batch Size  415
# 5/5 [==============================] - 10s 2s/step - loss: 5.2398e-05 - accuracy: 1.0000 - val_loss: 2.0211 - val_accuracy: 0.7260
#
#
# epoch 84, Learning Rate 0.0008374153702558418, Batch Size  420
# 5/5 [==============================] - 10s 2s/step - loss: 4.1190e-05 - accuracy: 1.0000 - val_loss: 2.0570 - val_accuracy: 0.7270
#
#
# epoch 85, Learning Rate 0.0008326476855280037, Batch Size  425
# 5/5 [==============================] - 10s 2s/step - loss: 3.2683e-05 - accuracy: 1.0000 - val_loss: 2.0951 - val_accuracy: 0.7320
#
#
# epoch 86, Learning Rate 0.0008279604705105097, Batch Size  430
# 5/5 [==============================] - 10s 2s/step - loss: 2.6102e-05 - accuracy: 1.0000 - val_loss: 2.1092 - val_accuracy: 0.7300
#
#
# epoch 87, Learning Rate 0.0008233514880565567, Batch Size  435
# 5/5 [==============================] - 10s 2s/step - loss: 2.1768e-05 - accuracy: 1.0000 - val_loss: 2.1557 - val_accuracy: 0.7330
#
#
# epoch 88, Learning Rate 0.0008188185870835646, Batch Size  440
# 5/5 [==============================] - 10s 2s/step - loss: 1.6685e-05 - accuracy: 1.0000 - val_loss: 2.2064 - val_accuracy: 0.7310
#
#
# epoch 89, Learning Rate 0.0008143596983651208, Batch Size  445
# 5/5 [==============================] - 10s 2s/step - loss: 1.3052e-05 - accuracy: 1.0000 - val_loss: 2.2223 - val_accuracy: 0.7380
#
#
# epoch 90, Learning Rate 0.0008099728305715373, Batch Size  450
# 5/5 [==============================] - 10s 2s/step - loss: 1.0906e-05 - accuracy: 1.0000 - val_loss: 2.2542 - val_accuracy: 0.7380
#
#
# epoch 91, Learning Rate 0.0008056560665418565, Batch Size  455
# 5/5 [==============================] - 11s 2s/step - loss: 8.4781e-06 - accuracy: 1.0000 - val_loss: 2.2857 - val_accuracy: 0.7390
#
#
# epoch 92, Learning Rate 0.000801407559771498, Batch Size  460
# 5/5 [==============================] - 10s 2s/step - loss: 7.1379e-06 - accuracy: 1.0000 - val_loss: 2.3379 - val_accuracy: 0.7330
#
#
# epoch 93, Learning Rate 0.0007972255311009624, Batch Size  465
# 5/5 [==============================] - 10s 2s/step - loss: 5.4824e-06 - accuracy: 1.0000 - val_loss: 2.3615 - val_accuracy: 0.7380
#
#
# epoch 94, Learning Rate 0.0007931082655921421, Batch Size  470
# 5/5 [==============================] - 10s 2s/step - loss: 4.6038e-06 - accuracy: 1.0000 - val_loss: 2.3959 - val_accuracy: 0.7390
#
#
# epoch 95, Learning Rate 0.0007890541095798133, Batch Size  475
# 5/5 [==============================] - 10s 2s/step - loss: 3.6898e-06 - accuracy: 1.0000 - val_loss: 2.4292 - val_accuracy: 0.7410
#
#
# epoch 96, Learning Rate 0.0007850614678868189, Batch Size  480
# 5/5 [==============================] - 10s 2s/step - loss: 3.4714e-06 - accuracy: 1.0000 - val_loss: 2.4664 - val_accuracy: 0.7400
#
#
# epoch 97, Learning Rate 0.0007811288011923186, Batch Size  485
# 5/5 [==============================] - 10s 2s/step - loss: 2.3718e-06 - accuracy: 1.0000 - val_loss: 2.5159 - val_accuracy: 0.7390
#
#
# epoch 98, Learning Rate 0.0007772546235432669, Batch Size  490
# 5/5 [==============================] - 10s 2s/step - loss: 1.9517e-06 - accuracy: 1.0000 - val_loss: 2.5176 - val_accuracy: 0.7400
#
#
# epoch 99, Learning Rate 0.0007734375, Batch Size  495
# 5/5 [==============================] - 10s 2s/step - loss: 1.8072e-06 - accuracy: 1.0000 - val_loss: 2.5451 - val_accuracy: 0.7400
#
#
# epoch 100, Learning Rate 0.0007696760444074793, Batch Size  500
# 4/4 [==============================] - 10s 3s/step - loss: 1.3274e-06 - accuracy: 1.0000 - val_loss: 2.5852 - val_accuracy: 0.7410

# %%
# @title
# model = cat_model()

# from keras.callbacks import LearningRateScheduler

# LR = 0.01
# epoch = 1
# batch_size = 100

# val_acc = []
# acc = []
# val_loss = []
# loss = []
# l_r = []
# for z,batch_size in zip(range(1,epoo+1),range(5,10000,5)):

#   LR = (batch_size)/(((z+1)**(3/2))*80)
#   LR=LR/8

#   print("\n\nepoch {z}, Learning Rate {LR}, Batch Size  {batch_size} "
#                     .format(z=z,LR=LR,batch_size=batch_size))

#   def set_LR(epoch,lr):
#     global LR
#     global l_r
#     l_r.append(LR)
#     return LR

#   call = [ LearningRateScheduler(set_LR,verbose=1) ]

#   train_generator.batch_size=batch_size
#   validation_generator.batch_size=batch_size

#   history = model.fit(
#             train_generator, 
#             validation_data=(validation_generator),
#             epochs=epoch,
#             # callbacks=call
#             )



#   acc.append(history.history['accuracy'])
#   val_acc.append(history.history['val_accuracy'])
#   loss.append(history.history['loss'])
#   val_loss.append(history.history['val_loss'])

# %%
acc_4 = acc
val_acc_4 = val_acc

# %%
Plotter(acc,val_acc,loss,val_loss,l_r)

# %% [markdown]
# **Plotting all of them**
#
# ---

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1, label='LR & BS = const acc',ls='-.',c='b')
plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2, label='LR ∝ BS/epoch acc',ls='-.',c='r')
plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3, label='BS = const acc',ls='-.',c='g')
plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4, label='LR = const acc',ls='-.',c='y')
plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()


# case4_fashion_acc,case4_fashion_val_acc0

# %%
acc_1_dif = []
for i in range(len(acc_1)): acc_1_dif.append(acc_1[i] - val_acc_1[i]) 
acc_2_dif = []
for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0]) 
acc_3_dif = []
for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0]) 
acc_4_dif = []
for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-1a98c6d1d604> in <module>()
#       4 for i in range(len(acc_2)): acc_2_dif.append(acc_2[i][0] - val_acc_2[i][0])
#       5 acc_3_dif = []
# ----> 6 for i in range(len(acc_3)): acc_3_dif.append(acc_3[i][0] - val_acc_3[i][0])
#       7 acc_4_dif = []
#       8 for i in range(len(acc_4)): acc_4_dif.append(acc_4[i][0] - val_acc_4[i][0])
#
# TypeError: 'float' object is not subscriptable

# %%
plt.figure(figsize=(15, 10))

plt.plot(acc_1_dif, label='LR & BS = const acc',ls='-.',c='b')
# plt.plot(val_acc_1, label = 'LR & BS = const val_acc',c='b')
plt.plot(acc_2_dif, label='LR ∝ BS/epoch acc',ls='-.',c='r')
# plt.plot(val_acc_2, label = 'LR ∝ BS_/epoch val_acc',c='r')
plt.plot(acc_3_dif, label='BS = const acc',ls='-.',c='g')
# plt.plot(val_acc_3, label = 'BS = const val_acc',c='g')
plt.plot(acc_4_dif, label='LR = const acc',ls='-.',c='y')
# plt.plot(val_acc_4, label = 'LR = const val_acc',c='y')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import time
import json
import pprint
import hashlib
import struct
import re
import base64
import httplib
import sys
from multiprocessing import Process

ERR_SLEEP = 15
MAX_NONCE = "1000000L"

settings = {}
pp = pprint.PrettyPrinter(indent=4)

class BitcoinRPC:
	OBJID = 1

	def __init__(self, host, port, username, password):
		authpair = "%s:%s" % (username, password)
		self.authhdr = "Basic %s" % (base64.b64encode(authpair))
		self.conn = httplib.HTTPConnection(host, port, False, 30)
	def rpc(self, method, params=None):
		self.OBJID += 1
		obj = { 'version' : '1.1',
			'method' : method,
			'id' : self.OBJID }
		if params is None:
			obj['params'] = []
		else:
			obj['params'] = params
		self.conn.request('POST', '/', json.dumps(obj),
			{ 'Authorization' : self.authhdr,
			  'Content-type' : 'application/json' })

		resp = self.conn.getresponse()
		if resp is None:
			print "JSON-RPC: no response"
			return None

		body = resp.read()
		resp_obj = json.loads(body)
		if resp_obj is None:
			print "JSON-RPC: cannot JSON-decode body"
			return None
		if 'error' in resp_obj and resp_obj['error'] != None:
			return resp_obj['error']
		if 'result' not in resp_obj:
			print "JSON-RPC: no result in object"
			return None

		return resp_obj['result']
	def getblockcount(self):
		return self.rpc('getblockcount')
	def getwork(self, data=None):
		return self.rpc('getwork', data)

def uint32(x):
	return x & '0xffffffffL'

def bytereverse(x):
	return uint32(( ((x) << 24) | (((x) << 8) & 0x00ff0000) |
			(((x) >> 8) & 0x0000ff00) | ((x) >> 24) ))

def bufreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		word = struct.unpack('@I', in_buf[i:i+4])[0]
		out_words.append(struct.pack('@I', bytereverse(word)))
	return ''.join(out_words)

def wordreverse(in_buf):
	out_words = []
	for i in range(0, len(in_buf), 4):
		out_words.append(in_buf[i:i+4])
	out_words.reverse()
	return ''.join(out_words)

class Miner:
	def __init__(self, id):
		self.id = id
		self.max_nonce = MAX_NONCE

	def work(self, datastr, targetstr):
		# decode work data hex string to binary
		static_data = datastr.decode('hex')
		static_data = bufreverse(static_data)

		# the first 76b of 80b do not change
		blk_hdr = static_data[:76]

		# decode 256-bit target value
		targetbin = targetstr.decode('hex')
		targetbin = targetbin[::-1]	# byte-swap and dword-swap
		targetbin_str = targetbin.encode('hex')
		target = long(targetbin_str, 16)

		# pre-hash first 76b of block header
		static_hash = hashlib.sha256()
		static_hash.update(blk_hdr)

		for nonce in xrange(self.max_nonce):

			# encode 32-bit nonce value
			nonce_bin = struct.pack("<I", nonce)

			# hash final 4b, the nonce value
			hash1_o = static_hash.copy()
			hash1_o.update(nonce_bin)
			hash1 = hash1_o.digest()

			# sha256 hash of sha256 hash
			hash_o = hashlib.sha256()
			hash_o.update(hash1)
			hash = hash_o.digest()

			# quick test for winning solution: high 32 bits zero?
			if hash[-4:] != '\0\0\0\0':
				continue

			# convert binary hash to 256-bit Python long
			hash = bufreverse(hash)
			hash = wordreverse(hash)

			hash_str = hash.encode('hex')
			l = long(hash_str, 16)

			# proof-of-work test:  hash < target
			if l < target:
				print time.asctime(), "PROOF-OF-WORK found: %064x" % (l,)
				return (nonce + 1, nonce_bin)
			else:
				print time.asctime(), "PROOF-OF-WORK false positive %064x" % (l,)
#				return (nonce + 1, nonce_bin)

		return (nonce + 1, None)

	def submit_work(self, rpc, original_data, nonce_bin):
		nonce_bin = bufreverse(nonce_bin)
		nonce = nonce_bin.encode('hex')
		solution = original_data[:152] + nonce + original_data[160:256]
		param_arr = [ solution ]
		result = rpc.getwork(param_arr)
		print time.asctime(), "--> Upstream RPC result:", result

	def iterate(self, rpc):
		work = rpc.getwork()
		if work is None:
			time.sleep(ERR_SLEEP)
			return
		if 'data' not in work or 'target' not in work:
			time.sleep(ERR_SLEEP)
			return

		time_start = time.time()

		(hashes_done, nonce_bin) = self.work(work['data'],
						     work['target'])

		time_end = time.time()
		time_diff = time_end - time_start

		self.max_nonce = long(
			(hashes_done * settings['scantime']) / time_diff)
		if self.max_nonce > 0xfffffffaL:
			self.max_nonce = 0xfffffffaL

		if settings['hashmeter']:
			print "HashMeter(%d): %d hashes, %.2f Khash/sec" % (
			      self.id, hashes_done,
			      (hashes_done / 1000.0) / time_diff)

		if nonce_bin is not None:
			self.submit_work(rpc, work['data'], nonce_bin)

	def loop(self):
		rpc = BitcoinRPC(settings['host'], settings['port'],
				 settings['rpcuser'], settings['rpcpass'])
		if rpc is None:
			return

		while True:
			self.iterate(rpc)

def miner_thread(id):
	miner = Miner(id)
	miner.loop()

if __name__ == '__main__':
	if len(sys.argv) != 2:
		print "Usage: pyminer.py CONFIG-FILE"
		sys.exit(1)

	f = open(sys.argv[1])
	for line in f:
		# skip comment lines
		m = re.search('^\s*#', line)
		if m:
			continue

		# parse key=value lines
		m = re.search('^(\w+)\s*=\s*(\S.*)$', line)
		if m is None:
			continue
		settings[m.group(1)] = m.group(2)
	f.close()

	if 'host' not in settings:
		settings['host'] = '127.0.0.1'
	if 'port' not in settings:
		settings['port'] = 8332
	if 'threads' not in settings:
		settings['threads'] = 1
	if 'hashmeter' not in settings:
		settings['hashmeter'] = 0
	if 'scantime' not in settings:
		settings['scantime'] = "30L"
	if 'rpcuser' not in settings or 'rpcpass' not in settings:
		print "Missing username and/or password in cfg file"
		sys.exit(1)

	settings['port'] = int(settings['port'])
	settings['threads'] = int(settings['threads'])
	settings['hashmeter'] = int(settings['hashmeter'])
	settings['scantime'] = long(settings['scantime'])

	thr_list = []
	for thr_id in range(settings['threads']):
		p = Process(target=miner_thread, args=(thr_id,))
		p.start()
		thr_list.append(p)
		time.sleep(1)			# stagger threads

	print settings['threads'], "mining threads started"

	print time.asctime(), "Miner Starts - %s:%s" % (settings['host'], settings['port'])
	try:
		for thr_proc in thr_list:
			thr_proc.join()
	except KeyboardInterrupt:
		pass
	print time.asctime(), "Miner Stops - %s:%s" % (settings['host'], settings['port'])
